# %% [markdown]
# # Building a Chat Bot with Deep NLP

# %% [markdown]
# # Ajay Bhat

# %% [markdown]
# The project has been split into 4 parts:
#
# Part 1 : Data Preprocessing
#
# Part 2 : Building the Seq2Seq model
#
# Part 3 : Training the Seq2Seq model
#
# Part 4 :Testing the Seq2Seq model

# %% [markdown]
# # Importing the libraries

# %% [markdown]
# 1. numpy library to work with arrays
#
# 2. tensorflow for deep learning
#
# 3. regular expression library to clean the text
#
# 4. time library to measure the training time of each epoch

# %%
import numpy as np
import tensorflow as tf
import re
import time

# %% [markdown]
# # PART 1 - DATA PREPROCESSING

# %% [markdown]
# # Importing the dataset

# %% [markdown]
# We are going to give two variable names for the data sets.
#
# The dataset of "lines" as lines and
#
# the dataset of "conversations" as conversations

# %%
lines = open('movie_lines.txt', encoding = 'utf-8', errors = 'ignore').read().split('\n')

# %% [markdown]
# To avoid encoding issue : pass argument encoding = 'utf-8'
#
# To ignore the insignifacant errors , we can do : errors = 'ignore'
#
# .split('\n') is done to split the lines of the dataset with respect to occurence of a new line

# %%
conversations = open('movie_conversations.txt', encoding = 'utf-8', errors = 'ignore').read().split('\n')

# %% [markdown]
# Let's have a look at the lines dataset

# %%
lines
# Out:
# ['L1045 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ They do not!',
#  'L1044 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ They do to!',
#  'L985 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I hope so.',
#  'L984 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ She okay?',
#  "L925 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Let's go.",
#  'L924 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Wow',
#  "L872 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Okay -- you're gonna need to learn how to lie.",
#  'L871 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ No',
#  'L870 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I\'m kidding.  You know how sometimes you just become this "persona"?  And you don\'t know how to quit?',
#  'L869 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Like my fear of wearing pastels?',
#  'L868 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ The "real you".',
#  'L867 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ What good stuff?',
#  "L866 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ I figured you'd get to the good stuff eventually.",
#  'L865 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Thank God!  If I had to hear one more story about your coiffure...',
#  "L864 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Me.  This endless ...blonde babble. I'm like, boring myself.",
#  'L863 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ What crap?',
#  'L862 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ do you listen to this crap?',
#  'L861 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ No...',
#  'L860 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Then Guillermo says, "If you go any lighter, you\'re gonna look like an extra on 90210."',
#  'L699 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ You always been this selfish?',
#  'L698 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ But',
#  "L697 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Then that's all you had to say.",
#  'L696 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Well, no...',
#  "L695 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ You never wanted to go out with 'me, did you?",
#  'L694 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I was?',
#  'L693 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ I looked for you back at the party, but you always seemed to be "occupied".',
#  'L663 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Tons',
#  'L662 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Have fun tonight?',
#  'L578 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ I believe we share an art instructor',
#  'L577 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ You know Chastity?',
#  'L576 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Looks like things worked out tonight, huh?',
#  'L575 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Hi.',
#  "L407 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Who knows?  All I've ever heard her say is that she'd dip before dating a guy that smokes.",
#  "L406 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ So that's the kind of guy she likes? Pretty ones?",
#  "L405 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Lesbian?  No. I found a picture of Jared Leto in one of her drawers, so I'm pretty sure she's not harboring same-sex tendencies.",
#  "L404 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ She's not a...",
#  "L403 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ I'm workin' on it. But she doesn't seem to be goin' for him.",
#  "L402 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I really, really, really wanna go, but I can't.  Not unless my sister goes.",
#  'L401 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Sure have.',
#  "L368 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Eber's Deep Conditioner every two days. And I never, ever use a blowdryer without the diffuser attachment.",
#  'L367 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ How do you get your hair to look like that?',
#  "L366 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ You're sweet.",
#  'L365 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ You have my word.  As a gentleman',
#  "L364 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I counted on you to help my cause. You and that thug are obviously failing. Aren't we ever going on our date?",
#  'L363 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ You got something on your mind?',
#  'L281 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Where?',
#  'L280 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ There.',
#  "L277 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Well, there's someone I think might be --",
#  'L276 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ How is our little Find the Wench A Date plan progressing?',
#  'L275 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Forget French.',
#  "L274 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ That's because it's such a nice one.",
#  "L273 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I don't want to know how to say that though.  I want to know useful things. Like where the good stores are.  How much does champagne cost?  Stuff like Chat.  I have never in my life had to point out my head to someone.",
#  "L272 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Right.  See?  You're ready for the quiz.",
#  "L271 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ C'esc ma tete. This is my head",
#  'L208 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Let me see what I can do.',
#  'L207 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Gosh, if only we could find Kat a boyfriend...',
#  "L206 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ That's a shame.",
#  'L205 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Unsolved mystery.  She used to be really popular when she started high school, then it was just like she got sick of it or something.',
#  'L204 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Why?',
#  'L203 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Seems like she could get a date easy enough...',
#  "L202 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ The thing is, Cameron -- I'm at the mercy of a particularly hideous breed of loser.  My sister.  I can't date until she does.",
#  'L201 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Cameron.',
#  "L200 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ No, no, it's my fault -- we didn't have a proper introduction ---",
#  'L199 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Forget it.',
#  "L198 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ You're asking me out.  That's so cute. What's your name again?",
#  "L197 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Okay... then how 'bout we try out some French cuisine.  Saturday?  Night?",
#  'L196 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Not the hacking and gagging and spitting part.  Please.',
#  "L195 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Well, I thought we'd start with pronunciation, if that's okay with you.",
#  'L194 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Can we make this quick?  Roxanne Korrine and Andrew Barrett are having an incredibly horrendous public break- up on the quad.  Again.',
#  'L953 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I did.',
#  "L952 +++$+++ u3 +++$+++ m0 +++$+++ CHASTITY +++$+++ You think you ' re the only sophomore at the prom?",
#  "L660 +++$+++ u3 +++$+++ m0 +++$+++ CHASTITY +++$+++ I don't have to be home 'til two.",
#  'L659 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I have to be home in twenty minutes.',
#  "L600 +++$+++ u3 +++$+++ m0 +++$+++ CHASTITY +++$+++ All I know is -- I'd give up my private line to go out with a guy like Joey.",
#  "L599 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Sometimes I wonder if the guys we're supposed to want to go out with are the ones we actually want to go out with, you know?",
#  "L598 +++$+++ u3 +++$+++ m0 +++$+++ CHASTITY +++$+++ Bianca, I don't think the highlights of dating Joey Dorsey are going to include door-opening and coat-holding.",
#  "L597 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Combination.  I don't know -- I thought he'd be different.  More of a gentleman...",
#  'L596 +++$+++ u3 +++$+++ m0 +++$+++ CHASTITY +++$+++ Is he oily or dry?',
#  "L595 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ He practically proposed when he found out we had the same dermatologist. I mean. Dr. Bonchowski is great an all, but he's not exactly relevant party conversation.",
#  'L580 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Would you mind getting me a drink, Cameron?',
#  'L579 +++$+++ u3 +++$+++ m0 +++$+++ CHASTITY +++$+++ Great',
#  'L573 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Joey.',
#  'L572 +++$+++ u3 +++$+++ m0 +++$+++ CHASTITY +++$+++ Who?',
#  'L571 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Where did he go?  He was just here.',
#  'L51 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ You might wanna think about it',
#  'L50 +++$+++ u3 +++$+++ m0 +++$+++ CHASTITY +++$+++ No.',
#  'L49 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Did you change your hair?',
#  "L760 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ You know the deal.  I can ' t go if Kat doesn't go --",
#  'L759 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Listen, I want to talk to you about the prom.',
#  "L758 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ You're concentrating awfully hard considering it's gym class.",
#  'L757 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Hi, Joey.',
#  'L756 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Hey, sweet cheeks.',
#  "L593 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ My agent says I've got a good shot at being the Prada guy next year.",
#  'L592 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Neat...',
#  "L591 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ It's a gay cruise line, but I'll be, like, wearing a uniform and stuff.",
#  'L590 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Queen Harry?',
#  'L589 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ So yeah, I\'ve got the Sears catalog thing going -- and the tube sock gig " that\'s gonna be huge.  And then I\'m up for an ad for Queen Harry next week.',
#  'L397 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Hopefully.',
#  "L396 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Exactly  So, you going to Bogey Lowenbrau's thing on Saturday?",
#  'L395 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Expensive?',
#  "L394 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ It's more",
#  'L1052 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Perm?',
#  'L1051 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Patrick -- is that- a.',
#  "L1022 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ It's just you.",
#  'L1021 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Is that woman a complete fruit-loop or is it just me?',
#  'L1011 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ No! I just wanted',
#  'L1010 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ What? To completely damage me?  To send me to therapy forever? What?',
#  'L1009 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I just wanted --',
#  'L1008 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ You set me up.',
#  'L1007 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Let go!',
#  'L983 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ So did you',
#  'L982 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ You looked beautiful last night, you know.',
#  "L914 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I guess I'll never know, will I?",
#  "L913 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Not all experiences are good, Bianca. You can't always trust the people you want to.",
#  "L912 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ God, you're just like him! Just keep me locked away in the dark, so I can't experience anything for myself",
#  'L911 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I guess I thought I was protecting you.',
#  "L910 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I'm not stupid enough to repeat your mistakes.",
#  "L909 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ That's not",
#  "L908 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ No. you didn't!  If you really thought I could make my own decisions, you would've let me go out with him instead of helping Daddy hold me hostage.",
#  'L907 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I wanted to let you make up your own mind about him.',
#  "L906 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Why didn't you tell me?",
#  'L905 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ After that, I swore I\'d never do anything just because "everyone else" was doing it.  And I haven\'t since. Except for Bogey\'s party, and my stunning gastro-intestinal display --',
#  'L904 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ But',
#  "L903 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Just once.  Afterwards, I told him I didn't want to anymore.  I wasn't ready. He got pissed.  Then he broke up with me.",
#  'L902 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ You did what?',
#  'L901 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ He said everyone was doing it.  So I did it.',
#  'L900 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ As in...',
#  'L899 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Now I do.  Back then, was a different story.',
#  'L898 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ But you hate Joey',
#  'L897 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ He was, like, a total babe',
#  'L896 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Why?',
#  'L895 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ In 9th.  For a month',
#  'L894 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ What?',
#  'L893 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Joey never told you we went out, did he?',
#  "L892 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I wish I had that luxury. I'm the only sophomore that got asked to the prom and I can't go, because you won ' t.",
#  "L891 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I do care. But I'm a firm believer in doing something for your own reasons, not someone else ' s .",
#  'L890 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Like you care.',
#  "L889 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Listen, I know you hate having to sit home because I'm not Susie High School.",
#  "L656 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ You're welcome.",
#  "L655 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I don't get you.  You act like you're too good for any of this, and then you go totally apeshit when you get here.",
#  "L602 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I really don't think I need any social advice from you right now.",
#  'L601 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Bianca, I need to talk to you -- I need to tell you --',
#  'L543 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Can we go now?',
#  'L542 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ You are so completely unbalanced.',
#  "L533 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Yeah, he's your freak friend Mandella's boyfriend.  I guess since I'm not allowed to go out, I should obsess over a dead guy, too.",
#  "L532 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ It's Shakespeare.  Maybe you've heard of him?",
#  "L531 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Like I'm supposed to know what that even means.",
#  "L530 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ At least I'm not a clouted fen- sucked hedge-pig.",
#  "L529 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Can't you forget for just one night that you're completely wretched?",
#  "L527 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Bogey Lowenstein's party is normal, but you're too busy listening to Bitches Who Need Prozac to know that.",
#  "L526 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ What's normal?",
#  "L525 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ You're ruining my life'  Because you won't be normal, I can't be normal.",
#  "L445 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I think you're a freak.  I think you do this to torture me.  And I think you suck.",
#  'L444 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ What do you think?',
#  "L443 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Oh, I thought you might have a date  I don't know why I'm bothering to ask, but are you going to Bogey Lowenstein's party Saturday night?",
#  "L442 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ It means that Gigglepuss is playing at Club Skunk and we're going.",
#  "L441 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Oh my God, does this mean you're becoming normal?",
#  'L320 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Can you at least start wearing a bra?',
#  "L319 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I have the potential to smack the crap out of you if you don't get out of my way.",
#  'L165 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Nowhere... Hi, Daddy.',
#  "L164 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Where've you been?",
#  "L923 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I have a date, Daddy.  And he ' s not a captain of oppression like some men we know.",
#  "L922 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ I'm missing something.",
#  "L884 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Fine.  I see that I'm a prisoner in my own house.  I'm not a daughter. I'm a possession!",
#  "L883 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ You're not going unless your sister goes.  End of story.",
#  'L882 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ He\'s not a "hot rod".  Whatever that is.',
#  "L881 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ It's that hot rod Joey, right? That ' s who you want me to bend my rules for?",
#  'L880 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ No, but',
#  'L879 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ The prom?  Kat has a date?',
#  "L878 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Daddy, I want to discuss the prom with you. It's tomorrow night --",
#  "L546 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ Because she'll scare them away.",
#  'L545 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Why?',
#  "L544 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ Promise me you won't talk to any boys unless your sister is present.",
#  'L540 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ Just for a minute',
#  'L539 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Daddy, no!',
#  'L538 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ Wear the belly before you go.',
#  "L537 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ It's just a party. Daddy.",
#  "L536 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ Oh, God.  It's starting.",
#  "L524 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ If Kat's not going, you're not going.",
#  'L523 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Daddy, people expect me to be there!',
#  'L521 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ It\'s just a party. Daddy, but I knew you\'d forbid me to go since "Gloria Steinem" over there isn\'t going --',
#  'L520 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ Otherwise known as an orgy?',
#  'L519 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ If you must know, we were attempting to go to a small study group of friends.',
#  "L518 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ And where're you going?",
#  'L517 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Daddy, I --',
#  'L190 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ Exactly my point',
#  "L189 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ But she doesn't want to date.",
#  "L183 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ But it's not fair -- she's a mutant, Daddy!",
#  "L182 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ Then neither will you.  And I'll get to sleep at night.",
#  'L181 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ What if she never starts dating?',
#  "L180 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ No! You're not dating until your sister starts dating.  End of discussion.",
#  "L179 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Now don't get upset. Daddy, but there's this boy... and I think he might ask...",
#  "L463 +++$+++ u1 +++$+++ m0 +++$+++ BRUCE +++$+++ Just sent 'em through.",
#  'L462 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Padua girls.  One tall, decent body. The other one kinda short and undersexed?',
#  'L461 +++$+++ u1 +++$+++ m0 +++$+++ BRUCE +++$+++ Never',
#  'L460 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Fan of a fan.  You see a couple of minors come in?',
#  "L459 +++$+++ u1 +++$+++ m0 +++$+++ BRUCE +++$+++ Didn't have you pegged for a Gigglepuss fan.  Aren't they a little too pre-teen belly-button ring for you?",
#  'L458 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Always a pleasure, Brucie.',
#  "L779 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Best case scenario, you're back on the payroll for awhile.",
#  'L778 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ You humiliated the woman! Sacrifice yourself on the altar of dignity and even the score.',
#  "L586 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ No, I ' m not.",
#  "L585 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Buttholus extremus.  But hey, you're making progress.",
#  "L584 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ The hell is that?  What kind of 'guy just picks up a girl and carries her away while you're talking to her?",
#  'L583 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Extremely unfortunate maneuver.',
#  "L500 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Hell, I've just been going over the whole thing in my head and -",
#  'L499 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ You told me that part already.',
#  "L433 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ It's her favorite band.",
#  'L432 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Assail your ears for one night.',
#  "L425 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Okay!  I wasn't sure",
#  "L424 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ He's pretty!",
#  'L419 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Dead at forty-one.',
#  'L418 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Her favorite uncle',
#  "L417 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ It's a lung cancer issue",
#  'L416 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Number one.  She hates smokers',
#  "L391 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Are you kidding?  He'll piss himself with joy.  He's the ultimate kiss ass.",
#  'L390 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Will Bogey get bent?',
#  "L389 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ In that case, we'll need to make it a school-wide blow out.",
#  'L388 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ This is it.  A golden opportunity. Patrick can ask Katarina to the party.',
#  "L245 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Like we had a choice?  Besides -- when you let the enemy think he's orchestrating the battle, you're in a position of power. We let him pretend he's calling the shots, and while he's busy setting up the plan, you have time to woo Bianca.",
#  'L244 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ You got him involved?',
#  "L225 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Hey -- I've gotta have a few clients when I get to Wall Street.",
#  'L224 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ I thought you hated those people.',
#  "L223 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ You know, if you do go out with Bianca, you'd be set.  You'd outrank everyone. Strictly A-list.  With me by your side.",
#  "L222 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ That's what I just said",
#  "L221 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Did she actually say she'd go out with you?",
#  "L220 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Forget his reputation.  Do you think we've got a plan or not?",
#  "L219 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ I'm serious, man, he's whacked.  He sold his own liver on the black market so he could buy new speakers.",
#  'L218 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ They always let felons sit in on Honors Biology?',
#  "L217 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ No kidding.  He's a criminal.  I heard he lit a state trooper on fire.  He just got out of Alcatraz...",
#  'L216 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ He seems like he thrives on danger',
#  "L215 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ What makes you think he'll do it?",
#  'L213 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ You wanna go out with him?',
#  'L212 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ What about him?',
#  "L211 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Unlikely, but even so, she still can't go out with you.  So what's the point?",
#  'L210 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ I teach her French, get to know her, dazzle her with charm and she falls in love with me.',
#  'L159 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ The mewling, rampalian wretch herself.',
#  "L158 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ That's her?  Bianca's sister?",
#  'L157 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Yeah, just a minor encounter with the shrew.',
#  'L147 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ You could consecrate with her, my friend.',
#  "L146 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ You mean I'd get a chance to talk to her?",
#  'L145 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Guess who just signed up for a tutor?',
#  "L144 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Sure do ... my Mom's from Canada",
#  'L143 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ You know French?',
#  "L142 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Joey Dorsey?  Perma-shit-grin.  I wish I could say he's a moron, but he's number twelve in the class.  And a model.  Mostly regional stuff, but he's rumored to have a big tube sock ad coming out.",
#  'L141 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ He always have that shit-eating grin?',
#  "L140 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Because they're bred to.  Their mothers liked guys like that, and their grandmothers before them. Their gene pool is rarely diluted.",
#  'L139 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Why do girls like that always like guys like that?',
#  "L92 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ I could start with your haircut, but it doesn't matter.  She's not allowed to date until her older sister does.  And that's an impossibility.",
#  'L91 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Why not?',
#  "L90 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Bianca Stratford.  Sophomore. Don't even think about it",
#  'L89 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Who is she?',
#  'L88 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ You burn, you pine, you perish?',
#  'L87 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ That girl -- I --',
#  'L78 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Yeah, but these guys have never seen a horse.  They just jack off to Clint Eastwood.',
#  "L77 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ That I'm used to.",
#  'L74 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Couple thousand. Most of them evil',
#  'L73 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ How many people go here?',
#  'L72 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Get out!',
#  'L71 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Thirty-two.',
#  'L70 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ How many people were in your old school?',
#  "L69 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Yeah.  A couple.  We're outnumbered by the cows, though.",
#  'L68 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ I was kidding. People actually live there?',
#  "L67 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ North, actually.  How'd you   ?",
#  'L66 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ So -- which Dakota you from?',
#  "L65 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ C'mon.  I'm supposed to give you the tour.",
#  'L64 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ So they tell me...',
#  'L63 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ You the new guy?',
#  'L781 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ You get the girl.',
#  "L780 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ What's the worst?",
#  'L745 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Where?',
#  'L744 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ She kissed me.',
#  "L743 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ You makin' any headway?",
#  "L741 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ She just needs time to cool off I'll give it a day.",
#  "L740 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ She hates you with the fire of a thousand suns .  That's a direct quote",
#  "L726 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ I don ' t know.  I decided not to nail her when she was too drunk to remember it.",
#  "L725 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ What'd you do to her?",
#  'L625 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Then, go get her',
#  'L624 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Sure',
#  'L623 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Cameron -- do you like the girl?',
#  "L622 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ She's partial to Joey, not me",
#  "L621 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ What 're you talking about?",
#  "L620 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ It's off. The whole thing.",
#  "L619 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Cameron, I'm a little busy",
#  "L431 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Don't make me do it, man",
#  'L430 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Gigglepuss is playing there tomorrow night.',
#  "L427 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ So what does that give me?  I'm supposed to buy her some noodles and a book and sit around listening to chicks who can't play their instruments?",
#  'L426 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Okay -- Likes:  Thai food, feminist prose, and "angry, stinky girl music of the indie-rock persuasion".',
#  "L412 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ I've retrieved certain pieces of information on Miss Katarina Stratford I think you'll find helpful.",
#  "L411 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ What've you got for me?",
#  "L386 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Yeah -- we'll see.",
#  'L385 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ And he means that strictly in a non- prison-movie type of way.',
#  'L558 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ And why would I do that?',
#  'L557 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Leave my sister alone.',
#  'L556 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Your sister here?',
#  'L555 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Away.',
#  'L554 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Where ya goin?',
#  'L336 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Not at all',
#  'L335 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Hey -- do you mind?',
#  "L150 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ They're running the rest of me next month.",
#  'L149 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Yeah, and I noticed the only part of you featured in your big Kmart spread was your elbow.  Tough break.',
#  "L148 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ The vintage look is over, Kat. Haven't you been reading your Sassy?",
#  "L748 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Enough with the Barbie n' Ken shit. I know.",
#  "L747 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ I don't know, Dorsey. ..the limo.-the flowers.  Another hundred for the tux --",
#  'L609 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Get her to act like a human',
#  'L608 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Do what?',
#  "L607 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ How'd you do it?",
#  "L606 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ A deal's a deal.",
#  "L605 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ It's about time.",
#  'L358 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Forget her sister, then.',
#  'L357 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Forget it.',
#  'L356 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ A hundred bucks a date.',
#  'L355 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ What?',
#  'L354 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ I just upped my price',
#  'L352 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ I got her under control. She just acts crazed in public to keep up the image.',
#  "L351 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Watching the bitch trash my car doesn't count as a date.",
#  "L350 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ I'm on it",
#  'L349 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ When I shell out fifty, I expect results.',
#  "L301 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Fifty, and you've got your man.",
#  "L300 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Take it or leave it.  This isn't a negotiation.",
#  'L299 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Fine, thirty.',
#  "L298 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ I can't take a girl like that out on twenty bucks.",
#  'L297 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ How much?',
#  "L296 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ I can't date her sister until that one gets a boyfriend.  And that's the catch. She doesn't want a boyfriend.",
#  "L295 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ You're gonna pay me to take out some girl?",
#  'L294 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ You got it, Verona.  I pick up the tab, you do the honors.',
#  "L292 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ But you'd go out with her if you had the cake?",
#  'L291 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ You need money to take a girl out',
#  'L290 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ You just said',
#  "L289 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Sure, Sparky.  I'll get right on it.",
#  'L288 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Yeah, whatever.  I want you to go out with her.',
#  'L287 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Two legs, nice rack...',
#  'L286 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ What do you think?',
#  'L285 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Yeah',
#  "L509 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Hey -- it's all for the higher good right?",
#  "L508 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ You better not fuck this up.  I'm heavily invested.",
#  'L505 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ What?  We took bathes together when we were kids.',
#  'L504 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ You and Verona?',
#  "L503 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Uh,  yeah.  We're old friend*",
#  "L502 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ I hear you're helpin' Verona.",
#  "L240 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ So what you need to do is recruit a guy who'll go out with her.  Someone who's up for the job.",
#  'L239 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Does this conversation have a purpose?',
#  "L238 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ But she can't go out with you because her sister is this insane head case and no one will go out with her. right?",
#  "L236 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ We're not.",
#  "L235 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Well, actually, I thought I'd run an idea by you.  You know, just to see if you're interested.",
#  "L234 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ We don't chat.",
#  'L233 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Nope - just came by to chat',
#  'L232 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Are you lost?',
#  'L231 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Hey.',
#  "L949 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Oh, honey -- tell me we haven't' progressed to full-on hallucinations.",
#  'L948 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ William - he asked me to meet him here.',
#  'L947 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Who?',
#  'L946 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ Have you seen him?',
#  'L755 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ Oh, good.  Something new and different for us.',
#  "L754 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ You ' re looking at this from the wrong perspective.  We're making a statement.",
#  "L753 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ Okay, okay, we won't go.  It's not like I have a dress anyway",
#  'L752 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Listen to you!  You sound like Betty, all pissed off because Archie is taking Veronica.',
#  "L751 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ Well, I guess we're not, since we don't have dates .",
#  'L750 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Can you even imagine?  Who the hell would go to this a bastion of commercial excess?',
#  'L721 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I got drunk.  I puked.  I got rejected. It was big fun.',
#  "L720 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ You didn't",
#  'L719 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I did Bianca a favor and it backfired.',
#  "L718 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ You didn't have a choice?  Where's Kat and what have you done with her?",
#  "L717 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I didn't have a choice.",
#  'L716 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ You went to the party?  I thought we were officially opposed to suburban social activity.',
#  'L491 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Who cares?',
#  "L490 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ What'd he say?",
#  'L448 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ No fear.',
#  "L447 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ You think this'll work?",
#  'L254 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ If I was Bianca, it would be, "Any school you want, precious.  Don\'t forget your tiara."',
#  'L253 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ Does it matter?',
#  "L252 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I appreciate your efforts toward a speedy death, but I'm consuming.  Do you mind?",
#  'L251 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Neither has his heterosexuality.',
#  "L250 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ That's never been proven",
#  "L249 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ William didn't even go to high school",
#  'L248 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ William would never have gone to a state school.',
#  'L247 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ So he has this huge raging fit about Sarah Lawrence and insists that I go to his male-dominated, puking frat boy, number one golf team school. I have no say at all.',
#  "L152 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ You could always go with me.  I'm sure William has some friends.",
#  'L151 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ The people at this school are so incredibly foul.',
#  "L134 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ But imagine the things he'd say during sex.",
#  "L133 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I realize that the men of this fine institution are severely lacking, but killing yourself so you can be with William Shakespeare is beyond the scope of normal teenage obsessions.  You're venturing far past daytime talk show fodder and entering the world of those who need very expensive therapy.",
#  'L132 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ An attempted slit.',
#  "L131 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ What's this?",
#  'L130 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ Just a little.',
#  'L129 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Mandella, eat.  Starving yourself is a very slow way to die.',
#  'L128 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Block E?',
#  'L127 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ He always look so',
#  "L126 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I'm sure he's completely incapable of doing anything that interesting.",
#  "L125 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ That's Pat Verona? The one who was gone for a year? I heard he was doing porn movies.",
#  'L124 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Patrick Verona   Random skid.',
#  "L123 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ Who's that?",
#  "L1043 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Don ' t you even dare. . .",
#  'L1042 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Oh, Bianca?  Can you get me my freshman yearbook?',
#  'L1041 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Because I like to torture you.',
#  'L1040 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Why is my veggie burger the only burnt object on this grill?',
#  'L1035 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Yeah, but then I fucked up. I fell for her.',
#  'L1034 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Is that right?',
#  'L1033 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Besides, I had some extra cash. Some asshole paid me to take out a really great girl.',
#  'L1032 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ I thought you could use it. When you start your band.',
#  'L1031 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ A Fender Strat. You bought this?',
#  "L977 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ I didn't care about the money.",
#  'L976 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Really?  What was it like?  A down payment now, then a bonus for sleeping with me?',
#  "L975 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ It wasn't like that.",
#  'L974 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ You were paid to take me out!  By -- the one person I truly hate.  I knew it was a set-up!',
#  'L973 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Wait I...',
#  'L961 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ It gets worse -- you still have your freshman yearbook?',
#  "L960 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ That ' s completely adorable!",
#  "L959 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ That's where I was last year.  She'd never lived alone -- my grandfather died -- I stayed with her.  I wasn't in jail, I don't know Marilyn Manson, and I've never slept with a Spice Girl.  I spent a year sitting next to my grandma on the couch watching Wheel of Fortune.  End of story.",
#  'L958 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ What?',
#  "L957 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ My grandmother's .",
#  "L940 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Look, I'm  -- sorry -- that I questioned your motives.  I was wrong.",
#  'L939 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Oh huh',
#  "L938 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ It's just something I had.  You know",
#  "L937 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ It's Scurvy's.  His date got convicted. Where'd you get the dress?",
#  "L936 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ How'd you get a tux at the last minute?",
#  "L857 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Nothing!  There's nothing in it for me. Just the pleasure of your company.",
#  'L856 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Answer the question, Patrick',
#  'L855 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ You need therapy.  Has anyone ever told you that?',
#  'L854 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ You tell me.',
#  'L853 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ So I have to have a motive to be with you?',
#  'L852 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Create a little drama?  Start a new rumor?  What?',
#  "L848 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Because I don't want to. It's a stupid tradition.",
#  'L847 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Why not?',
#  "L846 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ No, I won't go with you",
#  'L845 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ No what?',
#  'L844 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ No.',
#  'L843 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ You know what I mean',
#  'L842 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Is that a request or a command?',
#  'L841 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Go to the prom with me',
#  "L840 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ You're amazingly self-assured. Has anyone ever told you that?",
#  'L839 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ No one else knows',
#  'L838 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ What?',
#  "L837 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ You're sweet.  And sexy.  And completely hot for me.",
#  'L836 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ No -- something real.  Something no one else knows.',
#  'L835 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ I hate peas.',
#  'L834 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Tell me something true.',
#  "L832 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I know the porn career's a lie.",
#  'L831 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Hearsay.',
#  'L830 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ The duck?',
#  'L829 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Fallacy.',
#  'L828 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ State trooper?',
#  'L825 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ For. . . ?',
#  'L824 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ You up for it?',
#  'L823 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ You never disappointed me.',
#  'L822 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ How?',
#  'L821 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Then you screwed up',
#  'L820 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Something like that',
#  "L819 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ So if you disappoint them from the start, you're covered?",
#  "L818 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I don't like to do what people expect. Then they expect it all the time and they get disappointed when you change.",
#  'L817 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Yes',
#  'L816 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Acting the way we do.',
#  "L815 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ So what's your excuse?",
#  "L814 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Yeah, well, don't let it get out",
#  'L813 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ A soft side? Who knew?',
#  'L812 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I dazzled him with my wit',
#  "L811 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ So how'd you get Chapin to look the other way?",
#  'L810 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Good call.',
#  'L809 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ I figured it had to be something ridiculous to win your respect.  And piss you off.',
#  'L808 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ The Partridge Family?',
#  'L806 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Maybe.',
#  'L805 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ You want me to climb up and show you how to get down?',
#  "L804 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Forget it.  I'm stayin'.",
#  'L803 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Put your right foot there --',
#  "L802 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Try lookin' at it from this angle",
#  "L801 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ C'mon.  It's not that bad",
#  "L800 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ I guess I never told you I'm afraid of heights.",
#  'L799 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Look up, sunshine',
#  'L798 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ He left!  I sprung the dickhead and he cruised on me.',
#  'L774 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Other than my upchuck reflex? Nothing.',
#  'L773 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ So what did I have an effect on ?',
#  "L772 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Don't for one minute think that you had any effect whatsoever on my panties.",
#  'L771 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Unwelcome?  I guess someone still has her panties in a twist.',
#  'L770 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Unwelcome.',
#  'L769 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Wholesome.',
#  'L768 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Pleasant?',
#  "L767 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ You 're so --",
#  'L766 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ I heard there was a poetry reading.',
#  'L765 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ What are you doing here?',
#  'L764 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Excuse me, have you seen The Feminine Mystique?  I lost my copy.',
#  "L690 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ No offense, but you're sister is without.  I know everyone likes her and all, but ...",
#  'L689 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ BIANCA',
#  'L688 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Who?',
#  "L687 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ He just wants me to be someone I'm not.",
#  "L686 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ So what ' s up with your dad?  He a pain in the ass?",
#  "L684 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ I'm gettin' there",
#  'L683 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Oh, so now you think you know me?',
#  "L682 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ You don't strike me as the type that would ask permission.",
#  "L681 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ My father wouldn't approve of that that",
#  'L680 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Start a band?',
#  'L679 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ This.',
#  'L678 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Do what?',
#  'L677 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I should do this.',
#  "L676 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Why'd you lie?",
# ...
#  'L1959 +++$+++ u19 +++$+++ m1 +++$+++ MARCHENA +++$+++ How can you be so certain?',
#  'L1958 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ Ignorance!  I believe the Indies are no more than 750 leagues west of the Canary Islands.',
#  'L1957 +++$+++ u19 +++$+++ m1 +++$+++ MARCHENA +++$+++ How can you be so certain?  The Ocean is said to be infinite.',
#  'L1952 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ To open a new route to Asia.  At the moment there are only two ways of reaching it...',
#  'L1951 +++$+++ u19 +++$+++ m1 +++$+++ MARCHENA +++$+++ Why do you wish to sail west?',
#  'L1950 +++$+++ u19 +++$+++ m1 +++$+++ MARCHENA +++$+++ With some difficulty.  I had to promise them you were not a total fool.',
#  'L1949 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ How did you manage it?',
#  "L1948 +++$+++ u19 +++$+++ m1 +++$+++ MARCHENA +++$+++ That's what it says.",
#  "L1947 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ God... That's in a week!",
#  'L1943 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ Father, I am doing what I think is the best for him.  And he has the teacher I would have chosen for myself.',
#  'L1942 +++$+++ u19 +++$+++ m1 +++$+++ MARCHENA +++$+++ Diego is a bright boy -- a pleasure to teach -- but so serious... Brothers should be raised together, Colon.  Even brothers from different mothers...',
#  'L2459 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ Your Majesty -- some men are content to read about things.  I must see them with my own eyes.  I cannot be other than I am.',
#  "L2458 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ There is one thing I'd like to understand... Why do you want to go back, after all this?",
#  'L2457 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ Thank you.',
#  'L2456 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ But without your brothers.  Nor are you to return to Santo Domingo or any of the other colonies.  You may explore the continent.',
#  'L2280 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ They come and go as naked as the day God created them...',
#  'L2279 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ Do they have such thoughts?',
#  'L2086 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ Thirty seven, Your Majesty... And you?',
#  'L2085 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ How old are you, Senor Colon?',
#  'L2082 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ A woman?',
#  'L2081 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ I know what I see.  I see someone who doesn\'t accept the world as it is.  Who\'s not afraid.  I see a women who thinks... "What if?"...',
#  'L2080 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ You show no inclination to speak otherwise!',
#  'L2079 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ May I speak freely?',
#  'L2077 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ Surely you can do anything you want.',
#  'L2076 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ I cannot ignore the verdict of my council.',
#  'L2075 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ That she was impregnable.',
#  'L2074 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ What did they say about Granada before today?',
#  'L2073 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ The ocean is uncrossable?',
#  'L2072 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ No more than the woman who said she would take Granada from the Moors.',
#  'L2071 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ I should not even be listening to you, since my council said no.  But Santangel tells me you are a man of honor and sincerity... And Sanchez, that you are not a fool.',
#  'L2389 +++$+++ u21 +++$+++ m1 +++$+++ MOXICA +++$+++ You will regret this.',
#  "L2388 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ You'll be held in detention, deprived of your privileges and possessions.  Until you are returned to Spain where you will be judged. Have you anything to say?",
#  'L2387 +++$+++ u21 +++$+++ m1 +++$+++ MOXICA +++$+++ Savagery is what monkeys understand.',
#  'L2386 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ In one act of brutality, you have created chaos.  Tribes who were fighting each other are now joining forces against us!  All that because of your criminal savagery!',
#  'L2348 +++$+++ u21 +++$+++ m1 +++$+++ MOXICA +++$+++ You did not hear me, Don Colon.  Not my horse.',
#  'L2347 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ Don Moxica -- we all have to work.',
#  "L2346 +++$+++ u21 +++$+++ m1 +++$+++ MOXICA +++$+++ My horse doesn't work.",
#  "L2345 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ We can't raise the wheel without it.",
#  'L2333 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ We came here to stay!  To build! Not to start a crusade.  In this forest, there is enough danger to sweep us away in days!  So we will be brave and swallow our grief.  And in the name of those who died, we will accomplish what we came for.',
#  "L2332 +++$+++ u21 +++$+++ m1 +++$+++ MOXICA +++$+++ We don't need to know.",
#  'L2331 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ You want a war?  Fine.  We are a thousand.  They outnumber us by ten! Who will you kill?  Which tribe?',
#  "L2329 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ If you want to keep your head on your shoulders, you'll do as I say.",
#  'L2328 +++$+++ u21 +++$+++ m1 +++$+++ MOXICA +++$+++ We lost cousins, friends.  We will wash this in blood.',
#  'L2278 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ The Indians have no such word, Don Moxica.',
#  "L2277 +++$+++ u21 +++$+++ m1 +++$+++ MOXICA +++$+++ And you say this is an Indian vice? By God!  I don't see any kind of pleasure that would make this a sin.",
#  "L2492 +++$+++ u20 +++$+++ m1 +++$+++ MENDEZ +++$+++ We can't be.",
#  "L2491 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ He's drawing an isthmus... He's saying we're on an isthmus.",
#  "L2490 +++$+++ u20 +++$+++ m1 +++$+++ MENDEZ +++$+++ What's he doing?",
#  'L2165 +++$+++ u20 +++$+++ m1 +++$+++ MENDEZ +++$+++ Twenty eight.',
#  'L2164 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ What do you read?',
#  'L2160 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ Come over here.',
#  "L2159 +++$+++ u20 +++$+++ m1 +++$+++ MENDEZ +++$+++ Well, I surely know what a quadrant is!  But I've never seen it used at night before.",
#  'L2158 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ And what do you think Mendez?',
#  "L2157 +++$+++ u20 +++$+++ m1 +++$+++ MENDEZ +++$+++ Well... It's the men, Sir.  They wonder how you know our position. We've lost sight from land days ago...",
#  'L2155 +++$+++ u20 +++$+++ m1 +++$+++ MENDEZ +++$+++ God be with us admiral.',
#  'L2154 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ Due west, Captain Mendez.  And may God be with us...',
#  "L2211 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ You're right.  Let the men decide.",
#  'L2210 +++$+++ u22 +++$+++ m1 +++$+++ PINZON +++$+++ You tell that to them!',
#  'L2209 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ Pinzon, Pinzon... All we can do now is go forward!  Think about that!',
#  'L2208 +++$+++ u22 +++$+++ m1 +++$+++ PINZON +++$+++ You bloody...',
#  'L2207 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ You never did.  You did all the talking for both of us, remember?',
#  'L2206 +++$+++ u22 +++$+++ m1 +++$+++ PINZON +++$+++ Jesus Maria!  I should have never listened to you!',
#  'L2205 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ And then what?  Half of the water has gone, the rest is nearly putrid! You know that!',
#  "L2204 +++$+++ u22 +++$+++ m1 +++$+++ PINZON +++$+++ You don't know anything!  Listen Colon, these are my ships, right? So I'm telling you we're turning back!",
#  'L2203 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ The land is there.  I know it!',
#  "L2202 +++$+++ u22 +++$+++ m1 +++$+++ PINZON +++$+++ We're lost!",
#  "L2201 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ You think I don't know that?",
#  "L2200 +++$+++ u22 +++$+++ m1 +++$+++ PINZON +++$+++ We're on the verge of a mutiny, Colon!",
#  'L2199 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ We have to keep the hopes of these men alive!',
#  'L2198 +++$+++ u22 +++$+++ m1 +++$+++ PINZON +++$+++ You must be mad...!',
#  'L2197 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ Six days ago, yes.',
#  "L2196 +++$+++ u22 +++$+++ m1 +++$+++ PINZON +++$+++ You lied!  You cheated!  We're way past 750 leagues!",
#  'L2065 +++$+++ u22 +++$+++ m1 +++$+++ PINZON +++$+++ Immediately.',
#  'L2064 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ Where can I meet this man?',
#  'L2462 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ Because he is not afraid of me.',
#  'L2461 +++$+++ u24 +++$+++ m1 +++$+++ SANCHEZ +++$+++ Then why?',
#  'L2460 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ I know, I should not tolerate his impertinence.',
#  'L2419 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ And who would you think of, for such a task?',
#  'L2418 +++$+++ u24 +++$+++ m1 +++$+++ SANCHEZ +++$+++ He must be replaced.',
#  'L2417 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ Then, what do you suggest, Don Sanchez?',
#  'L2415 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ Is this true, Brother Buyl?',
#  'L2414 +++$+++ u24 +++$+++ m1 +++$+++ SANCHEZ +++$+++ ... But there is worse.  He ordered the execution of five members of the nobility...',
#  "L2377 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ We weren't expecting immediate profits, were we?  We must have faith.  We must give time for time.",
#  'L2376 +++$+++ u24 +++$+++ m1 +++$+++ SANCHEZ +++$+++ Every ship returns with a cargo of sick and dying.  But with no gold! The new world proves expensive, Your Majesty.',
#  "L2116 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ Yes.  It would be a pity, wouldn't it?  Call him back!",
#  'L2115 +++$+++ u24 +++$+++ m1 +++$+++ SANCHEZ +++$+++ ... Into a monk...',
#  'L2113 +++$+++ u24 +++$+++ m1 +++$+++ SANCHEZ +++$+++ Never, Your Majesty.  Although...',
#  'L2112 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ You were right, Don Sanchez... His demands could never be granted.',
#  'L1931 +++$+++ u24 +++$+++ m1 +++$+++ SANCHEZ +++$+++ Yes, Your Majesty.',
#  'L1930 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ Is that the man I knew, Treasurer Sanchez?',
#  "L3546 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Officers, there's your killer, do your duty, arrest him!",
#  'L3545 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ ...so we kill someone famous and if we are caught, we are sent to mental hospital...',
#  "L3497 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ I don't think it's abuse, I think it's torture.",
#  "L3496 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ I'm abused.  Don't you think?",
#  'L3493 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Can I see your back?',
#  'L3492 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ Out on my back when I was a small boy.',
#  'L3491 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Your father put cigarettes out on you?',
#  "L3490 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ That's what he did to me.  He put cigarettes out on me.",
#  'L3489 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ Yeah, he hated me from day when I was born.  Put it out.  Can you put the cigarette out?',
#  "L3488 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Your father blamed you for your mother's blindness?",
#  'L3487 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ Yeah, yeah...bad doctor gave her bad drugs which made her go blind.  And my father blamed me for her blindness...',
#  'L3486 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Back in the Czech Republic?',
#  'L3485 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ Yeah, she went blind giving birth to me. She went to fucking black market doctor to induce me.',
#  'L3484 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Your mother was blind?',
#  'L3483 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ My father always degraded me.  Killed my self-esteem.  And my mother was blind.',
#  'L3482 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Tell me about yourself.  What you did as a young boy... what your parents were like.',
#  'L3481 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ Give me another one, please.',
#  "L3480 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ I need to know about your background.  I need to know about your upbringing.  Why you're here.",
#  'L3479 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ What else do you need?',
#  'L3478 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ This is not about money, Emil.  I need your trust in me.',
#  "L3477 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ Thirty-percent.  No more.  Or I call another lawyer.  This is the biggest case of your life.  Don't try to negotiate.  Thirty percent.  Say yes or no.",
#  "L3476 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ But it's...",
#  'L3475 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ No.  No way.',
#  'L3474 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ I would say...half.  Half is fair.',
#  "L3473 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ What's your cut?  How much?",
#  "L3472 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Look, I haven't really focused on that kind of thing.",
#  'L3471 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ What about my movie rights?  Book rights?',
#  "L3470 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Don't worry about him.  Think about yourself.",
#  'L3469 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ No, he is here.  Shit...',
#  "L3468 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Disappeared.  They're looking everywhere.  Maybe he went back to Czechoslovakia.",
#  'L3467 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ What about Oleg?',
#  "L3466 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Well, you didn't appreciate the severity of it until recently.  No question about that.",
#  'L3465 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ I was all of these.',
#  'L3464 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ ...delusions and paranoia.',
#  'L3461 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Oh, sure.',
#  'L3460 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ You bring the cigarettes?',
#  "L3459 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ I brought you some letters.  It's really fan mail.  Women mostly.  One wants to buy you clothes, another sent a check. Another wants a check.",
#  "L3396 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ I'm invoking rights - this man is represented by counsel.  I'm coming with him.",
#  'L3395 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ Yes.  Yes, come with me!',
#  "L3394 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ I'm coming with you.",
#  'L3393 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ Where are we going?',
#  "L3392 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Don't say anything.",
#  'L3385 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ He has the camera!  He took the movie!',
#  'L3384 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Emil.  Take it easy.  Stay with me.  Sit down.  What do you need?  What are you looking for?',
#  'L3383 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ Oh no!  No!  Shit!',
#  'L3382 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ Here.  I have your money.',
#  "L3381 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ I'm not your lawyer until I see the money.",
#  "L3380 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ Are you my attorney?  I'm Emil.  I'm insane.",
#  'L3517 +++$+++ u34 +++$+++ m2 +++$+++ JORDY +++$+++ Daphne, I...',
#  "L3516 +++$+++ u27 +++$+++ m2 +++$+++ DAPHNE +++$+++ I don't want to drag you down with me.",
#  'L3515 +++$+++ u34 +++$+++ m2 +++$+++ JORDY +++$+++ ...Do you really want me to forget about you?',
#  'L3514 +++$+++ u27 +++$+++ m2 +++$+++ DAPHNE +++$+++ Forget about me.  You have enough problems of your own.',
#  'L3330 +++$+++ u27 +++$+++ m2 +++$+++ DAPHNE +++$+++ Pouring it out!',
#  'L3329 +++$+++ u34 +++$+++ m2 +++$+++ JORDY +++$+++ What are you doing?',
#  "L3318 +++$+++ u27 +++$+++ m2 +++$+++ DAPHNE +++$+++ I'll get my clothes.",
#  "L3317 +++$+++ u34 +++$+++ m2 +++$+++ JORDY +++$+++ I'll make some for us.",
#  'L3316 +++$+++ u27 +++$+++ m2 +++$+++ DAPHNE +++$+++ In the kitchen.',
#  'L3315 +++$+++ u34 +++$+++ m2 +++$+++ JORDY +++$+++ Do you have coffee?',
#  ...]

# %% [markdown]
# Explaining with an example :
#
# L1045 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ They do not!
#
# L1045  is a unique key identifier
#
# u0 represents user 0
#
# m0 represents in movie 0
#
# -------------------------------------------------------------------------------

# %% [markdown]
# Let's have a look at the conversations dataset

# %%
conversations
# Out:
# ["u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L194', 'L195', 'L196', 'L197']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L198', 'L199']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L200', 'L201', 'L202', 'L203']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L204', 'L205', 'L206']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L207', 'L208']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L271', 'L272', 'L273', 'L274', 'L275']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L276', 'L277']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L280', 'L281']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L363', 'L364']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L365', 'L366']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L367', 'L368']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L401', 'L402', 'L403']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L404', 'L405', 'L406', 'L407']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L575', 'L576']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L577', 'L578']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L662', 'L663']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L693', 'L694', 'L695']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L696', 'L697', 'L698', 'L699']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L860', 'L861']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L862', 'L863', 'L864', 'L865']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L866', 'L867', 'L868', 'L869']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L870', 'L871', 'L872']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L924', 'L925']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L984', 'L985']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L1044', 'L1045']",
#  "u0 +++$+++ u3 +++$+++ m0 +++$+++ ['L49', 'L50', 'L51']",
#  "u0 +++$+++ u3 +++$+++ m0 +++$+++ ['L571', 'L572', 'L573']",
#  "u0 +++$+++ u3 +++$+++ m0 +++$+++ ['L579', 'L580']",
#  "u0 +++$+++ u3 +++$+++ m0 +++$+++ ['L595', 'L596', 'L597']",
#  "u0 +++$+++ u3 +++$+++ m0 +++$+++ ['L598', 'L599', 'L600']",
#  "u0 +++$+++ u3 +++$+++ m0 +++$+++ ['L659', 'L660']",
#  "u0 +++$+++ u3 +++$+++ m0 +++$+++ ['L952', 'L953']",
#  "u0 +++$+++ u4 +++$+++ m0 +++$+++ ['L394', 'L395']",
#  "u0 +++$+++ u4 +++$+++ m0 +++$+++ ['L396', 'L397']",
#  "u0 +++$+++ u4 +++$+++ m0 +++$+++ ['L589', 'L590', 'L591']",
#  "u0 +++$+++ u4 +++$+++ m0 +++$+++ ['L592', 'L593']",
#  "u0 +++$+++ u4 +++$+++ m0 +++$+++ ['L756', 'L757', 'L758']",
#  "u0 +++$+++ u4 +++$+++ m0 +++$+++ ['L759', 'L760']",
#  "u0 +++$+++ u5 +++$+++ m0 +++$+++ ['L164', 'L165']",
#  "u0 +++$+++ u5 +++$+++ m0 +++$+++ ['L319', 'L320']",
#  "u0 +++$+++ u5 +++$+++ m0 +++$+++ ['L441', 'L442', 'L443', 'L444', 'L445']",
#  "u0 +++$+++ u5 +++$+++ m0 +++$+++ ['L525', 'L526', 'L527']",
#  "u0 +++$+++ u5 +++$+++ m0 +++$+++ ['L529', 'L530']",
#  "u0 +++$+++ u5 +++$+++ m0 +++$+++ ['L531', 'L532', 'L533']",
#  "u0 +++$+++ u5 +++$+++ m0 +++$+++ ['L542', 'L543']",
#  "u0 +++$+++ u5 +++$+++ m0 +++$+++ ['L601', 'L602']",
#  "u0 +++$+++ u5 +++$+++ m0 +++$+++ ['L655', 'L656']",
#  "u0 +++$+++ u5 +++$+++ m0 +++$+++ ['L889', 'L890', 'L891', 'L892']",
#  "u0 +++$+++ u5 +++$+++ m0 +++$+++ ['L893', 'L894', 'L895', 'L896', 'L897', 'L898', 'L899', 'L900']",
#  "u0 +++$+++ u5 +++$+++ m0 +++$+++ ['L901', 'L902', 'L903']",
#  "u0 +++$+++ u5 +++$+++ m0 +++$+++ ['L904', 'L905', 'L906', 'L907', 'L908']",
#  "u0 +++$+++ u5 +++$+++ m0 +++$+++ ['L909', 'L910', 'L911', 'L912', 'L913', 'L914']",
#  "u0 +++$+++ u5 +++$+++ m0 +++$+++ ['L982', 'L983']",
#  "u0 +++$+++ u5 +++$+++ m0 +++$+++ ['L1007', 'L1008', 'L1009', 'L1010', 'L1011']",
#  "u0 +++$+++ u5 +++$+++ m0 +++$+++ ['L1021', 'L1022']",
#  "u0 +++$+++ u5 +++$+++ m0 +++$+++ ['L1051', 'L1052']",
#  "u0 +++$+++ u11 +++$+++ m0 +++$+++ ['L179', 'L180', 'L181', 'L182', 'L183']",
#  "u0 +++$+++ u11 +++$+++ m0 +++$+++ ['L189', 'L190']",
#  "u0 +++$+++ u11 +++$+++ m0 +++$+++ ['L517', 'L518', 'L519', 'L520', 'L521']",
#  "u0 +++$+++ u11 +++$+++ m0 +++$+++ ['L523', 'L524']",
#  "u0 +++$+++ u11 +++$+++ m0 +++$+++ ['L536', 'L537']",
#  "u0 +++$+++ u11 +++$+++ m0 +++$+++ ['L538', 'L539', 'L540']",
#  "u0 +++$+++ u11 +++$+++ m0 +++$+++ ['L544', 'L545', 'L546']",
#  "u0 +++$+++ u11 +++$+++ m0 +++$+++ ['L878', 'L879', 'L880', 'L881', 'L882', 'L883', 'L884']",
#  "u0 +++$+++ u11 +++$+++ m0 +++$+++ ['L922', 'L923']",
#  "u1 +++$+++ u9 +++$+++ m0 +++$+++ ['L458', 'L459', 'L460', 'L461', 'L462', 'L463']",
#  "u2 +++$+++ u7 +++$+++ m0 +++$+++ ['L63', 'L64', 'L65']",
#  "u2 +++$+++ u7 +++$+++ m0 +++$+++ ['L66', 'L67', 'L68', 'L69', 'L70', 'L71', 'L72', 'L73', 'L74']",
#  "u2 +++$+++ u7 +++$+++ m0 +++$+++ ['L77', 'L78']",
#  "u2 +++$+++ u7 +++$+++ m0 +++$+++ ['L87', 'L88', 'L89', 'L90', 'L91', 'L92']",
#  "u2 +++$+++ u7 +++$+++ m0 +++$+++ ['L139', 'L140', 'L141', 'L142']",
#  "u2 +++$+++ u7 +++$+++ m0 +++$+++ ['L143', 'L144', 'L145', 'L146', 'L147']",
#  "u2 +++$+++ u7 +++$+++ m0 +++$+++ ['L157', 'L158', 'L159']",
#  "u2 +++$+++ u7 +++$+++ m0 +++$+++ ['L210', 'L211']",
#  "u2 +++$+++ u7 +++$+++ m0 +++$+++ ['L212', 'L213']",
#  "u2 +++$+++ u7 +++$+++ m0 +++$+++ ['L215', 'L216', 'L217', 'L218', 'L219', 'L220', 'L221', 'L222']",
#  "u2 +++$+++ u7 +++$+++ m0 +++$+++ ['L223', 'L224', 'L225']",
#  "u2 +++$+++ u7 +++$+++ m0 +++$+++ ['L244', 'L245']",
#  "u2 +++$+++ u7 +++$+++ m0 +++$+++ ['L388', 'L389', 'L390', 'L391']",
#  "u2 +++$+++ u7 +++$+++ m0 +++$+++ ['L416', 'L417', 'L418', 'L419']",
#  "u2 +++$+++ u7 +++$+++ m0 +++$+++ ['L424', 'L425']",
#  "u2 +++$+++ u7 +++$+++ m0 +++$+++ ['L432', 'L433']",
#  "u2 +++$+++ u7 +++$+++ m0 +++$+++ ['L499', 'L500']",
#  "u2 +++$+++ u7 +++$+++ m0 +++$+++ ['L583', 'L584', 'L585', 'L586']",
#  "u2 +++$+++ u7 +++$+++ m0 +++$+++ ['L778', 'L779']",
#  "u2 +++$+++ u9 +++$+++ m0 +++$+++ ['L385', 'L386']",
#  "u2 +++$+++ u9 +++$+++ m0 +++$+++ ['L411', 'L412']",
#  "u2 +++$+++ u9 +++$+++ m0 +++$+++ ['L426', 'L427']",
#  "u2 +++$+++ u9 +++$+++ m0 +++$+++ ['L430', 'L431']",
#  "u2 +++$+++ u9 +++$+++ m0 +++$+++ ['L619', 'L620']",
#  "u2 +++$+++ u9 +++$+++ m0 +++$+++ ['L621', 'L622']",
#  "u2 +++$+++ u9 +++$+++ m0 +++$+++ ['L623', 'L624', 'L625']",
#  "u2 +++$+++ u9 +++$+++ m0 +++$+++ ['L725', 'L726']",
#  "u2 +++$+++ u9 +++$+++ m0 +++$+++ ['L740', 'L741']",
#  "u2 +++$+++ u9 +++$+++ m0 +++$+++ ['L743', 'L744', 'L745']",
#  "u2 +++$+++ u9 +++$+++ m0 +++$+++ ['L780', 'L781']",
#  "u4 +++$+++ u5 +++$+++ m0 +++$+++ ['L148', 'L149', 'L150']",
#  "u4 +++$+++ u5 +++$+++ m0 +++$+++ ['L335', 'L336']",
#  "u4 +++$+++ u5 +++$+++ m0 +++$+++ ['L554', 'L555', 'L556']",
#  "u4 +++$+++ u5 +++$+++ m0 +++$+++ ['L557', 'L558']",
#  "u4 +++$+++ u9 +++$+++ m0 +++$+++ ['L285', 'L286']",
#  "u4 +++$+++ u9 +++$+++ m0 +++$+++ ['L287', 'L288', 'L289', 'L290', 'L291', 'L292']",
#  "u4 +++$+++ u9 +++$+++ m0 +++$+++ ['L294', 'L295', 'L296', 'L297']",
#  "u4 +++$+++ u9 +++$+++ m0 +++$+++ ['L298', 'L299']",
#  "u4 +++$+++ u9 +++$+++ m0 +++$+++ ['L300', 'L301']",
#  "u4 +++$+++ u9 +++$+++ m0 +++$+++ ['L349', 'L350', 'L351', 'L352']",
#  "u4 +++$+++ u9 +++$+++ m0 +++$+++ ['L354', 'L355', 'L356', 'L357', 'L358']",
#  "u4 +++$+++ u9 +++$+++ m0 +++$+++ ['L605', 'L606']",
#  "u4 +++$+++ u9 +++$+++ m0 +++$+++ ['L607', 'L608', 'L609']",
#  "u4 +++$+++ u9 +++$+++ m0 +++$+++ ['L747', 'L748']",
#  "u4 +++$+++ u7 +++$+++ m0 +++$+++ ['L231', 'L232', 'L233', 'L234', 'L235', 'L236']",
#  "u4 +++$+++ u7 +++$+++ m0 +++$+++ ['L238', 'L239', 'L240']",
#  "u4 +++$+++ u7 +++$+++ m0 +++$+++ ['L502', 'L503', 'L504', 'L505']",
#  "u4 +++$+++ u7 +++$+++ m0 +++$+++ ['L508', 'L509']",
#  "u5 +++$+++ u6 +++$+++ m0 +++$+++ ['L123', 'L124', 'L125', 'L126', 'L127', 'L128']",
#  "u5 +++$+++ u6 +++$+++ m0 +++$+++ ['L129', 'L130']",
#  "u5 +++$+++ u6 +++$+++ m0 +++$+++ ['L131', 'L132']",
#  "u5 +++$+++ u6 +++$+++ m0 +++$+++ ['L133', 'L134']",
#  "u5 +++$+++ u6 +++$+++ m0 +++$+++ ['L151', 'L152']",
#  "u5 +++$+++ u6 +++$+++ m0 +++$+++ ['L247', 'L248', 'L249', 'L250', 'L251']",
#  "u5 +++$+++ u6 +++$+++ m0 +++$+++ ['L252', 'L253', 'L254']",
#  "u5 +++$+++ u6 +++$+++ m0 +++$+++ ['L447', 'L448']",
#  "u5 +++$+++ u6 +++$+++ m0 +++$+++ ['L490', 'L491']",
#  "u5 +++$+++ u6 +++$+++ m0 +++$+++ ['L716', 'L717', 'L718', 'L719', 'L720', 'L721']",
#  "u5 +++$+++ u6 +++$+++ m0 +++$+++ ['L750', 'L751', 'L752', 'L753', 'L754', 'L755']",
#  "u5 +++$+++ u6 +++$+++ m0 +++$+++ ['L946', 'L947', 'L948', 'L949']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L304', 'L305', 'L306', 'L307']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L309', 'L310']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L311', 'L312', 'L313']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L322', 'L323', 'L324', 'L325', 'L326', 'L327', 'L328']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L330', 'L331', 'L332']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L333', 'L334']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L473', 'L474']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L475', 'L476', 'L477']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L481', 'L482', 'L483']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L564', 'L565', 'L566', 'L567']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L610', 'L611']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L612', 'L613', 'L614', 'L615', 'L616']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L626', 'L627', 'L628', 'L629', 'L630', 'L631', 'L632', 'L633', 'L634', 'L635', 'L636']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L639', 'L640', 'L641', 'L642', 'L643', 'L644', 'L645', 'L646']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L650', 'L651']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L668', 'L669']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L670', 'L671', 'L672', 'L673', 'L674', 'L675', 'L676']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L677', 'L678', 'L679']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L680', 'L681', 'L682']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L683', 'L684']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L686', 'L687', 'L688', 'L689', 'L690']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L764', 'L765', 'L766', 'L767', 'L768']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L769', 'L770', 'L771', 'L772', 'L773', 'L774']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L798', 'L799']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L800', 'L801', 'L802']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L803', 'L804', 'L805', 'L806']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L808', 'L809', 'L810', 'L811', 'L812']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L813', 'L814', 'L815', 'L816', 'L817', 'L818', 'L819', 'L820', 'L821', 'L822', 'L823']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L824', 'L825']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L828', 'L829', 'L830', 'L831', 'L832']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L834', 'L835', 'L836', 'L837', 'L838', 'L839', 'L840', 'L841']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L842', 'L843', 'L844', 'L845', 'L846', 'L847', 'L848']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L852', 'L853', 'L854', 'L855', 'L856', 'L857']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L936', 'L937', 'L938', 'L939', 'L940']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L957', 'L958', 'L959']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L960', 'L961']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L973', 'L974', 'L975', 'L976', 'L977']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L1031', 'L1032']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L1033', 'L1034', 'L1035']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L1040', 'L1041', 'L1042', 'L1043']",
#  "u5 +++$+++ u11 +++$+++ m0 +++$+++ ['L172', 'L173', 'L174']",
#  "u5 +++$+++ u11 +++$+++ m0 +++$+++ ['L184', 'L185']",
#  "u5 +++$+++ u11 +++$+++ m0 +++$+++ ['L338', 'L339', 'L340', 'L341', 'L342', 'L343', 'L344', 'L345', 'L346', 'L347']",
#  "u5 +++$+++ u11 +++$+++ m0 +++$+++ ['L986', 'L987', 'L988']",
#  "u5 +++$+++ u11 +++$+++ m0 +++$+++ ['L989', 'L990', 'L991', 'L992', 'L993', 'L994', 'L995', 'L996', 'L997']",
#  "u5 +++$+++ u11 +++$+++ m0 +++$+++ ['L998', 'L999', 'L1000']",
#  "u5 +++$+++ u8 +++$+++ m0 +++$+++ ['L103', 'L104', 'L105', 'L106', 'L107']",
#  "u5 +++$+++ u8 +++$+++ m0 +++$+++ ['L108', 'L109']",
#  "u5 +++$+++ u8 +++$+++ m0 +++$+++ ['L1017', 'L1018']",
#  "u6 +++$+++ u7 +++$+++ m0 +++$+++ ['L728', 'L729', 'L730', 'L731']",
#  "u6 +++$+++ u7 +++$+++ m0 +++$+++ ['L732', 'L733']",
#  "u6 +++$+++ u7 +++$+++ m0 +++$+++ ['L735', 'L736', 'L737', 'L738']",
#  "u7 +++$+++ u9 +++$+++ m0 +++$+++ ['L371', 'L372', 'L373']",
#  "u7 +++$+++ u9 +++$+++ m0 +++$+++ ['L375', 'L376', 'L377']",
#  "u7 +++$+++ u9 +++$+++ m0 +++$+++ ['L378', 'L379']",
#  "u7 +++$+++ u9 +++$+++ m0 +++$+++ ['L380', 'L381', 'L382']",
#  "u7 +++$+++ u9 +++$+++ m0 +++$+++ ['L383', 'L384']",
#  "u7 +++$+++ u9 +++$+++ m0 +++$+++ ['L414', 'L415']",
#  "u7 +++$+++ u9 +++$+++ m0 +++$+++ ['L420', 'L421']",
#  "u7 +++$+++ u9 +++$+++ m0 +++$+++ ['L428', 'L429']",
#  "u7 +++$+++ u9 +++$+++ m0 +++$+++ ['L436', 'L437']",
#  "u7 +++$+++ u9 +++$+++ m0 +++$+++ ['L723', 'L724']",
#  "u7 +++$+++ u9 +++$+++ m0 +++$+++ ['L775', 'L776', 'L777']",
#  "u8 +++$+++ u9 +++$+++ m0 +++$+++ ['L59', 'L60', 'L61', 'L62']",
#  "u8 +++$+++ u9 +++$+++ m0 +++$+++ ['L257', 'L258', 'L259']",
#  "u8 +++$+++ u9 +++$+++ m0 +++$+++ ['L261', 'L262', 'L263', 'L264']",
#  "u8 +++$+++ u9 +++$+++ m0 +++$+++ ['L511', 'L512']",
#  "u10 +++$+++ u11 +++$+++ m0 +++$+++ ['L161', 'L162']",
#  "u10 +++$+++ u11 +++$+++ m0 +++$+++ ['L170', 'L171']",
#  "u10 +++$+++ u11 +++$+++ m0 +++$+++ ['L191', 'L192', 'L193']",
#  "u10 +++$+++ u11 +++$+++ m0 +++$+++ ['L876', 'L877']",
#  "u10 +++$+++ u11 +++$+++ m0 +++$+++ ['L886', 'L887']",
#  "u10 +++$+++ u11 +++$+++ m0 +++$+++ ['L917', 'L918']",
#  "u10 +++$+++ u11 +++$+++ m0 +++$+++ ['L926', 'L927']",
#  "u10 +++$+++ u11 +++$+++ m0 +++$+++ ['L929', 'L930', 'L931', 'L932', 'L933']",
#  "u12 +++$+++ u23 +++$+++ m1 +++$+++ ['L2170', 'L2171', 'L2172']",
#  "u12 +++$+++ u23 +++$+++ m1 +++$+++ ['L2173', 'L2174', 'L2175']",
#  "u12 +++$+++ u23 +++$+++ m1 +++$+++ ['L2176', 'L2177']",
#  "u12 +++$+++ u23 +++$+++ m1 +++$+++ ['L2179', 'L2180', 'L2181']",
#  "u13 +++$+++ u16 +++$+++ m1 +++$+++ ['L1989', 'L1990', 'L1991', 'L1992', 'L1993']",
#  "u13 +++$+++ u16 +++$+++ m1 +++$+++ ['L2005', 'L2006']",
#  "u13 +++$+++ u16 +++$+++ m1 +++$+++ ['L2010', 'L2011', 'L2012']",
#  "u13 +++$+++ u16 +++$+++ m1 +++$+++ ['L2014', 'L2015', 'L2016']",
#  "u13 +++$+++ u16 +++$+++ m1 +++$+++ ['L2019', 'L2020']",
#  "u13 +++$+++ u16 +++$+++ m1 +++$+++ ['L2022', 'L2023']",
#  "u13 +++$+++ u16 +++$+++ m1 +++$+++ ['L2024', 'L2025']",
#  "u13 +++$+++ u24 +++$+++ m1 +++$+++ ['L2027', 'L2028', 'L2029']",
#  "u13 +++$+++ u24 +++$+++ m1 +++$+++ ['L2030', 'L2031']",
#  "u13 +++$+++ u24 +++$+++ m1 +++$+++ ['L2274', 'L2275']",
#  "u13 +++$+++ u24 +++$+++ m1 +++$+++ ['L2522', 'L2523', 'L2524']",
#  "u14 +++$+++ u16 +++$+++ m1 +++$+++ ['L1979', 'L1980', 'L1981', 'L1982', 'L1983', 'L1984']",
#  "u14 +++$+++ u16 +++$+++ m1 +++$+++ ['L1985', 'L1986']",
#  "u14 +++$+++ u16 +++$+++ m1 +++$+++ ['L2118', 'L2119']",
#  "u14 +++$+++ u16 +++$+++ m1 +++$+++ ['L2121', 'L2122', 'L2123']",
#  "u14 +++$+++ u16 +++$+++ m1 +++$+++ ['L2318', 'L2319', 'L2320']",
#  "u14 +++$+++ u16 +++$+++ m1 +++$+++ ['L2471', 'L2472']",
#  "u14 +++$+++ u16 +++$+++ m1 +++$+++ ['L2473', 'L2474']",
#  "u14 +++$+++ u16 +++$+++ m1 +++$+++ ['L2537', 'L2538']",
#  "u14 +++$+++ u16 +++$+++ m1 +++$+++ ['L2539', 'L2540']",
#  "u15 +++$+++ u16 +++$+++ m1 +++$+++ ['L2290', 'L2291', 'L2292', 'L2293']",
#  "u15 +++$+++ u16 +++$+++ m1 +++$+++ ['L2421', 'L2422']",
#  "u15 +++$+++ u16 +++$+++ m1 +++$+++ ['L2423', 'L2424', 'L2425', 'L2426']",
#  "u15 +++$+++ u16 +++$+++ m1 +++$+++ ['L2429', 'L2430', 'L2431', 'L2432']",
#  "u16 +++$+++ u17 +++$+++ m1 +++$+++ ['L2127', 'L2128', 'L2129']",
#  "u16 +++$+++ u17 +++$+++ m1 +++$+++ ['L2130', 'L2131']",
#  "u16 +++$+++ u17 +++$+++ m1 +++$+++ ['L2439', 'L2440']",
#  "u16 +++$+++ u17 +++$+++ m1 +++$+++ ['L2484', 'L2485']",
#  "u16 +++$+++ u17 +++$+++ m1 +++$+++ ['L2500', 'L2501']",
#  "u16 +++$+++ u17 +++$+++ m1 +++$+++ ['L2541', 'L2542']",
#  "u16 +++$+++ u17 +++$+++ m1 +++$+++ ['L2547', 'L2548', 'L2549']",
#  "u16 +++$+++ u17 +++$+++ m1 +++$+++ ['L2550', 'L2551', 'L2552']",
#  "u16 +++$+++ u24 +++$+++ m1 +++$+++ ['L2103', 'L2104', 'L2105']",
#  "u16 +++$+++ u24 +++$+++ m1 +++$+++ ['L2106', 'L2107', 'L2108']",
#  "u16 +++$+++ u24 +++$+++ m1 +++$+++ ['L2109', 'L2110']",
#  "u16 +++$+++ u24 +++$+++ m1 +++$+++ ['L2281', 'L2282']",
#  "u16 +++$+++ u24 +++$+++ m1 +++$+++ ['L2286', 'L2287']",
#  "u16 +++$+++ u24 +++$+++ m1 +++$+++ ['L2295', 'L2296', 'L2297']",
#  "u16 +++$+++ u24 +++$+++ m1 +++$+++ ['L2299', 'L2300', 'L2301']",
#  "u16 +++$+++ u24 +++$+++ m1 +++$+++ ['L2463', 'L2464']",
#  "u16 +++$+++ u24 +++$+++ m1 +++$+++ ['L2465', 'L2466']",
#  "u16 +++$+++ u24 +++$+++ m1 +++$+++ ['L2467', 'L2468', 'L2469']",
#  "u16 +++$+++ u25 +++$+++ m1 +++$+++ ['L2237', 'L2238', 'L2239']",
#  "u16 +++$+++ u25 +++$+++ m1 +++$+++ ['L2248', 'L2249', 'L2250', 'L2251']",
#  "u16 +++$+++ u25 +++$+++ m1 +++$+++ ['L2253', 'L2254', 'L2255']",
#  "u16 +++$+++ u25 +++$+++ m1 +++$+++ ['L2256', 'L2257', 'L2258', 'L2259', 'L2260']",
#  "u16 +++$+++ u25 +++$+++ m1 +++$+++ ['L2341', 'L2342', 'L2343']",
#  "u16 +++$+++ u25 +++$+++ m1 +++$+++ ['L2393', 'L2394']",
#  "u16 +++$+++ u25 +++$+++ m1 +++$+++ ['L2409', 'L2410']",
#  "u16 +++$+++ u19 +++$+++ m1 +++$+++ ['L1942', 'L1943']",
#  "u16 +++$+++ u19 +++$+++ m1 +++$+++ ['L1947', 'L1948', 'L1949', 'L1950']",
#  "u16 +++$+++ u19 +++$+++ m1 +++$+++ ['L1951', 'L1952']",
#  "u16 +++$+++ u19 +++$+++ m1 +++$+++ ['L1957', 'L1958', 'L1959', 'L1960', 'L1961', 'L1962']",
#  "u16 +++$+++ u19 +++$+++ m1 +++$+++ ['L1963', 'L1964', 'L1965', 'L1966', 'L1967', 'L1968', 'L1969']",
#  "u16 +++$+++ u19 +++$+++ m1 +++$+++ ['L2037', 'L2038', 'L2039', 'L2040']",
#  "u16 +++$+++ u19 +++$+++ m1 +++$+++ ['L2041', 'L2042']",
#  "u16 +++$+++ u19 +++$+++ m1 +++$+++ ['L2045', 'L2046']",
#  "u16 +++$+++ u19 +++$+++ m1 +++$+++ ['L2132', 'L2133']",
#  "u16 +++$+++ u19 +++$+++ m1 +++$+++ ['L2134', 'L2135', 'L2136', 'L2137', 'L2138', 'L2139']",
#  "u16 +++$+++ u19 +++$+++ m1 +++$+++ ['L2140', 'L2141', 'L2142', 'L2143']",
#  "u16 +++$+++ u19 +++$+++ m1 +++$+++ ['L2144', 'L2145']",
#  "u16 +++$+++ u19 +++$+++ m1 +++$+++ ['L2525', 'L2526']",
#  "u16 +++$+++ u19 +++$+++ m1 +++$+++ ['L2531', 'L2532', 'L2533', 'L2534', 'L2535']",
#  "u16 +++$+++ u18 +++$+++ m1 +++$+++ ['L2071', 'L2072']",
#  "u16 +++$+++ u18 +++$+++ m1 +++$+++ ['L2073', 'L2074', 'L2075']",
#  "u16 +++$+++ u18 +++$+++ m1 +++$+++ ['L2076', 'L2077']",
#  "u16 +++$+++ u18 +++$+++ m1 +++$+++ ['L2079', 'L2080', 'L2081', 'L2082']",
#  "u16 +++$+++ u18 +++$+++ m1 +++$+++ ['L2085', 'L2086']",
#  "u16 +++$+++ u18 +++$+++ m1 +++$+++ ['L2279', 'L2280']",
#  "u16 +++$+++ u18 +++$+++ m1 +++$+++ ['L2456', 'L2457', 'L2458', 'L2459']",
#  "u16 +++$+++ u21 +++$+++ m1 +++$+++ ['L2277', 'L2278']",
#  "u16 +++$+++ u21 +++$+++ m1 +++$+++ ['L2328', 'L2329']",
#  "u16 +++$+++ u21 +++$+++ m1 +++$+++ ['L2331', 'L2332', 'L2333']",
#  "u16 +++$+++ u21 +++$+++ m1 +++$+++ ['L2345', 'L2346']",
#  "u16 +++$+++ u21 +++$+++ m1 +++$+++ ['L2347', 'L2348']",
#  "u16 +++$+++ u21 +++$+++ m1 +++$+++ ['L2386', 'L2387', 'L2388', 'L2389']",
#  "u16 +++$+++ u20 +++$+++ m1 +++$+++ ['L2154', 'L2155']",
#  "u16 +++$+++ u20 +++$+++ m1 +++$+++ ['L2157', 'L2158', 'L2159', 'L2160']",
#  "u16 +++$+++ u20 +++$+++ m1 +++$+++ ['L2164', 'L2165']",
#  "u16 +++$+++ u20 +++$+++ m1 +++$+++ ['L2490', 'L2491', 'L2492']",
#  "u16 +++$+++ u22 +++$+++ m1 +++$+++ ['L2064', 'L2065']",
#  "u16 +++$+++ u22 +++$+++ m1 +++$+++ ['L2196', 'L2197', 'L2198', 'L2199', 'L2200', 'L2201', 'L2202', 'L2203', 'L2204', 'L2205', 'L2206', 'L2207', 'L2208', 'L2209', 'L2210', 'L2211']",
#  "u18 +++$+++ u24 +++$+++ m1 +++$+++ ['L1930', 'L1931']",
#  "u18 +++$+++ u24 +++$+++ m1 +++$+++ ['L2112', 'L2113']",
#  "u18 +++$+++ u24 +++$+++ m1 +++$+++ ['L2115', 'L2116']",
#  "u18 +++$+++ u24 +++$+++ m1 +++$+++ ['L2376', 'L2377']",
#  "u18 +++$+++ u24 +++$+++ m1 +++$+++ ['L2414', 'L2415']",
#  "u18 +++$+++ u24 +++$+++ m1 +++$+++ ['L2417', 'L2418', 'L2419']",
#  "u18 +++$+++ u24 +++$+++ m1 +++$+++ ['L2460', 'L2461', 'L2462']",
#  "u26 +++$+++ u30 +++$+++ m2 +++$+++ ['L3380', 'L3381', 'L3382']",
#  "u26 +++$+++ u30 +++$+++ m2 +++$+++ ['L3383', 'L3384', 'L3385']",
#  "u26 +++$+++ u30 +++$+++ m2 +++$+++ ['L3392', 'L3393', 'L3394', 'L3395', 'L3396']",
#  "u26 +++$+++ u30 +++$+++ m2 +++$+++ ['L3459', 'L3460', 'L3461']",
#  "u26 +++$+++ u30 +++$+++ m2 +++$+++ ['L3464', 'L3465', 'L3466', 'L3467', 'L3468', 'L3469', 'L3470', 'L3471', 'L3472', 'L3473', 'L3474', 'L3475', 'L3476', 'L3477', 'L3478', 'L3479', 'L3480', 'L3481']",
#  "u26 +++$+++ u30 +++$+++ m2 +++$+++ ['L3482', 'L3483', 'L3484', 'L3485', 'L3486', 'L3487', 'L3488', 'L3489']",
#  "u26 +++$+++ u30 +++$+++ m2 +++$+++ ['L3490', 'L3491', 'L3492', 'L3493']",
#  "u26 +++$+++ u30 +++$+++ m2 +++$+++ ['L3496', 'L3497']",
#  "u26 +++$+++ u30 +++$+++ m2 +++$+++ ['L3545', 'L3546']",
#  "u27 +++$+++ u34 +++$+++ m2 +++$+++ ['L3059', 'L3060', 'L3061']",
#  "u27 +++$+++ u34 +++$+++ m2 +++$+++ ['L3089', 'L3090', 'L3091', 'L3092']",
#  "u27 +++$+++ u34 +++$+++ m2 +++$+++ ['L3093', 'L3094', 'L3095']",
#  "u27 +++$+++ u34 +++$+++ m2 +++$+++ ['L3096', 'L3097']",
#  "u27 +++$+++ u34 +++$+++ m2 +++$+++ ['L3158', 'L3159', 'L3160']",
#  "u27 +++$+++ u34 +++$+++ m2 +++$+++ ['L3161', 'L3162', 'L3163', 'L3164', 'L3165', 'L3166']",
#  "u27 +++$+++ u34 +++$+++ m2 +++$+++ ['L3167', 'L3168', 'L3169', 'L3170']",
#  "u27 +++$+++ u34 +++$+++ m2 +++$+++ ['L3177', 'L3178', 'L3179', 'L3180', 'L3181']",
#  "u27 +++$+++ u34 +++$+++ m2 +++$+++ ['L3300', 'L3301', 'L3302']",
#  "u27 +++$+++ u34 +++$+++ m2 +++$+++ ['L3305', 'L3306', 'L3307', 'L3308']",
#  "u27 +++$+++ u34 +++$+++ m2 +++$+++ ['L3309', 'L3310', 'L3311']",
#  "u27 +++$+++ u34 +++$+++ m2 +++$+++ ['L3313', 'L3314']",
#  "u27 +++$+++ u34 +++$+++ m2 +++$+++ ['L3315', 'L3316', 'L3317', 'L3318']",
#  "u27 +++$+++ u34 +++$+++ m2 +++$+++ ['L3329', 'L3330']",
#  "u27 +++$+++ u34 +++$+++ m2 +++$+++ ['L3514', 'L3515', 'L3516', 'L3517']",
#  "u27 +++$+++ u29 +++$+++ m2 +++$+++ ['L3045', 'L3046', 'L3047', 'L3048']",
#  "u27 +++$+++ u29 +++$+++ m2 +++$+++ ['L3049', 'L3050', 'L3051']",
#  "u27 +++$+++ u29 +++$+++ m2 +++$+++ ['L3055', 'L3056']",
#  "u27 +++$+++ u29 +++$+++ m2 +++$+++ ['L3062', 'L3063', 'L3064', 'L3065']",
#  "u28 +++$+++ u29 +++$+++ m2 +++$+++ ['L3208', 'L3209', 'L3210', 'L3211', 'L3212', 'L3213', 'L3214']",
#  "u28 +++$+++ u34 +++$+++ m2 +++$+++ ['L2797', 'L2798', 'L2799', 'L2800']",
#  "u28 +++$+++ u34 +++$+++ m2 +++$+++ ['L3196', 'L3197']",
#  "u28 +++$+++ u34 +++$+++ m2 +++$+++ ['L3198', 'L3199', 'L3200', 'L3201', 'L3202', 'L3203']",
#  "u28 +++$+++ u34 +++$+++ m2 +++$+++ ['L3293', 'L3294']",
#  "u28 +++$+++ u34 +++$+++ m2 +++$+++ ['L3498', 'L3499', 'L3500', 'L3501', 'L3502', 'L3503', 'L3504', 'L3505', 'L3506']",
#  "u28 +++$+++ u35 +++$+++ m2 +++$+++ ['L2801', 'L2802', 'L2803', 'L2804', 'L2805']",
#  "u28 +++$+++ u35 +++$+++ m2 +++$+++ ['L3289', 'L3290', 'L3291', 'L3292']",
#  "u29 +++$+++ u36 +++$+++ m2 +++$+++ ['L2599', 'L2600', 'L2601']",
#  "u29 +++$+++ u36 +++$+++ m2 +++$+++ ['L2602', 'L2603']",
#  "u29 +++$+++ u36 +++$+++ m2 +++$+++ ['L2630', 'L2631', 'L2632', 'L2633']",
#  "u29 +++$+++ u36 +++$+++ m2 +++$+++ ['L2751', 'L2752']",
#  "u29 +++$+++ u36 +++$+++ m2 +++$+++ ['L2920', 'L2921', 'L2922', 'L2923']",
#  "u29 +++$+++ u36 +++$+++ m2 +++$+++ ['L2924', 'L2925']",
#  "u29 +++$+++ u36 +++$+++ m2 +++$+++ ['L2936', 'L2937', 'L2938']",
#  "u29 +++$+++ u36 +++$+++ m2 +++$+++ ['L3016', 'L3017']",
#  "u29 +++$+++ u36 +++$+++ m2 +++$+++ ['L3022', 'L3023']",
#  "u29 +++$+++ u36 +++$+++ m2 +++$+++ ['L3027', 'L3028']",
#  "u29 +++$+++ u44 +++$+++ m2 +++$+++ ['L2964', 'L2965', 'L2966', 'L2967']",
#  "u29 +++$+++ u44 +++$+++ m2 +++$+++ ['L2971', 'L2972', 'L2973']",
#  "u29 +++$+++ u44 +++$+++ m2 +++$+++ ['L2975', 'L2976', 'L2977', 'L2978']",
#  "u29 +++$+++ u44 +++$+++ m2 +++$+++ ['L2979', 'L2980', 'L2981']",
#  "u29 +++$+++ u44 +++$+++ m2 +++$+++ ['L2986', 'L2987', 'L2988', 'L2989', 'L2990']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L2730', 'L2731']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L2746', 'L2747', 'L2748']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L2875', 'L2876', 'L2877', 'L2878', 'L2879', 'L2880', 'L2881', 'L2882']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L2883', 'L2884', 'L2885', 'L2886']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L2887', 'L2888', 'L2889', 'L2890', 'L2891']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L2892', 'L2893']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L2895', 'L2896', 'L2897']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L2899', 'L2900', 'L2901', 'L2902', 'L2903', 'L2904', 'L2905', 'L2906']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L2949', 'L2950', 'L2951', 'L2952', 'L2953']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L2955', 'L2956', 'L2957', 'L2958']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L2962', 'L2963']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L2991', 'L2992']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L2993', 'L2994', 'L2995', 'L2996', 'L2997', 'L2998', 'L2999']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L3052', 'L3053', 'L3054']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L3057', 'L3058']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L3067', 'L3068']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L3069', 'L3070', 'L3071', 'L3072', 'L3073', 'L3074', 'L3075', 'L3076', 'L3077', 'L3078', 'L3079']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L3080', 'L3081', 'L3082']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L3219', 'L3220', 'L3221', 'L3222']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L3223', 'L3224', 'L3225', 'L3226', 'L3227', 'L3228']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L3229', 'L3230']",
#  "u29 +++$+++ u30 +++$+++ m2 +++$+++ ['L3236', 'L3237', 'L3238', 'L3239', 'L3240', 'L3241', 'L3242']",
#  "u29 +++$+++ u30 +++$+++ m2 +++$+++ ['L3243', 'L3244']",
#  "u29 +++$+++ u30 +++$+++ m2 +++$+++ ['L3248', 'L3249']",
#  "u29 +++$+++ u41 +++$+++ m2 +++$+++ ['L2758', 'L2759', 'L2760', 'L2761', 'L2762', 'L2763', 'L2764', 'L2765']",
#  "u29 +++$+++ u41 +++$+++ m2 +++$+++ ['L3029', 'L3030']",
#  "u29 +++$+++ u41 +++$+++ m2 +++$+++ ['L3031', 'L3032', 'L3033', 'L3034', 'L3035', 'L3036', 'L3037']",
#  "u29 +++$+++ u41 +++$+++ m2 +++$+++ ['L3038', 'L3039', 'L3040', 'L3041', 'L3042', 'L3043', 'L3044']",
#  "u29 +++$+++ u41 +++$+++ m2 +++$+++ ['L3101', 'L3102']",
#  "u29 +++$+++ u41 +++$+++ m2 +++$+++ ['L3103', 'L3104', 'L3105', 'L3106', 'L3107', 'L3108', 'L3109', 'L3110', 'L3111', 'L3112', 'L3113', 'L3114', 'L3115', 'L3116', 'L3117']",
#  "u29 +++$+++ u41 +++$+++ m2 +++$+++ ['L3119', 'L3120', 'L3121']",
#  "u29 +++$+++ u41 +++$+++ m2 +++$+++ ['L3126', 'L3127', 'L3128', 'L3129', 'L3130']",
#  "u29 +++$+++ u41 +++$+++ m2 +++$+++ ['L3135', 'L3136', 'L3137', 'L3138', 'L3139', 'L3140', 'L3141', 'L3142', 'L3143', 'L3144', 'L3145', 'L3146', 'L3147']",
#  "u29 +++$+++ u41 +++$+++ m2 +++$+++ ['L3148', 'L3149', 'L3150', 'L3151', 'L3152', 'L3153', 'L3154', 'L3155', 'L3156', 'L3157']",
#  "u29 +++$+++ u31 +++$+++ m2 +++$+++ ['L2595', 'L2596']",
#  "u29 +++$+++ u31 +++$+++ m2 +++$+++ ['L2604', 'L2605', 'L2606', 'L2607']",
#  "u29 +++$+++ u31 +++$+++ m2 +++$+++ ['L2611', 'L2612']",
#  "u29 +++$+++ u31 +++$+++ m2 +++$+++ ['L2644', 'L2645']",
#  "u29 +++$+++ u31 +++$+++ m2 +++$+++ ['L2646', 'L2647', 'L2648']",
#  "u29 +++$+++ u31 +++$+++ m2 +++$+++ ['L2651', 'L2652']",
#  "u29 +++$+++ u31 +++$+++ m2 +++$+++ ['L2653', 'L2654', 'L2655', 'L2656']",
#  "u29 +++$+++ u31 +++$+++ m2 +++$+++ ['L2664', 'L2665']",
#  "u30 +++$+++ u45 +++$+++ m2 +++$+++ ['L2621', 'L2622', 'L2623', 'L2624', 'L2625', 'L2626']",
#  "u30 +++$+++ u45 +++$+++ m2 +++$+++ ['L2627', 'L2628']",
#  "u30 +++$+++ u31 +++$+++ m2 +++$+++ ['L3278', 'L3279', 'L3280', 'L3281', 'L3282', 'L3283', 'L3284', 'L3285', 'L3286']",
#  "u30 +++$+++ u34 +++$+++ m2 +++$+++ ['L3419', 'L3420', 'L3421']",
#  "u30 +++$+++ u34 +++$+++ m2 +++$+++ ['L3431', 'L3432']",
#  "u30 +++$+++ u34 +++$+++ m2 +++$+++ ['L3433', 'L3434']",
#  "u30 +++$+++ u34 +++$+++ m2 +++$+++ ['L3435', 'L3436']",
#  "u30 +++$+++ u34 +++$+++ m2 +++$+++ ['L3554', 'L3555', 'L3556']",
#  "u30 +++$+++ u32 +++$+++ m2 +++$+++ ['L2845', 'L2846', 'L2847']",
#  "u30 +++$+++ u32 +++$+++ m2 +++$+++ ['L2848', 'L2849']",
#  "u30 +++$+++ u32 +++$+++ m2 +++$+++ ['L2850', 'L2851', 'L2852', 'L2853', 'L2854']",
#  "u30 +++$+++ u32 +++$+++ m2 +++$+++ ['L2855', 'L2856']",
#  "u30 +++$+++ u32 +++$+++ m2 +++$+++ ['L2857', 'L2858']",
#  "u30 +++$+++ u33 +++$+++ m2 +++$+++ ['L2563', 'L2564']",
#  "u30 +++$+++ u33 +++$+++ m2 +++$+++ ['L2565', 'L2566', 'L2567', 'L2568', 'L2569']",
#  "u30 +++$+++ u33 +++$+++ m2 +++$+++ ['L2570', 'L2571', 'L2572', 'L2573', 'L2574']",
#  "u30 +++$+++ u33 +++$+++ m2 +++$+++ ['L2577', 'L2578', 'L2579', 'L2580', 'L2581']",
#  "u30 +++$+++ u48 +++$+++ m2 +++$+++ ['L2908', 'L2909']",
#  "u30 +++$+++ u48 +++$+++ m2 +++$+++ ['L2910', 'L2911', 'L2912', 'L2913', 'L2914', 'L2915']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L2557', 'L2558']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L2559', 'L2560']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L2561', 'L2562']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L2635', 'L2636', 'L2637', 'L2638']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L2639', 'L2640']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L2666', 'L2667', 'L2668']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L2670', 'L2671']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L2778', 'L2779']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L2780', 'L2781', 'L2782', 'L2783']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L2789', 'L2790']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L2842', 'L2843', 'L2844']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L3083', 'L3084', 'L3085']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L3087', 'L3088']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L3183', 'L3184', 'L3185', 'L3186', 'L3187', 'L3188']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L3189', 'L3190']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L3191', 'L3192', 'L3193']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L3246', 'L3247']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L3250', 'L3251']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L3356', 'L3357']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L3359', 'L3360']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L3361', 'L3362']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L3363', 'L3364']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L3365', 'L3366']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L3368', 'L3369', 'L3370']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L3372', 'L3373', 'L3374', 'L3375']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L3376', 'L3377', 'L3378']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L3547', 'L3548']",
#  "u30 +++$+++ u39 +++$+++ m2 +++$+++ ['L2672', 'L2673']",
#  "u30 +++$+++ u39 +++$+++ m2 +++$+++ ['L2674', 'L2675', 'L2676']",
#  "u30 +++$+++ u39 +++$+++ m2 +++$+++ ['L2678', 'L2679']",
#  "u30 +++$+++ u39 +++$+++ m2 +++$+++ ['L2680', 'L2681', 'L2682']",
#  "u30 +++$+++ u39 +++$+++ m2 +++$+++ ['L2685', 'L2686', 'L2687', 'L2688', 'L2689', 'L2690', 'L2691', 'L2692']",
#  "u31 +++$+++ u37 +++$+++ m2 +++$+++ ['L3271', 'L3272', 'L3273', 'L3274', 'L3275']",
#  "u31 +++$+++ u37 +++$+++ m2 +++$+++ ['L3352', 'L3353']",
#  "u31 +++$+++ u36 +++$+++ m2 +++$+++ ['L2608', 'L2609', 'L2610']",
#  "u31 +++$+++ u36 +++$+++ m2 +++$+++ ['L2614', 'L2615']",
#  "u31 +++$+++ u36 +++$+++ m2 +++$+++ ['L3409', 'L3410']",
#  "u31 +++$+++ u36 +++$+++ m2 +++$+++ ['L3411', 'L3412', 'L3413']",
#  "u31 +++$+++ u41 +++$+++ m2 +++$+++ ['L3262', 'L3263', 'L3264', 'L3265', 'L3266', 'L3267', 'L3268', 'L3269']",
#  "u33 +++$+++ u42 +++$+++ m2 +++$+++ ['L2575', 'L2576']",
#  "u33 +++$+++ u42 +++$+++ m2 +++$+++ ['L2582', 'L2583', 'L2584', 'L2585', 'L2586', 'L2587', 'L2588', 'L2589', 'L2590', 'L2591']",
#  "u34 +++$+++ u36 +++$+++ m2 +++$+++ ['L2732', 'L2733']",
#  "u34 +++$+++ u36 +++$+++ m2 +++$+++ ['L2740', 'L2741', 'L2742', 'L2743']",
#  "u34 +++$+++ u36 +++$+++ m2 +++$+++ ['L2744', 'L2745']",
#  "u34 +++$+++ u36 +++$+++ m2 +++$+++ ['L3398', 'L3399', 'L3400', 'L3401', 'L3402', 'L3403']",
#  "u34 +++$+++ u40 +++$+++ m2 +++$+++ ['L2698', 'L2699', 'L2700']",
#  "u34 +++$+++ u40 +++$+++ m2 +++$+++ ['L2701', 'L2702', 'L2703']",
#  "u34 +++$+++ u40 +++$+++ m2 +++$+++ ['L2706', 'L2707']",
#  "u34 +++$+++ u40 +++$+++ m2 +++$+++ ['L2771', 'L2772', 'L2773']",
#  "u34 +++$+++ u38 +++$+++ m2 +++$+++ ['L2808', 'L2809', 'L2810', 'L2811', 'L2812', 'L2813']",
#  "u34 +++$+++ u35 +++$+++ m2 +++$+++ ['L2715', 'L2716', 'L2717', 'L2718', 'L2719', 'L2720', 'L2721']",
#  "u34 +++$+++ u35 +++$+++ m2 +++$+++ ['L2724', 'L2725']",
#  "u34 +++$+++ u35 +++$+++ m2 +++$+++ ['L2735', 'L2736', 'L2737']",
#  "u34 +++$+++ u35 +++$+++ m2 +++$+++ ['L2738', 'L2739']",
#  "u34 +++$+++ u35 +++$+++ m2 +++$+++ ['L2754', 'L2755', 'L2756', 'L2757']",
#  "u34 +++$+++ u35 +++$+++ m2 +++$+++ ['L2767', 'L2768']",
#  "u34 +++$+++ u35 +++$+++ m2 +++$+++ ['L2793', 'L2794', 'L2795']",
#  "u34 +++$+++ u35 +++$+++ m2 +++$+++ ['L2863', 'L2864', 'L2865']",
#  "u34 +++$+++ u35 +++$+++ m2 +++$+++ ['L2870', 'L2871', 'L2872']",
#  "u34 +++$+++ u35 +++$+++ m2 +++$+++ ['L3024', 'L3025', 'L3026']",
#  "u34 +++$+++ u35 +++$+++ m2 +++$+++ ['L3287', 'L3288']",
#  "u34 +++$+++ u35 +++$+++ m2 +++$+++ ['L3342', 'L3343', 'L3344']",
#  "u34 +++$+++ u47 +++$+++ m2 +++$+++ ['L2928', 'L2929', 'L2930']",
#  "u34 +++$+++ u47 +++$+++ m2 +++$+++ ['L3422', 'L3423', 'L3424']",
#  "u34 +++$+++ u47 +++$+++ m2 +++$+++ ['L3425', 'L3426', 'L3427']",
#  "u43 +++$+++ u46 +++$+++ m2 +++$+++ ['L2828', 'L2829', 'L2830', 'L2831', 'L2832', 'L2833', 'L2834', 'L2835', 'L2836', 'L2837', 'L2838', 'L2839', 'L2840']",
#  "u49 +++$+++ u55 +++$+++ m3 +++$+++ ['L3712', 'L3713']",
#  "u49 +++$+++ u55 +++$+++ m3 +++$+++ ['L3720', 'L3721']",
#  "u49 +++$+++ u55 +++$+++ m3 +++$+++ ['L3728', 'L3729']",
#  "u49 +++$+++ u55 +++$+++ m3 +++$+++ ['L3749', 'L3750']",
#  "u49 +++$+++ u55 +++$+++ m3 +++$+++ ['L3756', 'L3757']",
#  "u49 +++$+++ u55 +++$+++ m3 +++$+++ ['L3770', 'L3771']",
#  "u49 +++$+++ u55 +++$+++ m3 +++$+++ ['L3777', 'L3778']",
#  "u50 +++$+++ u60 +++$+++ m3 +++$+++ ['L3942', 'L3943', 'L3944', 'L3945']",
#  "u50 +++$+++ u60 +++$+++ m3 +++$+++ ['L3963', 'L3964', 'L3965', 'L3966', 'L3967', 'L3968', 'L3969']",
#  "u50 +++$+++ u60 +++$+++ m3 +++$+++ ['L3972', 'L3973', 'L3974', 'L3975', 'L3976']",
#  "u50 +++$+++ u60 +++$+++ m3 +++$+++ ['L3979', 'L3980', 'L3981', 'L3982', 'L3983', 'L3984']",
#  "u50 +++$+++ u60 +++$+++ m3 +++$+++ ['L3987', 'L3988', 'L3989', 'L3990', 'L3991', 'L3992']",
#  "u50 +++$+++ u60 +++$+++ m3 +++$+++ ['L3995', 'L3996', 'L3997', 'L3998', 'L3999', 'L4000', 'L4001']",
#  "u50 +++$+++ u60 +++$+++ m3 +++$+++ ['L4011', 'L4012', 'L4013', 'L4014', 'L4015', 'L4016', 'L4017']",
#  "u50 +++$+++ u60 +++$+++ m3 +++$+++ ['L4159', 'L4160', 'L4161', 'L4162', 'L4163']",
#  "u50 +++$+++ u60 +++$+++ m3 +++$+++ ['L4188', 'L4189', 'L4190', 'L4191', 'L4192', 'L4193']",
#  "u50 +++$+++ u60 +++$+++ m3 +++$+++ ['L4196', 'L4197', 'L4198', 'L4199']",
#  "u50 +++$+++ u60 +++$+++ m3 +++$+++ ['L4208', 'L4209']",
#  "u50 +++$+++ u60 +++$+++ m3 +++$+++ ['L4282', 'L4283']",
#  "u50 +++$+++ u60 +++$+++ m3 +++$+++ ['L4296', 'L4297', 'L4298', 'L4299', 'L4300']",
#  "u50 +++$+++ u56 +++$+++ m3 +++$+++ ['L4006', 'L4007']",
#  "u50 +++$+++ u56 +++$+++ m3 +++$+++ ['L4068', 'L4069', 'L4070']",
#  "u50 +++$+++ u56 +++$+++ m3 +++$+++ ['L4079', 'L4080']",
#  "u50 +++$+++ u56 +++$+++ m3 +++$+++ ['L4219', 'L4220', 'L4221', 'L4222', 'L4223', 'L4224']",
#  "u50 +++$+++ u56 +++$+++ m3 +++$+++ ['L4227', 'L4228', 'L4229', 'L4230']",
#  "u50 +++$+++ u56 +++$+++ m3 +++$+++ ['L4265', 'L4266', 'L4267', 'L4268', 'L4269', 'L4270', 'L4271']",
#  "u50 +++$+++ u56 +++$+++ m3 +++$+++ ['L4333', 'L4334', 'L4335']",
#  "u50 +++$+++ u56 +++$+++ m3 +++$+++ ['L4346', 'L4347', 'L4348', 'L4349', 'L4350']",
#  "u50 +++$+++ u56 +++$+++ m3 +++$+++ ['L4353', 'L4354', 'L4355', 'L4356', 'L4357']",
#  "u50 +++$+++ u56 +++$+++ m3 +++$+++ ['L4360', 'L4361', 'L4362', 'L4363']",
#  "u50 +++$+++ u56 +++$+++ m3 +++$+++ ['L4366', 'L4367', 'L4368']",
#  "u50 +++$+++ u51 +++$+++ m3 +++$+++ ['L3970', 'L3971']",
#  "u50 +++$+++ u51 +++$+++ m3 +++$+++ ['L3977', 'L3978']",
#  "u50 +++$+++ u51 +++$+++ m3 +++$+++ ['L3993', 'L3994']",
#  "u50 +++$+++ u51 +++$+++ m3 +++$+++ ['L4002', 'L4003']",
#  "u50 +++$+++ u51 +++$+++ m3 +++$+++ ['L4009', 'L4010']",
#  "u50 +++$+++ u51 +++$+++ m3 +++$+++ ['L4018', 'L4019']",
#  "u52 +++$+++ u55 +++$+++ m3 +++$+++ ['L3668', 'L3669']",
#  "u52 +++$+++ u55 +++$+++ m3 +++$+++ ['L3672', 'L3673', 'L3674', 'L3675', 'L3676', 'L3677']",
#  "u52 +++$+++ u55 +++$+++ m3 +++$+++ ['L3679', 'L3680', 'L3681', 'L3682', 'L3683', 'L3684', 'L3685']",
#  "u52 +++$+++ u55 +++$+++ m3 +++$+++ ['L3688', 'L3689', 'L3690', 'L3691', 'L3692', 'L3693']",
#  "u53 +++$+++ u59 +++$+++ m3 +++$+++ ['L3797', 'L3798', 'L3799']",
#  "u53 +++$+++ u59 +++$+++ m3 +++$+++ ['L3805', 'L3806', 'L3807', 'L3808', 'L3809', 'L3810']",
#  "u54 +++$+++ u55 +++$+++ m3 +++$+++ ['L3730', 'L3731', 'L3732', 'L3733', 'L3734', 'L3735']",
#  "u54 +++$+++ u55 +++$+++ m3 +++$+++ ['L3758', 'L3759']",
#  "u54 +++$+++ u55 +++$+++ m3 +++$+++ ['L3774', 'L3775', 'L3776']",
#  "u54 +++$+++ u55 +++$+++ m3 +++$+++ ['L3779', 'L3780']",
#  "u55 +++$+++ u58 +++$+++ m3 +++$+++ ['L3622', 'L3623']",
#  "u55 +++$+++ u58 +++$+++ m3 +++$+++ ['L3626', 'L3627', 'L3628', 'L3629', 'L3630', 'L3631']",
#  "u55 +++$+++ u58 +++$+++ m3 +++$+++ ['L3651', 'L3652', 'L3653']",
#  "u55 +++$+++ u61 +++$+++ m3 +++$+++ ['L3724', 'L3725', 'L3726']",
#  "u55 +++$+++ u61 +++$+++ m3 +++$+++ ['L3738', 'L3739', 'L3740']",
#  "u55 +++$+++ u61 +++$+++ m3 +++$+++ ['L3745', 'L3746', 'L3747', 'L3748']",
#  "u55 +++$+++ u61 +++$+++ m3 +++$+++ ['L3751', 'L3752', 'L3753', 'L3754']",
#  "u55 +++$+++ u61 +++$+++ m3 +++$+++ ['L3760', 'L3761', 'L3762', 'L3763']",
#  "u55 +++$+++ u61 +++$+++ m3 +++$+++ ['L3766', 'L3767', 'L3768']",
#  "u55 +++$+++ u61 +++$+++ m3 +++$+++ ['L3772', 'L3773']",
#  "u55 +++$+++ u57 +++$+++ m3 +++$+++ ['L3868', 'L3869']",
#  "u55 +++$+++ u57 +++$+++ m3 +++$+++ ['L3889', 'L3890', 'L3891', 'L3892', 'L3893']",
#  "u55 +++$+++ u57 +++$+++ m3 +++$+++ ['L3896', 'L3897']",
#  "u55 +++$+++ u57 +++$+++ m3 +++$+++ ['L3904', 'L3905', 'L3906', 'L3907']",
#  "u55 +++$+++ u59 +++$+++ m3 +++$+++ ['L3817', 'L3818', 'L3819', 'L3820', 'L3821']",
#  "u55 +++$+++ u59 +++$+++ m3 +++$+++ ['L3824', 'L3825', 'L3826', 'L3827', 'L3828', 'L3829']",
#  "u55 +++$+++ u59 +++$+++ m3 +++$+++ ['L3832', 'L3833', 'L3834']",
#  "u55 +++$+++ u59 +++$+++ m3 +++$+++ ['L3837', 'L3838', 'L3839']",
#  "u56 +++$+++ u60 +++$+++ m3 +++$+++ ['L4020', 'L4021', 'L4022', 'L4023', 'L4024', 'L4025']",
#  "u56 +++$+++ u60 +++$+++ m3 +++$+++ ['L4028', 'L4029', 'L4030', 'L4031', 'L4032', 'L4033']",
#  "u56 +++$+++ u60 +++$+++ m3 +++$+++ ['L4096', 'L4097']",
#  "u56 +++$+++ u60 +++$+++ m3 +++$+++ ['L4108', 'L4109', 'L4110', 'L4111', 'L4112', 'L4113']",
#  "u56 +++$+++ u60 +++$+++ m3 +++$+++ ['L4118', 'L4119']",
#  "u56 +++$+++ u60 +++$+++ m3 +++$+++ ['L4169', 'L4170']",
#  "u56 +++$+++ u60 +++$+++ m3 +++$+++ ['L4174', 'L4175']",
#  "u56 +++$+++ u60 +++$+++ m3 +++$+++ ['L4181', 'L4182', 'L4183']",
#  "u62 +++$+++ u75 +++$+++ m4 +++$+++ ['L5039', 'L5040']",
#  "u62 +++$+++ u75 +++$+++ m4 +++$+++ ['L5041', 'L5042']",
#  "u62 +++$+++ u75 +++$+++ m4 +++$+++ ['L5043', 'L5044']",
#  "u62 +++$+++ u75 +++$+++ m4 +++$+++ ['L5045', 'L5046', 'L5047', 'L5048']",
#  "u63 +++$+++ u71 +++$+++ m4 +++$+++ ['L4897', 'L4898', 'L4899', 'L4900']",
#  "u63 +++$+++ u71 +++$+++ m4 +++$+++ ['L4903', 'L4904', 'L4905', 'L4906']",
#  "u63 +++$+++ u71 +++$+++ m4 +++$+++ ['L4922', 'L4923']",
#  "u63 +++$+++ u71 +++$+++ m4 +++$+++ ['L4924', 'L4925']",
#  "u64 +++$+++ u69 +++$+++ m4 +++$+++ ['L4453', 'L4454']",
#  "u64 +++$+++ u69 +++$+++ m4 +++$+++ ['L4501', 'L4502', 'L4503', 'L4504', 'L4505']",
#  "u64 +++$+++ u69 +++$+++ m4 +++$+++ ['L4506', 'L4507', 'L4508', 'L4509', 'L4510', 'L4511']",
#  "u64 +++$+++ u69 +++$+++ m4 +++$+++ ['L4562', 'L4563']",
#  "u64 +++$+++ u69 +++$+++ m4 +++$+++ ['L4567', 'L4568']",
#  "u65 +++$+++ u71 +++$+++ m4 +++$+++ ['L5175', 'L5176', 'L5177', 'L5178', 'L5179', 'L5180']",
#  "u65 +++$+++ u71 +++$+++ m4 +++$+++ ['L5181', 'L5182']",
#  "u65 +++$+++ u71 +++$+++ m4 +++$+++ ['L5183', 'L5184', 'L5185', 'L5186', 'L5187', 'L5188']",
#  "u65 +++$+++ u71 +++$+++ m4 +++$+++ ['L5193', 'L5194']",
#  "u65 +++$+++ u71 +++$+++ m4 +++$+++ ['L5215', 'L5216']",
#  "u65 +++$+++ u71 +++$+++ m4 +++$+++ ['L5366', 'L5367', 'L5368']",
#  "u65 +++$+++ u71 +++$+++ m4 +++$+++ ['L5370', 'L5371']",
#  "u66 +++$+++ u67 +++$+++ m4 +++$+++ ['L4944', 'L4945']",
#  "u66 +++$+++ u67 +++$+++ m4 +++$+++ ['L4959', 'L4960']",
#  "u66 +++$+++ u67 +++$+++ m4 +++$+++ ['L5316', 'L5317', 'L5318']",
#  "u66 +++$+++ u67 +++$+++ m4 +++$+++ ['L5321', 'L5322', 'L5323', 'L5324', 'L5325']",
#  "u66 +++$+++ u67 +++$+++ m4 +++$+++ ['L5328', 'L5329']",
#  "u67 +++$+++ u69 +++$+++ m4 +++$+++ ['L4628', 'L4629']",
#  "u67 +++$+++ u69 +++$+++ m4 +++$+++ ['L5338', 'L5339', 'L5340']",
#  "u67 +++$+++ u69 +++$+++ m4 +++$+++ ['L5346', 'L5347', 'L5348']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L4727', 'L4728', 'L4729']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L4731', 'L4732']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L4739', 'L4740', 'L4741']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L4743', 'L4744', 'L4745', 'L4746', 'L4747', 'L4748', 'L4749', 'L4750', 'L4751']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L
",
#  "u84 +++$+++ u85 +++$+++ m5 +++$+++ ['L6267', 'L6268', 'L6269', 'L6270']",
#  "u84 +++$+++ u85 +++$+++ m5 +++$+++ ['L6289', 'L6290', 'L6291', 'L6292', 'L6293']",
#  "u84 +++$+++ u85 +++$+++ m5 +++$+++ ['L6297', 'L6298', 'L6299', 'L6300', 'L6301']",
#  "u84 +++$+++ u85 +++$+++ m5 +++$+++ ['L6302', 'L6303', 'L6304', 'L6305']",
#  "u84 +++$+++ u85 +++$+++ m5 +++$+++ ['L6308', 'L6309']",
#  "u84 +++$+++ u97 +++$+++ m5 +++$+++ ['L5722', 'L5723', 'L5724', 'L5725', 'L5726']",
#  "u84 +++$+++ u97 +++$+++ m5 +++$+++ ['L5728', 'L5729']",
#  "u84 +++$+++ u89 +++$+++ m5 +++$+++ ['L5531', 'L5532', 'L5533']",
#  "u84 +++$+++ u89 +++$+++ m5 +++$+++ ['L5534', 'L5535', 'L5536']",
#  "u84 +++$+++ u89 +++$+++ m5 +++$+++ ['L5537', 'L5538']",
#  "u84 +++$+++ u89 +++$+++ m5 +++$+++ ['L5539', 'L5540']",
#  "u87 +++$+++ u90 +++$+++ m5 +++$+++ ['L5560', 'L5561', 'L5562', 'L5563', 'L5564', 'L5565', 'L5566', 'L5567']",
#  "u87 +++$+++ u90 +++$+++ m5 +++$+++ ['L5568', 'L5569', 'L5570']",
#  "u87 +++$+++ u90 +++$+++ m5 +++$+++ ['L5573', 'L5574']",
#  "u87 +++$+++ u90 +++$+++ m5 +++$+++ ['L5585', 'L5586']",
#  "u87 +++$+++ u90 +++$+++ m5 +++$+++ ['L6313', 'L6314']",
#  "u90 +++$+++ u91 +++$+++ m5 +++$+++ ['L5767', 'L5768', 'L5769', 'L5770']",
#  "u90 +++$+++ u91 +++$+++ m5 +++$+++ ['L5773', 'L5774']",
#  "u90 +++$+++ u91 +++$+++ m5 +++$+++ ['L6254', 'L6255']",
#  "u91 +++$+++ u96 +++$+++ m5 +++$+++ ['L5441', 'L5442']",
#  "u91 +++$+++ u96 +++$+++ m5 +++$+++ ['L5443', 'L5444', 'L5445', 'L5446', 'L5447']",
#  "u91 +++$+++ u96 +++$+++ m5 +++$+++ ['L5448', 'L5449', 'L5450', 'L5451', 'L5452', 'L5453']",
#  "u91 +++$+++ u96 +++$+++ m5 +++$+++ ['L5479', 'L5480']",
#  "u92 +++$+++ u93 +++$+++ m5 +++$+++ ['L5396', 'L5397', 'L5398']",
#  "u92 +++$+++ u93 +++$+++ m5 +++$+++ ['L5399', 'L5400']",
#  "u92 +++$+++ u93 +++$+++ m5 +++$+++ ['L5404', 'L5405']",
#  "u92 +++$+++ u93 +++$+++ m5 +++$+++ ['L5406', 'L5407']",
#  "u94 +++$+++ u99 +++$+++ m5 +++$+++ ['L6219', 'L6220', 'L6221', 'L6222', 'L6223', 'L6224', 'L6225']",
#  "u95 +++$+++ u99 +++$+++ m5 +++$+++ ['L6002', 'L6003']",
#  "u95 +++$+++ u99 +++$+++ m5 +++$+++ ['L6004', 'L6005']",
#  "u95 +++$+++ u99 +++$+++ m5 +++$+++ ['L6006', 'L6007', 'L6008', 'L6009']",
#  "u95 +++$+++ u99 +++$+++ m5 +++$+++ ['L6011', 'L6012']",
#  "u100 +++$+++ u114 +++$+++ m6 +++$+++ ['L6335', 'L6336']",
#  "u100 +++$+++ u114 +++$+++ m6 +++$+++ ['L6337', 'L6338', 'L6339', 'L6340', 'L6341', 'L6342', 'L6343', 'L6344']",
#  "u100 +++$+++ u114 +++$+++ m6 +++$+++ ['L6347', 'L6348', 'L6349', 'L6350']",
#  "u100 +++$+++ u114 +++$+++ m6 +++$+++ ['L
",
#  "u110 +++$+++ u114 +++$+++ m6 +++$+++ ['L6473', 'L6474', 'L6475', 'L6476', 'L6477']",
#  "u110 +++$+++ u114 +++$+++ m6 +++$+++ ['L6479', 'L6480', 'L6481']",
#  "u110 +++$+++ u114 +++$+++ m6 +++$+++ ['L6482', 'L6483']",
#  "u110 +++$+++ u114 +++$+++ m6 +++$+++ ['L6485', 'L6486', 'L6487', 'L6488', 'L6489', 'L6490', 'L6491', 'L6492', 'L6493', 'L6494', 'L6495', 'L6496', 'L6497', 'L6498', 'L6499', 'L6500', 'L6501', 'L6502']",
#  "u110 +++$+++ u114 +++$+++ m6 +++$+++ ['L6503', 'L6504']",
#  "u110 +++$+++ u114 +++$+++ m6 +++$+++ ['L6507', 'L6508']",
#  "u110 +++$+++ u114 +++$+++ m6 +++$+++ ['L6511', 'L6512', 'L6513', 'L6514', 'L6515']",
#  "u110 +++$+++ u114 +++$+++ m6 +++$+++ ['L6516', 'L6517', 'L6518', 'L6519', 'L6520', 'L6521', 'L6522', 'L6523', 'L6524']",
#  "u110 +++$+++ u114 +++$+++ m6 +++$+++ ['L6525', 'L6526', 'L6527', 'L6528']",
#  "u110 +++$+++ u114 +++$+++ m6 +++$+++ ['L6531', 'L6532']",
#  "u110 +++$+++ u114 +++$+++ m6 +++$+++ ['L6534', 'L6535', 'L6536']",
#  "u110 +++$+++ u114 +++$+++ m6 +++$+++ ['L7081', 'L7082', 'L7083', 'L7084']",
#  "u110 +++$+++ u114 +++$+++ m6 +++$+++ ['L7085', 'L7086', 'L7087']",
#  "u110 +++$+++ u114 +++$+++ m6 +++$+++ ['L7088', 'L7089', 'L7090', 'L7091', 'L7092', 'L7093', 'L7094', 'L7095', 'L7096', 'L7097', 'L7098']",
#  "u111 +++$+++ u114 +++$+++ m6 +++$+++ ['L6657', 'L6658', 'L6659']",
#  "u111 +++$+++ u114 +++$+++ m6 +++$+++ ['L6661', 'L6662']",
#  "u111 +++$+++ u114 +++$+++ m6 +++$+++ ['L6665', 'L6666', 'L6667', 'L6668']",
#  "u111 +++$+++ u114 +++$+++ m6 +++$+++ ['L6669', 'L6670', 'L6671']",
#  "u112 +++$+++ u114 +++$+++ m6 +++$+++ ['L6354', 'L6355', 'L6356', 'L6357']",
#  "u112 +++$+++ u114 +++$+++ m6 +++$+++ ['L6358', 'L6359', 'L6360']",
#  "u113 +++$+++ u114 +++$+++ m6 +++$+++ ['L6676', 'L6677', 'L6678']",
#  "u113 +++$+++ u114 +++$+++ m6 +++$+++ ['L6679', 'L6680', 'L6681']",
#  "u113 +++$+++ u114 +++$+++ m6 +++$+++ ['L6682', 'L6683', 'L6684']",
#  "u115 +++$+++ u121 +++$+++ m7 +++$+++ ['L8029', 'L8030', 'L8031', 'L8032']",
#  "u115 +++$+++ u121 +++$+++ m7 +++$+++ ['L8033', 'L8034', 'L8035']",
#  "u115 +++$+++ u121 +++$+++ m7 +++$+++ ['L8036', 'L8037']",
#  "u115 +++$+++ u121 +++$+++ m7 +++$+++ ['L8094', 'L8095', 'L8096', 'L8097']",
#  "u115 +++$+++ u121 +++$+++ m7 +++$+++ ['L8155', 'L8156']",
#  "u115 +++$+++ u121 +++$+++ m7 +++$+++ ['L8196', 'L8197', 'L8198', 'L8199']",
#  ...]

# %% [markdown]
# Explaining with an example :
#
# Each row corresponds to one conversation between any two characters.
#
# u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L194', 'L195', 'L196', 'L197']
#
# Here the conversation is between user 0 and user 2 in movie 0
#
# And the key identifiers : ['L194', 'L195', 'L196', 'L197'] help us to locate the actual conversations that have taken place between the two users from the lines dataset

# %% [markdown]
# # Creating a dictionary that maps each line and its id

# %% [markdown]
# We want to create a dataset composing of input and outputs, and the easiest way to do that is by maintaining a dictionary.
#
# We want to map each line with it's ID.
#
# So the key identifier of the dictionary will be the ID of the line and the value will be the line itself.
#
# 1. declare an empty dictionary
#
# 2. iterate through all the lines of the "lines" dataset
#     a)now for each of the lines, split the line with respect to " +++$+++ "
#
#     b)now get the first element and place it as the key, and get the last value       and place it as the value
#
#     c) we are just placing an if statement to ensure that the line has 5              elements for splitting, else we might face some shfiting issue

# %%
id2line = {}
#iterate through all lines in the lines dataset
for line in lines:
    _line = line.split(' +++$+++ ')
    if len(_line) == 5:
        id2line[_line[0]] = _line[4]

# %% [markdown]
# Let's have a look at the dictionary we created in the above step

# %%
id2line
# Out:
# {'L169795': 'And?',
#  'L261935': 'Dad!',
#  'L341879': 'What do you see, Starling?',
#  'L306525': 'Please -- was at the time brandishing your firearm, trying in his rage to shoot an acquaintance -- friend of long standing --',
#  'L612204': 'AH UGH.',
#  'L73334': 'Bruce Wayne. In the flesh.',
#  'L295910': "All I want's the money.",
#  'L618251': 'Fifteen seconds. Perhaps you should consider hiring an attorney.',
#  'L543134': "I don't care where you're from you just can't disappear into thin air.",
#  'L30322': 'Oh - excuse me!',
#  'L315986': 'What are you doing?',
#  'L640678': 'It was an accident!',
#  'L437615': "Ooo, she's thinking of her date!  Come on, you've been dating a pilot.  We want to know what we can expect.",
#  'L113055': "Totally understood.  Totally wrong of me to talk shop after the day you've had.  Totally sorry.",
#  'L310837': "Why, Peter! Don't you want to hear about our lovely friends?",
#  'L352645': "I don't remember exactly... except I was a Green.  What would you like to relive, Logan?",
#  'L549013': "Annabelle, how's your video rep...",
#  'L10324': 'Lins, stay away from that guy.  I mean it.',
#  'L485773': "I don't know anybody who'd be interested in that.",
#  'L361665': 'Go fuck myself?',
#  'L62699': "That's right.  Money turns the wheel.",
#  'L396666': 'We stayed a little longer than expected with Mr and Mrs Grant.  It was most agreeable.',
#  'L309102': 'Some village in the mountains -- Alethera, I think.',
#  'L383159': 'The coat? A guy I did a favor once gave it to me. Christ.',
#  'L478554': "Look, man I'm sorry.  I know you got a thing for her.",
#  'L306870': "Exactly. And then -- maybe -- not right away -- There's a room right off the bedroom -- It would be perfect for a nursery.  It's a walk in humidor right now -- but if I took out the refrigeration unit --",
#  'L81436': 'We are not far...  ... our chairs almost touch.',
#  'L213134': 'The first rule of Project --',
#  'L663129': 'Know what happens when a man is strangled?',
#  'L596669': 'No. And before you ask, no, hes not gay! He has had girlfriends, but nothing serious...',
#  'L504599': '"The Day After Yesterday."',
#  'L362049': 'Bite it, Cynthia.  You could get free things from people that want you to endorse their products.',
#  'L565891': 'The man in jail is always for freedom.',
#  'L349570': "I'd be in Tahoe having fun if you had given up.",
#  'L221289': 'He deserves a show. He missed the movie.',
#  'L18755': 'You have great tits.',
#  'L219156': 'Like this?',
#  'L197944': "If he came to me for spritual help, I'd say no.",
#  'L653431': 'That bastard Pucinski...',
#  'L184761': "No, now I can't kill you.",
#  'L229122': "Well good, that's very... nice.",
#  'L362385': "You're a friend of the family I presume?",
#  'L3375': "Yes.  But there's only one problem - you want credit but the problem is - I don't share credit.",
#  'L219410': "Kareem's in the wash. I need a favor.",
#  'L440869': "Joe. I don't care a whit about your private life.",
#  'L474933': "There's a lot of things I don't see any sense to. But make up your mind. Learn to read or --  -- go back and watch the horses.",
#  'L368735': 'Which part? That or the day-to-day.',
#  'L48249': "I am -- I'm Captain B.L. Willard. This is Chief Warrant Officer Phillips -- it's his boat. We were shot up bad downriver and need repairs and food -- we can pay you in gold.",
#  'L479682': 'How romantic.',
#  'L522285': 'Urdu and Hindi.',
#  'L599645': 'T-w~e-l-v~e.',
#  'L513642': 'What?',
#  'L517113': "Seven acres.  I'm wonderin' what you'd pay for 'em.  Just curious, is all.",
#  'L361599': "I'm not askin', Marcie.",
#  'L117571': "Some kid hittin' .300 in Lynchburg ...probably a bust.",
#  'L514410': "It fizzled, baby. That's the way it goes. But we had our times, didn't we? It wasn't all bad.",
#  'L187784': 'Hang on...',
#  'L67626': "How's your shoulder?",
#  'L146372': 'Have you been in contact with the principal about your job?',
#  'L509732': "I'm ready to communicate with you now.",
#  'L34085': 'Um...Chris --',
#  'L46619': 'Baxter?',
#  'L454919': "It's fine.",
#  'L317969': 'Goodbye old friend.',
#  'L261839': "I need an antihistamine.  Mom thinks she's feeling her asthma, and so...",
#  'L140722': "He doesn't know you're up there!  Just stay right where you are!  Call the police!",
#  'L291724': "Look, I thought we were all right on this, Maura.  It's over.  You know that.",
#  'L108118': 'Good luck.',
#  'L305088': 'Who?',
#  'L262329': "No, I don't have time.",
#  'L350431': 'Did you just talk?',
#  'L401903': "You don't. It's random, there no trick.",
#  'L287929': "I've got the boy on the phone.  He's using a cell phone.  What was that, son?  I didn't hear you.",
#  'L232033': 'You worried about the cost?',
#  'L388735': 'In position.  Jack open the door, let the package roll.',
#  'L232002': "It's not safe.  I shouldn't have brought you here.",
#  'L5949': "Sometimes you can't learn everything from a screen..sometimes it's better to ask someone who has experience..",
#  'L311218': "You don't have to eat the carrots.  Just passed a pond with some ducks in it.",
#  'L176380': 'You do though, you look great.',
#  'L92621': 'Well, do we just go on up?!',
#  'L412234': "I ain't trying to rob you...",
#  'L295906': "It's what Eddie wants. He, uh, told me to give you some money.",
#  'L593039': "For dinner.  Unless I call and tell them we're still in New Hampshire.",
#  'L157247': 'Oh yeah.  Sure.  Valedictorian, National Merit Scholar',
#  'L180394': 'I meant no harm, it was the only place where I could find cardboard. I thought it has been thrown away.',
#  'L536209': 'No, Spock. It means he feels safer about your "guesses" than most other peoples facts.',
#  'L194472': "It's you! It's you who can't commit to anything! You have no idea how lucky you are I'm interested in you! I don't even know why I am! I should just end it right here, Joel. Leave you in the zoo. Maybe you could find a nice sloth to hang out with!",
#  'L101990': 'I felt it would bring closure to our relationship!',
#  'L230092': 'A little drastic maybe?',
#  'L81592': 'Will you be leaving now, Robert?',
#  'L480107': "Bob's in a hurry.",
#  'L609862': "You don't have to imagine it.  Not anymore.  Now all you've got to think up is what it's going to buy you.",
#  'L623341': "It's certainly a phenomenon in all walks of life.",
#  'L542412': 'We must hurry to the base.  We have little time before the Death Star arrives.',
#  'L600144': 'Meaning?',
#  'L115136': 'Would you sleep with them?',
#  'L276110': 'Must be nice.',
#  'L65926': 'No kidding, bright boy  we smelt Mundt all over this. Was he the idea man?',
#  'L345227': 'Name?',
#  'L162794': 'Ok, dudes, follow my lead.',
#  'L313441': "Not really. We didn't have much to say to each other anyway. I never got to know him that well, but I knew enough to know I wasn't missing much. I keep that, because of all the fuckin' time I was there, that's the only picture I got of me in Japan.  That's Japan.",
#  'L400552': 'You feel violated?',
#  'L118557': 'Is that a serious offer?',
#  'L101898': "He probably knew you'd end up nailing the fat guy, maybe one or two more, but he had to know you weren't walking out of there. Figure it out. Shooter's dead on the scene. No in-depth investigation. It'd slide right off his back. 'Cause as much as I love ya, you're not exactly Don Corleone. What would he be losing? A thirty- five year old delivery boy?",
#  'L446935': "Who hasn't--one way or another?",
#  'L423677': "Georgia. In case I didn't tell you, it's cash only, gentlemen.",
#  'L43827': 'Enough about me.',
#  'L112676': 'Mary said you might be coming.',
#  'L29381': "--quit equivocating, say what you mean--  --our story got Government Accounting to start an audit on CREEP's finances--",
#  'L296016': "No -- she just runs the place. She's everything else -- amazing woman, mother.  You'll like her.",
#  'L434744': 'What about us?  What if she has a gun?',
#  'L455023': "That's great -- Hawaii. I was thinking about going there.",
#  'L296501': 'It comes back.  Flashes.  My name.',
#  'L328166': "Shit!  Forgot to glue this fuckin' rug today.  You know, at one time I even had a full head of hair like everyone else.  And then I lost that. That fuckin' Clay Shaw.  I hate the bastard.  All I got left is in his rotten, bloody hands.  He tipped the newspapers - I know it.  That's how the Agency works.  They use people, chew them up, spit 'em out.  Now it's my turn.",
#  'L392101': 'My liege,  I am honored.',
#  'L451108': "He wouldn't say.  Edward... I think we got him.  His nuts are on the block and <u>we got him</u>.  You there?",
#  'L470995': "So what's your next move, Valiant?",
#  'L433843': 'His assistant.',
#  'L45939': "How dare you speak to me like that? I'm the Princess!",
#  'L116760': "Three-fourteen?  Hmmm...  Look't those thighs, Jackson",
#  'L380217': 'No.  You gonna give me phony reassurances?',
#  'L613811': 'Yes, madame?',
#  'L267203': 'I was afraid to ask.',
#  'L533134': "I wouldn't talk about things like that.",
#  'L234891': 'Sorry about your father.',
#  'L368859': 'Federal Bureau of Investigation, Tenth and Pennsylvania, Washington, D.C.',
#  'L221719': "I'm sure you'll see it my way in the end.",
#  'L412337': 'I hope to God that dog is happy.',
#  'L103731': "You think I'm improving?",
#  'L144948': "I'm gonna drop charges on the break-and-enter at Hudson's...",
#  'L154054': "And when the fog lifted, there's Darren with his head under Justine's skirt.",
#  'L251139': "No, Benjamin. I don't hate him. Unhook my blouse.",
#  'L73635': "I don't mind the work. Pity I can't see behind the mask.",
#  'L358695': '...the ark sank, the sun set, the ark sank again...',
#  'L619248': 'How do you feel?',
#  'L85074': 'Well--yeah, I guess--',
#  'L502145': "So what? You don't love him, do you? Answer me.",
#  'L496276': "I don't know. That's why I came to see Mrs. Redi. I'm trying to find her.",
#  'L621222': "Shouldn't they be there by now? What's taking them so long?!",
#  'L233342': "His shrink's trainer.",
#  'L97071': 'Yes.',
#  'L182342': 'I need to speak to you.',
#  'L282203': 'Oh yes, more than enough.',
#  'L87891': 'Nerves of steel.',
#  'L601048': 'Hooker!',
#  'L344030': 'Yes... I guess I knew that.',
#  'L305718': 'You dress me like a doll. You make my hair like a doll. Why?',
#  'L344981': "It's Elle!  Guess what I'm doing right this second?",
#  'L477859': 'What?!',
#  'L202980': 'Youre not married, are you?',
#  'L426016': "Where's Tommy?",
#  'L601527': "Nothin'.  I told ya everything there is.",
#  'L117249': 'I was great, eh?',
#  'L382229': 'What if you have the foggiest clue as to where the queen is?',
#  'L230811': 'So did I.',
#  'L554412': 'Diane?  Diane!',
#  'L3359': 'In movie they make of us, who do you think would act me?',
#  'L164757': "Dan'l Webster?",
#  'L376799': 'What a night.',
#  'L218449': "Would you tell her Bobby's here?",
#  'L96053': 'Shortly after I arrived at Danbury Federal Correctional Institute I related to Diego that the crime I was in for was smuggling marijuana. Diego told me he had high level connections in Colombia and they needed to find someone to help them transport cocaine into America...',
#  'L402658': 'Does he love her?',
#  'L410260': 'On a good run... yeah.',
#  'L560343': 'I know, but  --',
#  'L347726': 'How much time does that give us?',
#  'L317665': 'Asshole that does not count as a kill.',
#  'L242102': 'I take it this file is still open.',
#  'L115723': 'I crashed your party.',
#  'L42650': 'My head is throbbing.',
#  'L300118': "Are you crazy, a lift raft?! We're not sinking, we're crashing!",
#  'L24501': "A man, a human, was wiring it to your car.  I didn't get a good look at him.  I must call my wife...",
#  'L431': "Don't make me do it, man",
#  'L599452': "She's stunted, that's one thing.",
#  'L508271': 'Our lives are simple.  We have little need for material possessions.',
#  'L399979': "Or maybe it wasn't an accident at all --",
#  'L46965': 'Stop that, Fran.',
#  'L421400': "They sell tickets to an impeachment. Like a fucking circus ... Okay, so they impeach me.  Then it's a question of mathematics.  How many votes do we have in the Senate?",
#  'L172061': "I'll keep the greetings -- but you can send back the good will... what we need right now is twenty million dollars.",
#  'L434751': 'Different tables.',
#  'L61296': "I don't recall ever seeing it before.",
#  'L571223': "He'll find us, won't he?",
#  'L115594': "My bike!  She's a lesbian, too. She told me.",
#  'L324358': 'Chicken....',
#  'L187978': '"The fifth one this week"!',
#  'L63440': 'What?',
#  'L376903': "I'm sorry... um... ?",
#  'L183054': "He didn't.",
#  'L164267': "No, Jabez -- all I need is some rest -- You go and pay our debt. Everything'll be all right then ... everything.",
#  'L182363': "Rollo's the reason I became a cop. I wanted to catch the guys who thought they could get away with it.  It was supposed to be about truth and justice and Rollo.  But somewhere along the way I forgot all that... How about you, Jack? Why'd you become a cop?",
#  'L511178': 'I --',
#  'L410444': "You know why Linda's dead. She loved you and you let her down. It's that simple. Of course I did instigate certain events. Calculated the variables. I found her to be... expendable.",
#  'L430177': 'You gave it your best shot.  You tried.',
#  'L499073': 'No, then.',
#  'L68636': "You're asking me this because of the 'lapdog' remark. I read that. The person that wrote that has the compassion of a housefly. That's your enemy, not your audience. Your audience hasn't even been born yet. It's a lie that art is popular. The only thing popular about it is that it's written about in newspapers. I'm surprised when anybody comes to my openings. There're about ten people on the planet who know anything about painting, and Andy's one of them.",
#  'L187988': 'Halfdan the Black.',
#  'L481649': 'Backward.',
#  'L10239': "Hey, Lins...  I'm glad your here.",
#  'L501036': "Hey, I'm, you know --",
#  'L103590': 'What?',
#  'L258003': 'Okay.',
#  'L564979': "That won't happen, Billy.  Mitch Stephens' case is small, compared to some of those other guys.  The way he told me, all he needs is for you to say what you saw that day, driving behind the bus.  I know it's a painful thing to do, but it'll only take a few minutes of your time.  That'll be the end of it.",
#  'L360446': "We'll kill Fairfax this year.",
#  'L188192': "I can't swim! I can't swim!",
#  'L430553': "I'm sure.  And Kate, thank you for coming.  Thank you for being such a good friend.",
#  'L450777': 'The Rex.',
#  'L280128': "I dunno.  Didn't think about it, really.  It was the asking that was the important thing.",
#  'L630761': 'Norma, are you alright?',
#  'L461852': 'This is Doyle, Jeff.',
#  'L66680': 'Dunbar says you were.',
#  'L508391': 'Oh, right.  At my old place, we used to... wash cars.  Groom dogs.  So... nice loom.',
#  'L261055': "I'm getting the children out of here. At least until we know what we're dealing with.  John, I want you to come with us.",
#  'L260250': 'Your lucky.  I wish she could do the same for me.',
#  'L12486': "I'm sure, I'm positive it didn't happen the way Jack says it did.",
#  'L103430': 'Really. OK, Dad. But seriously, Anthony. These are fast shoes.',
#  'L232329': 'What can he do?  The British have massive superiority.',
#  'L290158': "Y'all find us country people real funny like don't ya... well, God damn pack up the mule and sling me some grits, I'ze a gotta get me some schooling.",
#  'L206358': "We've got a -",
#  'L85292': "Who the fuck are you?  Why've you been following me?  Come on, fuckhead!",
#  'L611876': "No way. No fuckin' way.",
#  'L511142': "It's you. You and your father.",
#  'L527326': 'I think I do.',
#  'L363027': "DADDY! DAD! DAD WHAT THE HELL IS GOIN' ON?",
#  'L491077': 'Is there a killer loose?',
#  'L482628': "Hey, you did the right thing. You wouldn't have stood a chance against these boys by yourself. They have eaten your ass alive.",
#  'L566234': 'Oh... right.',
#  'L228113': 'To keep the daylight out! This is where they sleep! Get to the door!',
#  'L413121': 'Keep the change.',
#  'L600053': 'Nah.',
#  'L233916': "Yeah. There's a girl in it now.",
#  'L507468': 'What?... What did you say?',
#  'L450989': "Thunder's a horse.  Come on.",
#  'L135426': "The Dante Hicks Dinner and a Movie Date. I think I've been on that one before.",
#  'L137761': "Nobody's got anything on me, brother, sir. I've been out of the rookers of the milicents for a long time now.",
#  'L275098': 'Come to Daddy.',
#  'L348442': "Hundred and Sixty First Street? That's Yankee Stadium.",
#  'L87319': "Look, you need Ich.  I've been here five years and I still can't read all the street signs.",
#  'L61850': 'Take your money? This guy will blow up your house and everyone in it!',
#  'L527667': 'She was supposed to be watching the sensor for me.',
#  'L485302': 'What the hell?!',
#  'L259236': "But you've created a virus that's going to cause a worldwide ecological disaster, just to arrest some hacker kid?",
#  'L587785': 'The Bijou?',
#  'L648101': 'You got it.',
#  'L393361': 'How nice. How do you do, Senator?',
#  'L223385': "I don't...",
#  'L338071': "Ah, Charley and I are...Well, we're thinking about...I mean, actually we're sort of talking about maybe getting back together.",
#  'L202221': 'Look Jack, in my experience the best way people deal with this is to just relax and breathe through it...let it come to you.',
#  'L175247': 'Tor!',
#  'L287769': 'Yes, sir.',
#  'L147726': "My friend Li Mu Bai.  He's given it to Sir Te as a gift.",
#  'L130606': 'I said the truth!',
#  'L199268': 'I mean maybe you should check with us before you go off and book us a month in advance.',
#  'L371878': 'We could steal one of the choppers.',
#  'L567018': "Why didn't you call?",
#  'L651860': 'Ladies first.  I insist.',
#  'L565696': "Susie, you're very much in my thoughts today.",
#  'L95573': 'What the fuck is going on?  When did you get out of jail?',
#  'L339516': "You don't think I love you?",
#  'L483289': "You know Wade was the eleventh of the twelve, you're the last one still alive.",
#  'L165028': "Ma says breakfast's ready, Mr. Webster!",
#  'L652477': 'What do you want me to do?',
#  'L6741': "I don't know if luck's the word. Are you feeling alright?",
#  'L395473': 'Yes. Have you any peculiar characteristics when you are creating?',
#  'L180368': 'Friends. Ah yes, friends! How nice.',
#  'L51513': "I'm on the last page. How do you spell conscience?",
#  'L504264': "Christine's dad -- he's been talking about bringing me into his property business. Showing me the ropes. And that's something, considering how long it took him to get over I'm not Armenian. So I'm thinking about it. But I don't know, might get a little incestuous. But Mike does pretty well. A lot of high-end commercial stuff.",
#  'L239761': 'Thanks.  Coming from you that really means a lot to me.',
#  'L34448': '...Guess what?',
#  'L250651': 'Mrs. Robinson -- you are trying to seduce me.',
#  'L426346': "Boys, we was chained together. I hadda tell ya somethin'. Bustin' out alone was not a option!",
#  'L250661': "We'll forget it right now. Finish your drink.",
#  'L248529': 'I bet you say that to all the girls...',
#  'L387636': 'Will she still love him with that special perfect love?',
#  'L104008': 'No. Bob did.',
#  'L130231': "Doesn't that strike you as odd?",
#  'L294647': 'Shall we close up, then?',
#  'L662316': "It's hard to describe.",
#  'L173278': 'You had some questions.',
#  'L197739': 'Are you planning to be home soon? LA, I mean.',
#  'L447733': "It's too weird David. This place is giving me the creeps. Did you know all the books are blank?",
#  'L134256': "There's a part of a Scotch castle over there, but we haven't bothered to unwrap it.",
#  'L507091': 'You look very grown up.  What are you doing?  You meeting your mom for dinner?',
#  'L134857': 'I guess not.',
#  'L595110': 'We gotta be inconspicuous.  Do you know what that means?',
#  'L621753': 'I got it, Woody!',
#  'L262153': "But there's nothing wrong with you.",
#  'L395713': 'The drums. He taught me to play some.',
#  'L497117': 'Graham is an unusual name.',
#  'L281788': 'Seven years ago I interviewed a guy. He said he saw two men fighting in an alley with swords.  One cut off the others head.  He shot the surviving guy twenty times and he got right back up and stabbed him.',
#  'L329900': "Wow! It's magical.",
#  'L294881': 'Go the fuck away, Rosie.',
#  'L6373': 'Apparently Mr. Longdale has something he feels he simply must say before you and I speak.',
#  'L187940': "What does that matter? But you've... you've... FELT like this before...",
#  'L227605': "Yeah, I saw the border. Through binoculars from on top of a high building. That's about as close as I risked getting. What's the TV say?",
#  'L89534': "Listen to your father, Jason. It's going to be a better world.",
#  'L358880': 'Thanks for handling this.',
#  'L402743': "NO!, He's fine.  Fish are very resilient animals you know. Don't worry, I won't get another fish.",
#  'L470568': 'Yeah... Threw my whole day off.',
#  'L187964': "There's nobody here, Father. Look for yourself.",
#  'L127523': "Shh. I'm not going to tell you not to go.",
#  'L51460': "That cleaning woman doesn't...",
#  'L134579': 'Twenty bucks.',
#  'L270312': 'Yes.',
#  'L244107': 'Not actually, no.',
#  'L598555': 'What were you doing when the voice came?',
#  'L377031': "You don't have to remember to be hungry.",
#  'L662707': 'You dont take no for an answer, do you?',
#  'L405646': "Mon Captain, it's for you. ",
#  'L542805': 'Closed.',
#  'L82579': 'Right.',
#  'L101203': 'I said, no thanks.',
#  'L258339': "Teacher asked me why we raise Black Angus-Herefords 'stead of Pure Herefords.",
#  'L431368': "Who is he! Edie, you're so softhearted and soft-headed you wouldn't recognize the devil if he had you by the throat. You know who this Terry Malloy is? The kid brother of Charlie the Gent, Johnny Friendly's right hand, a butcher in a camel hair coat.",
#  'L3127': 'Answer the phone.',
#  'L378427': "No -- you can't do that.",
#  'L180657': "I'm sorry I could only get you a third class ticket, but it's all we had.",
#  'L377493': "He knows you're no good on the phone, so\t\t    * he calls you up to bullshit you.\t\t\t\t  * Sometimes you stop taking his calls, so\t\t\t* he slips something under your door to\t\t\t  * frighten you into answering your phone\t\t\t * again. He's been pretending to help you.\t\t    * Feeding you a line of crap about John G.\t\t    * being some local drug dealer.\t\t\t\t\t*",
#  'L463248': "Who said it wa's me, hub?  Anyway... he fell off a ladder.  It wasn't really my fault.",
#  'L375705': "Lunch is 'in' today, have you given it any thought --_",
#  'L636429': 'So why play into his hands? We can protect you.',
#  'L65522': "...No, I've always found that writing comes from a great inner pain. Maybe it's a pain that comes from a realization that one must do something for one's fellow man  to help somehow to ease his suffering.  Maybe it's a personal pain. At any rate, I don't believe good work is possible without it.",
#  'L101620': "So what are you thinkin' here?",
#  'L433661': 'I have to qualify, is that it?',
#  'L276381': 'Take no offense Trevor. I see many patients a day and have an awful memory.',
#  'L506180': 'You like a good saloon?',
#  'L246197': 'This and that.  The only ones you maybe have heard of are the "Frankenstein" pictures.',
#  'L151563': "She'll talk about PMS and stare at her salad.",
#  'L452178': 'Good.  Yes.  Thursday.',
#  'L121059': 'Bullshit! Bullshit!',
#  'L665192': 'Dude, what are you doing here?',
#  'L44514': "Listen to yourself...  Don't worry, it's alright.  We'll find him.  What's wrong with you?",
#  'L540891': 'Yes.',
#  'L359210': 'You lied to me my whole life. Everything you said, everything you did.',
#  'L210664': "That's the oldest of the bunch, looked like the Grandpapa. We caught the little one, Junior, in the cooler there. As we've seen, what he lacks in size he more than makes up for in speed.",
#  'L279335': "It's the best collection I've ever seen.",
#  'L661867': "I don't need someone else.",
#  'L611978': "I know. Come on. We gotta get off the reservation or we're dead.",
#  'L230259': "I do know the answer to that. Why don't we watch the ball game later? We'll go to Mannion's.",
#  'L312342': 'On V-J Day he wept and prayed again.',
#  'L400810': 'Still angry that I kissed ya, huh?',
#  'L628325': 'Just put it in your purse.',
#  'L11322': 'What is it?',
#  'L540932': "I know... you'll all gladly die to save your home world.",
#  'L542213': "I can't do it.  I'll get hit.",
#  'L380142': 'Do we need this...?',
#  'L664345': 'I am trying to save our kind, Charles. You should do the same.',
#  'L411581': 'By Guy?',
#  'L359582': 'That was two words.',
#  'L125195': "Sorry won't bring the bloody thing back, will it, Mr. Franknum?",
#  'L356093': 'Whatiya mean?',
#  'L246329': 'Yeah, well keep your filthy thoughts to yourself.',
#  'L626769': "You're trespassing into the area of witness protection, Mr. Dowd. Such showboating puts lives at risk.",
#  'L598331': 'Jeanne... I have been hearing voices -- and believe me, those voices left me in no doubt that you must not go to Compiegne!',
#  'L334735': "Probably. Fuck that, I'll sneak in. I need some female vagina tonight.",
#  'L423528': "I... I don't know...",
#  'L254186': 'Come along, oh, Madam, come along. The train will be going.',
#  'L133169': 'Six years ago this May. No one came any more. You "know better than me, Mr. Di Vita, the crisis, television, videos. By now the movie business is only a dream. The city\'s bought it now to make a new parking lot. Next Saturday they\'re tearing it down...A pity!...',
#  'L568458': "Not so, Counsellor. That secretary of yours, she wasn't just your secretary, she procured women for you, didn't she? As many and as often as you wanted.",
#  'L267266': "If you'll pardon the expression, that's when you'll see the fur and feathers fly.  Good night.",
#  'L564970': "Because it's what we have to do.",
#  'L556814': 'First question got to be "Where."',
#  'L454360': "Why don't you call Norman and let him say just what happened, if he give the man a hot lead and he did just scooted off... it'll make the girl feel better, Albert.",
#  'L137781': "All right, no more picking on Dim, brother. That's part of the new way.",
#  'L269847': 'Is Kristen safe?',
#  'L335955': 'How?',
#  'L130134': 'Oh.',
#  'L357313': 'When was all this?',
#  'L162670': 'Yeah, right. She wishes. Look at that big ass.',
#  'L534942': 'Not exactly.',
#  'L603421': 'Do you mind if I come down and see it?',
#  'L625690': 'I hope you\'ve enjoyed being a command program, Sark. I wonder how you\'ll like working in a pocket calculator... maybe one of those watches that plays "Happy Birthday" to its User once a year.',
#  'L337969': 'Objection!',
#  'L421484': "June twenty-third, '72, sir.  The part that's underlined.  Your instructions to Haldeman regarding the CIA and the FBI.",
#  'L612071': "My mate has been acting very strange.  I can't explain it.....but.  I haven't been feeling very well myself.  I don't know, maybe it's me.  I needed an SP9 last night.  I feel as if something odd were happening to me. Something....",
#  'L326142': ".. feel like I'm getting close to this guy .. and all the time, feel like I'm sharpening a pencil with a broken load .. I'm sorry, King J ..",
#  'L154628': 'Yeah, sure, I understand.',
#  'L543720': "I'm not going on vacation ! I want to be acitizen ! It's my decision. I made it.",
#  'L903': "Just once.  Afterwards, I told him I didn't want to anymore.  I wasn't ready. He got pissed.  Then he broke up with me.",
#  'L434605': 'You were at Leavenworth, huh?',
#  'L587607': 'Exactly.',
#  'L115410': 'How can you keep doing this?',
#  'L48544': 'You had immense plans... immense plans...',
#  'L500323': 'Stop nagging.',
#  'L632385': 'Grace, tell him.',
#  'L478168': 'Carter...you ready to have some fun!?',
#  'L594288': 'Esther!',
#  'L560610': 'Do you like pink?',
#  'L660506': 'Yes, Hannah?',
#  'L356330': "You've been fucking somebody else haven't you?",
#  'L46428': 'No, no.  Just waiting for a friend. Good night, Mrs. Lieberman.',
#  'L457815': 'Have you got it? Is it completed?',
#  'L308792': "Maybe you've got the wrong crypt  after all it's twenty years when you wore last here.",
#  'L316139': 'What?!',
#  'L554019': 'Just put it down.',
#  'L31812': "It's cold, David, and I'm so alone. The undead surround me. Have you ever talked to a corpse? It's boring! I'm lonely! Kill yourself, David, before you kill others.",
#  'L150443': "I'll be right there.",
#  'L558359': "I must be. But I'm not.  Your home. This is your home.",
#  'L315799': 'Me, too.',
#  'L42398': 'We move to sunny L.A. All of show business is out there, Max.',
#  'L436581': 'Granted.  Where are you going?',
#  'L259838': "Subtle, isn't he? Hey creep!",
#  'L120463': 'You know why, right?',
#  'L287698': "I'm scared shitless.",
#  'L426021': 'Now you may call it an unreasoning optimism. You may call it obtuse. But the plain fact is we still have... close to... close to...',
#  'L447890': "They don't have that kind of potential.",
#  'L557214': "I can't see anything.",
#  'L237502': "That's all you're bringing?",
#  'L280091': "Haha.  Right.  It's no problem.  I love making tapes.",
#  'L474854': 'What are you waiting for? Do something.',
#  'L108750': "Abbott.  He knows about the embassy. He's coming down for a show and tell.",
#  'L273484': 'Steve...',
#  'L337070': 'I used a variation.  You should have anticipated that.  Have you figured out the message?',
#  'L588400': "Well, I'm sure we're all glad to see you came through it all right.",
#  'L515686': "Do you want me to say I'm sorry?",
#  'L125991': 'Then whose is it? His or theirs?',
#  'L247835': "Atley Jackson. How is that one? How's the leg... ?",
#  'L300067': 'Okey-doke, Indy! Hold onto your potatoes!',
#  'L334732': "You goin'?",
#  'L469128': 'Listen, you come down and stay with us for a few days. Just tell the old man that--',
#  'L439252': "If you took the trouble to write it, then sure, I'll take a look at it. But I'm beginning to think that maybe there's more to life than music. I wonder if people would still like me if I stopped being Mr. Excitement?",
#  'L560654': 'Oh, Mr. Luthor...',
#  'L637585': 'I was telling your wife, we have a very good case here.',
#  'L347215': 'Better let the Doc take a look at you, after dinner.',
#  'L258376': "Yeah, he's going to think about it. You want me to pack for you?",
#  'L310840': "I know a couple of truck drivers I'd like to have you meet sometime.  Come on, sit down.",
#  'L441263': "Hold still. Shit.  The goddamn vein's clotted. We have to go the goddamn hospital, so they can change the goddamn catheter.",
#  'L588442': 'Mr. Appleton, you are making light of a legally constituted committee of the United States Congress. Believe you me, you do not want to incur our wrath.',
#  'L48504': 'Gimme water.',
#  'L87635': 'Last time you asked me to come along I nearly got a hole in my head.',
#  'L481830': "Charley Vidal says!  Don't throw Charley Vidal up to me!",
#  'L534563': 'So am I. My friends were killed, too.',
#  'L147431': 'What room number?',
#  'L500195': 'Is this what they always look like?',
#  'L195833': 'Explosive decompression.',
#  'L120340': "...they're in Penthouse K.",
#  'L496659': "But you're always at the library.",
#  'L259484': "Whoever wrote this needs somebody to take the fall. And that's Phreak, and that's Joey, and that's us. We've got to get the rest of the file, so we can find out where the money is going before the worm disappears, so we can find out WHO created it.",
#  'L30998': 'Behold!',
#  'L322337': 'Sure.',
#  'L504600': 'Oh. You mean... today?',
#  'L239466': "Are you kidding?  We'll hit all that bridge traffic at 59th.  I'm going to take 72nd straight up to Fifth.  Trust me, I used to drive a cab.",
#  'L302404': 'Your name is Al...',
#  'L615195': 'Almost as good as you.',
#  'L558876': 'He missed the door, Uncle Lex.',
#  'L622689': "Honey, this is difficult, but we've all had our moments.  I tried --",
#  'L141010': "We had to see what your deal was. I'm just a little superstitious.",
#  'L662646': 'Now Robert is dead. He got his revenge.',
#  'L348773': 'Sure would like to see the house that Ruth built one more time.',
#  'L642425': "I don't know -- they've always been there.",
#  'L574832': "Said it went on for donkey's years.",
#  'L120049': 'What, are you trying to handicap me?',
#  'L360783': "No. I'll take a strega.",
#  'L635079': "Porch. I'm puttin' a porch on her so's I can puff my pipe of an evening an' drink my coffee an' watch the sun set.",
#  'L354178': "Nice to meet you, Ma'am.",
#  'L603753': "I've only read about them -- and the new internals.",
#  'L444848': 'You may go, Smythe.',
#  'L94576': 'Don?. Are you in with them?',
#  'L137031': "How yo doin', Gabe!",
#  'L648042': "Oh God.  He's back.  I'm sorry.  Please forget that I...I don't know what I'm saying.  Please...",
#  'L436528': 'Their names, ranks and posts?',
#  'L140335': 'Remember what you played?',
#  'L645068': 'Allright. Wait here...',
#  'L399717': "Don't tell me, 'cause I'm not going to tell you what I've got.",
#  'L500378': 'You were magnificent.',
#  'L343873': 'No?',
#  'L337659': "Don't let the bedbugs bite.",
#  'L192253': 'Are you kidding?',
#  'L274263': 'Remind me why I keep doing this.',
#  'L645122': "I guess I'll head back...",
#  'L634529': "I see guys like you all the time in my work. You find someone you think is emotionally vulnerable and you tell them a fantastic story, utterly convincing... and somewhere in there, you slip it in... 'I just need your credit card number','I just need a small down payment.'",
#  'L366955': "[Don't lie to me!]",
#  'L611518': "That's right. What are you doing here? This is a religious ceremony you're desecrating.",
#  'L303971': 'In the backyard.',
#  'L289323': 'I hope we all get to do many things. Can we go now?',
#  'L14576': 'Frightened.',
#  'L511759': "I am the Lord's voice in this town.",
#  'L106665': "He's the part of the business that the rest of them pretend to be. |But Mickey doesn't like it like they do.  I suppose that's why he's good at it.",
#  'L594989': "Neither do I, Thelma, but Darryl does it, how hard can it be?  I'll see you later.  Be ready.",
#  'L12206': "Where's Jill?",
#  'L555482': "I mean this is good dialogue along in here.  It'll play.",
#  'L357165': 'Mr. Barnard, I do not like this place. I definitely do not like this place.',
#  'L269956': "You know Granville's looking for you, Niki?",
#  'L259261': "Nope. His mom said he's grounded for his next three lifetimes.  He isn't to consort with his computer friends.  The secret service is really out to get him.  Hey there's a big party tonight, you wanna go?",
#  'L283696': "You haven't seen anything yet.",
#  'L295670': "Well, what's so funny?",
#  'L553003': "Hey, don't tell us about private property. This is America, my friend.",
#  'L376317': "Yeah, it's good to get together.",
#  'L247854': "Why don't you leave him alone?",
#  'L383607': 'I know you kids smoke that stuff, and we drink booze, but taking it across a border - it was stupid, Billy. Stupid.',
#  'L247706': 'I want that story, Audrey. Remember you work for me.',
#  'L131448': 'Privacy is exactly the point of drive- in movies.',
#  'L31726': 'Twenty-eight.',
#  'L599498': "Ohhh I've never been there. ",
#  'L348930': "Do you know what I'd give to have this! Forget how I got it!  I can't afford dirt in this town.  I live in Riverside, Goddammitt  And you get to piss in the ocean.",
#  'L101906': 'Then what the fuck?',
#  'L535044': 'Warp Speed, Mr. Sulu...',
#  'L205348': 'What gives you that idea?',
#  'L35293': 'Listen here, young man - nobody ever called me a liar yet and got away with it',
#  'L400735': "-- I know what you mean. I was there, alright. Seti's place. The City Of The Dead.",
#  'L221441': 'Who?',
#  'L403695': "They sure did! They got kicked out of school, they married truck drivers...these are my mother's greatest accomplishments? I'm sure glad I came all the way out here to find them out.",
#  'L8034': "But she wouldn't let Dad treat me like that.",
#  'L308171': "I'm not going anywhere. I'm fat, ugly, and depressed.",
#  'L222745': 'Let it go.',
#  'L603564': 'No.',
#  'L317914': "Where'd you get the gun?",
#  'L385053': "...you don't even know what you're looking for.",
#  'L643574': 'Hey, I know that, hey, I\'m <u>kidding</u>...  "It\'s a pageant"',
#  'L247873': 'You, too',
#  'L222108': "They knew the risks when they signed on. I've come too far to turn back now.",
#  'L450502': 'What motel you staying at?',
#  'L124279': "It's in your interest, Nels, since the additional passenger in my trunk -- an LAPD officer is probably carrying a few bullets in him traceable to the piece you're carrying.  Tell the man.",
#  'L81228': 'Do you realize, Mr. Gardiner, that more people will be watching you tonight than all those who have seen theater plays in the last forty years?',
#  'L558335': 'Your heart, Miss Teschmacher? I never knew you had one.',
#  'L542798': 'I am...',
#  'L550111': 'Huh?',
#  'L244131': 'For five thousand?',
#  'L127309': 'Unless he makes a move during seventh period.',
#  'L439794': "Well, it's actually reincarnation, but you get the idea. And some people think we just wink out...like a candle flame when the wind blows hard.",
#  'L139987': 'You like Bach?',
#  'L526758': "You've heard of me?",
#  'L195867': "I don't know, the screens are dead...!",
#  'L376048': '"Death and Taxes"?',
#  'L501499': 'You live a phony cheap cop-out existence.',
#  'L444173': "Means?  Oh no.  We won't know what it means until the end of the story and maybe then it won't seem quite as funny to you, Doctor Frankenstein!",
#  'L549797': 'But Rache...',
#  'L114115': 'Uh, hi.',
#  'L558283': 'I want to.',
#  'L723': 'So you got cozy with she who stings?',
#  'L457093': 'Why not?',
#  'L600229': 'Four kids, three different guys.',
#  'L242669': "You're a legate in the Roman army. Huh...?  and you act like one. What was your crime?",
#  'L65281': "I'm checking in. Barton Fink.",
#  'L212234': 'It must\'ve been Tuesday.  he was wearing his "cornflower-blue" tie.',
#  'L401603': "Wake up, we're in trouble.",
#  'L258091': "I, I don't mean to sound insensitive. I understand your situation. But there's nothing I can do. You just called the wrong person, that's all. I hear there are a bunch of therapists in New York. Maybe you should call one of them.",
#  'L160806': 'Fucking A.',
#  'L413366': 'Yes, Dad.',
#  'L475490': 'I tell you it was a miracle the way things turned out --',
#  'L586532': 'I was just trying to make a point. If --',
#  'L597081': 'Ho-hotel... Los Angeles... He...',
#  'L112961': 'You know, Tom, I feel a little proud when people comment on your looks.  Maybe you should feel that way.',
#  'L549300': 'That happens.  To families.',
#  'L142407': 'Can I talk to you a second?',
#  'L454598': "Yes I'm fine.",
#  'L511315': 'To call a person superstitious is to imply they fear magic, but not all magic is black.',
#  'L652029': "You're on the next plane home.",
#  'L553171': 'Jesus Christ.',
#  'L362885': "How many times....it's ok...just say... Just say...",
#  'L91804': 'Yes.',
#  'L300324': 'This is a different situation, Dr. Jones. These people are like children. We have to lead them slowly into the twentieth century.',
#  'L548284': 'You think so?',
#  'L437676': "Good on you, then, Rafe McCawley.  We'll get you situated in some quarters, and then introduce you to the equipment you'll be flying.",
#  'L490340': "Why don't you finish the job?",
#  'L291643': '-- ten.',
#  'L407201': 'Not yet. Listen, Norman, I want...',
#  'L523305': 'She did?',
#  'L89681': 'Scud.',
#  'L615339': 'Very good, Mary--',
#  'L475080': "There aren't any women here.",
#  'L522053': "I don't know how you did it, but whatever it was, keep doing it.",
#  'L583686': "[Pointedly] Of course you're not.",
#  'L19441': "Wait a minute. I know you. You're Kareem Abdul Jabbar. You play basketball for the Los Angeles Lakers!",
#  'L126643': 'What would you like me to say -- that a pretty girl with an outrageous manner means more to an old pro like me than a quarter of a million dollars?',
#  'L321026': "It's okay, it's okay....",
#  'L249390': "Thirty-two hundred bucks. That's what he gave me. Thirty-two hundred bucks for a lifetime. It wouldn't have paid for the coffin.",
#  'L67993': '"She loves me. Oh yeah she loves me! She loooooooves me, Oh yeah she loves me!" Bring me some chicken, baby!',
#  'L651427': "It's outta here!",
#  'L489026': 'Hmm.',
#  'L584529': "You were in love with him, weren't you?",
#  'L3314': 'Right.',
#  'L611760': "Yeah. Jimmy's prints are there. But they cross over Benjamin Black Star's prints. And he wasn't there until six o'clock the mornin' after to get eggs from the chickens. So Jimmy wasn't there til the next day. Follow?",
#  'L445491': "Now Gallagher, if we could only get a great scene - a tremendously emotional scene - something that would just wring the hearts out of the public - to bring the curtain down in the second act - that would be okay. Couldn't dig one out of your hat some place, could you?",
#  'L307150': 'I thought so.',
#  'L34319': "Uh...my dad's the manager.",
#  'L311446': "Yes. Personally, I think it's silly, too.",
#  'L486051': "I go to work the other day, there's nobody there.  Nobody tells me about this, I have to find out, I have to go in, everybody's gone -",
#  'L334468': 'Yep.',
#  'L507184': "I saw her picture on the, er... internet.  You really didn't notice anything -- unusual?",
#  'L180399': '...I learned a long time ago.',
#  'L336312': "You don't win by playing it safe, Peter.",
#  'L204998': 'Doctor...',
#  'L114439': "What am I doing?  I'm just telling Walter the truth.",
#  'L474917': "There's plenty of use for reading -- you'll see.",
#  'L82900': "I don't know anything about her. What if she's some sort of witch or something?",
#  'L402484': "Why d'you think these seats were empty.",
#  'L406766': "It's hard to say. Doctors thought she'd come home a week ago. All it was was appendix.",
#  'L236445': 'God, this paper is so boring. Who reads all this shit?  Here we go...  "Windsurfing Doctor, Mensan IQ, maverick Sagittarius. Let\'s hit the clubs, make each other laugh!"',
#  'L125519': 'What condition?',
#  'L411372': "Hey, where's your sweatshirt?",
#  'L356568': 'I got some hair stuff.',
#  'L313026': "Well, that's the State's offer. If you plead to possession and tell L.A.P.D. what they want to know, your bond will be set at one-thousand dollars. If you don't, L.A.P.D. will request one at twenty-five thousand based on your prior record and risk of flight. If you don't post it or don't know anyone who can, you'll spend six to eight weeks in County before your arraignment comes up.",
#  'L551048': 'Tell me.',
#  'L355248': 'Just curious.  Back to business.  Ever heard of a man called Nix?  Dorothea?',
#  'L303705': "...if you are, then I'll take Barbara to soccer and take you to dance after...",
#  'L542995': 'No.',
#  'L501458': "She's out, but you're supposed to wait.",
#  'L405931': 'Yes, Captain?  Have you anything you wish to say?',
#  'L417316': 'I can see that. You watch too damn much TV.',
#  'L133795': 'Yes, Mr. Bernstein.',
#  'L584406': 'Certainly.',
#  'L463247': "Chalk up another victory for Billy-Boy's one man war on crime.",
#  'L119445': 'And the names are Mr. and Mrs. Victor Laszlo.',
#  'L499432': "No. I have spoken to the Queen.  Her majesty's consent is requisite when a Wessex takes a wife, and once gained, her consent is her command.",
#  'L398676': 'Sure.',
#  'L154632': "Sooo...whattya think?  Maybe after I betray the woman who trusts me and you take her and her daughter out and execute them...we could go on a date.  Play a little miniature golf or somethin'.",
#  'L483261': "Just shut up, Ryan didn't kill Wade.",
#  'L349180': "Your nose ring comes out of your nose. If you've got them in your nipples, they come out, too.  And there's no make-up at my house.  No glue sniffing.  Huffing. No pills, no grass.",
#  'L63288': 'The Mantan Manifesto.  Catchy ain\'t it?  Number One.  We gainfully employ African Americans, in front of and behind the cameras.  Two. Let the audience decide.  Three. Who put these critics in charge? These so-called cultural police? Four.  Who determines what is black? Five.  Mantan is a satire.  Six. If they can\'t take a joke, "F" \'em.',
#  'L346962': 'Yes... Twice.',
#  'L224318': 'Dad, you there?  You okay?',
#  'L66086': 'Christ... Remind me to thank Bill for mentioning that on the phone --',
#  'L274197': "Well, I won't be around forever, you know?",
#  'L441041': "Andy, you don't want this.",
#  'L167213': "Aw, Jesus ... you been doin' us favors all night!",
#  'L333424': "The cemetery is nearer the Castle than anywhere else -- wasn't it part of the Castle originally?  -- I always assumed there'd be a gate or something.  Isn't there?",
#  'L569347': "Didn't look that way -- you know -- from a distance.",
#  'L644829': "Stay here, I'll see what I can do.",
#  'L439311': "Well, I like to speculate. This book I'm reading right now, a woman in Colorado says she lived in Ireland a hundred and fifty years ago. Her name was Bridey Murphy- and she gives names and dates and where she lived. She was hypnotized. Big bestseller.",
#  'L29511': 'One minute but then--',
#  'L516383': 'Objection, asking the witness to speculate.',
#  'L249801': 'Free?',
#  'L385141': "Oh, that's gonna work.",
#  'L84742': 'We?  What the fuck we?  You said you just wanted to come along--',
#  'L268114': 'Fifty years?',
#  'L284983': 'You -- you!!',
#  'L236399': 'Yeah, I just picked the one that sounded the easiest.',
#  'L636940': "Give 'em a box of Macanudos.",
#  'L297157': 'Oh jeez, Benjie. Well, here you are.',
#  'L117905': 'Lenny? Come on!',
#  'L576834': "He's right.",
#  'L325732': 'What does that mean, Sergeant?',
#  'L443342': 'And they fell out of the sky with you?',
#  'L412451': 'I saw it.',
#  'L613029': 'Any word?',
#  'L160583': 'Merle...',
#  'L624449': 'Sybok, you are my brother, but you do not know me. I am not the outcast boy you left behind those many years ago. Since that time I have found myself and my place. I know who I am. And I cannot go with you.',
#  'L231722': 'I was at home.',
#  'L225797': "I'm a slow eater.",
#  'L475842': 'Mm-hmm...',
#  'L632768': "He doesn't give it to us.  We take it.",
#  'L254926': 'Thought you was in jail.',
#  'L12648': "I remember clearly cause when I heard I became real careful around Pop. I was a careful child and I became a careful adult, but at least I wasn't afflicted by that man's violence.",
#  'L627413': "Uh... well, okay then.  You sound terrible.  I'll run out right now.  Just call the prescription in to the pharmacy.  Sure, no problem.  Bye.",
#  'L175353': "We didn't make a dime.",
#  'L458345': "Salvy, would I steer you wrong? Let's say that's the truck; it's full of cigarettes, right? Now, two o'clock this morning we move the truck from here to there,  take the cigarettes out, sell 'em, make some cash.",
#  'L479648': 'They made me put my hat back on.',
#  'L307221': "That's the Air Force Base.",
#  'L296754': "Ben you know that's your territory - and I wouldn't dream to trespass - you're the expert. Hey, how do you think Paramount's gonna do with that Blatty novel, what's it called? The Exorcist?",
#  'L163188': "Right, well, thanks for the drinks and stuff, Amanda, but there's no reason for me to stick around these parts anymore.",
#  'L356521': 'Oh no...',
#  'L635532': "I'll ride up close an' shoot 'em!",
#  'L304789': 'Typical seventeen year-old.  She went to a party Friday night?',
#  'L167708': "I refuse to turn out like them. Twenty-one years old and they're already looking for a husband.  Stupid fucking cunts with no self- esteem. They let the boys control their lives. Not me.",
#  'L141828': "Put down the gun and I'll take your statement.  Okay?",
#  'L502766': "It's not a matter that concerns you, Mr. Torrance - at least not at this point.",
#  'L126697': "Where's that airlines bag?",
#  'L45436': 'Great!',
#  'L448028': 'The pages filled in?',
#  'L36590': 'What?',
#  'L28151': "She's a girl of so many rare qualities.",
#  'L458215': "Go on, little girl, take your troubles somewhere else. I don't feel like talking to you.",
#  'L79032': 'I got an A!',
#  'L46702': 'Sure.',
#  'L414473': 'You believe in anything?',
#  'L504351': "Well, I'm tired. Aren't you tired?",
# ...
#  'L203424': 'We should stay here until we can define the extent of our changes...',
#  'L511667': 'Someone left last night.  Looked like they headed to the square, but I lost them in the forest.',
#  'L411376': "Remember, that poet that we liked  the reading he's doing at Big Cup? I got us tickets.",
#  'L236330': "It's a trap. There was no way we were gonna get away with that gold. Nobody ever does. It's just the bait. This ship sucks people in and it never lets them out.",
#  'L354109': 'Right. When he was killed.',
#  'L353667': 'Right.',
#  'L619686': "You know, Babe Brother's wife just dumps greens in the pot without washing them.",
#  'L148990': 'Did you solve your problems?',
#  'L325249': 'I want you all to come to Amity this summer.',
#  'L118819': "Well, I ain't sleepy either.",
#  'L423124': "By the way -- it's you.",
#  'L129307': '...stole a truck under arrest.',
#  'L445517': "You can't walk out of here like this.",
#  'L88013': 'It that mother real?',
#  'L601229': "No.  They're just the only ones we know of.",
#  'L384868': "Oh, right... They been here since noon. I told them you're real busy.",
#  'L603800': 'Sir...?',
#  'L30015': 'Well?',
#  'L157329': "Thanks but  I'd better do history.",
#  'L371147': "What's that?",
#  'L143189': "I'm in love with you, Ellie.",
#  'L80994': 'Yes. Are you going to leave and close the house when he dies?',
#  'L410438': 'I know who you are.',
#  'L89222': "And that's a good thing?",
#  'L410597': "The antitoxin. I'm not waiting until this is over. Give it to me now or there's no run.",
#  'L599998': 'Oh God.',
#  'L130234': 'Maybe.',
#  'L108594': 'Yes.',
#  'L386631': 'Baltimore.  Eastside.  Solomon P. Eddie M.D.  I was a plastic surgeon.',
#  'L31095': 'What?',
#  'L113061': 'That actually goes on...',
#  'L68392': "I hear your show was sold out already. There's a very important collector who's interested in some of your works.",
#  'L249542': "I'm serious Chuckie, I ain't goin'.",
#  'L447383': 'No doubt about that one.',
#  'L521363': 'Syncopators - does that mean you play that fast music - jazz?',
#  'L527268': 'You said something to me, before -- about how we were all going to die.',
#  'L499029': "It's a comedy.",
#  'L392269': "Look, it's my duty as a knight to try and sample as much peril as I can.",
#  'L417000': "I'm Jesse now, Lisa.",
#  'L184359': "No, but, no, not at all.  I'm sorry. You came to the doors, that's all and -  - such good manners for someone worried about mines.  That's all.",
#  'L95207': 'Shit, yeah.  Do you know how much money I could make if I had this stuff back east?',
#  'L648563': 'Okay.  Okay.',
#  'L454864': "I do pretty good, I think. I wish I was making more, doing a little bit better. I can,t get over a certain hump. I will...I will crack something soon I think and really do better...I'd like to diversify...but I'm doing great, I think, as a start.",
#  'L206322': 'Well, okay - thank you, Detective.',
#  'L118969': "I never drink in the morning. And every time you send my shipment over, it's always just a little bit short.",
#  'L496379': "Wait a minute. This has got a lot of angles. You've got to take it easy. Do you know a Mrs. Redi?",
#  'L262591': "Mickey, you're off the hook.  You should be celebrating.",
#  'L399653': 'What do you want to know?',
#  'L462497': "Crunch--my father's--You going to kill him?",
#  'L117000': "Y'know if you make it to the Bigs you could still become the host of Dance Fever.  Baseball's a good stepping stone for things like that.",
#  'L284160': "The Governor gave me his word of honor he wouldn't interfere. Two days ago!",
#  'L147415': 'We still have to get out of here.',
#  'L406968': 'No. Probably stay at a motel tonight.',
#  'L195007': 'I just got in.',
#  'L72636': 'Watch the first step.',
#  'L295886': 'Cash.',
#  'L15203': "He's out there somewhere, causing trouble just to upset me.",
#  'L312560': "I haven't won my wings yet. That's why I'm an angel Second Class.",
#  'L122961': "He didn't remember to roll up his window...",
#  'L140999': 'You interested in a little work?',
#  'L523956': "Where you goin'!?",
#  'L137778': 'Appy polly loggies. I had something of a pain in the gulliver so had to sleep. I was not awakened when I gave orders for awakening.',
#  'L213166': 'But, this is Project Mayhem.',
#  'L566185': "I took out three hundred, but I'm only gonna bet with one. I figure if we buy a lot of chips, the pit boss will see and they'll comp us all sorts of shit, then we trade back the chips at the end of the night. You gotta be cool though.",
#  'L591702': "You don't.",
#  'L273009': "I'm saving them for a rainy day.",
#  'L406610': "A treaty?  Don't be ridiculous. What treaty is this?  Who made it? Who has been giving orders?",
#  'L549001': '&quot;In the great green room there was a telephone and a red balloon...&quot;',
#  'L637874': 'Should I?',
#  'L638316': "Dr. Towler; page 406, 'Contraindications to general anaesthetic.  Ideally a  patient should refrain from taking nourishment up to nine hours prior to induction of general anaesthetic.'  Does that sound familiar?",
#  'L182573': 'What?',
#  'L352890': "Fish and plankton, sea greens and protein from the sea.  It's all here -- ready -- fresh as harvest day. Fish and plankton, sea greens and protein from the sea... And then it stopped coming and they...  ...came instead. So I store them here. I'm ready. And you're ready. It's my Job -- protein, plankton, grass from the sea.",
#  'L652059': "You do like girls, don't you?",
#  'L144245': 'My third grade teacher at the convent shot better than that.',
#  'L440952': '... interview every employee, support staff, associates, partners. Did <u>any</u> of them know Andy was sick? <u>How</u> did they know? Did he tell them? Did they notice something was wrong with his appearance? None of this information got to the managing partners. We know that. Make sure everyone else does too... And Beckett: I want to know everything about his personal life. Did he frequent those pathetic bars on Camac Street?',
#  'L126691': 'What is it?',
#  'L354510': 'You told me one time it was true love.',
#  'L423816': 'Nice move. Cedars Sinai?',
#  'L387730': 'Do you have any of those new Paul Sheldon books?',
#  'L534426': 'Rake her.',
#  'L533028': 'Every time the men get Red Cross packages you have to think up an angle to rob them.',
#  'L388777': 'My team.  Claire, Jack, even Jim - - Hannah, maybe, I -- dont know',
#  'L484353': 'Swear to god, I need to know the truth.',
#  'L202503': 'I pick up the kids, walk the dog, which by the way, carries the added bonus of carting away her monstrous crap...I play with the kids, take out the garbage, get six hours of sleep if Im lucky, and then it starts all over again...and why is it that I always have to drive everyone everywhere?  I spend practically my entire day in that slow as hell mini-van listening to Raffi tapes and trying to figure out how the cup holders work...Im sick of it.',
#  'L92841': "If it will make you feel any better, I don't have a gun.",
#  'L126647': "Don't you know I'm having a tough time keeping my eyes off of you?",
#  'L43728': "Promise you'll be nice to the neighbors.",
#  'L87683': 'Where the hell you been?',
#  'L169270': 'Where are we going?',
#  'L28709': '"Please forgive me for butting into what seems such a happy occasion - but it\'s most important that I speak with you. Please" - it\'s underlined - "meet me in the Ladies\' Room. Eve."',
#  'L148659': "Without hope there's no point to anything.",
#  'L19297': "It takes so many things to make love last. Most of all it takes respect. And I can't live with a man I don't respect!",
#  'L572989': "That's not true...",
#  'L553488': 'Mine too.',
#  'L649377': 'Really...?  Your family there...?',
#  'L371670': "You aspirate the blood from the chest cavity. Damn, there's more of it than I thought.",
#  'L434328': "I don't know about that.  You can't do three falls and think you have much of a brain.",
#  'L587487': "No, I'll be fine.  Can you just hand me a glass of water?",
#  'L490271': 'What, Ben?',
#  'L623295': "Yeah. No more. I'm finished with that shite.",
#  'L439572': "Missy Dandridge. And she says it's a operation!",
#  'L443761': "They think you're behaving foolishly. I must say I agree. Where will you go?",
#  'L267474': 'This room is full of ghosts.',
#  'L553817': 'Oh, fuck it, man!',
#  'L589796': "Well, then, Doctor MacFarlane -- although I've known a time, Toddy, when you liked the name.  Aye, and many are dead now who called you by it; rough and wild ones they were, too.  But come Toddy, sit down here with your young friend.",
#  'L97025': "I don't know if you're a detective or a pervert.",
#  'L463898': "Gabriel! You said talk to him. That's all you ever said...",
#  'L478019': 'The art.',
#  'L42496': 'Tell him.',
#  'L475976': 'What are you thinking?  We were only supposed to scare him!',
#  'L651596': "This is your moment, don't you see? The instant when you know that your life is never going to be the same again.  When you stand up and are counted.",
#  'L361610': "Ok. Marcie. Starting now I want you to have a new attitude with me.  The more you play games, the more suspicious I'm gonna become that you've been up to something.",
#  'L349351': "I'm surprised he hasn't left.",
#  'L34882': "But Dude, listen - couldn't we make this some other time?",
#  'L540625': 'You sick bastard!',
#  'L268310': "I haven't told you, Harold, how comical I think you are.",
#  'L631169': "Sure, but I can't get it till after school tomorrow.",
#  'L411062': 'Nauseated. I look nauseated. Oh God.',
#  'L248471': 'Her parole officer strongly recommended it ...',
#  'L556881': 'Uh-huh.',
#  'L244704': 'Your contract went out to the bank.',
#  'L293522': 'I --',
#  'L154341': "How do I know you're telling the truth?",
#  'L395037': "We'd like to get in touch with him. It's very important.",
#  'L412099': "Yeah, ya'll got a notice today.  It came certified mail.",
#  'L526424': 'I gotta survive.',
#  'L460271': "Boy, for four or five days there I didn't think I'd live. But I'm my old self again!",
#  'L603505': "Hello, Nick!  And a party - celebrating father's third murder - ",
#  'L187452': 'Is it summer or winter, Erik?',
#  'L504286': "It's going to be great. Here's to us.",
#  'L457252': 'Will you sleep soundly tonight?',
#  'L160348': "I'll tell you something, Nick. I wouldn't hunt with anyone but you. I won't hunt with a yo-yo.",
#  'L507548': "We've got our best people on it, Mr. Sayer.",
#  'L292860': "So when's that Sebastian-Cabot- Buckingham-Palace-looking- Butlerhead getting here?",
#  'L154471': "That's deep.  But before you lecture me about the meaning of life maybe you oughta get one...ta ta.",
#  'L281459': 'Get outta here.',
#  'L63187': "That'swhatI'mtalkin'bout! That'swhatI'mtalkin'bout!  I want to be the first to welcome you to the second taping of Mantan - The New Millennium Minstrel Show.",
#  'L258160': "Fine -- I'll take my bath.",
#  'L388731': 'Such a nice ass.',
#  'L603756': "There's a cantilevered gasket on the --",
#  'L257335': 'You never could have kept this from me.',
#  'L360712': "Don't play dumb. You know what I'm talking about.",
#  'L68296': "Forget it .I'll take six, no, seven chocolate shakes, an order of fries, a Big Mac, and two apple pies.",
#  'L376279': 'Sure.',
#  'L437918': 'I sent telegrams, I guess the military traffic held them up.',
#  'L157486': 'So?',
#  'L449254': 'Who cares!',
#  'L247129': 'Thanks.',
#  'L402118': "Uhh, Miss devoto, these people are already at ease. This is not a Beauty Parlor, it's a Funeral Parlor.",
#  'L352134': "Yeah, one of them's out.",
#  'L611469': "You've got no jurisdiction.",
#  'L496266': "Mary, I'm amazed. Didn't Jacqueline tell you? She sold the business to me at least eight months ago. It's my business now.",
#  'L297013': "It's a one-on-one kind of date thing.",
#  'L338376': 'What do you see?',
#  'L95979': 'I swear.  On my life.',
#  'L134031': 'If you want to come in and wash your face -  I can get you some hot water to get that dirt off your trousers -',
#  'L466707': 'How are we doing?',
#  'L99319': "I am who I am.  I can't deny it, anymore than you can deny who you are.  I like sex different -- I like it wild.  That's not a crime.  I loved Andrew.  We made love together.  We made it differently, but we still made love.  It was our way.  It was private -- and now the whole world wants to look in through the pretense of justice.  If I was some middle-aged divorcee who screwed him once a week do you think this would be happening to me?",
#  'L512898': "He never did want to. I figure he ain't changed his mind much.",
#  'L603272': "I can't remember offhand, Lieutenant.  Maybe I was over at Charlie's shooting pool. Maybe I was here.  She'd remember.",
#  'L87896': 'During the road test...',
#  'L11323': 'Nothing, nothing  at all. I was just looking for Sandro.',
#  'L499779': 'Well, that will have them rolling in the aisles.',
#  'L399404': "No. You're too busy being a smart aleck to be thinkin'. Now I want ya to think and quit bein' such a smart aleck. Can ya do that for me?",
#  'L582411': "What's wrong?",
#  'L470167': "I'm askin' ya to go to him -- As a favor.",
#  'L42967': 'Oh, you-you have to be artificially relaxed before we can go to bed?',
#  'L44905': "Well, he micro-managed the company till it got too big...  'Guess he needs to micro-manage something.",
#  'L295229': "Stay with this kid. He's a loser.",
#  'L388043': 'Very.',
#  'L121522': 'Fine.  Just gonna get the bowl for my thing.',
#  'L407226': 'Fungus?',
#  'L119410': "Oh, save it. We've still lots of things to do.",
#  'L147275': 'What for?',
#  'L449384': "... Felony B and E, three months in juvey.  Better.  Felony assault. Postgraduate work at Chino. Excellent.  I'm lovin' it.  What about the brother?  Great!  Another model citizen. These guys really fit the profile.",
#  'L207256': "Romance in Ridgemont? We don't even get cable TV.",
#  'L646916': "Promise.  Cross my heart.  But until Mommy gets back, Dylan, whatever you do, don't fall asleep.",
#  'L221725': "No, I'm warning you! Who do you think you are, God? You bumble around with your folders...  ...and your pencils...  ...and your god-damn buttons...  ...all your badges of authority! But you have no authority! You're nothing! You're a zero!",
#  'L526530': 'Way too late. Buzz Fazeli is history.  Too late for what?',
#  'L87048': 'Short shift?',
#  'L140672': 'Slow down.',
#  'L454460': "We have to go into that cabin and search it, Sam... no matter what we're afraid of finding and no matter how much it may hurt.",
#  'L219013': 'You got any change?',
#  'L197066': 'It is.',
#  'L373135': "No you don't.  Did you see the woman in the red dress?",
#  'L525884': 'Goddamn it Barnes this really steams my onions!',
#  'L334646': "Come on. Don't cry. We'll work it out.",
#  'L87126': 'Why me?',
#  'L355667': 'Yes.',
#  'L402479': "Ssshhhhh, I don't want them to see me.",
#  'L614270': 'Thank you.  Seventy-six, eighty--',
#  'L164214': '" ... and if the final vote shall leave thousands of our fellow citizens and their families in hopeless distress, can we -- members of the Government -- go to our beds with a clear conscience, can we, without self- reproach, supplicate the Almighty Mercy to forgive us our debts as we forgive our debtors?',
#  'L309199': 'I shall not leave the island ',
#  'L526748': 'Keep watching the news.  Are you watching the news?',
#  'L554526': 'My best friend got pregnant.',
#  'L328439': "She's the best damn witness we have!",
#  'L370786': 'Goodnight.',
#  'L463618': 'GUARD!!!',
#  'L181859': 'Four of the defendants recanted their testimony.',
#  'L279763': 'How many tickets can I put you down for?',
#  'L305205': 'Yes.',
#  'L443927': 'The replicators?',
#  'L77033': 'Jesus Jumped-Up Christ! If this were to fall into the wrong hands...',
#  'L367647': 'Did she have tits like that?',
#  'L219992': "California. San Berdoo. Utah's part of my route. Can I ask you a few questions?",
#  'L24464': 'This is getting out of hand.  I want you to deal with it.  Immediately.',
#  'L641104': 'Did she believe you?',
#  'L258754': "Guess you don't have to figure it out until you go home.",
#  'L574934': "What's so fucking funny?",
#  'L260290': "Why wasn't I notified?",
#  'L124108': "I still don't see you.",
#  'L568963': 'Thanks.',
#  ...}

# %% [markdown]
# # Creating a list of all conversations with the IDs

# %% [markdown]
# We want to create a list of conversations with line IDs because we need to keep track of conversations for the training data.
#
# 1. declare an empty list
#
# 2. the last row in the conversations dataset is an empty row, so the little trick to care of that is skip the last row using array slicing in python [:-1]
#
#    now, for each conversation in the conversations dataset
#       a) split the conversation with respect to " +++$+++ "
#
#       while splitting we ensure we want the last part of each conversation,           hence the usage of [:-1]. This last part consists of the list of line           IDs.
#
#       Now we do not want the opening and closing square brackets,hence using
#       string slicing from [1:-1]
#
#       We also want to get rid of all quotes(') and all the spaces(" "),hence         using replace("'","") and also using replace(" ","") respectively
#
#       b) now append the line IDs to the list by splitting with respect to the          comma(",")

# %%
conversations_ids = []
for conversation in conversations[:-1]:
    _conversation = conversation.split(' +++$+++ ')[-1][1:-1].replace("'", "").replace(" ", "")
    conversations_ids.append(_conversation.split(','))

# %% [markdown]
# Let's have a look at our conversations_ids list we created above

# %%
conversations_ids
# Out:
# [['L194', 'L195', 'L196', 'L197'],
#  ['L198', 'L199'],
#  ['L200', 'L201', 'L202', 'L203'],
#  ['L204', 'L205', 'L206'],
#  ['L207', 'L208'],
#  ['L271', 'L272', 'L273', 'L274', 'L275'],
#  ['L276', 'L277'],
#  ['L280', 'L281'],
#  ['L363', 'L364'],
#  ['L365', 'L366'],
#  ['L367', 'L368'],
#  ['L401', 'L402', 'L403'],
#  ['L404', 'L405', 'L406', 'L407'],
#  ['L575', 'L576'],
#  ['L577', 'L578'],
#  ['L662', 'L663'],
#  ['L693', 'L694', 'L695'],
#  ['L696', 'L697', 'L698', 'L699'],
#  ['L860', 'L861'],
#  ['L862', 'L863', 'L864', 'L865'],
#  ['L866', 'L867', 'L868', 'L869'],
#  ['L870', 'L871', 'L872'],
#  ['L924', 'L925'],
#  ['L984', 'L985'],
#  ['L1044', 'L1045'],
#  ['L49', 'L50', 'L51'],
#  ['L571', 'L572', 'L573'],
#  ['L579', 'L580'],
#  ['L595', 'L596', 'L597'],
#  ['L598', 'L599', 'L600'],
#  ['L659', 'L660'],
#  ['L952', 'L953'],
#  ['L394', 'L395'],
#  ['L396', 'L397'],
#  ['L589', 'L590', 'L591'],
#  ['L592', 'L593'],
#  ['L756', 'L757', 'L758'],
#  ['L759', 'L760'],
#  ['L164', 'L165'],
#  ['L319', 'L320'],
#  ['L441', 'L442', 'L443', 'L444', 'L445'],
#  ['L525', 'L526', 'L527'],
#  ['L529', 'L530'],
#  ['L531', 'L532', 'L533'],
#  ['L542', 'L543'],
#  ['L601', 'L602'],
#  ['L655', 'L656'],
#  ['L889', 'L890', 'L891', 'L892'],
#  ['L893', 'L894', 'L895', 'L896', 'L897', 'L898', 'L899', 'L900'],
#  ['L901', 'L902', 'L903'],
#  ['L904', 'L905', 'L906', 'L907', 'L908'],
#  ['L909', 'L910', 'L911', 'L912', 'L913', 'L914'],
#  ['L982', 'L983'],
#  ['L1007', 'L1008', 'L1009', 'L1010', 'L1011'],
#  ['L1021', 'L1022'],
#  ['L1051', 'L1052'],
#  ['L179', 'L180', 'L181', 'L182', 'L183'],
#  ['L189', 'L190'],
#  ['L517', 'L518', 'L519', 'L520', 'L521'],
#  ['L523', 'L524'],
#  ['L536', 'L537'],
#  ['L538', 'L539', 'L540'],
#  ['L544', 'L545', 'L546'],
#  ['L878', 'L879', 'L880', 'L881', 'L882', 'L883', 'L884'],
#  ['L922', 'L923'],
#  ['L458', 'L459', 'L460', 'L461', 'L462', 'L463'],
#  ['L63', 'L64', 'L65'],
#  ['L66', 'L67', 'L68', 'L69', 'L70', 'L71', 'L72', 'L73', 'L74'],
#  ['L77', 'L78'],
#  ['L87', 'L88', 'L89', 'L90', 'L91', 'L92'],
#  ['L139', 'L140', 'L141', 'L142'],
#  ['L143', 'L144', 'L145', 'L146', 'L147'],
#  ['L157', 'L158', 'L159'],
#  ['L210', 'L211'],
#  ['L212', 'L213'],
#  ['L215', 'L216', 'L217', 'L218', 'L219', 'L220', 'L221', 'L222'],
#  ['L223', 'L224', 'L225'],
#  ['L244', 'L245'],
#  ['L388', 'L389', 'L390', 'L391'],
#  ['L416', 'L417', 'L418', 'L419'],
#  ['L424', 'L425'],
#  ['L432', 'L433'],
#  ['L499', 'L500'],
#  ['L583', 'L584', 'L585', 'L586'],
#  ['L778', 'L779'],
#  ['L385', 'L386'],
#  ['L411', 'L412'],
#  ['L426', 'L427'],
#  ['L430', 'L431'],
#  ['L619', 'L620'],
#  ['L621', 'L622'],
#  ['L623', 'L624', 'L625'],
#  ['L725', 'L726'],
#  ['L740', 'L741'],
#  ['L743', 'L744', 'L745'],
#  ['L780', 'L781'],
#  ['L148', 'L149', 'L150'],
#  ['L335', 'L336'],
#  ['L554', 'L555', 'L556'],
#  ['L557', 'L558'],
#  ['L285', 'L286'],
#  ['L287', 'L288', 'L289', 'L290', 'L291', 'L292'],
#  ['L294', 'L295', 'L296', 'L297'],
#  ['L298', 'L299'],
#  ['L300', 'L301'],
#  ['L349', 'L350', 'L351', 'L352'],
#  ['L354', 'L355', 'L356', 'L357', 'L358'],
#  ['L605', 'L606'],
#  ['L607', 'L608', 'L609'],
#  ['L747', 'L748'],
#  ['L231', 'L232', 'L233', 'L234', 'L235', 'L236'],
#  ['L238', 'L239', 'L240'],
#  ['L502', 'L503', 'L504', 'L505'],
#  ['L508', 'L509'],
#  ['L123', 'L124', 'L125', 'L126', 'L127', 'L128'],
#  ['L129', 'L130'],
#  ['L131', 'L132'],
#  ['L133', 'L134'],
#  ['L151', 'L152'],
#  ['L247', 'L248', 'L249', 'L250', 'L251'],
#  ['L252', 'L253', 'L254'],
#  ['L447', 'L448'],
#  ['L490', 'L491'],
#  ['L716', 'L717', 'L718', 'L719', 'L720', 'L721'],
#  ['L750', 'L751', 'L752', 'L753', 'L754', 'L755'],
#  ['L946', 'L947', 'L948', 'L949'],
#  ['L304', 'L305', 'L306', 'L307'],
#  ['L309', 'L310'],
#  ['L311', 'L312', 'L313'],
#  ['L322', 'L323', 'L324', 'L325', 'L326', 'L327', 'L328'],
#  ['L330', 'L331', 'L332'],
#  ['L333', 'L334'],
#  ['L473', 'L474'],
#  ['L475', 'L476', 'L477'],
#  ['L481', 'L482', 'L483'],
#  ['L564', 'L565', 'L566', 'L567'],
#  ['L610', 'L611'],
#  ['L612', 'L613', 'L614', 'L615', 'L616'],
#  ['L626',
#   'L627',
#   'L628',
#   'L629',
#   'L630',
#   'L631',
#   'L632',
#   'L633',
#   'L634',
#   'L635',
#   'L636'],
#  ['L639', 'L640', 'L641', 'L642', 'L643', 'L644', 'L645', 'L646'],
#  ['L650', 'L651'],
#  ['L668', 'L669'],
#  ['L670', 'L671', 'L672', 'L673', 'L674', 'L675', 'L676'],
#  ['L677', 'L678', 'L679'],
#  ['L680', 'L681', 'L682'],
#  ['L683', 'L684'],
#  ['L686', 'L687', 'L688', 'L689', 'L690'],
#  ['L764', 'L765', 'L766', 'L767', 'L768'],
#  ['L769', 'L770', 'L771', 'L772', 'L773', 'L774'],
#  ['L798', 'L799'],
#  ['L800', 'L801', 'L802'],
#  ['L803', 'L804', 'L805', 'L806'],
#  ['L808', 'L809', 'L810', 'L811', 'L812'],
#  ['L813',
#   'L814',
#   'L815',
#   'L816',
#   'L817',
#   'L818',
#   'L819',
#   'L820',
#   'L821',
#   'L822',
#   'L823'],
#  ['L824', 'L825'],
#  ['L828', 'L829', 'L830', 'L831', 'L832'],
#  ['L834', 'L835', 'L836', 'L837', 'L838', 'L839', 'L840', 'L841'],
#  ['L842', 'L843', 'L844', 'L845', 'L846', 'L847', 'L848'],
#  ['L852', 'L853', 'L854', 'L855', 'L856', 'L857'],
#  ['L936', 'L937', 'L938', 'L939', 'L940'],
#  ['L957', 'L958', 'L959'],
#  ['L960', 'L961'],
#  ['L973', 'L974', 'L975', 'L976', 'L977'],
#  ['L1031', 'L1032'],
#  ['L1033', 'L1034', 'L1035'],
#  ['L1040', 'L1041', 'L1042', 'L1043'],
#  ['L172', 'L173', 'L174'],
#  ['L184', 'L185'],
#  ['L338',
#   'L339',
#   'L340',
#   'L341',
#   'L342',
#   'L343',
#   'L344',
#   'L345',
#   'L346',
#   'L347'],
#  ['L986', 'L987', 'L988'],
#  ['L989', 'L990', 'L991', 'L992', 'L993', 'L994', 'L995', 'L996', 'L997'],
#  ['L998', 'L999', 'L1000'],
#  ['L103', 'L104', 'L105', 'L106', 'L107'],
#  ['L108', 'L109'],
#  ['L1017', 'L1018'],
#  ['L728', 'L729', 'L730', 'L731'],
#  ['L732', 'L733'],
#  ['L735', 'L736', 'L737', 'L738'],
#  ['L371', 'L372', 'L373'],
#  ['L375', 'L376', 'L377'],
#  ['L378', 'L379'],
#  ['L380', 'L381', 'L382'],
#  ['L383', 'L384'],
#  ['L414', 'L415'],
#  ['L420', 'L421'],
#  ['L428', 'L429'],
#  ['L436', 'L437'],
#  ['L723', 'L724'],
#  ['L775', 'L776', 'L777'],
#  ['L59', 'L60', 'L61', 'L62'],
#  ['L257', 'L258', 'L259'],
#  ['L261', 'L262', 'L263', 'L264'],
#  ['L511', 'L512'],
#  ['L161', 'L162'],
#  ['L170', 'L171'],
#  ['L191', 'L192', 'L193'],
#  ['L876', 'L877'],
#  ['L886', 'L887'],
#  ['L917', 'L918'],
#  ['L926', 'L927'],
#  ['L929', 'L930', 'L931', 'L932', 'L933'],
#  ['L2170', 'L2171', 'L2172'],
#  ['L2173', 'L2174', 'L2175'],
#  ['L2176', 'L2177'],
#  ['L2179', 'L2180', 'L2181'],
#  ['L1989', 'L1990', 'L1991', 'L1992', 'L1993'],
#  ['L2005', 'L2006'],
#  ['L2010', 'L2011', 'L2012'],
#  ['L2014', 'L2015', 'L2016'],
#  ['L2019', 'L2020'],
#  ['L2022', 'L2023'],
#  ['L2024', 'L2025'],
#  ['L2027', 'L2028', 'L2029'],
#  ['L2030', 'L2031'],
#  ['L2274', 'L2275'],
#  ['L2522', 'L2523', 'L2524'],
#  ['L1979', 'L1980', 'L1981', 'L1982', 'L1983', 'L1984'],
#  ['L1985', 'L1986'],
#  ['L2118', 'L2119'],
#  ['L2121', 'L2122', 'L2123'],
#  ['L2318', 'L2319', 'L2320'],
#  ['L2471', 'L2472'],
#  ['L2473', 'L2474'],
#  ['L2537', 'L2538'],
#  ['L2539', 'L2540'],
#  ['L2290', 'L2291', 'L2292', 'L2293'],
#  ['L2421', 'L2422'],
#  ['L2423', 'L2424', 'L2425', 'L2426'],
#  ['L2429', 'L2430', 'L2431', 'L2432'],
#  ['L2127', 'L2128', 'L2129'],
#  ['L2130', 'L2131'],
#  ['L2439', 'L2440'],
#  ['L2484', 'L2485'],
#  ['L2500', 'L2501'],
#  ['L2541', 'L2542'],
#  ['L2547', 'L2548', 'L2549'],
#  ['L2550', 'L2551', 'L2552'],
#  ['L2103', 'L2104', 'L2105'],
#  ['L2106', 'L2107', 'L2108'],
#  ['L2109', 'L2110'],
#  ['L2281', 'L2282'],
#  ['L2286', 'L2287'],
#  ['L2295', 'L2296', 'L2297'],
#  ['L2299', 'L2300', 'L2301'],
#  ['L2463', 'L2464'],
#  ['L2465', 'L2466'],
#  ['L2467', 'L2468', 'L2469'],
#  ['L2237', 'L2238', 'L2239'],
#  ['L2248', 'L2249', 'L2250', 'L2251'],
#  ['L2253', 'L2254', 'L2255'],
#  ['L2256', 'L2257', 'L2258', 'L2259', 'L2260'],
#  ['L2341', 'L2342', 'L2343'],
#  ['L2393', 'L2394'],
#  ['L2409', 'L2410'],
#  ['L1942', 'L1943'],
#  ['L1947', 'L1948', 'L1949', 'L1950'],
#  ['L1951', 'L1952'],
#  ['L1957', 'L1958', 'L1959', 'L1960', 'L1961', 'L1962'],
#  ['L1963', 'L1964', 'L1965', 'L1966', 'L1967', 'L1968', 'L1969'],
#  ['L2037', 'L2038', 'L2039', 'L2040'],
#  ['L2041', 'L2042'],
#  ['L2045', 'L2046'],
#  ['L2132', 'L2133'],
#  ['L2134', 'L2135', 'L2136', 'L2137', 'L2138', 'L2139'],
#  ['L2140', 'L2141', 'L2142', 'L2143'],
#  ['L2144', 'L2145'],
#  ['L2525', 'L2526'],
#  ['L2531', 'L2532', 'L2533', 'L2534', 'L2535'],
#  ['L2071', 'L2072'],
#  ['L2073', 'L2074', 'L2075'],
#  ['L2076', 'L2077'],
#  ['L2079', 'L2080', 'L2081', 'L2082'],
#  ['L2085', 'L2086'],
#  ['L2279', 'L2280'],
#  ['L2456', 'L2457', 'L2458', 'L2459'],
#  ['L2277', 'L2278'],
#  ['L2328', 'L2329'],
#  ['L2331', 'L2332', 'L2333'],
#  ['L2345', 'L2346'],
#  ['L2347', 'L2348'],
#  ['L2386', 'L2387', 'L2388', 'L2389'],
#  ['L2154', 'L2155'],
#  ['L2157', 'L2158', 'L2159', 'L2160'],
#  ['L2164', 'L2165'],
#  ['L2490', 'L2491', 'L2492'],
#  ['L2064', 'L2065'],
#  ['L2196',
#   'L2197',
#   'L2198',
#   'L2199',
#   'L2200',
#   'L2201',
#   'L2202',
#   'L2203',
#   'L2204',
#   'L2205',
#   'L2206',
#   'L2207',
#   'L2208',
#   'L2209',
#   'L2210',
#   'L2211'],
#  ['L1930', 'L1931'],
#  ['L2112', 'L2113'],
#  ['L2115', 'L2116'],
#  ['L2376', 'L2377'],
#  ['L2414', 'L2415'],
#  ['L2417', 'L2418', 'L2419'],
#  ['L2460', 'L2461', 'L2462'],
#  ['L3380', 'L3381', 'L3382'],
#  ['L3383', 'L3384', 'L3385'],
#  ['L3392', 'L3393', 'L3394', 'L3395', 'L3396'],
#  ['L3459', 'L3460', 'L3461'],
#  ['L3464',
#   'L3465',
#   'L3466',
#   'L3467',
#   'L3468',
#   'L3469',
#   'L3470',
#   'L3471',
#   'L3472',
#   'L3473',
#   'L3474',
#   'L3475',
#   'L3476',
#   'L3477',
#   'L3478',
#   'L3479',
#   'L3480',
#   'L3481'],
#  ['L3482', 'L3483', 'L3484', 'L3485', 'L3486', 'L3487', 'L3488', 'L3489'],
#  ['L3490', 'L3491', 'L3492', 'L3493'],
#  ['L3496', 'L3497'],
#  ['L3545', 'L3546'],
#  ['L3059', 'L3060', 'L3061'],
#  ['L3089', 'L3090', 'L3091', 'L3092'],
#  ['L3093', 'L3094', 'L3095'],
#  ['L3096', 'L3097'],
#  ['L3158', 'L3159', 'L3160'],
#  ['L3161', 'L3162', 'L3163', 'L3164', 'L3165', 'L3166'],
#  ['L3167', 'L3168', 'L3169', 'L3170'],
#  ['L3177', 'L3178', 'L3179', 'L3180', 'L3181'],
#  ['L3300', 'L3301', 'L3302'],
#  ['L3305', 'L3306', 'L3307', 'L3308'],
#  ['L3309', 'L3310', 'L3311'],
#  ['L3313', 'L3314'],
#  ['L3315', 'L3316', 'L3317', 'L3318'],
#  ['L3329', 'L3330'],
#  ['L3514', 'L3515', 'L3516', 'L3517'],
#  ['L3045', 'L3046', 'L3047', 'L3048'],
#  ['L3049', 'L3050', 'L3051'],
#  ['L3055', 'L3056'],
#  ['L3062', 'L3063', 'L3064', 'L3065'],
#  ['L3208', 'L3209', 'L3210', 'L3211', 'L3212', 'L3213', 'L3214'],
#  ['L2797', 'L2798', 'L2799', 'L2800'],
#  ['L3196', 'L3197'],
#  ['L3198', 'L3199', 'L3200', 'L3201', 'L3202', 'L3203'],
#  ['L3293', 'L3294'],
#  ['L3498',
#   'L3499',
#   'L3500',
#   'L3501',
#   'L3502',
#   'L3503',
#   'L3504',
#   'L3505',
#   'L3506'],
#  ['L2801', 'L2802', 'L2803', 'L2804', 'L2805'],
#  ['L3289', 'L3290', 'L3291', 'L3292'],
#  ['L2599', 'L2600', 'L2601'],
#  ['L2602', 'L2603'],
#  ['L2630', 'L2631', 'L2632', 'L2633'],
#  ['L2751', 'L2752'],
#  ['L2920', 'L2921', 'L2922', 'L2923'],
#  ['L2924', 'L2925'],
#  ['L2936', 'L2937', 'L2938'],
#  ['L3016', 'L3017'],
#  ['L3022', 'L3023'],
#  ['L3027', 'L3028'],
#  ['L2964', 'L2965', 'L2966', 'L2967'],
#  ['L2971', 'L2972', 'L2973'],
#  ['L2975', 'L2976', 'L2977', 'L2978'],
#  ['L2979', 'L2980', 'L2981'],
#  ['L2986', 'L2987', 'L2988', 'L2989', 'L2990'],
#  ['L2730', 'L2731'],
#  ['L2746', 'L2747', 'L2748'],
#  ['L2875', 'L2876', 'L2877', 'L2878', 'L2879', 'L2880', 'L2881', 'L2882'],
#  ['L2883', 'L2884', 'L2885', 'L2886'],
#  ['L2887', 'L2888', 'L2889', 'L2890', 'L2891'],
#  ['L2892', 'L2893'],
#  ['L2895', 'L2896', 'L2897'],
#  ['L2899', 'L2900', 'L2901', 'L2902', 'L2903', 'L2904', 'L2905', 'L2906'],
#  ['L2949', 'L2950', 'L2951', 'L2952', 'L2953'],
#  ['L2955', 'L2956', 'L2957', 'L2958'],
#  ['L2962', 'L2963'],
#  ['L2991', 'L2992'],
#  ['L2993', 'L2994', 'L2995', 'L2996', 'L2997', 'L2998', 'L2999'],
#  ['L3052', 'L3053', 'L3054'],
#  ['L3057', 'L3058'],
#  ['L3067', 'L3068'],
#  ['L3069',
#   'L3070',
#   'L3071',
#   'L3072',
#   'L3073',
#   'L3074',
#   'L3075',
#   'L3076',
#   'L3077',
#   'L3078',
#   'L3079'],
#  ['L3080', 'L3081', 'L3082'],
#  ['L3219', 'L3220', 'L3221', 'L3222'],
#  ['L3223', 'L3224', 'L3225', 'L3226', 'L3227', 'L3228'],
#  ['L3229', 'L3230'],
#  ['L3236', 'L3237', 'L3238', 'L3239', 'L3240', 'L3241', 'L3242'],
#  ['L3243', 'L3244'],
#  ['L3248', 'L3249'],
#  ['L2758', 'L2759', 'L2760', 'L2761', 'L2762', 'L2763', 'L2764', 'L2765'],
#  ['L3029', 'L3030'],
#  ['L3031', 'L3032', 'L3033', 'L3034', 'L3035', 'L3036', 'L3037'],
#  ['L3038', 'L3039', 'L3040', 'L3041', 'L3042', 'L3043', 'L3044'],
#  ['L3101', 'L3102'],
#  ['L3103',
#   'L3104',
#   'L3105',
#   'L3106',
#   'L3107',
#   'L3108',
#   'L3109',
#   'L3110',
#   'L3111',
#   'L3112',
#   'L3113',
#   'L3114',
#   'L3115',
#   'L3116',
#   'L3117'],
#  ['L3119', 'L3120', 'L3121'],
#  ['L3126', 'L3127', 'L3128', 'L3129', 'L3130'],
#  ['L3135',
#   'L3136',
#   'L3137',
#   'L3138',
#   'L3139',
#   'L3140',
#   'L3141',
#   'L3142',
#   'L3143',
#   'L3144',
#   'L3145',
#   'L3146',
#   'L3147'],
#  ['L3148',
#   'L3149',
#   'L3150',
#   'L3151',
#   'L3152',
#   'L3153',
#   'L3154',
#   'L3155',
#   'L3156',
#   'L3157'],
#  ['L2595', 'L2596'],
#  ['L2604', 'L2605', 'L2606', 'L2607'],
#  ['L2611', 'L2612'],
#  ['L2644', 'L2645'],
#  ['L2646', 'L2647', 'L2648'],
#  ['L2651', 'L2652'],
#  ['L2653', 'L2654', 'L2655', 'L2656'],
#  ['L2664', 'L2665'],
#  ['L2621', 'L2622', 'L2623', 'L2624', 'L2625', 'L2626'],
#  ['L2627', 'L2628'],
#  ['L3278',
#   'L3279',
#   'L3280',
#   'L3281',
#   'L3282',
#   'L3283',
#   'L3284',
#   'L3285',
#   'L3286'],
#  ['L3419', 'L3420', 'L3421'],
#  ['L3431', 'L3432'],
#  ['L3433', 'L3434'],
#  ['L3435', 'L3436'],
#  ['L3554', 'L3555', 'L3556'],
#  ['L2845', 'L2846', 'L2847'],
#  ['L2848', 'L2849'],
#  ['L2850', 'L2851', 'L2852', 'L2853', 'L2854'],
#  ['L2855', 'L2856'],
#  ['L2857', 'L2858'],
#  ['L2563', 'L2564'],
#  ['L2565', 'L2566', 'L2567', 'L2568', 'L2569'],
#  ['L2570', 'L2571', 'L2572', 'L2573', 'L2574'],
#  ['L2577', 'L2578', 'L2579', 'L2580', 'L2581'],
#  ['L2908', 'L2909'],
#  ['L2910', 'L2911', 'L2912', 'L2913', 'L2914', 'L2915'],
#  ['L2557', 'L2558'],
#  ['L2559', 'L2560'],
#  ['L2561', 'L2562'],
#  ['L2635', 'L2636', 'L2637', 'L2638'],
#  ['L2639', 'L2640'],
#  ['L2666', 'L2667', 'L2668'],
#  ['L2670', 'L2671'],
#  ['L2778', 'L2779'],
#  ['L2780', 'L2781', 'L2782', 'L2783'],
#  ['L2789', 'L2790'],
#  ['L2842', 'L2843', 'L2844'],
#  ['L3083', 'L3084', 'L3085'],
#  ['L3087', 'L3088'],
#  ['L3183', 'L3184', 'L3185', 'L3186', 'L3187', 'L3188'],
#  ['L3189', 'L3190'],
#  ['L3191', 'L3192', 'L3193'],
#  ['L3246', 'L3247'],
#  ['L3250', 'L3251'],
#  ['L3356', 'L3357'],
#  ['L3359', 'L3360'],
#  ['L3361', 'L3362'],
#  ['L3363', 'L3364'],
#  ['L3365', 'L3366'],
#  ['L3368', 'L3369', 'L3370'],
#  ['L3372', 'L3373', 'L3374', 'L3375'],
#  ['L3376', 'L3377', 'L3378'],
#  ['L3547', 'L3548'],
#  ['L2672', 'L2673'],
#  ['L2674', 'L2675', 'L2676'],
#  ['L2678', 'L2679'],
#  ['L2680', 'L2681', 'L2682'],
#  ['L2685', 'L2686', 'L2687', 'L2688', 'L2689', 'L2690', 'L2691', 'L2692'],
#  ['L3271', 'L3272', 'L3273', 'L3274', 'L3275'],
#  ['L3352', 'L3353'],
#  ['L2608', 'L2609', 'L2610'],
#  ['L2614', 'L2615'],
#  ['L3409', 'L3410'],
#  ['L3411', 'L3412', 'L3413'],
#  ['L3262', 'L3263', 'L3264', 'L3265', 'L3266', 'L3267', 'L3268', 'L3269'],
#  ['L2575', 'L2576'],
#  ['L2582',
#   'L2583',
#   'L2584',
#   'L2585',
#   'L2586',
#   'L2587',
#   'L2588',
#   'L2589',
#   'L2590',
#   'L2591'],
#  ['L2732', 'L2733'],
#  ['L2740', 'L2741', 'L2742', 'L2743'],
#  ['L2744', 'L2745'],
#  ['L3398', 'L3399', 'L3400', 'L3401', 'L3402', 'L3403'],
#  ['L2698', 'L2699', 'L2700'],
#  ['L2701', 'L2702', 'L2703'],
#  ['L2706', 'L2707'],
#  ['L2771', 'L2772', 'L2773'],
#  ['L2808', 'L2809', 'L2810', 'L2811', 'L2812', 'L2813'],
#  ['L2715', 'L2716', 'L2717', 'L2718', 'L2719', 'L2720', 'L2721'],
#  ['L2724', 'L2725'],
#  ['L2735', 'L2736', 'L2737'],
#  ['L2738', 'L2739'],
#  ['L2754', 'L2755', 'L2756', 'L2757'],
#  ['L2767', 'L2768'],
#  ['L2793', 'L2794', 'L2795'],
#  ['L2863', 'L2864', 'L2865'],
#  ['L2870', 'L2871', 'L2872'],
#  ['L3024', 'L3025', 'L3026'],
#  ['L3287', 'L3288'],
#  ['L3342', 'L3343', 'L3344'],
#  ['L2928', 'L2929', 'L2930'],
#  ['L3422', 'L3423', 'L3424'],
#  ['L3425', 'L3426', 'L3427'],
#  ['L2828',
#   'L2829',
#   'L2830',
#   'L2831',
#   'L2832',
#   'L2833',
#   'L2834',
#   'L2835',
#   'L2836',
#   'L2837',
#   'L2838',
#   'L2839',
#   'L2840'],
#  ['L3712', 'L3713'],
#  ['L3720', 'L3721'],
#  ['L3728', 'L3729'],
#  ['L3749', 'L3750'],
#  ['L3756', 'L3757'],
#  ['L3770', 'L3771'],
#  ['L3777', 'L3778'],
#  ['L3942', 'L3943', 'L3944', 'L3945'],
#  ['L3963', 'L3964', 'L3965', 'L3966', 'L3967', 'L3968', 'L3969'],
#  ['L3972', 'L3973', 'L3974', 'L3975', 'L3976'],
#  ['L3979', 'L3980', 'L3981', 'L3982', 'L3983', 'L3984'],
#  ['L3987', 'L3988', 'L3989', 'L3990', 'L3991', 'L3992'],
#  ['L3995', 'L3996', 'L3997', 'L3998', 'L3999', 'L4000', 'L4001'],
#  ['L4011', 'L4012', 'L4013', 'L4014', 'L4015', 'L4016', 'L4017'],
#  ['L4159', 'L4160', 'L4161', 'L4162', 'L4163'],
#  ['L4188', 'L4189', 'L4190', 'L4191', 'L4192', 'L4193'],
#  ['L4196', 'L4197', 'L4198', 'L4199'],
#  ['L4208', 'L4209'],
#  ['L4282', 'L4283'],
#  ['L4296', 'L4297', 'L4298', 'L4299', 'L4300'],
#  ['L4006', 'L4007'],
#  ['L4068', 'L4069', 'L4070'],
#  ['L4079', 'L4080'],
#  ['L4219', 'L4220', 'L4221', 'L4222', 'L4223', 'L4224'],
#  ['L4227', 'L4228', 'L4229', 'L4230'],
#  ['L4265', 'L4266', 'L4267', 'L4268', 'L4269', 'L4270', 'L4271'],
#  ['L4333', 'L4334', 'L4335'],
#  ['L4346', 'L4347', 'L4348', 'L4349', 'L4350'],
#  ['L4353', 'L4354', 'L4355', 'L4356', 'L4357'],
#  ['L4360', 'L4361', 'L4362', 'L4363'],
#  ['L4366', 'L4367', 'L4368'],
#  ['L3970', 'L3971'],
#  ['L3977', 'L3978'],
#  ['L3993', 'L3994'],
#  ['L4002', 'L4003'],
#  ['L4009', 'L4010'],
#  ['L4018', 'L4019'],
#  ['L3668', 'L3669'],
#  ['L3672', 'L3673', 'L3674', 'L3675', 'L3676', 'L3677'],
#  ['L3679', 'L3680', 'L3681', 'L3682', 'L3683', 'L3684', 'L3685'],
#  ['L3688', 'L3689', 'L3690', 'L3691', 'L3692', 'L3693'],
#  ['L3797', 'L3798', 'L3799'],
#  ['L3805', 'L3806', 'L3807', 'L3808', 'L3809', 'L3810'],
#  ['L3730', 'L3731', 'L3732', 'L3733', 'L3734', 'L3735'],
#  ['L3758', 'L3759'],
#  ['L3774', 'L3775', 'L3776'],
#  ['L3779', 'L3780'],
#  ['L3622', 'L3623'],
#  ['L3626', 'L3627', 'L3628', 'L3629', 'L3630', 'L3631'],
#  ['L3651', 'L3652', 'L3653'],
#  ['L3724', 'L3725', 'L3726'],
#  ['L3738', 'L3739', 'L3740'],
#  ['L3745', 'L3746', 'L3747', 'L3748'],
#  ['L3751', 'L3752', 'L3753', 'L3754'],
#  ['L3760', 'L3761', 'L3762', 'L3763'],
#  ['L3766', 'L3767', 'L3768'],
#  ['L3772', 'L3773'],
#  ['L3868', 'L3869'],
#  ['L3889', 'L3890', 'L3891', 'L3892', 'L3893'],
#  ['L3896', 'L3897'],
#  ['L3904', 'L3905', 'L3906', 'L3907'],
#  ['L3817', 'L3818', 'L3819', 'L3820', 'L3821'],
#  ['L3824', 'L3825', 'L3826', 'L3827', 'L3828', 'L3829'],
#  ['L3832', 'L3833', 'L3834'],
#  ['L3837', 'L3838', 'L3839'],
#  ['L4020', 'L4021', 'L4022', 'L4023', 'L4024', 'L4025'],
#  ['L4028', 'L4029', 'L4030', 'L4031', 'L4032', 'L4033'],
#  ['L4096', 'L4097'],
#  ['L4108', 'L4109', 'L4110', 'L4111', 'L4112', 'L4113'],
#  ['L4118', 'L4119'],
#  ['L4169', 'L4170'],
#  ['L4174', 'L4175'],
#  ['L4181', 'L4182', 'L4183'],
#  ['L5039', 'L5040'],
#  ['L5041', 'L5042'],
#  ['L5043', 'L5044'],
#  ['L5045', 'L5046', 'L5047', 'L5048'],
#  ['L4897', 'L4898', 'L4899', 'L4900'],
#  ['L4903', 'L4904', 'L4905', 'L4906'],
#  ['L4922', 'L4923'],
#  ['L4924', 'L4925'],
#  ['L4453', 'L4454'],
#  ['L4501', 'L4502', 'L4503', 'L4504', 'L4505'],
#  ['L4506', 'L4507', 'L4508', 'L4509', 'L4510', 'L4511'],
#  ['L4562', 'L4563'],
#  ['L4567', 'L4568'],
#  ['L5175', 'L5176', 'L5177', 'L5178', 'L5179', 'L5180'],
#  ['L5181', 'L5182'],
#  ['L5183', 'L5184', 'L5185', 'L5186', 'L5187', 'L5188'],
#  ['L5193', 'L5194'],
#  ['L5215', 'L5216'],
#  ['L5366', 'L5367', 'L5368'],
#  ['L5370', 'L5371'],
#  ['L4944', 'L4945'],
#  ['L4959', 'L4960'],
#  ['L5316', 'L5317', 'L5318'],
#  ['L5321', 'L5322', 'L5323', 'L5324', 'L5325'],
#  ['L5328', 'L5329'],
#  ['L4628', 'L4629'],
#  ['L5338', 'L5339', 'L5340'],
#  ['L5346', 'L5347', 'L5348'],
#  ['L4727', 'L4728', 'L4729'],
#  ['L4731', 'L4732'],
#  ['L4739', 'L4740', 'L4741'],
#  ['L4743',
#   'L4744',
#   'L4745',
#   'L4746',
#   'L4747',
#   'L4748',
#   'L4749',
#   'L4750',
#   'L4751'],
#  ['L4763', 'L4764'],
#  ['L4765', 'L4766'],
#  ['L4769', 'L4770'],
#  ['L4771', 'L4772', 'L4773', 'L4774', 'L4775'],
#  ['L4778', 'L4779'],
#  ['L4780', 'L4781', 'L4782', 'L4783', 'L4784', 'L4785'],
#  ['L4786', 'L4787', 'L4788'],
#  ['L4789', 'L4790', 'L4791', 'L4792'],
#  ['L4800', 'L4801', 'L4802', 'L4803'],
#  ['L4814', 'L4815', 'L4816'],
#  ['L4825', 'L4826', 'L4827', 'L4828'],
#  ['L4848', 'L4849', 'L4850', 'L4851', 'L4852', 'L4853', 'L4854', 'L4855'],
#  ['L4857', 'L4858'],
#  ['L4860', 'L4861'],
#  ['L4863', 'L4864'],
#  ['L4866', 'L4867'],
#  ['L4868', 'L4869'],
#  ['L4870', 'L4871'],
#  ['L4873', 'L4874', 'L4875', 'L4876', 'L4877', 'L4878', 'L4879'],
#  ['L4880', 'L4881'],
#  ['L4882', 'L4883', 'L4884', 'L4885', 'L4886'],
#  ['L4887', 'L4888', 'L4889', 'L4890', 'L4891'],
#  ['L4893', 'L4894'],
#  ['L4895', 'L4896'],
#  ['L4911', 'L4912'],
#  ['L4929', 'L4930'],
#  ['L4937', 'L4938', 'L4939'],
#  ['L4964', 'L4965'],
#  ['L4969', 'L4970', 'L4971', 'L4972', 'L4973'],
#  ['L4974', 'L4975'],
#  ['L4994', 'L4995', 'L4996', 'L4997'],
#  ['L5002', 'L5003', 'L5004', 'L5005'],
#  ['L5007', 'L5008', 'L5009', 'L5010'],
#  ['L5011', 'L5012', 'L5013', 'L5014'],
#  ['L5016', 'L5017'],
#  ['L5018', 'L5019', 'L5020'],
#  ['L5021', 'L5022'],
#  ['L5023', 'L5024', 'L5025'],
#  ['L5028', 'L5029', 'L5030'],
#  ['L5033', 'L5034', 'L5035'],
#  ['L5036', 'L5037', 'L5038'],
#  ['L5049', 'L5050', 'L5051'],
#  ['L5052', 'L5053', 'L5054', 'L5055', 'L5056'],
#  ['L5057', 'L5058', 'L5059'],
#  ['L5060', 'L5061', 'L5062', 'L5063', 'L5064'],
#  ['L5065', 'L5066'],
#  ['L5067', 'L5068'],
#  ['L5069', 'L5070', 'L5071', 'L5072'],
#  ['L5073', 'L5074'],
#  ['L5076', 'L5077'],
#  ['L5083', 'L5084', 'L5085'],
#  ['L5171', 'L5172'],
#  ['L5190', 'L5191', 'L5192'],
#  ['L5195', 'L5196'],
#  ['L5197', 'L5198', 'L5199', 'L5200'],
#  ['L5201', 'L5202'],
#  ['L5204', 'L5205'],
#  ['L5206', 'L5207'],
#  ['L5208', 'L5209', 'L5210'],
#  ['L5212', 'L5213'],
#  ['L5224', 'L5225', 'L5226', 'L5227'],
#  ['L5236', 'L5237'],
#  ['L5249', 'L5250', 'L5251', 'L5252'],
#  ['L5253', 'L5254', 'L5255'],
#  ['L5256', 'L5257'],
#  ['L5290', 'L5291'],
#  ['L5304', 'L5305'],
#  ['L5306', 'L5307'],
#  ['L5308', 'L5309', 'L5310', 'L5311', 'L5312', 'L5313', 'L5314'],
#  ['L5351', 'L5352', 'L5353'],
#  ['L5372', 'L5373'],
#  ['L5375', 'L5376'],
#  ['L5377', 'L5378', 'L5379', 'L5380', 'L5381', 'L5382'],
#  ['L5383', 'L5384'],
#  ['L4689', 'L4690'],
#  ['L4691', 'L4692'],
#  ['L4693',
#   'L4694',
#   'L4695',
#   'L4696',
#   'L4697',
#   'L4698',
#   'L4699',
#   'L4700',
#   'L4701',
#   'L4702',
#   'L4703'],
#  ['L5093', 'L5094', 'L5095', 'L5096'],
#  ['L5097', 'L5098', 'L5099'],
#  ['L5100', 'L5101'],
#  ['L5102', 'L5103', 'L5104'],
#  ['L5242', 'L5243'],
#  ['L5244', 'L5245'],
#  ['L4636', 'L4637', 'L4638', 'L4639'],
#  ['L4642', 'L4643', 'L4644'],
#  ['L4669', 'L4670', 'L4671'],
#  ['L4672', 'L4673'],
#  ['L4675', 'L4676'],
#  ['L4677', 'L4678', 'L4679', 'L4680'],
#  ['L4681', 'L4682'],
#  ['L4685', 'L4686', 'L4687'],
#  ['L5132', 'L5133', 'L5134', 'L5135', 'L5136', 'L5137', 'L5138'],
#  ['L5142', 'L5143'],
#  ['L5144', 'L5145'],
#  ['L5158', 'L5159'],
#  ['L5162', 'L5163'],
#  ['L4809', 'L4810', 'L4811', 'L4812', 'L4813'],
#  ['L4817', 'L4818', 'L4819'],
#  ['L4821', 'L4822', 'L4823'],
#  ['L4467', 'L4468'],
#  ['L4469', 'L4470', 'L4471'],
#  ['L4472', 'L4473', 'L4474'],
#  ['L4475', 'L4476'],
#  ['L4477',
#   'L4478',
#   'L4479',
#   'L4480',
#   'L4481',
#   'L4482',
#   'L4483',
#   'L4484',
#   'L4485',
#   'L4486',
#   'L4487',
#   'L4488'],
#  ['L4513', 'L4514'],
#  ['L4516', 'L4517'],
#  ['L4519', 'L4520', 'L4521', 'L4522'],
#  ['L4523', 'L4524', 'L4525'],
#  ['L4528', 'L4529', 'L4530', 'L4531', 'L4532'],
#  ['L4533', 'L4534', 'L4535'],
#  ['L4704', 'L4705', 'L4706'],
#  ['L4707', 'L4708', 'L4709'],
#  ['L4712', 'L4713', 'L4714', 'L4715', 'L4716', 'L4717', 'L4718'],
#  ['L4836', 'L4837'],
#  ['L4839', 'L4840'],
#  ['L5149', 'L5150', 'L5151', 'L5152', 'L5153'],
#  ['L5164', 'L5165'],
#  ['L5167', 'L5168', 'L5169'],
#  ['L5219', 'L5220', 'L5221'],
#  ['L5258', 'L5259', 'L5260', 'L5261', 'L5262', 'L5263'],
#  ['L5275', 'L5276'],
#  ['L5284', 'L5285', 'L5286', 'L5287'],
#  ['L5292', 'L5293', 'L5294', 'L5295', 'L5296', 'L5297', 'L5298'],
#  ['L5301', 'L5302', 'L5303'],
#  ['L5355', 'L5356', 'L5357', 'L5358'],
#  ['L5359', 'L5360', 'L5361', 'L5362', 'L5363'],
#  ['L5364', 'L5365'],
#  ['L5264', 'L5265'],
#  ['L5266', 'L5267', 'L5268'],
#  ['L5279', 'L5280', 'L5281', 'L5282'],
#  ['L5288', 'L5289'],
#  ['L4600', 'L4601', 'L4602'],
#  ['L4603', 'L4604'],
#  ['L4609', 'L4610'],
#  ['L4612', 'L4613'],
#  ['L4493', 'L4494'],
#  ['L4495', 'L4496', 'L4497', 'L4498', 'L4499', 'L4500'],
#  ['L4543', 'L4544', 'L4545', 'L4546', 'L4547'],
#  ['L4548', 'L4549', 'L4550', 'L4551', 'L4552', 'L4553', 'L4554', 'L4555'],
#  ['L4558', 'L4559'],
#  ['L5230', 'L5231'],
#  ['L5233', 'L5234'],
#  ['L5105', 'L5106'],
#  ['L5107', 'L5108'],
#  ['L5109', 'L5110'],
#  ['L5113', 'L5114'],
#  ['L5115', 'L5116', 'L5117', 'L5118', 'L5119', 'L5120'],
#  ['L5121', 'L5122', 'L5123'],
#  ['L5124', 'L5125'],
#  ['L5643', 'L5644', 'L5645'],
#  ['L5673', 'L5674'],
#  ['L5678', 'L5679', 'L5680'],
#  ['L5692', 'L5693'],
#  ['L5875', 'L5876'],
#  ['L5889', 'L5890'],
#  ['L5710', 'L5711'],
#  ['L5737',
#   'L5738',
#   'L5739',
#   'L5740',
#   'L5741',
#   'L5742',
#   'L5743',
#   'L5744',
#   'L5745'],
#  ['L5746', 'L5747', 'L5748'],
#  ['L5751', 'L5752'],
#  ['L5754', 'L5755', 'L5756'],
#  ['L5760', 'L5761'],
#  ['L5613', 'L5614'],
#  ['L5615', 'L5616', 'L5617'],
#  ['L5620', 'L5621', 'L5622'],
#  ['L5624', 'L5625', 'L5626', 'L5627', 'L5628'],
#  ['L5648', 'L5649', 'L5650', 'L5651'],
#  ['L5652', 'L5653', 'L5654', 'L5655'],
#  ['L5656', 'L5657', 'L5658'],
#  ['L5826', 'L5827', 'L5828', 'L5829', 'L5830', 'L5831', 'L5832', 'L5833'],
#  ['L5839', 'L5840'],
#  ['L6168', 'L6169', 'L6170', 'L6171', 'L6172'],
#  ['L6258', 'L6259'],
#  ['L6263', 'L6264', 'L6265', 'L6266'],
#  ['L5463', 'L5464'],
#  ['L5468', 'L5469', 'L5470'],
#  ['L5508', 'L5509', 'L5510'],
#  ['L5511', 'L5512'],
#  ['L5515', 'L5516'],
#  ['L5521', 'L5522'],
#  ['L5556', 'L5557'],
#  ['L5630', 'L5631', 'L5632'],
#  ['L5636', 'L5637'],
#  ['L5646', 'L5647'],
#  ['L5671', 'L5672'],
#  ['L5675', 'L5676'],
#  ['L5686', 'L5687'],
#  ['L5688', 'L5689'],
#  ['L5730', 'L5731'],
#  ['L5911', 'L5912', 'L5913'],
#  ['L6251', 'L6252'],
#  ['L6105', 'L6106', 'L6107'],
#  ['L6108', 'L6109', 'L6110'],
#  ['L6114', 'L6115', 'L6116', 'L6117', 'L6118', 'L6119', 'L6120'],
#  ['L6123', 'L6124'],
#  ['L5488', 'L5489'],
#  ['L5490', 'L5491', 'L5492'],
#  ['L5493', 'L5494', 'L5495', 'L5496'],
#  ['L5497', 'L5498', 'L5499'],
#  ['L5501', 'L5502', 'L5503', 'L5504', 'L5505', 'L5506'],
#  ['L5664', 'L5665', 'L5666', 'L5667', 'L5668'],
#  ['L5669', 'L5670'],
#  ['L5596', 'L5597'],
#  ['L5605', 'L5606'],
#  ['L5609', 'L5610'],
#  ['L5611', 'L5612'],
#  ['L5633', 'L5634'],
#  ['L5638', 'L5639', 'L5640', 'L5641'],
#  ['L5420', 'L5421'],
#  ['L5422', 'L5423', 'L5424', 'L5425'],
#  ['L5426', 'L5427'],
#  ['L5777', 'L5778', 'L5779', 'L5780'],
#  ['L5782', 'L5783'],
#  ['L5785', 'L5786'],
#  ['L5787', 'L5788', 'L5789'],
#  ['L5790', 'L5791', 'L5792'],
#  ['L5880', 'L5881', 'L5882'],
#  ['L6029', 'L6030', 'L6031', 'L6032'],
#  ['L5543', 'L5544'],
#  ['L5545', 'L5546', 'L5547', 'L5548'],
#  ['L5834', 'L5835'],
#  ['L6208', 'L6209'],
#  ['L6211', 'L6212'],
#  ['L5922', 'L5923'],
#  ['L5924', 'L5925'],
#  ['L5933', 'L5934'],
#  ['L6020', 'L6021', 'L6022', 'L6023', 'L6024', 'L6025', 'L6026'],
#  ['L6132', 'L6133'],
#  ['L6156', 'L6157', 'L6158'],
#  ['L6183', 'L6184'],
#  ['L6190', 'L6191'],
#  ['L6206', 'L6207'],
#  ['L6213', 'L6214'],
#  ['L6215', 'L6216'],
#  ['L6278', 'L6279', 'L6280'],
#  ['L6282', 'L6283'],
#  ['L5794', 'L5795', 'L5796', 'L5797', 'L5798', 'L5799', 'L5800'],
#  ['L5801', 'L5802', 'L5803'],
#  ['L5804', 'L5805', 'L5806'],
#  ['L5809', 'L5810', 'L5811', 'L5812', 'L5813'],
#  ['L5815', 'L5816'],
#  ['L5817', 'L5818', 'L5819'],
#  ['L5820', 'L5821', 'L5822'],
#  ['L5824', 'L5825'],
#  ['L5858', 'L5859'],
#  ['L5869', 'L5870', 'L5871'],
#  ['L5900', 'L5901'],
#  ['L5943', 'L5944'],
#  ['L5946', 'L5947'],
#  ['L5949', 'L5950'],
#  ['L5954', 'L5955', 'L5956', 'L5957'],
#  ['L5958', 'L5959', 'L5960', 'L5961', 'L5962', 'L5963', 'L5964', 'L5965'],
#  ['L6051', 'L6052', 'L6053', 'L6054', 'L6055', 'L6056'],
#  ['L6057', 'L6058', 'L6059'],
#  ['L6062', 'L6063', 'L6064'],
#  ['L6066', 'L6067'],
#  ['L6237', 'L6238', 'L6239', 'L6240', 'L6241'],
#  ['L6267', 'L6268', 'L6269', 'L6270'],
#  ['L6289', 'L6290', 'L6291', 'L6292', 'L6293'],
#  ['L6297', 'L6298', 'L6299', 'L6300', 'L6301'],
#  ['L6302', 'L6303', 'L6304', 'L6305'],
#  ['L6308', 'L6309'],
#  ['L5722', 'L5723', 'L5724', 'L5725', 'L5726'],
#  ['L5728', 'L5729'],
#  ['L5531', 'L5532', 'L5533'],
#  ['L5534', 'L5535', 'L5536'],
#  ['L5537', 'L5538'],
#  ['L5539', 'L5540'],
#  ['L5560', 'L5561', 'L5562', 'L5563', 'L5564', 'L5565', 'L5566', 'L5567'],
#  ['L5568', 'L5569', 'L5570'],
#  ['L5573', 'L5574'],
#  ['L5585', 'L5586'],
#  ['L6313', 'L6314'],
#  ['L5767', 'L5768', 'L5769', 'L5770'],
#  ['L5773', 'L5774'],
#  ['L6254', 'L6255'],
#  ['L5441', 'L5442'],
#  ['L5443', 'L5444', 'L5445', 'L5446', 'L5447'],
#  ['L5448', 'L5449', 'L5450', 'L5451', 'L5452', 'L5453'],
#  ['L5479', 'L5480'],
#  ['L5396', 'L5397', 'L5398'],
#  ['L5399', 'L5400'],
#  ['L5404', 'L5405'],
#  ['L5406', 'L5407'],
#  ['L6219', 'L6220', 'L6221', 'L6222', 'L6223', 'L6224', 'L6225'],
#  ['L6002', 'L6003'],
#  ['L6004', 'L6005'],
#  ['L6006', 'L6007', 'L6008', 'L6009'],
#  ['L6011', 'L6012'],
#  ['L6335', 'L6336'],
#  ['L6337', 'L6338', 'L6339', 'L6340', 'L6341', 'L6342', 'L6343', 'L6344'],
#  ['L6347', 'L6348', 'L6349', 'L6350'],
#  ['L6351', 'L6352'],
#  ['L6361', 'L6362', 'L6363', 'L6364', 'L6365'],
#  ['L6429', 'L6430', 'L6431', 'L6432', 'L6433', 'L6434', 'L6435'],
#  ['L6957', 'L6958', 'L6959'],
#  ['L6960', 'L6961', 'L6962', 'L6963', 'L6964'],
#  ['L6971', 'L6972', 'L6973', 'L6974', 'L6975', 'L6976'],
#  ['L6977', 'L6978', 'L6979'],
#  ['L6980', 'L6981', 'L6982', 'L6983', 'L6984', 'L6985'],
#  ['L6986', 'L6987', 'L6988', 'L6989', 'L6990', 'L6991', 'L6992', 'L6993'],
#  ['L6996', 'L6997', 'L6998', 'L6999', 'L7000'],
#  ['L7001', 'L7002'],
#  ['L6605', 'L6606'],
#  ['L6607', 'L6608', 'L6609', 'L6610', 'L6611', 'L6612'],
#  ['L6707',
#   'L6708',
#   'L6709',
#   'L6710',
#   'L6711',
#   'L6712',
#   'L6713',
#   'L6714',
#   'L6715',
#   'L6716',
#   'L6717'],
#  ['L6909', 'L6910'],
#  ['L6779', 'L6780'],
#  ['L6781', 'L6782', 'L6783', 'L6784'],
#  ['L6789', 'L6790'],
#  ['L6791',
#   'L6792',
#   'L6793',
#   'L6794',
#   'L6795',
#   'L6796',
#   'L6797',
#   'L6798',
#   'L6799'],
#  ['L6800', 'L6801', 'L6802'],
#  ['L6803', 'L6804', 'L6805', 'L6806', 'L6807', 'L6808'],
#  ['L6810', 'L6811', 'L6812'],
#  ['L6814', 'L6815'],
#  ['L6828', 'L6829'],
#  ['L6830', 'L6831', 'L6832'],
#  ['L6833', 'L6834', 'L6835'],
#  ['L6840', 'L6841', 'L6842'],
#  ['L6844', 'L6845', 'L6846'],
#  ['L6852', 'L6853'],
#  ['L6858', 'L6859', 'L6860', 'L6861', 'L6862'],
#  ['L6863', 'L6864'],
#  ['L6847', 'L6848'],
#  ['L6865', 'L6866'],
#  ['L6906', 'L6907', 'L6908'],
#  ['L6911', 'L6912'],
#  ['L6935', 'L6936'],
#  ['L6437', 'L6438', 'L6439', 'L6440', 'L6441', 'L6442'],
#  ['L6443',
#   'L6444',
#   'L6445',
#   'L6446',
#   'L6447',
#   'L6448',
#   'L6449',
#   'L6450',
#   'L6451',
#   'L6452'],
#  ['L6453', 'L6454'],
#  ['L6460', 'L6461', 'L6462', 'L6463', 'L6464'],
#  ['L6693',
#   'L6694',
#   'L6695',
#   'L6696',
#   'L6697',
#   'L6698',
#   'L6699',
#   'L6700',
#   'L6701',
#   'L6702'],
#  ['L6919', 'L6920'],
#  ['L7013', 'L7014', 'L7015'],
#  ['L7016', 'L7017'],
#  ['L7018', 'L7019', 'L7020', 'L7021', 'L7022', 'L7023', 'L7024', 'L7025'],
#  ['L7026', 'L7027', 'L7028', 'L7029', 'L7030', 'L7031', 'L7032', 'L7033'],
#  ['L7034', 'L7035', 'L7036', 'L7037', 'L7038', 'L7039'],
#  ['L7043', 'L7044', 'L7045'],
#  ['L7048',
#   'L7049',
#   'L7050',
#   'L7051',
#   'L7052',
#   'L7053',
#   'L7054',
#   'L7055',
#   'L7056',
#   'L7057'],
#  ['L7059', 'L7060'],
#  ['L7061', 'L7062', 'L7063', 'L7064', 'L7065', 'L7066', 'L7067'],
#  ['L7070', 'L7071', 'L7072', 'L7073', 'L7074', 'L7075', 'L7076'],
#  ['L6686', 'L6687', 'L6688', 'L6689', 'L6690', 'L6691', 'L6692'],
#  ['L6374', 'L6375', 'L6376', 'L6377', 'L6378', 'L6379', 'L6380'],
#  ['L6868',
#   'L6869',
#   'L6870',
#   'L6871',
#   'L6872',
#   'L6873',
#   'L6874',
#   'L6875',
#   'L6876',
#   'L6877',
#   'L6878',
#   'L6879',
#   'L6880'],
#  ['L6881', 'L6882', 'L6883', 'L6884', 'L6885'],
#  ['L6886', 'L6887', 'L6888', 'L6889'],
#  ['L6890', 'L6891', 'L6892', 'L6893', 'L6894'],
#  ['L6898', 'L6899'],
#  ['L6900', 'L6901'],
#  ['L6902', 'L6903'],
#  ['L6921', 'L6922'],
#  ['L6546', 'L6547', 'L6548', 'L6549', 'L6550', 'L6551', 'L6552', 'L6553'],
#  ['L6556', 'L6557'],
#  ['L6558', 'L6559', 'L6560', 'L6561'],
#  ['L6568', 'L6569'],
#  ['L6570', 'L6571'],
#  ['L6574', 'L6575'],
#  ['L6576',
#   'L6577',
#   'L6578',
#   'L6579',
#   'L6580',
#   'L6581',
#   'L6582',
#   'L6583',
#   'L6584',
#   'L6585',
#   'L6586',
#   'L6587',
#   'L6588',
#   'L6589',
#   'L6590',
#   'L6591',
#   'L6592',
#   'L6593',
#   'L6594',
#   'L6595',
#   'L6596'],
#  ['L6597', 'L6598'],
#  ['L6614',
#   'L6615',
#   'L6616',
#   'L6617',
#   'L6618',
#   'L6619',
#   'L6620',
#   'L6621',
#   'L6622'],
#  ['L6623',
#   'L6624',
#   'L6625',
#   'L6626',
#   'L6627',
#   'L6628',
#   'L6629',
#   'L6630',
#   'L6631',
#   'L6632',
#   'L6633',
#   'L6634',
#   'L6635',
#   'L6636',
#   'L6637'],
#  ['L6722',
#   'L6723',
#   'L6724',
#   'L6725',
#   'L6726',
#   'L6727',
#   'L6728',
#   'L6729',
#   'L6730',
#   'L6731',
#   'L6732',
#   'L6733',
#   'L6734',
#   'L6735',
#   'L6736',
#   'L6737'],
#  ['L6750', 'L6751', 'L6752'],
#  ['L6753', 'L6754'],
#  ['L6757', 'L6758'],
#  ['L6762', 'L6763', 'L6764', 'L6765'],
#  ['L6768', 'L6769'],
#  ['L6787', 'L6788'],
#  ['L6816', 'L6817', 'L6818', 'L6819'],
#  ['L6821', 'L6822'],
#  ['L6823', 'L6824'],
#  ['L6368', 'L6369'],
#  ['L6372', 'L6373'],
#  ['L6382', 'L6383'],
#  ['L6384', 'L6385'],
#  ['L6386', 'L6387', 'L6388'],
#  ['L6389', 'L6390', 'L6391', 'L6392'],
#  ['L6395', 'L6396', 'L6397', 'L6398'],
#  ['L6399', 'L6400', 'L6401'],
#  ['L6402', 'L6403', 'L6404', 'L6405', 'L6406'],
#  ['L6407', 'L6408', 'L6409'],
#  ['L6410', 'L6411'],
#  ['L6412', 'L6413', 'L6414', 'L6415', 'L6416', 'L6417', 'L6418'],
#  ['L6419', 'L6420', 'L6421', 'L6422', 'L6423', 'L6424'],
#  ['L6425', 'L6426', 'L6427', 'L6428'],
#  ['L6639', 'L6640', 'L6641', 'L6642'],
#  ['L6643', 'L6644', 'L6645', 'L6646', 'L6647'],
#  ['L6648', 'L6649', 'L6650', 'L6651', 'L6652', 'L6653', 'L6654', 'L6655'],
#  ['L6738',
#   'L6739',
#   'L6740',
#   'L6741',
#   'L6742',
#   'L6743',
#   'L6744',
#   'L6745',
#   'L6746'],
#  ['L6747', 'L6748', 'L6749'],
#  ['L6466', 'L6467'],
#  ['L6468', 'L6469', 'L6470', 'L6471', 'L6472'],
#  ['L6473', 'L6474', 'L6475', 'L6476', 'L6477'],
#  ['L6479', 'L6480', 'L6481'],
#  ['L6482', 'L6483'],
#  ['L6485',
#   'L6486',
#   'L6487',
#   'L6488',
#   'L6489',
#   'L6490',
#   'L6491',
#   'L6492',
#   'L6493',
#   'L6494',
#   'L6495',
#   'L6496',
#   'L6497',
#   'L6498',
#   'L6499',
#   'L6500',
#   'L6501',
#   'L6502'],
#  ['L6503', 'L6504'],
#  ['L6507', 'L6508'],
#  ['L6511', 'L6512', 'L6513', 'L6514', 'L6515'],
#  ['L6516',
#   'L6517',
#   'L6518',
#   'L6519',
#   'L6520',
#   'L6521',
#   'L6522',
#   'L6523',
#   'L6524'],
#  ['L6525', 'L6526', 'L6527', 'L6528'],
#  ['L6531', 'L6532'],
#  ['L6534', 'L6535', 'L6536'],
#  ['L7081', 'L7082', 'L7083', 'L7084'],
#  ['L7085', 'L7086', 'L7087'],
#  ['L7088',
#   'L7089',
#   'L7090',
#   'L7091',
#   'L7092',
#   'L7093',
#   'L7094',
#   'L7095',
#   'L7096',
#   'L7097',
#   'L7098'],
#  ['L6657', 'L6658', 'L6659'],
#  ['L6661', 'L6662'],
#  ['L6665', 'L6666', 'L6667', 'L6668'],
#  ['L6669', 'L6670', 'L6671'],
#  ['L6354', 'L6355', 'L6356', 'L6357'],
#  ['L6358', 'L6359', 'L6360'],
#  ['L6676', 'L6677', 'L6678'],
#  ['L6679', 'L6680', 'L6681'],
#  ['L6682', 'L6683', 'L6684'],
#  ['L8029', 'L8030', 'L8031', 'L8032'],
#  ['L8033', 'L8034', 'L8035'],
#  ['L8036', 'L8037'],
#  ['L8094', 'L8095', 'L8096', 'L8097'],
#  ['L8155', 'L8156'],
#  ['L8196', 'L8197', 'L8198', 'L8199'],
#  ...]

# %% [markdown]
# # Getting the questions and answers separately

# %% [markdown]
# "questions" will be the input and "answers" will be the target outcome for the neural network to learn.
#
# from the conversations_ids we will get the key identifiers for each conversation and using the dictionary we created above, we will get the corresponding text of the line.
#
#
# 1. Declare two empty lists - one for questions and the other for answers
#
# 2. iterate through the conversations_ids and get each conversation, now for each of the conversation separate out the question and answer and append them to the respective lists
#
# Note: For the answer, we use one index right after the question becuase they denote the immediate response to a question and hence the index i+1,i.e, the index to a question appears right after the question is asked

# %%
questions = []
answers = []
for conversation in conversations_ids:
    for i in range(len(conversation) - 1):
        questions.append(id2line[conversation[i]])
        answers.append(id2line[conversation[i+1]])

# %% [markdown]
# Let's have a look at the questions list we created above

# %%
questions
# Out:
# ['Can we make this quick?  Roxanne Korrine and Andrew Barrett are having an incredibly horrendous public break- up on the quad.  Again.',
#  "Well, I thought we'd start with pronunciation, if that's okay with you.",
#  'Not the hacking and gagging and spitting part.  Please.',
#  "You're asking me out.  That's so cute. What's your name again?",
#  "No, no, it's my fault -- we didn't have a proper introduction ---",
#  'Cameron.',
#  "The thing is, Cameron -- I'm at the mercy of a particularly hideous breed of loser.  My sister.  I can't date until she does.",
#  'Why?',
#  'Unsolved mystery.  She used to be really popular when she started high school, then it was just like she got sick of it or something.',
#  'Gosh, if only we could find Kat a boyfriend...',
#  "C'esc ma tete. This is my head",
#  "Right.  See?  You're ready for the quiz.",
#  "I don't want to know how to say that though.  I want to know useful things. Like where the good stores are.  How much does champagne cost?  Stuff like Chat.  I have never in my life had to point out my head to someone.",
#  "That's because it's such a nice one.",
#  'How is our little Find the Wench A Date plan progressing?',
#  'There.',
#  'You got something on your mind?',
#  'You have my word.  As a gentleman',
#  'How do you get your hair to look like that?',
#  'Sure have.',
#  "I really, really, really wanna go, but I can't.  Not unless my sister goes.",
#  "She's not a...",
#  "Lesbian?  No. I found a picture of Jared Leto in one of her drawers, so I'm pretty sure she's not harboring same-sex tendencies.",
#  "So that's the kind of guy she likes? Pretty ones?",
#  'Hi.',
#  'You know Chastity?',
#  'Have fun tonight?',
#  'I looked for you back at the party, but you always seemed to be "occupied".',
#  'I was?',
#  'Well, no...',
#  "Then that's all you had to say.",
#  'But',
#  'Then Guillermo says, "If you go any lighter, you\'re gonna look like an extra on 90210."',
#  'do you listen to this crap?',
#  'What crap?',
#  "Me.  This endless ...blonde babble. I'm like, boring myself.",
#  "I figured you'd get to the good stuff eventually.",
#  'What good stuff?',
#  'The "real you".',
#  'I\'m kidding.  You know how sometimes you just become this "persona"?  And you don\'t know how to quit?',
#  'No',
#  'Wow',
#  'She okay?',
#  'They do to!',
#  'Did you change your hair?',
#  'No.',
#  'Where did he go?  He was just here.',
#  'Who?',
#  'Great',
#  "He practically proposed when he found out we had the same dermatologist. I mean. Dr. Bonchowski is great an all, but he's not exactly relevant party conversation.",
#  'Is he oily or dry?',
#  "Bianca, I don't think the highlights of dating Joey Dorsey are going to include door-opening and coat-holding.",
#  "Sometimes I wonder if the guys we're supposed to want to go out with are the ones we actually want to go out with, you know?",
#  'I have to be home in twenty minutes.',
#  "You think you ' re the only sophomore at the prom?",
#  "It's more",
#  "Exactly  So, you going to Bogey Lowenbrau's thing on Saturday?",
#  'So yeah, I\'ve got the Sears catalog thing going -- and the tube sock gig " that\'s gonna be huge.  And then I\'m up for an ad for Queen Harry next week.',
#  'Queen Harry?',
#  'Neat...',
#  'Hey, sweet cheeks.',
#  'Hi, Joey.',
#  'Listen, I want to talk to you about the prom.',
#  "Where've you been?",
#  "I have the potential to smack the crap out of you if you don't get out of my way.",
#  "Oh my God, does this mean you're becoming normal?",
#  "It means that Gigglepuss is playing at Club Skunk and we're going.",
#  "Oh, I thought you might have a date  I don't know why I'm bothering to ask, but are you going to Bogey Lowenstein's party Saturday night?",
#  'What do you think?',
#  "You're ruining my life'  Because you won't be normal, I can't be normal.",
#  "What's normal?",
#  "Can't you forget for just one night that you're completely wretched?",
#  "Like I'm supposed to know what that even means.",
#  "It's Shakespeare.  Maybe you've heard of him?",
#  'You are so completely unbalanced.',
#  'Bianca, I need to talk to you -- I need to tell you --',
#  "I don't get you.  You act like you're too good for any of this, and then you go totally apeshit when you get here.",
#  "Listen, I know you hate having to sit home because I'm not Susie High School.",
#  'Like you care.',
#  "I do care. But I'm a firm believer in doing something for your own reasons, not someone else ' s .",
#  'Joey never told you we went out, did he?',
#  'What?',
#  'In 9th.  For a month',
#  'Why?',
#  'He was, like, a total babe',
#  'But you hate Joey',
#  'Now I do.  Back then, was a different story.',
#  'He said everyone was doing it.  So I did it.',
#  'You did what?',
#  'But',
#  'After that, I swore I\'d never do anything just because "everyone else" was doing it.  And I haven\'t since. Except for Bogey\'s party, and my stunning gastro-intestinal display --',
#  "Why didn't you tell me?",
#  'I wanted to let you make up your own mind about him.',
#  "That's not",
#  "I'm not stupid enough to repeat your mistakes.",
#  'I guess I thought I was protecting you.',
#  "God, you're just like him! Just keep me locked away in the dark, so I can't experience anything for myself",
#  "Not all experiences are good, Bianca. You can't always trust the people you want to.",
#  'You looked beautiful last night, you know.',
#  'Let go!',
#  'You set me up.',
#  'I just wanted --',
#  'What? To completely damage me?  To send me to therapy forever? What?',
#  'Is that woman a complete fruit-loop or is it just me?',
#  'Patrick -- is that- a.',
#  "Now don't get upset. Daddy, but there's this boy... and I think he might ask...",
#  "No! You're not dating until your sister starts dating.  End of discussion.",
#  'What if she never starts dating?',
#  "Then neither will you.  And I'll get to sleep at night.",
#  "But she doesn't want to date.",
#  'Daddy, I --',
#  "And where're you going?",
#  'If you must know, we were attempting to go to a small study group of friends.',
#  'Otherwise known as an orgy?',
#  'Daddy, people expect me to be there!',
#  "Oh, God.  It's starting.",
#  'Wear the belly before you go.',
#  'Daddy, no!',
#  "Promise me you won't talk to any boys unless your sister is present.",
#  'Why?',
#  "Daddy, I want to discuss the prom with you. It's tomorrow night --",
#  'The prom?  Kat has a date?',
#  'No, but',
#  "It's that hot rod Joey, right? That ' s who you want me to bend my rules for?",
#  'He\'s not a "hot rod".  Whatever that is.',
#  "You're not going unless your sister goes.  End of story.",
#  "I'm missing something.",
#  'Always a pleasure, Brucie.',
#  "Didn't have you pegged for a Gigglepuss fan.  Aren't they a little too pre-teen belly-button ring for you?",
#  'Fan of a fan.  You see a couple of minors come in?',
#  'Never',
#  'Padua girls.  One tall, decent body. The other one kinda short and undersexed?',
#  'You the new guy?',
#  'So they tell me...',
#  'So -- which Dakota you from?',
#  "North, actually.  How'd you   ?",
#  'I was kidding. People actually live there?',
#  "Yeah.  A couple.  We're outnumbered by the cows, though.",
#  'How many people were in your old school?',
#  'Thirty-two.',
#  'Get out!',
#  'How many people go here?',
#  "That I'm used to.",
#  'That girl -- I --',
#  'You burn, you pine, you perish?',
#  'Who is she?',
#  "Bianca Stratford.  Sophomore. Don't even think about it",
#  'Why not?',
#  'Why do girls like that always like guys like that?',
#  "Because they're bred to.  Their mothers liked guys like that, and their grandmothers before them. Their gene pool is rarely diluted.",
#  'He always have that shit-eating grin?',
#  'You know French?',
#  "Sure do ... my Mom's from Canada",
#  'Guess who just signed up for a tutor?',
#  "You mean I'd get a chance to talk to her?",
#  'Yeah, just a minor encounter with the shrew.',
#  "That's her?  Bianca's sister?",
#  'I teach her French, get to know her, dazzle her with charm and she falls in love with me.',
#  'What about him?',
#  "What makes you think he'll do it?",
#  'He seems like he thrives on danger',
#  "No kidding.  He's a criminal.  I heard he lit a state trooper on fire.  He just got out of Alcatraz...",
#  'They always let felons sit in on Honors Biology?',
#  "I'm serious, man, he's whacked.  He sold his own liver on the black market so he could buy new speakers.",
#  "Forget his reputation.  Do you think we've got a plan or not?",
#  "Did she actually say she'd go out with you?",
#  "You know, if you do go out with Bianca, you'd be set.  You'd outrank everyone. Strictly A-list.  With me by your side.",
#  'I thought you hated those people.',
#  'You got him involved?',
#  'This is it.  A golden opportunity. Patrick can ask Katarina to the party.',
#  "In that case, we'll need to make it a school-wide blow out.",
#  'Will Bogey get bent?',
#  'Number one.  She hates smokers',
#  "It's a lung cancer issue",
#  'Her favorite uncle',
#  "He's pretty!",
#  'Assail your ears for one night.',
#  'You told me that part already.',
#  'Extremely unfortunate maneuver.',
#  "The hell is that?  What kind of 'guy just picks up a girl and carries her away while you're talking to her?",
#  "Buttholus extremus.  But hey, you're making progress.",
#  'You humiliated the woman! Sacrifice yourself on the altar of dignity and even the score.',
#  'And he means that strictly in a non- prison-movie type of way.',
#  "What've you got for me?",
#  'Okay -- Likes:  Thai food, feminist prose, and "angry, stinky girl music of the indie-rock persuasion".',
#  'Gigglepuss is playing there tomorrow night.',
#  "Cameron, I'm a little busy",
#  "What 're you talking about?",
#  'Cameron -- do you like the girl?',
#  'Sure',
#  "What'd you do to her?",
#  "She hates you with the fire of a thousand suns .  That's a direct quote",
#  "You makin' any headway?",
#  'She kissed me.',
#  "What's the worst?",
#  "The vintage look is over, Kat. Haven't you been reading your Sassy?",
#  'Yeah, and I noticed the only part of you featured in your big Kmart spread was your elbow.  Tough break.',
#  'Hey -- do you mind?',
#  'Where ya goin?',
#  'Away.',
#  'Leave my sister alone.',
#  'Yeah',
#  'Two legs, nice rack...',
#  'Yeah, whatever.  I want you to go out with her.',
#  "Sure, Sparky.  I'll get right on it.",
#  'You just said',
#  'You need money to take a girl out',
#  'You got it, Verona.  I pick up the tab, you do the honors.',
#  "You're gonna pay me to take out some girl?",
#  "I can't date her sister until that one gets a boyfriend.  And that's the catch. She doesn't want a boyfriend.",
#  "I can't take a girl like that out on twenty bucks.",
#  "Take it or leave it.  This isn't a negotiation.",
#  'When I shell out fifty, I expect results.',
#  "I'm on it",
#  "Watching the bitch trash my car doesn't count as a date.",
#  'I just upped my price',
#  'What?',
#  'A hundred bucks a date.',
#  'Forget it.',
#  "It's about time.",
#  "How'd you do it?",
#  'Do what?',
#  "I don't know, Dorsey. ..the limo.-the flowers.  Another hundred for the tux --",
#  'Hey.',
#  'Are you lost?',
#  'Nope - just came by to chat',
#  "We don't chat.",
#  "Well, actually, I thought I'd run an idea by you.  You know, just to see if you're interested.",
#  "But she can't go out with you because her sister is this insane head case and no one will go out with her. right?",
#  'Does this conversation have a purpose?',
#  "I hear you're helpin' Verona.",
#  "Uh,  yeah.  We're old friend*",
#  'You and Verona?',
#  "You better not fuck this up.  I'm heavily invested.",
#  "Who's that?",
#  'Patrick Verona   Random skid.',
#  "That's Pat Verona? The one who was gone for a year? I heard he was doing porn movies.",
#  "I'm sure he's completely incapable of doing anything that interesting.",
#  'He always look so',
#  'Mandella, eat.  Starving yourself is a very slow way to die.',
#  "What's this?",
#  "I realize that the men of this fine institution are severely lacking, but killing yourself so you can be with William Shakespeare is beyond the scope of normal teenage obsessions.  You're venturing far past daytime talk show fodder and entering the world of those who need very expensive therapy.",
#  'The people at this school are so incredibly foul.',
#  'So he has this huge raging fit about Sarah Lawrence and insists that I go to his male-dominated, puking frat boy, number one golf team school. I have no say at all.',
#  'William would never have gone to a state school.',
#  "William didn't even go to high school",
#  "That's never been proven",
#  "I appreciate your efforts toward a speedy death, but I'm consuming.  Do you mind?",
#  'Does it matter?',
#  "You think this'll work?",
#  "What'd he say?",
#  'You went to the party?  I thought we were officially opposed to suburban social activity.',
#  "I didn't have a choice.",
#  "You didn't have a choice?  Where's Kat and what have you done with her?",
#  'I did Bianca a favor and it backfired.',
#  "You didn't",
#  'Can you even imagine?  Who the hell would go to this a bastion of commercial excess?',
#  "Well, I guess we're not, since we don't have dates .",
#  'Listen to you!  You sound like Betty, all pissed off because Archie is taking Veronica.',
#  "Okay, okay, we won't go.  It's not like I have a dress anyway",
#  "You ' re looking at this from the wrong perspective.  We're making a statement.",
#  'Have you seen him?',
#  'Who?',
#  'William - he asked me to meet him here.',
#  "I mean Wo-man.  How ya doin'?",
#  'Sweating like a pig, actually.  And yourself?',
#  "There's a way to get a guy's attention.",
#  'Pick you up Friday, then',
#  "The night I take you to places you've never been before.  And back.",
#  'Like where?  The 7-Eleven on Burnside? Do you even know my name, screwboy?',
#  "You hate me don't you?",
#  "I don't really think you warrant that strong an emotion.",
#  "Then say you'll spend Dollar Night at the track with me.",
#  'And why would I do that?',
#  'Come on -- the ponies, the flat beer, you with money in your eyes, me with my hand on your ass...',
#  'You -- covered in my vomit.',
#  'Are you following me?',
#  "I was in the laundromat. I saw your car. Thought I'd say hi.",
#  "You're not a big talker, are you?",
#  'hey.  Great show, huh?',
#  'Excuse me?',
#  "That's what you want, isn't it?",
#  "You know, these guys are no Bikini Kill or The Raincoats, but they're right up there.",
#  'You know who The Raincoats are?',
#  "What's this?",
#  '"I\'m getting trashed, man." Isn\'t that what you\'re supposed to do at a party?',
#  'I say, do what you wanna do.',
#  'Okay?',
#  "You're not okay.",
#  'I just need to lie down for awhile',
#  "Uh, uh. You lie down and you'll go to sleep",
#  'I know, just let me sleep',
#  'This is so patronizing.',
#  "Leave it to you to use big words when you're shitfaced.",
#  "Why 're you doing this?",
#  'I told you',
#  "You don't care if I die",
#  'Sure, I do',
#  'Why?',
#  "Because then I'd have to start taking out girls who like me.",
#  'Like you could find one',
#  "See that?  Who needs affection when I've got blind hatred?",
#  "Why'd you let him get to you?",
#  'Who?',
#  'Dorsey.',
#  'I hate him.',
#  "I know.  It'd have to be a pretty big deal to get you to mainline tequila. You don't seem like the type.",
#  'Hey man. . .  You don \' t think I can be "cool"?  You don\'t think I can be "laid back" like everyone else?',
#  'I thought you were above all that',
#  'Kat! Wake up!',
#  "And I'm in control of it.",
#  'When you were gone last year -- where were you?',
#  'Busy',
#  'Were you in jail?',
#  'Maybe.',
#  "No, you weren't",
#  "Then why'd you ask?",
#  'I should do this.',
#  'Do what?',
#  'Start a band?',
#  "My father wouldn't approve of that that",
#  'Oh, so now you think you know me?',
#  "So what ' s up with your dad?  He a pain in the ass?",
#  "He just wants me to be someone I'm not.",
#  'Who?',
#  'BIANCA',
#  'Excuse me, have you seen The Feminine Mystique?  I lost my copy.',
#  'What are you doing here?',
#  'I heard there was a poetry reading.',
#  "You 're so --",
#  'Wholesome.',
#  'Unwelcome.',
#  'Unwelcome?  I guess someone still has her panties in a twist.',
#  "Don't for one minute think that you had any effect whatsoever on my panties.",
#  'So what did I have an effect on ?',
#  'He left!  I sprung the dickhead and he cruised on me.',
#  "I guess I never told you I'm afraid of heights.",
#  "C'mon.  It's not that bad",
#  'Put your right foot there --',
#  "Forget it.  I'm stayin'.",
#  'You want me to climb up and show you how to get down?',
#  'The Partridge Family?',
#  'I figured it had to be something ridiculous to win your respect.  And piss you off.',
#  'Good call.',
#  "So how'd you get Chapin to look the other way?",
#  'A soft side? Who knew?',
#  "Yeah, well, don't let it get out",
#  "So what's your excuse?",
#  'Acting the way we do.',
#  'Yes',
#  "I don't like to do what people expect. Then they expect it all the time and they get disappointed when you change.",
#  "So if you disappoint them from the start, you're covered?",
#  'Something like that',
#  'Then you screwed up',
#  'How?',
#  'You up for it?',
#  'State trooper?',
#  'Fallacy.',
#  'The duck?',
#  'Hearsay.',
#  'Tell me something true.',
#  'I hate peas.',
#  'No -- something real.  Something no one else knows.',
#  "You're sweet.  And sexy.  And completely hot for me.",
#  'What?',
#  'No one else knows',
#  "You're amazingly self-assured. Has anyone ever told you that?",
#  'Is that a request or a command?',
#  'You know what I mean',
#  'No.',
#  'No what?',
#  "No, I won't go with you",
#  'Why not?',
#  'Create a little drama?  Start a new rumor?  What?',
#  'So I have to have a motive to be with you?',
#  'You tell me.',
#  'You need therapy.  Has anyone ever told you that?',
#  'Answer the question, Patrick',
#  "How'd you get a tux at the last minute?",
#  "It's Scurvy's.  His date got convicted. Where'd you get the dress?",
#  "It's just something I had.  You know",
#  'Oh huh',
#  "My grandmother's .",
#  'What?',
#  "That ' s completely adorable!",
#  'Wait I...',
#  'You were paid to take me out!  By -- the one person I truly hate.  I knew it was a set-up!',
#  "It wasn't like that.",
#  'Really?  What was it like?  A down payment now, then a bonus for sleeping with me?',
#  'A Fender Strat. You bought this?',
#  'Besides, I had some extra cash. Some asshole paid me to take out a really great girl.',
#  'Is that right?',
#  'Why is my veggie burger the only burnt object on this grill?',
#  'Because I like to torture you.',
#  'Oh, Bianca?  Can you get me my freshman yearbook?',
#  'I know.',
#  'I thought we decided you were going to school here.  At U of 0.',
#  'This from someone whose diary is devoted to favorite grooming tips?',
#  'My insurance does not cover PMS',
#  'Then tell them I had a seizure.',
#  'Is this about Sarah Lawrence? You punishing me?',
#  'I thought you were punishing me.',
#  "Why can't we agree on this?",
#  "Because you're making decisions for me.",
#  "As a parent, that's my right",
#  "So what I want doesn't matter?",
#  "You're eighteen.  You don't know what you want.  You won't know until you're forty-five and you don't have it.",
#  'Was that your sister?',
#  'Yeah.  She left with some bikers Big ones.  Full of sperm.',
#  "I don't understand the allure of dehydrated food.  Is this something I should be hip to?",
#  'No, Daddy.',
#  'So tell me about this dance. Was it fun?',
#  'Parts of it.',
#  'Which parts?',
#  'The part where Bianca beat the hell out of some guy.',
#  'Bianca did what?',
#  "What's the matter?  Upset that I rubbed off on her?",
#  "You know, fathers don't like to admit that their daughters are capable of running their own lives.  It means we've become spectators.  Bianca still lets me play a few innings.  You've had me on the bleachers for years.  When you go to Sarah Lawrence, I won't even be able to watch the game.",
#  'When I go?',
#  "Katarina Stratford.  My, my.  You've been terrorizing Ms. Blaise again.",
#  'Expressing my opinion is not a terrorist action.',
#  "Well, yes, compared to your other choices of expression this year, today's events are quite mild.  By the way, Bobby Rictor's gonad retrieval operation went quite well, in case you're interested.",
#  'I still maintain that he kicked himself in the balls.  I was merely a spectator.',
#  'Tempestuous?',
#  'Am I supposed to feel better? Like, right now?  Or do I have some time to think about it?',
#  'Hey there.  Tired of breathing?',
#  'Hi.',
#  'Cool pictures.  You a fan?',
#  'You think?',
#  'Macbeth, right?',
#  'Right.',
#  'Kat a fan, too?',
#  'Say it',
#  'What?',
#  'What plan?',
#  'The situation is, my man Cameron here has a major jones for Bianca Stratford.',
#  "I think I speak correctly when I say that Cameron's love is pure.  Purer than say -- Joey Dorsey's.",
#  "That's where we can help you.  With Kat.",
#  'So Dorsey can get the girl?',
#  'You two are gonna help me tame the wild beast?',
#  'What?!',
#  'Are you telling me I\'m a -  "non-smoker"?',
#  'Ever been to Club Skunk?',
#  'I prefer to think of it simply as an alternative to what the law allows.',
#  'So you got cozy with she who stings?',
#  "You were right. She's still pissed.",
#  'Sweet love, renew thy force!',
#  'I missed you.',
#  'It says here you exposed yourself to a group of freshmen girls.',
#  'It was a bratwurst.  I was eating lunch.',
#  "I don't understand, Patrick.  You haven't done anything asinine this week. Are you not feeling well?",
#  'Touch of the flu.',
#  "Why don't we discuss your driving need to be a hemorrhoid?",
#  "What's to discuss?",
#  "You weren't abused, you aren't stupid, and as far as I can tell, you're only slightly psychotic -- so why is it that you're such a fuck-up?",
#  "You're completely demented.",
#  'In the microwave.',
#  "What's a synonym for throbbing?",
#  'Jesus!  Can a man even grab a sandwich before you women start dilating?',
#  'Tumescent!',
#  'Would you rather be ravished by a pirate or a British rear admiral?',
#  "They'll dance, they'll kiss, they'll come home.  Let her go.",
#  "What do you wanna watch?  We've got crap, crap, crap or crap",
#  'Have a great time, honey!',
#  'What just happened?',
#  'Your daughters went to the prom.',
#  'Did I have anything to say about it?',
#  'Absolutely not.',
#  'I never seen heat like this!  Not even in Las Minas!',
#  "The water's going putrid in the barrels.",
#  'What are you listening to, chicken ass?',
#  "Ah, leave him alone.  He's doing no harm.",
#  "He's the devil's child...",
#  'We should have seen land.',
#  "We left three weeks ago, Alonso. Can't be that near.",
#  'You say Asia can be found by sailing west?',
#  'Yes, your Eminence.  The voyage should not take more than six or seven weeks.',
#  'Unfortunately, Don Colon, that is precisely where our opinions differ...  Are you familiar with the work of Aristotle?  Erathostene?  Ptolemeus?',
#  'I am, Your Eminence',
#  'Senor Colon, an experienced captain such as yourself will understand our concern with the crew.  I am not willing to have on my conscience the loss of men who would have relied upon our judgment.',
#  'Your Eminence, there is only one way to settle the matter.  And that is to make the journey.  I am ready to risk my life to prove it possible.',
#  'Your life, and that of others!',
#  'Trade, Your Excellency.  According to Marco Polo, the Kingdom of China is one of the richest of the world. Even the meanest buildings are roofed with gold.',
#  'Is that all that interests you? Gold?',
#  'If God intended our proximity to Asia, do you believe he would have waited for you to show it to the world?',
#  "Don't you realize your words could be considered heretical?",
#  'Asia can be found to the west -- and I will prove it.',
#  "The State has some reason to be interested in this man's proposition, Your Eminence...",
#  'The Judgment is ours!',
#  'He is a mercenary!  Did he not already try to convince the King of Portugal of his absurd notions?',
#  "It won't be easy to get rid of your prophet now, Don Sanchez.",
#  'You can see for yourself.',
#  'What a tragedy... what a waste of a life...',
#  'I could be gone for years.',
#  'I know.',
#  "I haven't given you much of a life.",
#  "Well... that's true.  I have a child by a man who won't marry me!  Who's always leaving...",
#  'Are we going to argue?',
#  'Perhaps I was never meant to live with a woman...',
#  'She said yes.',
#  "I'm not asking you to swear to anything.",
#  "I don't want you to wait for me.",
#  'Beatrix, I want to ask you something.',
#  "You don't usually ask.",
#  "God... you're so beautiful!  I can't believe no other man has ever taken you away from me...",
#  'They took everything...',
#  "Can't you stay with us a little?",
#  'What is it, now?  Tell me...',
#  'I understand that you will soon be appointing Governors for the islands?  Is it not so?',
#  'Forgive me, Don Bobadilla -- those positions have already been taken.',
#  'May I ask by whom?',
#  'Don Alonso de Bobadilla.',
#  'My letters of appointment.',
#  'Appointment to what?',
#  'Viceroy of the West Indies.',
#  'How far from here?',
#  'I am not a seaman.  But I heard it is no more than a week at sea.  I hope you are not too disappointed.',
#  'How could I be?  The mainland has been found.  Exactly as I said it would.',
#  'I want to go with you!',
#  "There'll be a time.",
#  'Do you swear on all the Holy Saints in heaven?',
#  'I have to explore the mainland.',
#  'How are you feeling, Fernando?',
#  'Father...',
#  'What are you listening to?',
#  'What does he say?',
#  'He asks when he can come to visit you.  He left his address.',
#  'I want you to tell me everything you remember, Father.  From the beginning.  Everything.',
#  "Really?  God... I wouldn't know where to start... and yet...",
#  'No...',
#  'No?',
#  'I remind you, Senor Colon, that you are in no position to bargain with me.',
#  "I'm not bargaining!",
#  'And were you never ambitious, Excellency?  Or is ambition only a virtue among the nobles, a fault for the rest of us?',
#  "They don't see sin in their nakedness.  They live according to nature, in a never ending summer. The islands are covered with trees, filled with blossoms and fruits. And...",
#  'You defend yourself admirably...',
#  'But we do have a lack of notaries. You should contact my administration.',
#  'Don Bobadilla is already a judge, my Dear Don Cristobal.',
#  'You seem to have a special talent for making friends.',
#  'What...?  Do I have so many already?',
#  'All I have to do is call the guards.',
#  'I am not afraid of you.  You are nothing but a dreamer.',
#  'What do you see?',
#  'Roofs... towers, palaces... spires...',
#  'Say not here!  Cuba!',
#  'What is it?  A tribe?  An island?',
#  'You come!  You speak first!',
#  'Tell the Chief we thank him.',
#  'Chief knows.',
#  'Chief says -- how many?',
#  'Thousands.',
#  'To bring the word of God.',
#  'Chief says -- he has a God.',
#  '... and also to bring medicine.',
#  'Chief says...',
#  'We will work with his people.  We want peace.  Ask the Chief if he understands?',
#  'He understands.',
#  'You have to find them, Utapan.  Look what they did!',
#  "Utapan, won't you speak to me?  You used to know how to speak to me.",
#  'Diego is a bright boy -- a pleasure to teach -- but so serious... Brothers should be raised together, Colon.  Even brothers from different mothers...',
#  "God... That's in a week!",
#  "That's what it says.",
#  'How did you manage it?',
#  'Why do you wish to sail west?',
#  'How can you be so certain?  The Ocean is said to be infinite.',
#  'Ignorance!  I believe the Indies are no more than 750 leagues west of the Canary Islands.',
#  'How can you be so certain?',
#  'The calculations of Toscanelli Marin de Tyr, Esdras...',
#  'Esdras is a Jew.',
#  "Two minutes... and already you're a dead man.  Don't let passion overwhelm you, Colon.",
#  "I'll try to remember that, Marchena...",
#  'Father Marchena!',
#  'Passion is something one cannot control!',
#  'You get so carried away when you are being contradicted!',
#  "I've been contradicted all my life... Eternity!",
#  "You mustn't give way to despair. You must wait.",
#  "Wait!  I've waited seven years already!  How much longer do you want me to wait?",
#  'If God intends you to go, then you will go.',
#  'Colon!',
#  'All of them!  Just lies!',
#  'In Nomine Patris et Filius, et Spiritus Sancti.',
#  'I am listening, my son.',
#  'Father, I have betrayed my family. I betrayed my men.  And I betrayed you.',
#  'What are you saying?',
#  'I lied.  The journey will be longer than I said.',
#  'How long?',
#  'May God forgive you...!  You must tell them!  You must tell your men!',
#  "If I tell them, they won't follow me.  You know that I am right, Father.  You trust me...",
#  "My son, my son...  Your certitudes are sometimes frightening...  Christopher, you must speak to them. And if you don't I will.",
#  'I believed in you...',
#  "I suppose we're both old men now.",
#  'I have to disagree.',
#  'I knew you would.',
#  'New worlds create new people.',
#  'Oh?  So you are a new man?',
#  'I should not even be listening to you, since my council said no.  But Santangel tells me you are a man of honor and sincerity... And Sanchez, that you are not a fool.',
#  'The ocean is uncrossable?',
#  'What did they say about Granada before today?',
#  'I cannot ignore the verdict of my council.',
#  'May I speak freely?',
#  'You show no inclination to speak otherwise!',
#  'I know what I see.  I see someone who doesn\'t accept the world as it is.  Who\'s not afraid.  I see a women who thinks... "What if?"...',
#  'How old are you, Senor Colon?',
#  'Do they have such thoughts?',
#  'But without your brothers.  Nor are you to return to Santo Domingo or any of the other colonies.  You may explore the continent.',
#  'Thank you.',
#  "There is one thing I'd like to understand... Why do you want to go back, after all this?",
#  "And you say this is an Indian vice? By God!  I don't see any kind of pleasure that would make this a sin.",
#  'We lost cousins, friends.  We will wash this in blood.',
#  'You want a war?  Fine.  We are a thousand.  They outnumber us by ten! Who will you kill?  Which tribe?',
#  "We don't need to know.",
#  "We can't raise the wheel without it.",
#  'Don Moxica -- we all have to work.',
#  'In one act of brutality, you have created chaos.  Tribes who were fighting each other are now joining forces against us!  All that because of your criminal savagery!',
#  'Savagery is what monkeys understand.',
#  "You'll be held in detention, deprived of your privileges and possessions.  Until you are returned to Spain where you will be judged. Have you anything to say?",
#  'Due west, Captain Mendez.  And may God be with us...',
#  "Well... It's the men, Sir.  They wonder how you know our position. We've lost sight from land days ago...",
#  'And what do you think Mendez?',
#  "Well, I surely know what a quadrant is!  But I've never seen it used at night before.",
#  'What do you read?',
#  "What's he doing?",
#  "He's drawing an isthmus... He's saying we're on an isthmus.",
#  'Where can I meet this man?',
#  "You lied!  You cheated!  We're way past 750 leagues!",
#  'Six days ago, yes.',
#  'You must be mad...!',
#  'We have to keep the hopes of these men alive!',
#  "We're on the verge of a mutiny, Colon!",
#  "You think I don't know that?",
#  "We're lost!",
#  'The land is there.  I know it!',
#  "You don't know anything!  Listen Colon, these are my ships, right? So I'm telling you we're turning back!",
#  'And then what?  Half of the water has gone, the rest is nearly putrid! You know that!',
#  'Jesus Maria!  I should have never listened to you!',
#  'You never did.  You did all the talking for both of us, remember?',
#  'You bloody...',
#  'Pinzon, Pinzon... All we can do now is go forward!  Think about that!',
#  'You tell that to them!',
#  'Is that the man I knew, Treasurer Sanchez?',
#  'You were right, Don Sanchez... His demands could never be granted.',
#  '... Into a monk...',
#  'Every ship returns with a cargo of sick and dying.  But with no gold! The new world proves expensive, Your Majesty.',
#  '... But there is worse.  He ordered the execution of five members of the nobility...',
#  'Then, what do you suggest, Don Sanchez?',
#  'He must be replaced.',
#  'I know, I should not tolerate his impertinence.',
#  'Then why?',
#  "Are you my attorney?  I'm Emil.  I'm insane.",
#  "I'm not your lawyer until I see the money.",
#  'Oh no!  No!  Shit!',
#  'Emil.  Take it easy.  Stay with me.  Sit down.  What do you need?  What are you looking for?',
#  "Don't say anything.",
#  'Where are we going?',
#  "I'm coming with you.",
#  'Yes.  Yes, come with me!',
#  "I brought you some letters.  It's really fan mail.  Women mostly.  One wants to buy you clothes, another sent a check. Another wants a check.",
#  'You bring the cigarettes?',
#  '...delusions and paranoia.',
#  'I was all of these.',
#  "Well, you didn't appreciate the severity of it until recently.  No question about that.",
#  'What about Oleg?',
#  "Disappeared.  They're looking everywhere.  Maybe he went back to Czechoslovakia.",
#  'No, he is here.  Shit...',
#  "Don't worry about him.  Think about yourself.",
#  'What about my movie rights?  Book rights?',
#  "Look, I haven't really focused on that kind of thing.",
#  "What's your cut?  How much?",
#  'I would say...half.  Half is fair.',
#  'No.  No way.',
#  "But it's...",
#  "Thirty-percent.  No more.  Or I call another lawyer.  This is the biggest case of your life.  Don't try to negotiate.  Thirty percent.  Say yes or no.",
#  'This is not about money, Emil.  I need your trust in me.',
#  'What else do you need?',
#  "I need to know about your background.  I need to know about your upbringing.  Why you're here.",
#  'Tell me about yourself.  What you did as a young boy... what your parents were like.',
#  'My father always degraded me.  Killed my self-esteem.  And my mother was blind.',
#  'Your mother was blind?',
#  'Yeah, she went blind giving birth to me. She went to fucking black market doctor to induce me.',
#  'Back in the Czech Republic?',
#  'Yeah, yeah...bad doctor gave her bad drugs which made her go blind.  And my father blamed me for her blindness...',
#  "Your father blamed you for your mother's blindness?",
#  "That's what he did to me.  He put cigarettes out on me.",
#  'Your father put cigarettes out on you?',
#  'Out on my back when I was a small boy.',
#  "I'm abused.  Don't you think?",
#  '...so we kill someone famous and if we are caught, we are sent to mental hospital...',
#  '...my little sister and I shared a flat - I came home one night and a man was raping her.  His gun was on the chair... He came at me and I shot him.',
#  "Alright.  That's a justifiable homicide.",
#  'Now I become custody of police department?',
#  "If you cooperate with the DA - maybe they'll help you with your situation.",
#  "I will if they don't send me back.",
#  'Are you married?',
#  'Divorced.',
#  "I can't take you to my place.",
#  'The men are out of quarters - practicing putting out fires.',
#  'So...the station is empty?',
#  'You considered becoming a prostitute?',
#  'Yes, I considered it.',
#  'Did you ever turn tricks before?',
#  'No.',
#  'What about back home?',
#  "I came here.  I had no money.  I knew no one.  I couldn't get a job because you have to have a green card to get work. They approached me - I could've made a lot of money.  I considered it, but... it's not who I am.  They pay me below the table at Ludwig's.",
#  'So you were never a prostitute?',
#  'What are you asking me?',
#  "I'm not a whore.  I'm not a whore.",
#  'I know.',
#  "You don't know.  I'm sorry.  I was desperate.  That's not me.  I shot a cop.  Can you imagine what they'll do to me when I got to prison?",
#  "They're not gonna send you right back.",
#  'Are you alright?',
#  "I still can't believe Eddie's gone.",
#  'Is he your boyfriend?',
#  "Ludwig?  He's gay - are you jealous?",
#  'If I was your boyfriend, I might be.',
#  'A good Immigration lawyer could stall the process.  Eddie recommended one.',
#  "No matter what happens...I'm glad I met you.",
#  'You better get packed.',
#  'Do you have coffee?',
#  'In the kitchen.',
#  "I'll make some for us.",
#  'What are you doing?',
#  'Forget about me.  You have enough problems of your own.',
#  '...Do you really want me to forget about you?',
#  "I don't want to drag you down with me.",
#  "I told your partner, I can't help.  I didn't see anything.",
#  "C'mon, start at the beginning.  You know these people?",
#  'Tamina was a friend of mine.  My shower was broken, she let me use theirs.',
#  "Whether you tell us or not, we'll find out.  Better if it comes from you.",
#  'If I tell you, will you arrest me?',
#  "Are you here illegally?  Don't worry about that.  We'll talk to Immigration. They won't deport you.",
#  'A cop?',
#  "I'm from a small town in Slovakia.  Like the South here.  The Police is right, a civilian is wrong.  So I fled.",
#  "Look, we can help you but right now we have to deal with what's happening here. Tell us the truth...is that the truth?",
#  'Oh.',
#  'It was my decision, not his.',
#  "Well, I'm the Deputy Chief Fire Marshall and every now and then I'd like to be included in decisions.",
#  'Look, after Jordy briefs me, you can do the press conference.  How about that? The case is all yours.',
#  'Oh yeah...?  Alright.',
#  "I'm ready to be briefed.  Excuse us.",
#  'Who did cause and origin?',
#  'Who do you think, Chief?!',
#  "Then why didn't you talk to the reporter?",
#  'Hey, Chief, what are you doing here?',
#  'Ladder 20 was on the Rock for training. We stopped there... so she could get cleaned up.',
#  "What do you mean, 'cleaned up?'",
#  'I let her take a shower.',
#  'A shower!?  Did you take one, too?',
#  'No!  Nothing happened.',
#  'Chief - mind if I take her?',
#  "The public doesn't have any idea what we do and now you're going to define our image!  This is going to be our Rodney King!",
#  'What was I supposed to do?  The guy tried to mug me.  I was gonna send a cop back - I just forgot.',
#  'Forgot?  You handcuffed a civilian to a tree?!',
#  'Chief - I know I screwed up - but this guy was no innocent civilian.',
#  'Well this is gonna end your career and probably mine.',
#  'End my career?',
#  "How are you going to fight this?  Maybe if Oleg hadn't gotten away and you'd been on the front page, as a hero, this thing would be easier to fight.  You'd have the good to weight against the bad! It's unfortunate that I have to make decisions based upon your press coverage but there's nothing I can do!  Gimme your shield.",
#  'But Chief?  Over this??',
#  "Don't you guys understand?  It's all about image.  The better we look the more money I get to pay you guys overtime.",
#  'Yeah, right.',
#  'What was that, Korfin?',
#  "I said, yeah, you're right, Chief.  As soon as we get somethin' we'll let you alert the media.",
#  'Did the D.A. videotape her deposition?',
#  'Yeah.  He finished awhile ago.',
#  'Alright.  Swing by her apartment.  Let her pick up her clothes and take her straight to Hoover Street.  You got that?',
#  'Coffee for me, I gotta slow down.',
#  'Vodka tonic.',
#  "It was freaky, I'll tell you.  Stupid kid.",
#  "I'm gonna propose.",
#  'When?',
#  'Tomorrow.  At lunch.',
#  "What's he looking for?",
#  'Where is she?',
#  "Takin' a bath.",
#  'Any I.D.?',
#  'Sorry...PD only.',
#  'Only one guys checked in?',
#  'Yeah.',
#  "The other side of the street.  The guy with the videocamera.  Don't look - put her in the car.  Stay this side.",
#  'Are you hit?',
#  'He got my gun!  Motherfucker was filming the whole time!',
#  "Who's there?",
#  "Police.  We'd like to ask you a few questions.",
#  "I have nothin' to say.  If you wanna contact my attorney...",
#  "What's wrong?",
#  "We don't have her I.D. yet, but one of your girls was killed last night at the King Edward Hotel.",
#  "Yeah.  He wanted a girl from Czechoslovakia, but I sent him Honey 'cause once they get there, you know, it doesn't really matter - Honey was killed...?  Poor girl...",
#  'Do you have any Czech girls working for you?',
#  'No.',
#  "Boy, she's so popular all the sudden.",
#  'What are you saying?',
#  'He said he was her cousin.  I told him where she works.  They were just here.',
#  'Describe him.',
#  "Tall, short-haired, scary eyes.  Second guy with him was...shorter, with a wrestler's build.  And he wouldn't turn his videocamera off me.",
#  'He had a videocamera?  Where is she? Quickly!',
#  "Hey, that's great you guys got it all wrapped up, but you don't mind if we go through the routine?  It gives us somethin' to do.",
#  'You know what that is, right?',
#  'No, what is it?',
#  "It's your crime scene now.  You can do what you want.",
#  'Watch the news?',
#  'Nah, I musta missed it.',
#  'Well, just so you know.  I gave you guys the credit.',
#  "Well, just so you know, I don't care about that stuff.",
#  'Nah, why should you?',
#  "I don't even watch TV.",
#  'Did you get a report from the M.E.?',
#  'Sure.  But I would like to ask you something.  You got a problem with me?',
#  "If you found me steppin' on your crime scene - it might piss you off, too.  What about the report?",
#  "The Super said he'd seen her before but she didn't live here.",
#  'Pretty.',
#  'Hmmmm.',
#  "Maybe you don't care about that either.  Prettiest suspect I've had in awhile.",
#  'What would you call her?',
#  "Maybe it's a ritual thing or someone trying to send a message.  Burial rites are taken very seriously in Eastern Europe.  It could be to humiliate them. Just burning them up, no proper funeral, it's like condemning them to hell.",
#  'Eastern Europe.  Like what?  Romania? Hungary?',
#  "I'll come with you.",
#  "There wasn't a fire.  There'll be nothing for you to do.",
#  "I can watch you, Eddie.  Maybe I'll learn something.",
#  "This isn't homicide school.",
#  'My parents are from Poland.  I can help with the Eastern European angle.',
#  "You're Polish?",
#  'My folks are.',
#  "You goin' to the escort service?",
#  'You got any better ideas?',
#  'Mind if I ride along with you?',
#  'This has nothing to do with your fire.',
#  "I'll let you know what happens.",
#  "This is ridiculous.  I'm not gonna be in your way - we can talk the case over.",
#  "Tell you what - I'll flip you a coin. If you win you can come with me.  If you don't win, you don't come.",
#  'Two heads.',
#  "Leon - meet us at 63rd and Madison. Hair salon.  Ludwig's.",
#  'You thirsty?',
#  "I'm on duty.",
#  "So am I.  Alright, I'll go inside and you cover the back.",
#  'Of course.',
#  "Hey!  I always wanted to be a cop when I was a kid.  I dreamed of running up to a door, kicking it in, pulling my gun and yelling 'Freeze!' at the bad guy! What'd you dream about?",
#  'I wanted to run up to a building on fire, kick in the door, rush into the smoke and save a kid.',
#  'What are you hiding?  Why are you afraid',
#  'She just saw two of her friends killed! They probably threatened her.',
#  'Why not?',
#  "She's fucked.  Even if that story is true.",
#  "Look - let me talk to her.  Any leads I get, they're all yours.  Just let me have a first crack at her.",
#  'You wanna talk to her alone?',
#  'Yeah.',
#  'What would your girlfriend think of that?',
#  "I don't have a girlfriend.",
#  'My point exactly.',
#  "I'm serious here.",
#  'So am I.',
#  "C'mon.  You intimidate her 'cause you're a celebrity.  She sees me differently.",
#  "You're her Savior?  Is she the kid you're gonna save from the burning building?",
#  "Okay, tell you what, I'll give you a head start.  You take her to the station house.  Don't let her out of your sight. She's the only warm body we got left.",
#  "Hey.  I'm a professional.",
#  "Look, Eddie, I'm tellin' you - I didn't touch her.",
#  "Well, you shoulda because nobody's gonna believe you didn't...including me.",
#  "I took her there for a shower and that's it.",
#  "Yeah, just her in the shower.  Nothing happened.  Look, I'm sure you probably think I'm a fool and I fucked up, but...",
#  "No, I don't think you were a fool, I just think you were stupid about it.  I mean, to say the least, you outta know better.  You don't know her well enough. She's got the potential to fucking hang you even if she suggests that you made a pass at her, it's fuckin' over.  You can deny it all you want, but it will not make one fucking bit of difference. You're dead.",
#  "I told you, you know, I thought I was doing the right thing, you know, I think she's innocent.",
#  "Well, it's not up to you to decide whether she's innocent or not.  Don't you understand, that's why you're a professional.",
#  "But, I mean, didn't you ever go out on a limb for somebody?  I mean, you shoulda heard her there.  Tellin' her whole story...I believed her.",
#  "Why'd you help me back there with the Chief?  Why'd you stand up for me like that?",
#  "So...who's Nicky?",
#  'What do you want?',
#  'Your opinion.  You see, they going to make a movie about me, too, Eddie.  And write books.',
#  "What's your accomplishment.",
#  'I kill someone famous.',
#  'Then do it, asshole.',
#  "So tabloids don't have to do re enactments.  They going to have real movie this time.",
#  "You really think you'll be able to fool a jury with this bullshit?  How fuckin' stupid are you?",
#  'Detective, does it look like a murder?',
#  "We don't know that yet.  It's much too early.  There's a lot to be done.",
#  'How many victims are up there?',
#  'There are two bodies found at this point.',
#  'Can we go up to the crime scene?',
#  "You know you can't do that.  C'mon.",
#  'Is it drug related?',
#  'Detective - can you tell us what happened here?',
#  'I understand, but I noticed that the Fire Marshall is here with you.  Is this somehow related to the fire department?',
#  "I really can't give out any information right now at this point.",
#  "Okay.  But I do understand that your partner, Leon Jackson's been injured. Is that correct?",
#  "He was hurt, but not seriously.  He'll be fine.",
#  'Do you have the suspect in custody?',
#  "Um...now is not a good time, okay. Detective Jackson's hurt.  He's fine. I've got a Fire Marshall shot, Detective Jackson is hurt but not seriously.",
#  'Eddie, are you okay?',
#  "Yeah.  Now's not a good time.",
#  'Alright.',
#  'Alright?',
#  'Alright.',
#  'Alright.',
#  'Hey, honey.',
#  "What is your problem?  Why'd you snap at me?  I just wanted a statement.",
#  "I can't...I can't answer you just because you want me to answer you!",
#  "You didn't have to embarrass me in front of my colleagues.  You could give me something.",
#  "Oh, I'm sorry.  Did I embarrass you, sweetheart?  Oh...",
#  'Stop it.',
#  'Maybe I should just, ya know...turn to the cameras and say, do you mind if we just work something out?',
#  "Alright, alright, Eddie.  Don't patronize me.",
#  "I'm not.",
#  "Yes you are.  I'm not just some reporter.  I don't just stick a microphone in your face.  You could give me something.",
#  'Yeah, well you took the camera and put it right down on the evidence.  That was...',
#  'That was good.  You were holding the evidence.',
#  "You were merciless.  You didn't give a shit if you got me or not.",
#  'Well, who was it that taught me how to do that?  Huh?',
#  "You're ruthless.",
#  'Look at this.  You have blood on your shirt.  Whose is it?',
#  "Could be Leon's.",
#  "Don't worry about the damn phone.  I won't answer it.",
#  'Answer the phone.',
#  'No.  Tell me what you want to say.',
#  'Answer it.',
#  'Oh my G-d, they want me to anchor.  They want me to anchor tonight!',
#  "That's good.",
#  'Yeah.',
#  "Well, that's great.",
#  "Okay.  That is great.  But I can't go now, we're in the middle of something here.",
#  "No.  Go ahead.  You're gonna be great.",
#  "No.  No, listen to me here.  I want to know what you're talking about.  You know, the shoe thing and the marriages and...",
#  "I'll tell you tonight.  Let's do it tonight.  As soon as you get back we'll talk.  We'll talk.",
#  'Promise?',
#  "I promise.  We'll talk.  You'll be great.  You'll be fine.  Go ahead, just imagine that, uh... Just look into the lens and imagine you're talking to me.",
#  "Yeah.  I'll do that.  As long as you're not patronizing me.",
#  'Patronizing you... Nay, I love you.',
#  'Okay, til tonight.',
#  'Tonight.',
#  'You promise?',
#  'Yeah.  I promise.',
#  "Okay.  And you know what, I'll swing by my place, grab a couple pairs of shoes and maybe just test them out next to yours...How's that... Would that be a good thing.",
#  'Yeah, yeah.  Good thing.',
#  'Okay.',
#  'See you later.  Good luck.',
#  'Thank you.',
#  "So we're waitin' to hit this warrant - we got Emergency Service with the heavy weapons standin' by - ready to go.  I say, lemme get a cigar outta the car.  I go to get the cigar and BOOM!  All the sudden I turn around and a kid with a shotgun let one go.  Right where I was standin'.  That coulda been it.  I coulda had my head blown off and for what?  Some stupid kid got panicky, takes the safety off and it's over.  If I hadn't gone back for that cigar - for a bad habit - I would've had my head blown off.",
#  "Sooner or later that's everybody.",
#  'Not chopped up.  Not chopped up like that.  I mean, what do I got left? Coupla articles.  A medal or two. Plaque here and there and in a coupla years no one remembers me anymore.',
#  "I think you're getting a little moody there, Eddie.",
#  'How old are your kids?',
#  "So what's unique?",
#  "He's from Antigua.  His girlfriend was taking too long to put her make-up on. they were late for a party.  Stabbed her with a beer bottle.",
#  "That's unique.",
#  "I hope this prick doesn't run.  My knees are killing me.  Stay behind me.",
#  'Ready?',
#  'Keep them out of my way.',
#  'Okay.  You ready?',
#  'Any chance we can do that again?',
#  'Okay.  You work in a vodka factory.  I understand that.  And what kind of work do you do?',
#  'I am butcher.',
#  "You're a butcher?  What do you use pig intestines for?",
#  'You stuff sausage in it.',
#  'And what do you do with the bones?',
#  'Are you married?',
#  "Come to 45 Broadway.  Don't bring the Police.  Come alone or you'll be in my next film.",
#  "Look asshole.  I've been threatened by better than you.",
#  "No.  I'm the best that's ever threatened you.",
#  "I'll meet you on one condition - I get exclusivity and you surrender to me.",
#  "We'll talk about that.  Four o'clock gives you time to go to bank.  Three hundred thousand dollars.",
#  "What?  It doesn't work that way.",
#  "If you don't want my film - I'll call another show.  And they will show it.",
#  'Wait a minute.  Wait a minute.',
#  'Were you a fireman?  That how you knew how to rig the apartment?',
#  "My father was.  He gave me many lessons about fire.  Now it's my friend.",
#  "You can't kill me.  You're not a cop. Just fireman with a gun.  I bet you never shot anybody in your life.",
#  "C'mon.  Pull the trigger.  Do it.  Oh, look, you're sweating.  You don't have the balls.",
#  "Where's your partner?",
#  'Tell him to put his gun down!',
#  'Let her go!  Let her go!!',
#  "Hi, I'm Honey.",
#  "Where's Czech girl?",
#  "Now I like to get business out of the way before we get down to pleasure.  Why don'tchya put my money on the dresser.",
#  "It's an outcall service run out of an apartment.  I don't meet the other girls.  Aren't you gonna get undressed?",
#  'Where is escort service?',
#  "That's confidential.  Could you put the money on the dresser?",
#  'I like to talk to the person who runs the service.  Can you give me address?',
#  "Listen to me.  I don't want sex.  Just give me the address and then you go.",
#  'Give me the address!!',
#  'Next.  Could I see your documents, please?',
#  'What is your intended purpose of your visit to the United States?',
#  'Two weeks holiday.',
#  'How much money are you carrying with you?',
#  'I have five-hundred dollars.',
#  'Is he with you?  Are you travelling together?',
#  'Yes.',
#  'Please join us.  Come on forward.',
#  'Is there a problem?',
#  'We are both from Prague.',
#  'How long are you planning to stay?',
#  'Two weeks.',
#  "I'd like to speak for himself, okay?",
#  'Who is he?',
#  'This all you want?',
#  'Do you know how much killer gets for movie rights?',
#  'In here, says he wants a million.',
#  'Million?!  The killer gets one million dollars for a television interview?',
#  'Hey, tabloids paid Ted Bundy - famous serial killer - half a million for his interview.  And how much you think Monica got for writing book about the President coming on to her?  It pays to be a killer or a whore in this country. Look, you want magazine or not?',
#  "Just do what I do.  Say the same thing I say.  Don't open your mouth.",
#  "Don't fool around.",
#  'Did you hear what I said?',
#  'Look.  Times Square.  Just like in the movies!',
#  "Don't speak Russian!",
#  'Why?  Why do I always have to speak to you in Czech?',
#  'Look.  New videocameras.  Color viewfinder.  Image stabilization. Solarization.  Night vision.',
#  ...]

# %% [markdown]
# Let's have a look at the answers list we created above

# %%
answers
# Out:
# ["Well, I thought we'd start with pronunciation, if that's okay with you.",
#  'Not the hacking and gagging and spitting part.  Please.',
#  "Okay... then how 'bout we try out some French cuisine.  Saturday?  Night?",
#  'Forget it.',
#  'Cameron.',
#  "The thing is, Cameron -- I'm at the mercy of a particularly hideous breed of loser.  My sister.  I can't date until she does.",
#  'Seems like she could get a date easy enough...',
#  'Unsolved mystery.  She used to be really popular when she started high school, then it was just like she got sick of it or something.',
#  "That's a shame.",
#  'Let me see what I can do.',
#  "Right.  See?  You're ready for the quiz.",
#  "I don't want to know how to say that though.  I want to know useful things. Like where the good stores are.  How much does champagne cost?  Stuff like Chat.  I have never in my life had to point out my head to someone.",
#  "That's because it's such a nice one.",
#  'Forget French.',
#  "Well, there's someone I think might be --",
#  'Where?',
#  "I counted on you to help my cause. You and that thug are obviously failing. Aren't we ever going on our date?",
#  "You're sweet.",
#  "Eber's Deep Conditioner every two days. And I never, ever use a blowdryer without the diffuser attachment.",
#  "I really, really, really wanna go, but I can't.  Not unless my sister goes.",
#  "I'm workin' on it. But she doesn't seem to be goin' for him.",
#  "Lesbian?  No. I found a picture of Jared Leto in one of her drawers, so I'm pretty sure she's not harboring same-sex tendencies.",
#  "So that's the kind of guy she likes? Pretty ones?",
#  "Who knows?  All I've ever heard her say is that she'd dip before dating a guy that smokes.",
#  'Looks like things worked out tonight, huh?',
#  'I believe we share an art instructor',
#  'Tons',
#  'I was?',
#  "You never wanted to go out with 'me, did you?",
#  "Then that's all you had to say.",
#  'But',
#  'You always been this selfish?',
#  'No...',
#  'What crap?',
#  "Me.  This endless ...blonde babble. I'm like, boring myself.",
#  'Thank God!  If I had to hear one more story about your coiffure...',
#  'What good stuff?',
#  'The "real you".',
#  'Like my fear of wearing pastels?',
#  'No',
#  "Okay -- you're gonna need to learn how to lie.",
#  "Let's go.",
#  'I hope so.',
#  'They do not!',
#  'No.',
#  'You might wanna think about it',
#  'Who?',
#  'Joey.',
#  'Would you mind getting me a drink, Cameron?',
#  'Is he oily or dry?',
#  "Combination.  I don't know -- I thought he'd be different.  More of a gentleman...",
#  "Sometimes I wonder if the guys we're supposed to want to go out with are the ones we actually want to go out with, you know?",
#  "All I know is -- I'd give up my private line to go out with a guy like Joey.",
#  "I don't have to be home 'til two.",
#  'I did.',
#  'Expensive?',
#  'Hopefully.',
#  'Queen Harry?',
#  "It's a gay cruise line, but I'll be, like, wearing a uniform and stuff.",
#  "My agent says I've got a good shot at being the Prada guy next year.",
#  'Hi, Joey.',
#  "You're concentrating awfully hard considering it's gym class.",
#  "You know the deal.  I can ' t go if Kat doesn't go --",
#  'Nowhere... Hi, Daddy.',
#  'Can you at least start wearing a bra?',
#  "It means that Gigglepuss is playing at Club Skunk and we're going.",
#  "Oh, I thought you might have a date  I don't know why I'm bothering to ask, but are you going to Bogey Lowenstein's party Saturday night?",
#  'What do you think?',
#  "I think you're a freak.  I think you do this to torture me.  And I think you suck.",
#  "What's normal?",
#  "Bogey Lowenstein's party is normal, but you're too busy listening to Bitches Who Need Prozac to know that.",
#  "At least I'm not a clouted fen- sucked hedge-pig.",
#  "It's Shakespeare.  Maybe you've heard of him?",
#  "Yeah, he's your freak friend Mandella's boyfriend.  I guess since I'm not allowed to go out, I should obsess over a dead guy, too.",
#  'Can we go now?',
#  "I really don't think I need any social advice from you right now.",
#  "You're welcome.",
#  'Like you care.',
#  "I do care. But I'm a firm believer in doing something for your own reasons, not someone else ' s .",
#  "I wish I had that luxury. I'm the only sophomore that got asked to the prom and I can't go, because you won ' t.",
#  'What?',
#  'In 9th.  For a month',
#  'Why?',
#  'He was, like, a total babe',
#  'But you hate Joey',
#  'Now I do.  Back then, was a different story.',
#  'As in...',
#  'You did what?',
#  "Just once.  Afterwards, I told him I didn't want to anymore.  I wasn't ready. He got pissed.  Then he broke up with me.",
#  'After that, I swore I\'d never do anything just because "everyone else" was doing it.  And I haven\'t since. Except for Bogey\'s party, and my stunning gastro-intestinal display --',
#  "Why didn't you tell me?",
#  'I wanted to let you make up your own mind about him.',
#  "No. you didn't!  If you really thought I could make my own decisions, you would've let me go out with him instead of helping Daddy hold me hostage.",
#  "I'm not stupid enough to repeat your mistakes.",
#  'I guess I thought I was protecting you.',
#  "God, you're just like him! Just keep me locked away in the dark, so I can't experience anything for myself",
#  "Not all experiences are good, Bianca. You can't always trust the people you want to.",
#  "I guess I'll never know, will I?",
#  'So did you',
#  'You set me up.',
#  'I just wanted --',
#  'What? To completely damage me?  To send me to therapy forever? What?',
#  'No! I just wanted',
#  "It's just you.",
#  'Perm?',
#  "No! You're not dating until your sister starts dating.  End of discussion.",
#  'What if she never starts dating?',
#  "Then neither will you.  And I'll get to sleep at night.",
#  "But it's not fair -- she's a mutant, Daddy!",
#  'Exactly my point',
#  "And where're you going?",
#  'If you must know, we were attempting to go to a small study group of friends.',
#  'Otherwise known as an orgy?',
#  'It\'s just a party. Daddy, but I knew you\'d forbid me to go since "Gloria Steinem" over there isn\'t going --',
#  "If Kat's not going, you're not going.",
#  "It's just a party. Daddy.",
#  'Daddy, no!',
#  'Just for a minute',
#  'Why?',
#  "Because she'll scare them away.",
#  'The prom?  Kat has a date?',
#  'No, but',
#  "It's that hot rod Joey, right? That ' s who you want me to bend my rules for?",
#  'He\'s not a "hot rod".  Whatever that is.',
#  "You're not going unless your sister goes.  End of story.",
#  "Fine.  I see that I'm a prisoner in my own house.  I'm not a daughter. I'm a possession!",
#  "I have a date, Daddy.  And he ' s not a captain of oppression like some men we know.",
#  "Didn't have you pegged for a Gigglepuss fan.  Aren't they a little too pre-teen belly-button ring for you?",
#  'Fan of a fan.  You see a couple of minors come in?',
#  'Never',
#  'Padua girls.  One tall, decent body. The other one kinda short and undersexed?',
#  "Just sent 'em through.",
#  'So they tell me...',
#  "C'mon.  I'm supposed to give you the tour.",
#  "North, actually.  How'd you   ?",
#  'I was kidding. People actually live there?',
#  "Yeah.  A couple.  We're outnumbered by the cows, though.",
#  'How many people were in your old school?',
#  'Thirty-two.',
#  'Get out!',
#  'How many people go here?',
#  'Couple thousand. Most of them evil',
#  'Yeah, but these guys have never seen a horse.  They just jack off to Clint Eastwood.',
#  'You burn, you pine, you perish?',
#  'Who is she?',
#  "Bianca Stratford.  Sophomore. Don't even think about it",
#  'Why not?',
#  "I could start with your haircut, but it doesn't matter.  She's not allowed to date until her older sister does.  And that's an impossibility.",
#  "Because they're bred to.  Their mothers liked guys like that, and their grandmothers before them. Their gene pool is rarely diluted.",
#  'He always have that shit-eating grin?',
#  "Joey Dorsey?  Perma-shit-grin.  I wish I could say he's a moron, but he's number twelve in the class.  And a model.  Mostly regional stuff, but he's rumored to have a big tube sock ad coming out.",
#  "Sure do ... my Mom's from Canada",
#  'Guess who just signed up for a tutor?',
#  "You mean I'd get a chance to talk to her?",
#  'You could consecrate with her, my friend.',
#  "That's her?  Bianca's sister?",
#  'The mewling, rampalian wretch herself.',
#  "Unlikely, but even so, she still can't go out with you.  So what's the point?",
#  'You wanna go out with him?',
#  'He seems like he thrives on danger',
#  "No kidding.  He's a criminal.  I heard he lit a state trooper on fire.  He just got out of Alcatraz...",
#  'They always let felons sit in on Honors Biology?',
#  "I'm serious, man, he's whacked.  He sold his own liver on the black market so he could buy new speakers.",
#  "Forget his reputation.  Do you think we've got a plan or not?",
#  "Did she actually say she'd go out with you?",
#  "That's what I just said",
#  'I thought you hated those people.',
#  "Hey -- I've gotta have a few clients when I get to Wall Street.",
#  "Like we had a choice?  Besides -- when you let the enemy think he's orchestrating the battle, you're in a position of power. We let him pretend he's calling the shots, and while he's busy setting up the plan, you have time to woo Bianca.",
#  "In that case, we'll need to make it a school-wide blow out.",
#  'Will Bogey get bent?',
#  "Are you kidding?  He'll piss himself with joy.  He's the ultimate kiss ass.",
#  "It's a lung cancer issue",
#  'Her favorite uncle',
#  'Dead at forty-one.',
#  "Okay!  I wasn't sure",
#  "It's her favorite band.",
#  "Hell, I've just been going over the whole thing in my head and -",
#  "The hell is that?  What kind of 'guy just picks up a girl and carries her away while you're talking to her?",
#  "Buttholus extremus.  But hey, you're making progress.",
#  "No, I ' m not.",
#  "Best case scenario, you're back on the payroll for awhile.",
#  "Yeah -- we'll see.",
#  "I've retrieved certain pieces of information on Miss Katarina Stratford I think you'll find helpful.",
#  "So what does that give me?  I'm supposed to buy her some noodles and a book and sit around listening to chicks who can't play their instruments?",
#  "Don't make me do it, man",
#  "It's off. The whole thing.",
#  "She's partial to Joey, not me",
#  'Sure',
#  'Then, go get her',
#  "I don ' t know.  I decided not to nail her when she was too drunk to remember it.",
#  "She just needs time to cool off I'll give it a day.",
#  'She kissed me.',
#  'Where?',
#  'You get the girl.',
#  'Yeah, and I noticed the only part of you featured in your big Kmart spread was your elbow.  Tough break.',
#  "They're running the rest of me next month.",
#  'Not at all',
#  'Away.',
#  'Your sister here?',
#  'And why would I do that?',
#  'What do you think?',
#  'Yeah, whatever.  I want you to go out with her.',
#  "Sure, Sparky.  I'll get right on it.",
#  'You just said',
#  'You need money to take a girl out',
#  "But you'd go out with her if you had the cake?",
#  "You're gonna pay me to take out some girl?",
#  "I can't date her sister until that one gets a boyfriend.  And that's the catch. She doesn't want a boyfriend.",
#  'How much?',
#  'Fine, thirty.',
#  "Fifty, and you've got your man.",
#  "I'm on it",
#  "Watching the bitch trash my car doesn't count as a date.",
#  'I got her under control. She just acts crazed in public to keep up the image.',
#  'What?',
#  'A hundred bucks a date.',
#  'Forget it.',
#  'Forget her sister, then.',
#  "A deal's a deal.",
#  'Do what?',
#  'Get her to act like a human',
#  "Enough with the Barbie n' Ken shit. I know.",
#  'Are you lost?',
#  'Nope - just came by to chat',
#  "We don't chat.",
#  "Well, actually, I thought I'd run an idea by you.  You know, just to see if you're interested.",
#  "We're not.",
#  'Does this conversation have a purpose?',
#  "So what you need to do is recruit a guy who'll go out with her.  Someone who's up for the job.",
#  "Uh,  yeah.  We're old friend*",
#  'You and Verona?',
#  'What?  We took bathes together when we were kids.',
#  "Hey -- it's all for the higher good right?",
#  'Patrick Verona   Random skid.',
#  "That's Pat Verona? The one who was gone for a year? I heard he was doing porn movies.",
#  "I'm sure he's completely incapable of doing anything that interesting.",
#  'He always look so',
#  'Block E?',
#  'Just a little.',
#  'An attempted slit.',
#  "But imagine the things he'd say during sex.",
#  "You could always go with me.  I'm sure William has some friends.",
#  'William would never have gone to a state school.',
#  "William didn't even go to high school",
#  "That's never been proven",
#  'Neither has his heterosexuality.',
#  'Does it matter?',
#  'If I was Bianca, it would be, "Any school you want, precious.  Don\'t forget your tiara."',
#  'No fear.',
#  'Who cares?',
#  "I didn't have a choice.",
#  "You didn't have a choice?  Where's Kat and what have you done with her?",
#  'I did Bianca a favor and it backfired.',
#  "You didn't",
#  'I got drunk.  I puked.  I got rejected. It was big fun.',
#  "Well, I guess we're not, since we don't have dates .",
#  'Listen to you!  You sound like Betty, all pissed off because Archie is taking Veronica.',
#  "Okay, okay, we won't go.  It's not like I have a dress anyway",
#  "You ' re looking at this from the wrong perspective.  We're making a statement.",
#  'Oh, good.  Something new and different for us.',
#  'Who?',
#  'William - he asked me to meet him here.',
#  "Oh, honey -- tell me we haven't' progressed to full-on hallucinations.",
#  'Sweating like a pig, actually.  And yourself?',
#  "There's a way to get a guy's attention.",
#  'My mission in life.',
#  'Oh, right.  Friday.',
#  'Like where?  The 7-Eleven on Burnside? Do you even know my name, screwboy?',
#  'I know a lot more than that',
#  "I don't really think you warrant that strong an emotion.",
#  "Then say you'll spend Dollar Night at the track with me.",
#  'And why would I do that?',
#  'Come on -- the ponies, the flat beer, you with money in your eyes, me with my hand on your ass...',
#  'You -- covered in my vomit.',
#  'Seven-thirty?',
#  "I was in the laundromat. I saw your car. Thought I'd say hi.",
#  'Hi',
#  "Depends on the topic. My fenders don't really whip me into a verbal frenzy.",
#  '',
#  "That's what you want, isn't it?",
#  "Do you mind?  You're sort of ruining it for me.",
#  'You know who The Raincoats are?',
#  "Why, don't you?",
#  '"I\'m getting trashed, man." Isn\'t that what you\'re supposed to do at a party?',
#  'I say, do what you wanna do.',
#  "Funny, you're the only one",
#  "I'm fine. I'm",
#  'I just need to lie down for awhile',
#  "Uh, uh. You lie down and you'll go to sleep",
#  'I know, just let me sleep',
#  'What if you have a concussion? My dog went to sleep with a concussion and woke up a vegetable. Not that I could tell the difference...',
#  "Leave it to you to use big words when you're shitfaced.",
#  "Why 're you doing this?",
#  'I told you',
#  "You don't care if I die",
#  'Sure, I do',
#  'Why?',
#  "Because then I'd have to start taking out girls who like me.",
#  'Like you could find one',
#  "See that?  Who needs affection when I've got blind hatred?",
#  'Just let me sit down.',
#  'Who?',
#  'Dorsey.',
#  'I hate him.',
#  "I know.  It'd have to be a pretty big deal to get you to mainline tequila. You don't seem like the type.",
#  'Hey man. . .  You don \' t think I can be "cool"?  You don\'t think I can be "laid back" like everyone else?',
#  'I thought you were above all that',
#  'You know what they say',
#  'What?',
#  "But it's Gigglepuss - I know you like them.  I saw you there.",
#  'Busy',
#  'Were you in jail?',
#  'Maybe.',
#  "No, you weren't",
#  "Then why'd you ask?",
#  "Why'd you lie?",
#  'Do what?',
#  'This.',
#  "My father wouldn't approve of that that",
#  "You don't strike me as the type that would ask permission.",
#  "I'm gettin' there",
#  "He just wants me to be someone I'm not.",
#  'Who?',
#  'BIANCA',
#  "No offense, but you're sister is without.  I know everyone likes her and all, but ...",
#  'What are you doing here?',
#  'I heard there was a poetry reading.',
#  "You 're so --",
#  'Pleasant?',
#  'Unwelcome.',
#  'Unwelcome?  I guess someone still has her panties in a twist.',
#  "Don't for one minute think that you had any effect whatsoever on my panties.",
#  'So what did I have an effect on ?',
#  'Other than my upchuck reflex? Nothing.',
#  'Look up, sunshine',
#  "C'mon.  It's not that bad",
#  "Try lookin' at it from this angle",
#  "Forget it.  I'm stayin'.",
#  'You want me to climb up and show you how to get down?',
#  'Maybe.',
#  'I figured it had to be something ridiculous to win your respect.  And piss you off.',
#  'Good call.',
#  "So how'd you get Chapin to look the other way?",
#  'I dazzled him with my wit',
#  "Yeah, well, don't let it get out",
#  "So what's your excuse?",
#  'Acting the way we do.',
#  'Yes',
#  "I don't like to do what people expect. Then they expect it all the time and they get disappointed when you change.",
#  "So if you disappoint them from the start, you're covered?",
#  'Something like that',
#  'Then you screwed up',
#  'How?',
#  'You never disappointed me.',
#  'For. . . ?',
#  'Fallacy.',
#  'The duck?',
#  'Hearsay.',
#  "I know the porn career's a lie.",
#  'I hate peas.',
#  'No -- something real.  Something no one else knows.',
#  "You're sweet.  And sexy.  And completely hot for me.",
#  'What?',
#  'No one else knows',
#  "You're amazingly self-assured. Has anyone ever told you that?",
#  'Go to the prom with me',
#  'You know what I mean',
#  'No.',
#  'No what?',
#  "No, I won't go with you",
#  'Why not?',
#  "Because I don't want to. It's a stupid tradition.",
#  'So I have to have a motive to be with you?',
#  'You tell me.',
#  'You need therapy.  Has anyone ever told you that?',
#  'Answer the question, Patrick',
#  "Nothing!  There's nothing in it for me. Just the pleasure of your company.",
#  "It's Scurvy's.  His date got convicted. Where'd you get the dress?",
#  "It's just something I had.  You know",
#  'Oh huh',
#  "Look, I'm  -- sorry -- that I questioned your motives.  I was wrong.",
#  'What?',
#  "That's where I was last year.  She'd never lived alone -- my grandfather died -- I stayed with her.  I wasn't in jail, I don't know Marilyn Manson, and I've never slept with a Spice Girl.  I spent a year sitting next to my grandma on the couch watching Wheel of Fortune.  End of story.",
#  'It gets worse -- you still have your freshman yearbook?',
#  'You were paid to take me out!  By -- the one person I truly hate.  I knew it was a set-up!',
#  "It wasn't like that.",
#  'Really?  What was it like?  A down payment now, then a bonus for sleeping with me?',
#  "I didn't care about the money.",
#  'I thought you could use it. When you start your band.',
#  'Is that right?',
#  'Yeah, but then I fucked up. I fell for her.',
#  'Because I like to torture you.',
#  'Oh, Bianca?  Can you get me my freshman yearbook?',
#  "Don ' t you even dare. . .",
#  'I thought we decided you were going to school here.  At U of 0.',
#  'You decided.',
#  'Enough!',
#  'Then tell them I had a seizure.',
#  'Is this about Sarah Lawrence? You punishing me?',
#  'I thought you were punishing me.',
#  "Why can't we agree on this?",
#  "Because you're making decisions for me.",
#  "As a parent, that's my right",
#  "So what I want doesn't matter?",
#  "You're eighteen.  You don't know what you want.  You won't know until you're forty-five and you don't have it.",
#  'I want to go to an East Coast school! I want you to trust me to make my own choices.  I want --',
#  'Yeah.  She left with some bikers Big ones.  Full of sperm.',
#  'Funny.',
#  'No, Daddy.',
#  'So tell me about this dance. Was it fun?',
#  'Parts of it.',
#  'Which parts?',
#  'The part where Bianca beat the hell out of some guy.',
#  'Bianca did what?',
#  "What's the matter?  Upset that I rubbed off on her?",
#  'No -- impressed.',
#  'When I go?',
#  "Oh, Christ.  Don't tell me you've changed your mind.  I already sent 'em a check.",
#  'Expressing my opinion is not a terrorist action.',
#  "Well, yes, compared to your other choices of expression this year, today's events are quite mild.  By the way, Bobby Rictor's gonad retrieval operation went quite well, in case you're interested.",
#  'I still maintain that he kicked himself in the balls.  I was merely a spectator.',
#  'The point is Kat -- people perceive you as somewhat ...',
#  'No ... I believe "heinous bitch" is the term used most often.',
#  'Just smack her now.',
#  'Hi.',
#  'Cool pictures.  You a fan?',
#  'Yeah.  I guess.',
#  'Oh yeah.',
#  'Right.',
#  'Kat a fan, too?',
#  'Yeah...',
#  'What?',
#  "Whatever the hell it is you're standin' there waitin' to say.",
#  'The situation is, my man Cameron here has a major jones for Bianca Stratford.',
#  'What is it with this chick?  She have three tits?',
#  "Dorsey can plow whoever he wants. I'm just in this for the cash.",
#  'So Dorsey can get the girl?',
#  "Patrick, Pat, you're not looking at the big picture.  Joey's just a pawn. We set this whole thing up so Cameron can get the girl.",
#  "We're your guys.",
#  'Good enough.',
#  'Just for now.',
#  'Yeah.',
#  "I'm likin' you guys better",
#  "No - I've got a sweet-payin' job that I'm about to lose.",
#  'Sweet love, renew thy force!',
#  "Man -- don't say shit like that to  me. People can hear you.",
#  'It says here you exposed yourself to a group of freshmen girls.',
#  'It was a bratwurst.  I was eating lunch.',
#  'With the teeth of your zipper?',
#  'Touch of the flu.',
#  "I'm at a loss, then.  What should we talk about? Your year of absence?",
#  "What's to discuss?",
#  "You weren't abused, you aren't stupid, and as far as I can tell, you're only slightly psychotic -- so why is it that you're such a fuck-up?",
#  "Well, you know -- there's the prestige of the job title... and the benefits package is pretty good...",
#  'See you next week!',
#  'Make anyone cry today?',
#  'Sarah Lawrence is on the other side of the country.',
#  'Tumescent!',
#  "You're not helping.",
#  'Pirate -- no question.',
#  "Kissing?  Is that what you think happens?  Kissing isn't what keeps me up to my elbows in placenta all day.",
#  'Dr. Ruth?',
#  'But -- who -- what --?',
#  'Your daughters went to the prom.',
#  'Did I have anything to say about it?',
#  'Absolutely not.',
#  "That ' s what I thought",
#  "The water's going putrid in the barrels.",
#  "You'll be drinking your own piss... For the glory of Spain... and Admiral Colon...!  Bastard!",
#  "Ah, leave him alone.  He's doing no harm.",
#  "With a face like that?  I don't want you looking at me.  You hear?",
#  "We'll all go crazy...",
#  "We left three weeks ago, Alonso. Can't be that near.",
#  "Can't be that far, I say.  Also, I don't like the smell of the sea around here.  Smells like a cunt. Bad sign...",
#  'Yes, your Eminence.  The voyage should not take more than six or seven weeks.',
#  'Unfortunately, Don Colon, that is precisely where our opinions differ...  Are you familiar with the work of Aristotle?  Erathostene?  Ptolemeus?',
#  'I am, Your Eminence',
#  'Then you cannot ignore that according to their calculations, the circumference of the Earth is approximately...  22,000 leagues or more.  Which makes the ocean... uncrossable.',
#  'Excellency, you are right.',
#  'Your life, and that of others!',
#  'If they agree to follow me, yes.',
#  'Is that all that interests you? Gold?',
#  'No.  The Portuguese have already discovered black-skinned people.  I, too, will find other populations -- and bring them to the word of God.',
#  "Did He not choose a carpenter's son to reveal Himself to the world?",
#  'Blind faith is what I consider heresy!',
#  'IF-GOD-WILLS-IT!',
#  'The Judgment is ours!',
#  'Naturally.  But I would really deplore the loss of such a potential opportunity for Spain for a... dispute over a point of geography.',
#  'Indeed.  The world is full of mercenaries -- and states often make use of them, when it benefits them.  My only concern is the welfare and prosperity of Spain.',
#  'On the contrary, Your Eminence.  It seems to me the man is preparing his own cross.',
#  'What a tragedy... what a waste of a life...',
#  'A waste...?  Let me tell you something, Arojaz.  If your name, or mine, is ever remembered -- it will only be because of his.',
#  'I know.',
#  "I haven't given you much of a life.",
#  "Well... that's true.  I have a child by a man who won't marry me!  Who's always leaving...",
#  'Are we going to argue?',
#  "I'd love to argue with you sometimes.  But you're never here!",
#  'I find that hard to believe.',
#  'Thank God...',
#  "I don't want you to wait for me.",
#  "That's something you can't decide.",
#  "You don't usually ask.",
#  'I can arrange for the Queen to take Fernando and Diego into her service.',
#  "They tried... but I didn't let them.",
#  "Not everything... Do you think I care?  I'm a free man again.  Riches don't make a man rich, they only make him busier...",
#  'I am busy inside.',
#  "I can't keep my eyes off you.  I would like to catch up with all the moments I didn't spend with you.",
#  'Forgive me, Don Bobadilla -- those positions have already been taken.',
#  'May I ask by whom?',
#  'Bartolome and Giacomo Colon.',
#  'Yes... I remember...',
#  'Appointment to what?',
#  'Viceroy of the West Indies.',
#  'Congratulations.  Then I am free to search for the mainland.',
#  'I am not a seaman.  But I heard it is no more than a week at sea.  I hope you are not too disappointed.',
#  'How could I be?  The mainland has been found.  Exactly as I said it would.',
#  'I am afraid this is not the worst news.',
#  "There'll be a time.",
#  'You promise?  Do you swear on St. Christopher...?',
#  'Yes... Yes, I do... On all of them!',
#  'This time with me!',
#  'Not bad.',
#  'There must be a passage to that other ocean.',
#  "I am not listening, Father.  But I can't help hearing.",
#  'He asks when he can come to visit you.  He left his address.',
#  'He never had one... except aboard my ships!',
#  "Really?  God... I wouldn't know where to start... and yet...",
#  'Tell me the first thing that comes to your mind.',
#  'No?',
#  'NO...!  I have waited too long, fought too hard.  Now you expect me to take all the risks while you take the profit!  No... I will not be your servant!',
#  "I'm not bargaining!",
#  'Then you are too ambitious.',
#  "If you won't accept our proposal, we'll simply find someone who will.",
#  'Forgive me, Don Colon.  But what about gold?',
#  '... for a commoner?',
#  'Don Bobadilla is already a judge, my Dear Don Cristobal.',
#  'Good!  We are also in need of judges.  Except there are no thieves!',
#  'What...?  Do I have so many already?',
#  'To rise so high, in so short a time, is a dangerous occupation.  A little hypocrisy goes a long way.',
#  'Call them.',
#  'Look out of that window.',
#  'Roofs... towers, palaces... spires...',
#  'All of them created by people like me.',
#  'What is it?  A tribe?  An island?',
#  'Island.  Far.',
#  'Tell the Chief we thank him.',
#  'Chief knows.',
#  'Tell him his country is very beautiful.  Tell him we are leaving men here -- to build a fort.',
#  'Thousands.',
#  'Why?',
#  'Chief says -- he has a God.',
#  '... and also to bring medicine.',
#  'Chief says...',
#  'He has medicine.  Tell him we admire his people.',
#  'He understands.',
#  'Ask him if he will help.',
#  'You did the same to your God!',
#  'You never learned how to speak my language.',
#  'Father, I am doing what I think is the best for him.  And he has the teacher I would have chosen for myself.',
#  "That's what it says.",
#  'How did you manage it?',
#  'With some difficulty.  I had to promise them you were not a total fool.',
#  'To open a new route to Asia.  At the moment there are only two ways of reaching it...',
#  'Ignorance!  I believe the Indies are no more than 750 leagues west of the Canary Islands.',
#  'How can you be so certain?',
#  'The calculations of Toscanelli Marin de Tyr, Esdras...',
#  'Esdras is a Jew.',
#  'So was Christ!',
#  "I'll try to remember that, Marchena...",
#  'Father Marchena!',
#  'Passion is something one cannot control!',
#  'You get so carried away when you are being contradicted!',
#  "I've been contradicted all my life... Eternity!",
#  'Only God knows the meaning of such words, my son.',
#  "Wait!  I've waited seven years already!  How much longer do you want me to wait?",
#  'If God intends you to go, then you will go.',
#  'Damn God!',
#  'Damn all of you!  You all set up theories based on what?  You never leave the safety of your studies! Go out!  Find out what the world is about and then tell me something I can listen to!',
#  "Colon!  Don't!",
#  'Forgive me, Father.  For I have sinned.',
#  'Father, I have betrayed my family. I betrayed my men.  And I betrayed you.',
#  'What are you saying?',
#  'I lied.  The journey will be longer than I said.',
#  'How long?',
#  'I am not sure... It could be twice the distance.',
#  "If I tell them, they won't follow me.  You know that I am right, Father.  You trust me...",
#  "My son, my son...  Your certitudes are sometimes frightening...  Christopher, you must speak to them. And if you don't I will.",
#  'You are bound by an oath, Father.',
#  'Give me absolution.',
#  "You'll always be older than me, Father.",
#  'I knew you would.',
#  'New worlds create new people.',
#  'Oh?  So you are a new man?',
#  "I don't know... I have the impression that I didn't change that much.  I still can't accept the world as it is!",
#  'No more than the woman who said she would take Granada from the Moors.',
#  'What did they say about Granada before today?',
#  'That she was impregnable.',
#  'Surely you can do anything you want.',
#  'You show no inclination to speak otherwise!',
#  'I know what I see.  I see someone who doesn\'t accept the world as it is.  Who\'s not afraid.  I see a women who thinks... "What if?"...',
#  'A woman?',
#  'Thirty seven, Your Majesty... And you?',
#  'They come and go as naked as the day God created them...',
#  'Thank you.',
#  "There is one thing I'd like to understand... Why do you want to go back, after all this?",
#  'Your Majesty -- some men are content to read about things.  I must see them with my own eyes.  I cannot be other than I am.',
#  'The Indians have no such word, Don Moxica.',
#  "If you want to keep your head on your shoulders, you'll do as I say.",
#  "We don't need to know.",
#  'We came here to stay!  To build! Not to start a crusade.  In this forest, there is enough danger to sweep us away in days!  So we will be brave and swallow our grief.  And in the name of those who died, we will accomplish what we came for.',
#  "My horse doesn't work.",
#  'You did not hear me, Don Colon.  Not my horse.',
#  'Savagery is what monkeys understand.',
#  "You'll be held in detention, deprived of your privileges and possessions.  Until you are returned to Spain where you will be judged. Have you anything to say?",
#  'You will regret this.',
#  'God be with us admiral.',
#  'And what do you think Mendez?',
#  "Well, I surely know what a quadrant is!  But I've never seen it used at night before.",
#  'Come over here.',
#  'Twenty eight.',
#  "He's drawing an isthmus... He's saying we're on an isthmus.",
#  "We can't be.",
#  'Immediately.',
#  'Six days ago, yes.',
#  'You must be mad...!',
#  'We have to keep the hopes of these men alive!',
#  "We're on the verge of a mutiny, Colon!",
#  "You think I don't know that?",
#  "We're lost!",
#  'The land is there.  I know it!',
#  "You don't know anything!  Listen Colon, these are my ships, right? So I'm telling you we're turning back!",
#  'And then what?  Half of the water has gone, the rest is nearly putrid! You know that!',
#  'Jesus Maria!  I should have never listened to you!',
#  'You never did.  You did all the talking for both of us, remember?',
#  'You bloody...',
#  'Pinzon, Pinzon... All we can do now is go forward!  Think about that!',
#  'You tell that to them!',
#  "You're right.  Let the men decide.",
#  'Yes, Your Majesty.',
#  'Never, Your Majesty.  Although...',
#  "Yes.  It would be a pity, wouldn't it?  Call him back!",
#  "We weren't expecting immediate profits, were we?  We must have faith.  We must give time for time.",
#  'Is this true, Brother Buyl?',
#  'He must be replaced.',
#  'And who would you think of, for such a task?',
#  'Then why?',
#  'Because he is not afraid of me.',
#  "I'm not your lawyer until I see the money.",
#  'Here.  I have your money.',
#  'Emil.  Take it easy.  Stay with me.  Sit down.  What do you need?  What are you looking for?',
#  'He has the camera!  He took the movie!',
#  'Where are we going?',
#  "I'm coming with you.",
#  'Yes.  Yes, come with me!',
#  "I'm invoking rights - this man is represented by counsel.  I'm coming with him.",
#  'You bring the cigarettes?',
#  'Oh, sure.',
#  'I was all of these.',
#  "Well, you didn't appreciate the severity of it until recently.  No question about that.",
#  'What about Oleg?',
#  "Disappeared.  They're looking everywhere.  Maybe he went back to Czechoslovakia.",
#  'No, he is here.  Shit...',
#  "Don't worry about him.  Think about yourself.",
#  'What about my movie rights?  Book rights?',
#  "Look, I haven't really focused on that kind of thing.",
#  "What's your cut?  How much?",
#  'I would say...half.  Half is fair.',
#  'No.  No way.',
#  "But it's...",
#  "Thirty-percent.  No more.  Or I call another lawyer.  This is the biggest case of your life.  Don't try to negotiate.  Thirty percent.  Say yes or no.",
#  'This is not about money, Emil.  I need your trust in me.',
#  'What else do you need?',
#  "I need to know about your background.  I need to know about your upbringing.  Why you're here.",
#  'Give me another one, please.',
#  'My father always degraded me.  Killed my self-esteem.  And my mother was blind.',
#  'Your mother was blind?',
#  'Yeah, she went blind giving birth to me. She went to fucking black market doctor to induce me.',
#  'Back in the Czech Republic?',
#  'Yeah, yeah...bad doctor gave her bad drugs which made her go blind.  And my father blamed me for her blindness...',
#  "Your father blamed you for your mother's blindness?",
#  'Yeah, he hated me from day when I was born.  Put it out.  Can you put the cigarette out?',
#  'Your father put cigarettes out on you?',
#  'Out on my back when I was a small boy.',
#  'Can I see your back?',
#  "I don't think it's abuse, I think it's torture.",
#  "Officers, there's your killer, do your duty, arrest him!",
#  "Alright.  That's a justifiable homicide.",
#  'Yes, but he was a cop.',
#  "If you cooperate with the DA - maybe they'll help you with your situation.",
#  "I will if they don't send me back.",
#  "They won't until this is over.",
#  'Divorced.',
#  "Do you live alone?  I've been in these clothes since...the killings.  Could we stop at your place? I could take a shower...before I go into custody?",
#  'Somewhere else?',
#  'So...the station is empty?',
#  'Yeah.  This way.',
#  'Yes, I considered it.',
#  'Did you ever turn tricks before?',
#  'No.',
#  'What about back home?',
#  'No.',
#  'So you were never a prostitute?',
#  'What are you asking me?',
#  "I'm just trying to find out who you are.",
#  'I know.',
#  "You don't know.  I'm sorry.  I was desperate.  That's not me.  I shot a cop.  Can you imagine what they'll do to me when I got to prison?",
#  "They're not gonna send you right back.",
#  "I'm sorry.  I didn't mean to...I'm glad. Actually I'm glad it's over.  All this time.  Hiding.  Never being able to look anyone in the eyes. Always afraid that someone would find out who I was.  Never trusting anyone...",
#  "I still can't believe Eddie's gone.",
#  "I'm sorry.",
#  "Ludwig?  He's gay - are you jealous?",
#  'If I was your boyfriend, I might be.',
#  "If you were my boyfriend, I'd suggest you find another girlfriend that isn't going to jail ten-thousand miles away.",
#  "No matter what happens...I'm glad I met you.",
#  "I'm glad I met you.",
#  'Right.',
#  'In the kitchen.',
#  "I'll make some for us.",
#  "I'll get my clothes.",
#  'Pouring it out!',
#  '...Do you really want me to forget about you?',
#  "I don't want to drag you down with me.",
#  'Daphne, I...',
#  "C'mon, start at the beginning.  You know these people?",
#  'Tamina was a friend of mine.  My shower was broken, she let me use theirs.',
#  'Go on.',
#  'If I tell you, will you arrest me?',
#  'Arrest you for what?  Why would we arrest you?',
#  "No, no, don't talk to Immigration!",
#  "I'm from a small town in Slovakia.  Like the South here.  The Police is right, a civilian is wrong.  So I fled.",
#  "Look, we can help you but right now we have to deal with what's happening here. Tell us the truth...is that the truth?",
#  "You're a cop - you'll never believe me.",
#  'It was my decision, not his.',
#  "Well, I'm the Deputy Chief Fire Marshall and every now and then I'd like to be included in decisions.",
#  'Look, after Jordy briefs me, you can do the press conference.  How about that? The case is all yours.',
#  'Oh yeah...?  Alright.',
#  "I'm ready to be briefed.  Excuse us.",
#  "Yeah, sure.  Beep me when you're ready for the press conference.",
#  'Who do you think, Chief?!',
#  "Then why didn't you talk to the reporter?",
#  "'Cause we got more important things to do, like finding out who did it.",
#  "I came to see how the investigation was going.  I called and you're not here.  I wait up at the station and you don't even show up!!!  I beep you - you don't return my call.  Where the hell have you been?!",
#  "What do you mean, 'cleaned up?'",
#  'I let her take a shower.',
#  'A shower!?  Did you take one, too?',
#  'No!  Nothing happened.',
#  "Oh really.  That's nice.  You took a homicide witness to take a shower after your partner was shot?  Are you out of your fucking mind??  Are you having that much trouble gettin' dates?!",
#  'Okay.  But not water sports.',
#  'What was I supposed to do?  The guy tried to mug me.  I was gonna send a cop back - I just forgot.',
#  'Forgot?  You handcuffed a civilian to a tree?!',
#  'Chief - I know I screwed up - but this guy was no innocent civilian.',
#  'Well this is gonna end your career and probably mine.',
#  'End my career?',
#  "How are you going to fight this?  Maybe if Oleg hadn't gotten away and you'd been on the front page, as a hero, this thing would be easier to fight.  You'd have the good to weight against the bad! It's unfortunate that I have to make decisions based upon your press coverage but there's nothing I can do!  Gimme your shield.",
#  'But Chief?  Over this??',
#  "There's nothing to talk about.  Get a good lawyer.  You're suspended until your trial.",
#  'Yeah, right.',
#  'What was that, Korfin?',
#  "I said, yeah, you're right, Chief.  As soon as we get somethin' we'll let you alert the media.",
#  "You do that, wiseguy.  Now let's solve this thing before Eddie Flemming does.",
#  'Yeah.  He finished awhile ago.',
#  'Alright.  Swing by her apartment.  Let her pick up her clothes and take her straight to Hoover Street.  You got that?',
#  'Yeah.',
#  'Vodka tonic.',
#  'Maybe you could just put in a shot of Martell?',
#  "What's the kid gonna say - sorry? Meanwhile I'm not here anymore. Like last week - we were at the morgue and this guy was all chopped up - spleen here - liver there - his heart in a pan. Six hours ago this guy was walkin' his dog or buyin' a quart of milk.  Who knows?  But some kid's robbed him for $3 or some shit and shot him and now you can't tell if he's a piece of beef or a human being and I'm thinkin' that's me. Sooner or later.  That's me.",
#  'When?',
#  'Tomorrow.  At lunch.',
#  'You ready?',
#  'A timer.',
#  "Takin' a bath.",
#  'Any I.D.?',
#  "Still unknown but we're running prints. Kid over there caught the case.",
#  "It's okay.",
#  'Yeah.',
#  "C'mere.  You wanna go to homicide school?  Here - make yourself useful.",
#  'Stay with her.',
#  "No.  I'm okay.",
#  "I know.  Relax.  Take it easy.  Don't worry, we'll get those fuckers.",
#  "Police.  We'd like to ask you a few questions.",
#  "I have nothin' to say.  If you wanna contact my attorney...",
#  "Homicide, Miss Hearn.  It's Detective Eddie Flemming.  Open up.",
#  "We don't have her I.D. yet, but one of your girls was killed last night at the King Edward Hotel.",
#  "Oh my G-d.  Honey!  Honey's dead?",
#  'Do you have any Czech girls working for you?',
#  'No.',
#  'Did you tell him you did?',
#  'What are you saying?',
#  'Daphne.  Another guy came in asking me about her, too.',
#  'Describe him.',
#  "Tall, short-haired, scary eyes.  Second guy with him was...shorter, with a wrestler's build.  And he wouldn't turn his videocamera off me.",
#  'He had a videocamera?  Where is she? Quickly!',
#  "She washes hair up at Ludwig's - a salon on 63rd and Madison.",
#  "No, we don't mind.  You mind Leon?",
#  'No, what is it?',
#  "Why don't you explain it, Bobby.  Hey Camello!  You mind punching a hole in the floor?",
#  'Watch the news?',
#  'Nah, I musta missed it.',
#  'Well, just so you know.  I gave you guys the credit.',
#  "Well, just so you know, I don't care about that stuff.",
#  'Nah, why should you?',
#  "I don't even watch TV.",
#  'Good.  Good.  Commendable.',
#  'Sure.  But I would like to ask you something.  You got a problem with me?',
#  "If you found me steppin' on your crime scene - it might piss you off, too.  What about the report?",
#  "You were right, they were both dead before the fire.  The male was stabbed so hard the killer broke off the tip of the knife in his spine.  That's usually an indicator of something personal.",
#  'Pretty.',
#  'Hmmmm.',
#  "Maybe you don't care about that either.  Prettiest suspect I've had in awhile.",
#  "Who says she's a suspect?",
#  "Look, I'm not even sure she has anything to do with this.  I saw her outside after the fire - thought it was a lead. Maybe she saw something.  Maybe she was visiting somebody here.  Who knows?",
#  'Eastern Europe.  Like what?  Romania? Hungary?',
#  'Or Czechoslovakia.  The Slavs have been fighting the Germans and the Russians for a thousand years.  These are very intense people and they take things personally.',
#  "There wasn't a fire.  There'll be nothing for you to do.",
#  "I can watch you, Eddie.  Maybe I'll learn something.",
#  "This isn't homicide school.",
#  'My parents are from Poland.  I can help with the Eastern European angle.',
#  "You're Polish?",
#  'My folks are.',
#  'Stay here.',
#  'You got any better ideas?',
#  'Mind if I ride along with you?',
#  'This has nothing to do with your fire.',
#  'But what if it does?  You might need my help.',
#  "This is ridiculous.  I'm not gonna be in your way - we can talk the case over.",
#  "Tell you what - I'll flip you a coin. If you win you can come with me.  If you don't win, you don't come.",
#  "I'll call it... tails.",
#  'Better than one.',
#  "I'm on my way with Eddie.  Ludwig's. 63rd and Madison.  The suspects might be there already.",
#  "I'm on duty.",
#  "So am I.  Alright, I'll go inside and you cover the back.",
#  'Of course.',
#  "Hey!  I always wanted to be a cop when I was a kid.  I dreamed of running up to a door, kicking it in, pulling my gun and yelling 'Freeze!' at the bad guy! What'd you dream about?",
#  'I wanted to run up to a building on fire, kick in the door, rush into the smoke and save a kid.',
#  "Then I guess we're doin' this the right way, aren't we?  If we pull up to a burning building I'll gladly let you go first.",
#  'She just saw two of her friends killed! They probably threatened her.',
#  'Is that all there is?',
#  'Something back home?',
#  'Raw deal.',
#  'You wanna talk to her alone?',
#  'Yeah.',
#  'What would your girlfriend think of that?',
#  "I don't have a girlfriend.",
#  'My point exactly.',
#  "I'm serious here.",
#  'So am I.',
#  "C'mon.  You intimidate her 'cause you're a celebrity.  She sees me differently.",
#  "You're her Savior?  Is she the kid you're gonna save from the burning building?",
#  "You know what I'm saying here.",
#  "Hey.  I'm a professional.",
#  'Women like that have a way of turning professionals into amateurs.',
#  "Well, you shoulda because nobody's gonna believe you didn't...including me.",
#  "I took her there for a shower and that's it.",
#  'Just a shower?',
#  "No, I don't think you were a fool, I just think you were stupid about it.  I mean, to say the least, you outta know better.  You don't know her well enough. She's got the potential to fucking hang you even if she suggests that you made a pass at her, it's fuckin' over.  You can deny it all you want, but it will not make one fucking bit of difference. You're dead.",
#  "I told you, you know, I thought I was doing the right thing, you know, I think she's innocent.",
#  "Well, it's not up to you to decide whether she's innocent or not.  Don't you understand, that's why you're a professional.",
#  "But, I mean, didn't you ever go out on a limb for somebody?  I mean, you shoulda heard her there.  Tellin' her whole story...I believed her.",
#  "How you go out on a limb for somebody is by giving her a number of an Immigration lawyer.  Here, here's a number of an Immigration lawyer.  That's how you help her. But you can't get involved in her like that.  You're gonna jeopardize your career, your life and you're gonna jeopardize my case.  And lemme give you another piece of advice.  Maybe you don't watch TV but I'll let you in on a little secret - the whole fuckin' world watches television.  And when you get out there, they know your face.  And the little fame, the little fuckin' itty bitty fame that I get in this city makes it a lot easier for my job.  And I get more done because of it.",
#  "You know, I don't know.  I like you. You remind me of a puppy I used to have. He pissed on the rug all the time, but I still kept him.",
#  'What do you want?',
#  'Your opinion.  You see, they going to make a movie about me, too, Eddie.  And write books.',
#  "What's your accomplishment.",
#  'I kill someone famous.',
#  'Then do it, asshole.',
#  'Good - be tough to the end.  Actor who plays you will want to die like hero.',
#  "If you kill me and film it you're putting a noose around your neck.",
#  "Smarter than Americans.  You're fed cry baby talk shows all day long.  Not only will Americans believe me, they'll cry for me.  So...Detective Eddie Flemming, would you like to say goodbye to your Nicolette? Maybe you can propose to her now?",
#  "We don't know that yet.  It's much too early.  There's a lot to be done.",
#  'How many victims are up there?',
#  'There are two bodies found at this point.',
#  'Can we go up to the crime scene?',
#  "You know you can't do that.  C'mon.",
#  'Is it drug related?',
#  "We don't know.  When I have more I'll let you know.",
#  "I can't talk right now.  We have some things to take care of.",
#  "I really can't give out any information right now at this point.",
#  "Okay.  But I do understand that your partner, Leon Jackson's been injured. Is that correct?",
#  "He was hurt, but not seriously.  He'll be fine.",
#  'Do you have the suspect in custody?',
#  "Um...now is not a good time, okay. Detective Jackson's hurt.  He's fine. I've got a Fire Marshall shot, Detective Jackson is hurt but not seriously.",
#  'Alright, cut, cut, cut.',
#  "Yeah.  Now's not a good time.",
#  'Alright.',
#  'Alright?',
#  'Alright.',
#  'Alright.',
#  'Okay.',
#  'Hey.',
#  "I can't...I can't answer you just because you want me to answer you!",
#  "You didn't have to embarrass me in front of my colleagues.  You could give me something.",
#  "Oh, I'm sorry.  Did I embarrass you, sweetheart?  Oh...",
#  'Stop it.',
#  'Maybe I should just, ya know...turn to the cameras and say, do you mind if we just work something out?',
#  "Alright, alright, Eddie.  Don't patronize me.",
#  "I'm not.",
#  "Yes you are.  I'm not just some reporter.  I don't just stick a microphone in your face.  You could give me something.",
#  'Yeah, well you took the camera and put it right down on the evidence.  That was...',
#  'That was good.  You were holding the evidence.',
#  "You were merciless.  You didn't give a shit if you got me or not.",
#  'Well, who was it that taught me how to do that?  Huh?',
#  "You're ruthless.",
#  "You're not so bad yourself.",
#  "Could be Leon's.",
#  'Jesus.  And last week you came over with blood on your shoes.  What am I going to do with you?',
#  'Answer the phone.',
#  'No.  Tell me what you want to say.',
#  'Answer it.',
#  "Okay.  Okay.  Hold that thought just for a second.  They only call me when it's an emergency.  Just hold that thought.  Can you call back?",
#  "That's good.",
#  'Yeah.',
#  "Well, that's great.",
#  "Okay.  That is great.  But I can't go now, we're in the middle of something here.",
#  "No.  Go ahead.  You're gonna be great.",
#  "No.  No, listen to me here.  I want to know what you're talking about.  You know, the shoe thing and the marriages and...",
#  "I'll tell you tonight.  Let's do it tonight.  As soon as you get back we'll talk.  We'll talk.",
#  'Promise?',
#  "I promise.  We'll talk.  You'll be great.  You'll be fine.  Go ahead, just imagine that, uh... Just look into the lens and imagine you're talking to me.",
#  "Yeah.  I'll do that.  As long as you're not patronizing me.",
#  'Patronizing you... Nay, I love you.',
#  'I love you.',
#  'Tonight.',
#  'You promise?',
#  'Yeah.  I promise.',
#  "Okay.  And you know what, I'll swing by my place, grab a couple pairs of shoes and maybe just test them out next to yours...How's that... Would that be a good thing.",
#  'Yeah, yeah.  Good thing.',
#  'Okay.',
#  'See you later.  Good luck.',
#  'Thank you.',
#  "Don't be late.",
#  'Jesus Christ.',
#  'Not chopped up.  Not chopped up like that.  I mean, what do I got left? Coupla articles.  A medal or two. Plaque here and there and in a coupla years no one remembers me anymore.',
#  "I think you're getting a little moody there, Eddie.",
#  "I'm not moody.",
#  "My kids?  Let's see...Susan's 15. Aundrea's 9.  Don't tell me you're thinking about having a kid!  How old are you?  Never mind. Let me just tell you this: Every stupid cliche you hear about kids - they change your life, they make you a better person, they make you whole...  It's all true!  Before I had kids when friends talked about their kids, I wanted to vomit.  Now -- I get it.  Am I right, Leon?",
#  'Not what.  Who.',
#  "That's unique.",
#  'Yeah.  And he still went to the party.',
#  "You're worried for my safety.  I'm touched.",
#  'Keep them out of my way.',
#  'Okay.  You ready?',
#  'Yeah, yeah.  Jesus.',
#  "Again?  I didn't wanna do it the first time.",
#  'I am butcher.',
#  "You're a butcher?  What do you use pig intestines for?",
#  'You stuff sausage in it.',
#  'And what do you do with the bones?',
#  'Dog food.',
#  'No.  Are you proposing?',
#  "Look asshole.  I've been threatened by better than you.",
#  "No.  I'm the best that's ever threatened you.",
#  "I'll meet you on one condition - I get exclusivity and you surrender to me.",
#  "We'll talk about that.  Four o'clock gives you time to go to bank.  Three hundred thousand dollars.",
#  "What?  It doesn't work that way.",
#  "If you don't want my film - I'll call another show.  And they will show it.",
#  'Wait a minute.  Wait a minute.',
#  "Come alone.  Bring cash.  And we'll talk about surrendering.",
#  "My father was.  He gave me many lessons about fire.  Now it's my friend.",
#  'Tommy, take a walk.',
#  "You'll be my first.",
#  'Get down on your knees.',
#  "The Sheraton!  On Broadway!  Room 210. Go get Oleg.  He'll kill you.",
#  'Let her go!  Let her go!!',
#  "If he doesn't lower his gun I'll fucking kill her.",
#  "Where's Czech girl?",
#  "Baby, I'm anybody you want me to be. I'm a little schoolgirl, I'm mommy, I'm a Czech girl.",
#  'I ordered a Czech girl.  Daphne, you know her?',
#  'Where is escort service?',
#  "That's confidential.  Could you put the money on the dresser?",
#  'I like to talk to the person who runs the service.  Can you give me address?',
#  "Look.  Do we have a problem here? There's no reason to have a problem. I'm gonna make you feel real good.  You wanna Czech girl? After I'm done with you, you won't miss her.  Now why don't you pay me?",
#  "Look, man, I don't give a shit if you want sex or not, but you're payin' for my time.",
#  "Alright, alright - don't hurt me! Please, it's in my book, in my purse!",
#  'Yes sir.',
#  'Two weeks holiday.',
#  'How much money are you carrying with you?',
#  'I have five-hundred dollars.',
#  'Can you show me?  Sir, no cameras in the FIS area!',
#  'Yes.',
#  'Please join us.  Come on forward.',
#  'Is there a problem?',
#  "No, you're travelling together.  I want to talk to you together.  Hi, how are you?  Can I take a look at your documents?  Are you related?",
#  'How long are you planning to stay?',
#  'Two weeks.',
#  "I'd like to speak for himself, okay?",
#  "He doesn't speak English.",
#  "New York's finest.  This is his case.",
#  'Do you know how much killer gets for movie rights?',
#  'In here, says he wants a million.',
#  'Million?!  The killer gets one million dollars for a television interview?',
#  'Hey, tabloids paid Ted Bundy - famous serial killer - half a million for his interview.  And how much you think Monica got for writing book about the President coming on to her?  It pays to be a killer or a whore in this country. Look, you want magazine or not?',
#  'Yes.  Both.',
#  'Okay.',
#  'Okay.',
#  'I want to document my trip to America.',
#  "Don't speak Russian!",
#  'Why?  Why do I always have to speak to you in Czech?',
#  "Because I don't like your ugly language. I heard enough of it in school!  Now speak Czech or English.  And don't fool around anymore.  You almost got us thrown out!",
#  'We have no money.  Come on.',
#  ...]

# %% [markdown]
# # Cleaning of the texts

# %% [markdown]
# 1. put everything in lowercase
#
# 2. remove all the apostrophes
#
# 3. removing all non-essential words
#
# creating a function that will carry out all of the above activities
#
# Steps 1 and 2 will be carried out in the below function

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub(r"i'm", "i am", text)
    text = re.sub(r"he's", "he is", text)
    text = re.sub(r"she's", "she is", text)
    text = re.sub(r"that's", "that is", text)
    text = re.sub(r"what's", "what is", text)
    text = re.sub(r"where's", "where is", text)
    text = re.sub(r"\'ll", " will", text)
    text = re.sub(r"\'ve", " have", text)
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"\'d", " would", text)
    text = re.sub(r"won't", "will not", text)
    text = re.sub(r"can't", "cannot", text)
    text = re.sub(r"[-()\"#/@;:<>{}+=~|.?,]", "", text)
    return text

# %% [markdown]
# # Applying the above function for cleaning the questions
#
#
# 1.declare an empty list to store the questions after cleaning
#
# 2.iterate through the questions and clean each question one by one, and append the same to the clean_questions list

# %%
clean_questions = []
for question in questions:
    clean_questions.append(clean_text(question))

# %% [markdown]
# # Applying the clean_text function for cleaning the questions
#
# 1.declare an empty list to store the answers after cleaning
#
# 2.iterate through the answers and clean each answer one by one, and append the same to the clean_answers list

# %%
clean_answers = []
for answer in answers:
    clean_answers.append(clean_text(answer))

# %% [markdown]
# Let's have a look at the clean_questions list we created above

# %%
clean_questions
# Out:
# ['can we make this quick  roxanne korrine and andrew barrett are having an incredibly horrendous public break up on the quad  again',
#  'well i thought we would start with pronunciation if that is okay with you',
#  'not the hacking and gagging and spitting part  please',
#  'you are asking me out  that is so cute what is your name again',
#  "no no it's my fault  we didn't have a proper introduction ",
#  'cameron',
#  'the thing is cameron  i am at the mercy of a particularly hideous breed of loser  my sister  i cannot date until she does',
#  'why',
#  'unsolved mystery  she used to be really popular when she started high school then it was just like she got sick of it or something',
#  'gosh if only we could find kat a boyfriend',
#  "c'esc ma tete this is my head",
#  'right  see  you are ready for the quiz',
#  "i don't want to know how to say that though  i want to know useful things like where the good stores are  how much does champagne cost  stuff like chat  i have never in my life had to point out my head to someone",
#  "that is because it's such a nice one",
#  'how is our little find the wench a date plan progressing',
#  'there',
#  'you got something on your mind',
#  'you have my word  as a gentleman',
#  'how do you get your hair to look like that',
#  'sure have',
#  'i really really really wanna go but i cannot  not unless my sister goes',
#  'she is not a',
#  'lesbian  no i found a picture of jared leto in one of her drawers so i am pretty sure she is not harboring samesex tendencies',
#  'so that is the kind of guy she likes pretty ones',
#  'hi',
#  'you know chastity',
#  'have fun tonight',
#  'i looked for you back at the party but you always seemed to be occupied',
#  'i was',
#  'well no',
#  'then that is all you had to say',
#  'but',
#  'then guillermo says if you go any lighter you are gonna look like an extra on 90210',
#  'do you listen to this crap',
#  'what crap',
#  'me  this endless blonde babble i am like boring myself',
#  'i figured you would get to the good stuff eventually',
#  'what good stuff',
#  'the real you',
#  "i am kidding  you know how sometimes you just become this persona  and you don't know how to quit",
#  'no',
#  'wow',
#  'she okay',
#  'they do to!',
#  'did you change your hair',
#  'no',
#  'where did he go  he was just here',
#  'who',
#  'great',
#  'he practically proposed when he found out we had the same dermatologist i mean dr bonchowski is great an all but he is not exactly relevant party conversation',
#  'is he oily or dry',
#  "bianca i don't think the highlights of dating joey dorsey are going to include dooropening and coatholding",
#  'sometimes i wonder if the guys we are supposed to want to go out with are the ones we actually want to go out with you know',
#  'i have to be home in twenty minutes',
#  "you think you ' re the only sophomore at the prom",
#  "it's more",
#  "exactly  so you going to bogey lowenbrau's thing on saturday",
#  'so yeah i have got the sears catalog thing going  and the tube sock gig  that is gonna be huge  and then i am up for an ad for queen harry next week',
#  'queen harry',
#  'neat',
#  'hey sweet cheeks',
#  'hi joey',
#  'listen i want to talk to you about the prom',
#  'where have you been',
#  "i have the potential to smack the crap out of you if you don't get out of my way",
#  'oh my god does this mean you are becoming normal',
#  'it means that gigglepuss is playing at club skunk and we are going',
#  "oh i thought you might have a date  i don't know why i am bothering to ask but are you going to bogey lowenstein's party saturday night",
#  'what do you think',
#  "you are ruining my life'  because you will not be normal i cannot be normal",
#  'what is normal',
#  'cannot you forget for just one night that you are completely wretched',
#  'like i am supposed to know what that even means',
#  "it's shakespeare  maybe you have heard of him",
#  'you are so completely unbalanced',
#  'bianca i need to talk to you  i need to tell you ',
#  "i don't get you  you act like you are too good for any of this and then you go totally apeshit when you get here",
#  'listen i know you hate having to sit home because i am not susie high school',
#  'like you care',
#  "i do care but i am a firm believer in doing something for your own reasons not someone else ' s ",
#  'joey never told you we went out did he',
#  'what',
#  'in 9th  for a month',
#  'why',
#  'he was like a total babe',
#  'but you hate joey',
#  'now i do  back then was a different story',
#  'he said everyone was doing it  so i did it',
#  'you did what',
#  'but',
#  "after that i swore i would never do anything just because everyone else was doing it  and i haven't since except for bogey's party and my stunning gastrointestinal display ",
#  "why didn't you tell me",
#  'i wanted to let you make up your own mind about him',
#  'that is not',
#  'i am not stupid enough to repeat your mistakes',
#  'i guess i thought i was protecting you',
#  'god you are just like him! just keep me locked away in the dark so i cannot experience anything for myself',
#  'not all experiences are good bianca you cannot always trust the people you want to',
#  'you looked beautiful last night you know',
#  'let go!',
#  'you set me up',
#  'i just wanted ',
#  'what to completely damage me  to send me to therapy forever what',
#  'is that woman a complete fruitloop or is it just me',
#  'patrick  is that a',
#  "now don't get upset daddy but there's this boy and i think he might ask",
#  'no! you are not dating until your sister starts dating  end of discussion',
#  'what if she never starts dating',
#  'then neither will you  and i will get to sleep at night',
#  "but she doesn't want to date",
#  'daddy i ',
#  'and where are you going',
#  'if you must know we were attempting to go to a small study group of friends',
#  'otherwise known as an orgy',
#  'daddy people expect me to be there!',
#  "oh god  it's starting",
#  'wear the belly before you go',
#  'daddy no!',
#  'promise me you will not talk to any boys unless your sister is present',
#  'why',
#  "daddy i want to discuss the prom with you it's tomorrow night ",
#  'the prom  kat has a date',
#  'no but',
#  "it's that hot rod joey right that ' s who you want me to bend my rules for",
#  'he is not a hot rod  whatever that is',
#  'you are not going unless your sister goes  end of story',
#  'i am missing something',
#  'always a pleasure brucie',
#  "didn't have you pegged for a gigglepuss fan  aren't they a little too preteen bellybutton ring for you",
#  'fan of a fan  you see a couple of minors come in',
#  'never',
#  'padua girls  one tall decent body the other one kinda short and undersexed',
#  'you the new guy',
#  'so they tell me',
#  'so  which dakota you from',
#  'north actually  how would you   ',
#  'i was kidding people actually live there',
#  'yeah  a couple  we are outnumbered by the cows though',
#  'how many people were in your old school',
#  'thirtytwo',
#  'get out!',
#  'how many people go here',
#  'that i am used to',
#  'that girl  i ',
#  'you burn you pine you perish',
#  'who is she',
#  "bianca stratford  sophomore don't even think about it",
#  'why not',
#  'why do girls like that always like guys like that',
#  'because they are bred to  their mothers liked guys like that and their grandmothers before them their gene pool is rarely diluted',
#  'he always have that shiteating grin',
#  'you know french',
#  "sure do  my mom's from canada",
#  'guess who just signed up for a tutor',
#  'you mean i would get a chance to talk to her',
#  'yeah just a minor encounter with the shrew',
#  "that is her  bianca's sister",
#  'i teach her french get to know her dazzle her with charm and she falls in love with me',
#  'what about him',
#  'what makes you think he will do it',
#  'he seems like he thrives on danger',
#  'no kidding  he is a criminal  i heard he lit a state trooper on fire  he just got out of alcatraz',
#  'they always let felons sit in on honors biology',
#  'i am serious man he is whacked  he sold his own liver on the black market so he could buy new speakers',
#  'forget his reputation  do you think we have got a plan or not',
#  'did she actually say she would go out with you',
#  'you know if you do go out with bianca you would be set  you would outrank everyone strictly alist  with me by your side',
#  'i thought you hated those people',
#  'you got him involved',
#  'this is it  a golden opportunity patrick can ask katarina to the party',
#  'in that case we will need to make it a schoolwide blow out',
#  'will bogey get bent',
#  'number one  she hates smokers',
#  "it's a lung cancer issue",
#  'her favorite uncle',
#  'he is pretty!',
#  'assail your ears for one night',
#  'you told me that part already',
#  'extremely unfortunate maneuver',
#  "the hell is that  what kind of 'guy just picks up a girl and carries her away while you are talking to her",
#  'buttholus extremus  but hey you are making progress',
#  'you humiliated the woman! sacrifice yourself on the altar of dignity and even the score',
#  'and he means that strictly in a non prisonmovie type of way',
#  'what have you got for me',
#  'okay  likes  thai food feminist prose and angry stinky girl music of the indierock persuasion',
#  'gigglepuss is playing there tomorrow night',
#  'cameron i am a little busy',
#  'what  are you talking about',
#  'cameron  do you like the girl',
#  'sure',
#  'what would you do to her',
#  'she hates you with the fire of a thousand suns   that is a direct quote',
#  "you makin' any headway",
#  'she kissed me',
#  'what is the worst',
#  "the vintage look is over kat haven't you been reading your sassy",
#  'yeah and i noticed the only part of you featured in your big kmart spread was your elbow  tough break',
#  'hey  do you mind',
#  'where ya goin',
#  'away',
#  'leave my sister alone',
#  'yeah',
#  'two legs nice rack',
#  'yeah whatever  i want you to go out with her',
#  'sure sparky  i will get right on it',
#  'you just said',
#  'you need money to take a girl out',
#  'you got it verona  i pick up the tab you do the honors',
#  'you are gonna pay me to take out some girl',
#  "i cannot date her sister until that one gets a boyfriend  and that is the catch she doesn't want a boyfriend",
#  'i cannot take a girl like that out on twenty bucks',
#  "take it or leave it  this isn't a negotiation",
#  'when i shell out fifty i expect results',
#  'i am on it',
#  "watching the bitch trash my car doesn't count as a date",
#  'i just upped my price',
#  'what',
#  'a hundred bucks a date',
#  'forget it',
#  "it's about time",
#  'how would you do it',
#  'do what',
#  "i don't know dorsey the limothe flowers  another hundred for the tux ",
#  'hey',
#  'are you lost',
#  'nope  just came by to chat',
#  "we don't chat",
#  'well actually i thought i would run an idea by you  you know just to see if you are interested',
#  'but she cannot go out with you because her sister is this insane head case and no one will go out with her right',
#  'does this conversation have a purpose',
#  "i hear you are helpin' verona",
#  'uh  yeah  we are old friend*',
#  'you and verona',
#  'you better not fuck this up  i am heavily invested',
#  "who's that",
#  'patrick verona   random skid',
#  'that is pat verona the one who was gone for a year i heard he was doing porn movies',
#  'i am sure he is completely incapable of doing anything that interesting',
#  'he always look so',
#  'mandella eat  starving yourself is a very slow way to die',
#  'what is this',
#  'i realize that the men of this fine institution are severely lacking but killing yourself so you can be with william shakespeare is beyond the scope of normal teenage obsessions  you are venturing far past daytime talk show fodder and entering the world of those who need very expensive therapy',
#  'the people at this school are so incredibly foul',
#  'so he has this huge raging fit about sarah lawrence and insists that i go to his maledominated puking frat boy number one golf team school i have no say at all',
#  'william would never have gone to a state school',
#  "william didn't even go to high school",
#  'that is never been proven',
#  'i appreciate your efforts toward a speedy death but i am consuming  do you mind',
#  'does it matter',
#  'you think this will work',
#  'what would he say',
#  'you went to the party  i thought we were officially opposed to suburban social activity',
#  "i didn't have a choice",
#  "you didn't have a choice  where is kat and what have you done with her",
#  'i did bianca a favor and it backfired',
#  "you didn't",
#  'can you even imagine  who the hell would go to this a bastion of commercial excess',
#  "well i guess we are not since we don't have dates ",
#  'listen to you!  you sound like betty all pissed off because archie is taking veronica',
#  "okay okay we will not go  it's not like i have a dress anyway",
#  "you ' re looking at this from the wrong perspective  we are making a statement",
#  'have you seen him',
#  'who',
#  'william  he asked me to meet him here',
#  "i mean woman  how ya doin'",
#  'sweating like a pig actually  and yourself',
#  "there's a way to get a guy's attention",
#  'pick you up friday then',
#  'the night i take you to places you have never been before  and back',
#  'like where  the 7eleven on burnside do you even know my name screwboy',
#  "you hate me don't you",
#  "i don't really think you warrant that strong an emotion",
#  'then say you will spend dollar night at the track with me',
#  'and why would i do that',
#  'come on  the ponies the flat beer you with money in your eyes me with my hand on your ass',
#  'you  covered in my vomit',
#  'are you following me',
#  'i was in the laundromat i saw your car thought i would say hi',
#  'you are not a big talker are you',
#  'hey  great show huh',
#  'excuse me',
#  "that is what you want isn't it",
#  'you know these guys are no bikini kill or the raincoats but they are right up there',
#  'you know who the raincoats are',
#  'what is this',
#  "i am getting trashed man isn't that what you are supposed to do at a party",
#  'i say do what you wanna do',
#  'okay',
#  'you are not okay',
#  'i just need to lie down for awhile',
#  'uh uh you lie down and you will go to sleep',
#  'i know just let me sleep',
#  'this is so patronizing',
#  'leave it to you to use big words when you are shitfaced',
#  'why  are you doing this',
#  'i told you',
#  "you don't care if i die",
#  'sure i do',
#  'why',
#  'because then i would have to start taking out girls who like me',
#  'like you could find one',
#  'see that  who needs affection when i have got blind hatred',
#  'why would you let him get to you',
#  'who',
#  'dorsey',
#  'i hate him',
#  "i know  it would have to be a pretty big deal to get you to mainline tequila you don't seem like the type",
#  "hey man    you don ' t think i can be cool  you don't think i can be laid back like everyone else",
#  'i thought you were above all that',
#  'kat! wake up!',
#  'and i am in control of it',
#  'when you were gone last year  where were you',
#  'busy',
#  'were you in jail',
#  'maybe',
#  "no you weren't",
#  'then why would you ask',
#  'i should do this',
#  'do what',
#  'start a band',
#  "my father wouldn't approve of that that",
#  'oh so now you think you know me',
#  "so what ' s up with your dad  he a pain in the ass",
#  'he just wants me to be someone i am not',
#  'who',
#  'bianca',
#  'excuse me have you seen the feminine mystique  i lost my copy',
#  'what are you doing here',
#  'i heard there was a poetry reading',
#  'you  are so ',
#  'wholesome',
#  'unwelcome',
#  'unwelcome  i guess someone still has her panties in a twist',
#  "don't for one minute think that you had any effect whatsoever on my panties",
#  'so what did i have an effect on ',
#  'he left!  i sprung the dickhead and he cruised on me',
#  'i guess i never told you i am afraid of heights',
#  "c'mon  it's not that bad",
#  'put your right foot there ',
#  "forget it  i am stayin'",
#  'you want me to climb up and show you how to get down',
#  'the partridge family',
#  'i figured it had to be something ridiculous to win your respect  and piss you off',
#  'good call',
#  'so how would you get chapin to look the other way',
#  'a soft side who knew',
#  "yeah well don't let it get out",
#  'so what is your excuse',
#  'acting the way we do',
#  'yes',
#  "i don't like to do what people expect then they expect it all the time and they get disappointed when you change",
#  'so if you disappoint them from the start you are covered',
#  'something like that',
#  'then you screwed up',
#  'how',
#  'you up for it',
#  'state trooper',
#  'fallacy',
#  'the duck',
#  'hearsay',
#  'tell me something true',
#  'i hate peas',
#  'no  something real  something no one else knows',
#  'you are sweet  and sexy  and completely hot for me',
#  'what',
#  'no one else knows',
#  'you are amazingly selfassured has anyone ever told you that',
#  'is that a request or a command',
#  'you know what i mean',
#  'no',
#  'no what',
#  'no i will not go with you',
#  'why not',
#  'create a little drama  start a new rumor  what',
#  'so i have to have a motive to be with you',
#  'you tell me',
#  'you need therapy  has anyone ever told you that',
#  'answer the question patrick',
#  'how would you get a tux at the last minute',
#  "it's scurvy's  his date got convicted where would you get the dress",
#  "it's just something i had  you know",
#  'oh huh',
#  "my grandmother's ",
#  'what',
#  "that ' s completely adorable!",
#  'wait i',
#  'you were paid to take me out!  by  the one person i truly hate  i knew it was a setup!',
#  "it wasn't like that",
#  'really  what was it like  a down payment now then a bonus for sleeping with me',
#  'a fender strat you bought this',
#  'besides i had some extra cash some asshole paid me to take out a really great girl',
#  'is that right',
#  'why is my veggie burger the only burnt object on this grill',
#  'because i like to torture you',
#  'oh bianca  can you get me my freshman yearbook',
#  'i know',
#  'i thought we decided you were going to school here  at u of 0',
#  'this from someone whose diary is devoted to favorite grooming tips',
#  'my insurance does not cover pms',
#  'then tell them i had a seizure',
#  'is this about sarah lawrence you punishing me',
#  'i thought you were punishing me',
#  'why cannot we agree on this',
#  'because you are making decisions for me',
#  'as a parent that is my right',
#  "so what i want doesn't matter",
#  "you are eighteen  you don't know what you want  you will not know until you are fortyfive and you don't have it",
#  'was that your sister',
#  'yeah  she left with some bikers big ones  full of sperm',
#  "i don't understand the allure of dehydrated food  is this something i should be hip to",
#  'no daddy',
#  'so tell me about this dance was it fun',
#  'parts of it',
#  'which parts',
#  'the part where bianca beat the hell out of some guy',
#  'bianca did what',
#  'what is the matter  upset that i rubbed off on her',
#  "you know fathers don't like to admit that their daughters are capable of running their own lives  it means we have become spectators  bianca still lets me play a few innings  you have had me on the bleachers for years  when you go to sarah lawrence i will not even be able to watch the game",
#  'when i go',
#  'katarina stratford  my my  you have been terrorizing ms blaise again',
#  'expressing my opinion is not a terrorist action',
#  "well yes compared to your other choices of expression this year today's events are quite mild  by the way bobby rictor's gonad retrieval operation went quite well in case you are interested",
#  'i still maintain that he kicked himself in the balls  i was merely a spectator',
#  'tempestuous',
#  'am i supposed to feel better like right now  or do i have some time to think about it',
#  'hey there  tired of breathing',
#  'hi',
#  'cool pictures  you a fan',
#  'you think',
#  'macbeth right',
#  'right',
#  'kat a fan too',
#  'say it',
#  'what',
#  'what plan',
#  'the situation is my man cameron here has a major jones for bianca stratford',
#  "i think i speak correctly when i say that cameron's love is pure  purer than say  joey dorsey's",
#  'that is where we can help you  with kat',
#  'so dorsey can get the girl',
#  'you two are gonna help me tame the wild beast',
#  'what!',
#  'are you telling me i am a   nonsmoker',
#  'ever been to club skunk',
#  'i prefer to think of it simply as an alternative to what the law allows',
#  'so you got cozy with she who stings',
#  'you were right she is still pissed',
#  'sweet love renew thy force!',
#  'i missed you',
#  'it says here you exposed yourself to a group of freshmen girls',
#  'it was a bratwurst  i was eating lunch',
#  "i don't understand patrick  you haven't done anything asinine this week are you not feeling well",
#  'touch of the flu',
#  "why don't we discuss your driving need to be a hemorrhoid",
#  'what is to discuss',
#  "you weren't abused you aren't stupid and as far as i can tell you are only slightly psychotic  so why is it that you are such a fuckup",
#  'you are completely demented',
#  'in the microwave',
#  'what is a synonym for throbbing',
#  'jesus!  can a man even grab a sandwich before you women start dilating',
#  'tumescent!',
#  'would you rather be ravished by a pirate or a british rear admiral',
#  'they will dance they will kiss they will come home  let her go',
#  'what do you wanna watch  we have got crap crap crap or crap',
#  'have a great time honey!',
#  'what just happened',
#  'your daughters went to the prom',
#  'did i have anything to say about it',
#  'absolutely not',
#  'i never seen heat like this!  not even in las minas!',
#  "the water's going putrid in the barrels",
#  'what are you listening to chicken ass',
#  'ah leave him alone  he is doing no harm',
#  "he is the devil's child",
#  'we should have seen land',
#  'we left three weeks ago alonso cannot be that near',
#  'you say asia can be found by sailing west',
#  'yes your eminence  the voyage should not take more than six or seven weeks',
#  'unfortunately don colon that is precisely where our opinions differ  are you familiar with the work of aristotle  erathostene  ptolemeus',
#  'i am your eminence',
#  'senor colon an experienced captain such as yourself will understand our concern with the crew  i am not willing to have on my conscience the loss of men who would have relied upon our judgment',
#  'your eminence there is only one way to settle the matter  and that is to make the journey  i am ready to risk my life to prove it possible',
#  'your life and that of others!',
#  'trade your excellency  according to marco polo the kingdom of china is one of the richest of the world even the meanest buildings are roofed with gold',
#  'is that all that interests you gold',
#  'if god intended our proximity to asia do you believe he would have waited for you to show it to the world',
#  "don't you realize your words could be considered heretical",
#  'asia can be found to the west  and i will prove it',
#  "the state has some reason to be interested in this man's proposition your eminence",
#  'the judgment is ours!',
#  'he is a mercenary!  did he not already try to convince the king of portugal of his absurd notions',
#  'it will not be easy to get rid of your prophet now don sanchez',
#  'you can see for yourself',
#  'what a tragedy what a waste of a life',
#  'i could be gone for years',
#  'i know',
#  "i haven't given you much of a life",
#  "well that is true  i have a child by a man who will not marry me!  who's always leaving",
#  'are we going to argue',
#  'perhaps i was never meant to live with a woman',
#  'she said yes',
#  'i am not asking you to swear to anything',
#  "i don't want you to wait for me",
#  'beatrix i want to ask you something',
#  "you don't usually ask",
#  'god you are so beautiful!  i cannot believe no other man has ever taken you away from me',
#  'they took everything',
#  'cannot you stay with us a little',
#  'what is it now  tell me',
#  'i understand that you will soon be appointing governors for the islands  is it not so',
#  'forgive me don bobadilla  those positions have already been taken',
#  'may i ask by whom',
#  'don alonso de bobadilla',
#  'my letters of appointment',
#  'appointment to what',
#  'viceroy of the west indies',
#  'how far from here',
#  'i am not a seaman  but i heard it is no more than a week at sea  i hope you are not too disappointed',
#  'how could i be  the mainland has been found  exactly as i said it would',
#  'i want to go with you!',
#  'there will be a time',
#  'do you swear on all the holy saints in heaven',
#  'i have to explore the mainland',
#  'how are you feeling fernando',
#  'father',
#  'what are you listening to',
#  'what does he say',
#  'he asks when he can come to visit you  he left his address',
#  'i want you to tell me everything you remember father  from the beginning  everything',
#  "really  god i wouldn't know where to start and yet",
#  'no',
#  'no',
#  'i remind you senor colon that you are in no position to bargain with me',
#  'i am not bargaining!',
#  'and were you never ambitious excellency  or is ambition only a virtue among the nobles a fault for the rest of us',
#  "they don't see sin in their nakedness  they live according to nature in a never ending summer the islands are covered with trees filled with blossoms and fruits and",
#  'you defend yourself admirably',
#  'but we do have a lack of notaries you should contact my administration',
#  'don bobadilla is already a judge my dear don cristobal',
#  'you seem to have a special talent for making friends',
#  'what  do i have so many already',
#  'all i have to do is call the guards',
#  'i am not afraid of you  you are nothing but a dreamer',
#  'what do you see',
#  'roofs towers palaces spires',
#  'say not here!  cuba!',
#  'what is it  a tribe  an island',
#  'you come!  you speak first!',
#  'tell the chief we thank him',
#  'chief knows',
#  'chief says  how many',
#  'thousands',
#  'to bring the word of god',
#  'chief says  he has a god',
#  ' and also to bring medicine',
#  'chief says',
#  'we will work with his people  we want peace  ask the chief if he understands',
#  'he understands',
#  'you have to find them utapan  look what they did!',
#  'utapan will not you speak to me  you used to know how to speak to me',
#  'diego is a bright boy  a pleasure to teach  but so serious brothers should be raised together colon  even brothers from different mothers',
#  'god that is in a week!',
#  'that is what it says',
#  'how did you manage it',
#  'why do you wish to sail west',
#  'how can you be so certain  the ocean is said to be infinite',
#  'ignorance!  i believe the indies are no more than 750 leagues west of the canary islands',
#  'how can you be so certain',
#  'the calculations of toscanelli marin de tyr esdras',
#  'esdras is a jew',
#  "two minutes and already you are a dead man  don't let passion overwhelm you colon",
#  'i will try to remember that marchena',
#  'father marchena!',
#  'passion is something one cannot control!',
#  'you get so carried away when you are being contradicted!',
#  'i have been contradicted all my life eternity!',
#  "you mustn't give way to despair you must wait",
#  'wait!  i have waited seven years already!  how much longer do you want me to wait',
#  'if god intends you to go then you will go',
#  'colon!',
#  'all of them!  just lies!',
#  'in nomine patris et filius et spiritus sancti',
#  'i am listening my son',
#  'father i have betrayed my family i betrayed my men  and i betrayed you',
#  'what are you saying',
#  'i lied  the journey will be longer than i said',
#  'how long',
#  'may god forgive you!  you must tell them!  you must tell your men!',
#  'if i tell them they will not follow me  you know that i am right father  you trust me',
#  "my son my son  your certitudes are sometimes frightening  christopher you must speak to them and if you don't i will",
#  'i believed in you',
#  'i suppose we are both old men now',
#  'i have to disagree',
#  'i knew you would',
#  'new worlds create new people',
#  'oh  so you are a new man',
#  'i should not even be listening to you since my council said no  but santangel tells me you are a man of honor and sincerity and sanchez that you are not a fool',
#  'the ocean is uncrossable',
#  'what did they say about granada before today',
#  'i cannot ignore the verdict of my council',
#  'may i speak freely',
#  'you show no inclination to speak otherwise!',
#  "i know what i see  i see someone who doesn't accept the world as it is  who's not afraid  i see a women who thinks what if",
#  'how old are you senor colon',
#  'do they have such thoughts',
#  'but without your brothers  nor are you to return to santo domingo or any of the other colonies  you may explore the continent',
#  'thank you',
#  'there is one thing i would like to understand why do you want to go back after all this',
#  "and you say this is an indian vice by god!  i don't see any kind of pleasure that would make this a sin",
#  'we lost cousins friends  we will wash this in blood',
#  'you want a war  fine  we are a thousand  they outnumber us by ten! who will you kill  which tribe',
#  "we don't need to know",
#  'we cannot raise the wheel without it',
#  'don moxica  we all have to work',
#  'in one act of brutality you have created chaos  tribes who were fighting each other are now joining forces against us!  all that because of your criminal savagery!',
#  'savagery is what monkeys understand',
#  'you will be held in detention deprived of your privileges and possessions  until you are returned to spain where you will be judged have you anything to say',
#  'due west captain mendez  and may god be with us',
#  "well it's the men sir  they wonder how you know our position we have lost sight from land days ago",
#  'and what do you think mendez',
#  'well i surely know what a quadrant is!  but i have never seen it used at night before',
#  'what do you read',
#  'what is he doing',
#  'he is drawing an isthmus he is saying we are on an isthmus',
#  'where can i meet this man',
#  'you lied!  you cheated!  we are way past 750 leagues!',
#  'six days ago yes',
#  'you must be mad!',
#  'we have to keep the hopes of these men alive!',
#  'we are on the verge of a mutiny colon!',
#  "you think i don't know that",
#  'we are lost!',
#  'the land is there  i know it!',
#  "you don't know anything!  listen colon these are my ships right so i am telling you we are turning back!",
#  'and then what  half of the water has gone the rest is nearly putrid! you know that!',
#  'jesus maria!  i should have never listened to you!',
#  'you never did  you did all the talking for both of us remember',
#  'you bloody',
#  'pinzon pinzon all we can do now is go forward!  think about that!',
#  'you tell that to them!',
#  'is that the man i knew treasurer sanchez',
#  'you were right don sanchez his demands could never be granted',
#  ' into a monk',
#  'every ship returns with a cargo of sick and dying  but with no gold! the new world proves expensive your majesty',
#  ' but there is worse  he ordered the execution of five members of the nobility',
#  'then what do you suggest don sanchez',
#  'he must be replaced',
#  'i know i should not tolerate his impertinence',
#  'then why',
#  'are you my attorney  i am emil  i am insane',
#  'i am not your lawyer until i see the money',
#  'oh no!  no!  shit!',
#  'emil  take it easy  stay with me  sit down  what do you need  what are you looking for',
#  "don't say anything",
#  'where are we going',
#  'i am coming with you',
#  'yes  yes come with me!',
#  "i brought you some letters  it's really fan mail  women mostly  one wants to buy you clothes another sent a check another wants a check",
#  'you bring the cigarettes',
#  'delusions and paranoia',
#  'i was all of these',
#  "well you didn't appreciate the severity of it until recently  no question about that",
#  'what about oleg',
#  'disappeared  they are looking everywhere  maybe he went back to czechoslovakia',
#  'no he is here  shit',
#  "don't worry about him  think about yourself",
#  'what about my movie rights  book rights',
#  "look i haven't really focused on that kind of thing",
#  'what is your cut  how much',
#  'i would sayhalf  half is fair',
#  'no  no way',
#  "but it's",
#  "thirtypercent  no more  or i call another lawyer  this is the biggest case of your life  don't try to negotiate  thirty percent  say yes or no",
#  'this is not about money emil  i need your trust in me',
#  'what else do you need',
#  'i need to know about your background  i need to know about your upbringing  why you are here',
#  'tell me about yourself  what you did as a young boy what your parents were like',
#  'my father always degraded me  killed my selfesteem  and my mother was blind',
#  'your mother was blind',
#  'yeah she went blind giving birth to me she went to fucking black market doctor to induce me',
#  'back in the czech republic',
#  'yeah yeahbad doctor gave her bad drugs which made her go blind  and my father blamed me for her blindness',
#  "your father blamed you for your mother's blindness",
#  'that is what he did to me  he put cigarettes out on me',
#  'your father put cigarettes out on you',
#  'out on my back when i was a small boy',
#  "i am abused  don't you think",
#  'so we kill someone famous and if we are caught we are sent to mental hospital',
#  'my little sister and i shared a flat  i came home one night and a man was raping her  his gun was on the chair he came at me and i shot him',
#  'alright  that is a justifiable homicide',
#  'now i become custody of police department',
#  'if you cooperate with the da  maybe they will help you with your situation',
#  "i will if they don't send me back",
#  'are you married',
#  'divorced',
#  'i cannot take you to my place',
#  'the men are out of quarters  practicing putting out fires',
#  'sothe station is empty',
#  'you considered becoming a prostitute',
#  'yes i considered it',
#  'did you ever turn tricks before',
#  'no',
#  'what about back home',
#  "i came here  i had no money  i knew no one  i couldn't get a job because you have to have a green card to get work they approached me  i could have made a lot of money  i considered it but it's not who i am  they pay me below the table at ludwig's",
#  'so you were never a prostitute',
#  'what are you asking me',
#  'i am not a whore  i am not a whore',
#  'i know',
#  "you don't know  i am sorry  i was desperate  that is not me  i shot a cop  can you imagine what they will do to me when i got to prison",
#  'they are not gonna send you right back',
#  'are you alright',
#  "i still cannot believe eddie's gone",
#  'is he your boyfriend',
#  'ludwig  he is gay  are you jealous',
#  'if i was your boyfriend i might be',
#  'a good immigration lawyer could stall the process  eddie recommended one',
#  'no matter what happensi am glad i met you',
#  'you better get packed',
#  'do you have coffee',
#  'in the kitchen',
#  'i will make some for us',
#  'what are you doing',
#  'forget about me  you have enough problems of your own',
#  'do you really want me to forget about you',
#  "i don't want to drag you down with me",
#  "i told your partner i cannot help  i didn't see anything",
#  "c'mon start at the beginning  you know these people",
#  'tamina was a friend of mine  my shower was broken she let me use theirs',
#  'whether you tell us or not we will find out  better if it comes from you',
#  'if i tell you will you arrest me',
#  "are you here illegally  don't worry about that  we will talk to immigration they will not deport you",
#  'a cop',
#  'i am from a small town in slovakia  like the south here  the police is right a civilian is wrong  so i fled',
#  'look we can help you but right now we have to deal with what is happening here tell us the truthis that the truth',
#  'oh',
#  'it was my decision not his',
#  'well i am the deputy chief fire marshall and every now and then i would like to be included in decisions',
#  'look after jordy briefs me you can do the press conference  how about that the case is all yours',
#  'oh yeah  alright',
#  'i am ready to be briefed  excuse us',
#  'who did cause and origin',
#  'who do you think chief!',
#  "then why didn't you talk to the reporter",
#  'hey chief what are you doing here',
#  'ladder 20 was on the rock for training we stopped there so she could get cleaned up',
#  "what do you mean 'cleaned up'",
#  'i let her take a shower',
#  'a shower!  did you take one too',
#  'no!  nothing happened',
#  'chief  mind if i take her',
#  "the public doesn't have any idea what we do and now you are going to define our image!  this is going to be our rodney king!",
#  'what was i supposed to do  the guy tried to mug me  i was gonna send a cop back  i just forgot',
#  'forgot  you handcuffed a civilian to a tree!',
#  'chief  i know i screwed up  but this guy was no innocent civilian',
#  'well this is gonna end your career and probably mine',
#  'end my career',
#  "how are you going to fight this  maybe if oleg hadn't gotten away and you would been on the front page as a hero this thing would be easier to fight  you would have the good to weight against the bad! it's unfortunate that i have to make decisions based upon your press coverage but there's nothing i can do!  gimme your shield",
#  'but chief  over this',
#  "don't you guys understand  it's all about image  the better we look the more money i get to pay you guys overtime",
#  'yeah right',
#  'what was that korfin',
#  "i said yeah you are right chief  as soon as we get somethin' we will let you alert the media",
#  'did the da videotape her deposition',
#  'yeah  he finished awhile ago',
#  'alright  swing by her apartment  let her pick up her clothes and take her straight to hoover street  you got that',
#  'coffee for me i gotta slow down',
#  'vodka tonic',
#  'it was freaky i will tell you  stupid kid',
#  'i am gonna propose',
#  'when',
#  'tomorrow  at lunch',
#  'what is he looking for',
#  'where is she',
#  "takin' a bath",
#  'any id',
#  'sorrypd only',
#  'only one guys checked in',
#  'yeah',
#  "the other side of the street  the guy with the videocamera  don't look  put her in the car  stay this side",
#  'are you hit',
#  'he got my gun!  motherfucker was filming the whole time!',
#  "who's there",
#  'police  we would like to ask you a few questions',
#  "i have nothin' to say  if you wanna contact my attorney",
#  'what is wrong',
#  "we don't have her id yet but one of your girls was killed last night at the king edward hotel",
#  "yeah  he wanted a girl from czechoslovakia but i sent him honey 'cause once they get there you know it doesn't really matter  honey was killed  poor girl",
#  'do you have any czech girls working for you',
#  'no',
#  'boy she is so popular all the sudden',
#  'what are you saying',
#  'he said he was her cousin  i told him where she works  they were just here',
#  'describe him',
#  "tall shorthaired scary eyes  second guy with him wasshorter with a wrestler's build  and he wouldn't turn his videocamera off me",
#  'he had a videocamera  where is she quickly!',
#  "hey that is great you guys got it all wrapped up but you don't mind if we go through the routine  it gives us somethin' to do",
#  'you know what that is right',
#  'no what is it',
#  "it's your crime scene now  you can do what you want",
#  'watch the news',
#  'nah i musta missed it',
#  'well just so you know  i gave you guys the credit',
#  "well just so you know i don't care about that stuff",
#  'nah why should you',
#  "i don't even watch tv",
#  'did you get a report from the me',
#  'sure  but i would like to ask you something  you got a problem with me',
#  "if you found me steppin' on your crime scene  it might piss you off too  what about the report",
#  "the super said he would seen her before but she didn't live here",
#  'pretty',
#  'hmmmm',
#  "maybe you don't care about that either  prettiest suspect i have had in awhile",
#  'what would you call her',
#  "maybe it's a ritual thing or someone trying to send a message  burial rites are taken very seriously in eastern europe  it could be to humiliate them just burning them up no proper funeral it's like condemning them to hell",
#  'eastern europe  like what  romania hungary',
#  'i will come with you',
#  "there wasn't a fire  there will be nothing for you to do",
#  'i can watch you eddie  maybe i will learn something',
#  "this isn't homicide school",
#  'my parents are from poland  i can help with the eastern european angle',
#  'you are polish',
#  'my folks are',
#  "you goin' to the escort service",
#  'you got any better ideas',
#  'mind if i ride along with you',
#  'this has nothing to do with your fire',
#  'i will let you know what happens',
#  'this is ridiculous  i am not gonna be in your way  we can talk the case over',
#  "tell you what  i will flip you a coin if you win you can come with me  if you don't win you don't come",
#  'two heads',
#  "leon  meet us at 63rd and madison hair salon  ludwig's",
#  'you thirsty',
#  'i am on duty',
#  'so am i  alright i will go inside and you cover the back',
#  'of course',
#  "hey!  i always wanted to be a cop when i was a kid  i dreamed of running up to a door kicking it in pulling my gun and yelling 'freeze!' at the bad guy! what would you dream about",
#  'i wanted to run up to a building on fire kick in the door rush into the smoke and save a kid',
#  'what are you hiding  why are you afraid',
#  'she just saw two of her friends killed! they probably threatened her',
#  'why not',
#  'she is fucked  even if that story is true',
#  'look  let me talk to her  any leads i get they are all yours  just let me have a first crack at her',
#  'you wanna talk to her alone',
#  'yeah',
#  'what would your girlfriend think of that',
#  "i don't have a girlfriend",
#  'my point exactly',
#  'i am serious here',
#  'so am i',
#  "c'mon  you intimidate her 'cause you are a celebrity  she sees me differently",
#  'you are her savior  is she the kid you are gonna save from the burning building',
#  "okay tell you what i will give you a head start  you take her to the station house  don't let her out of your sight she is the only warm body we got left",
#  'hey  i am a professional',
#  "look eddie i am tellin' you  i didn't touch her",
#  "well you shoulda because nobody's gonna believe you didn'tincluding me",
#  'i took her there for a shower and that is it',
#  'yeah just her in the shower  nothing happened  look i am sure you probably think i am a fool and i fucked up but',
#  "no i don't think you were a fool i just think you were stupid about it  i mean to say the least you outta know better  you don't know her well enough she is got the potential to fucking hang you even if she suggests that you made a pass at her it's fuckin' over  you can deny it all you want but it will not make one fucking bit of difference you are dead",
#  'i told you you know i thought i was doing the right thing you know i think she is innocent',
#  "well it's not up to you to decide whether she is innocent or not  don't you understand that is why you are a professional",
#  "but i mean didn't you ever go out on a limb for somebody  i mean you shoulda heard her there  tellin' her whole storyi believed her",
#  'why would you help me back there with the chief  why would you stand up for me like that',
#  "sowho's nicky",
#  'what do you want',
#  'your opinion  you see they going to make a movie about me too eddie  and write books',
#  'what is your accomplishment',
#  'i kill someone famous',
#  'then do it asshole',
#  "so tabloids don't have to do re enactments  they going to have real movie this time",
#  "you really think you will be able to fool a jury with this bullshit  how fuckin' stupid are you",
#  'detective does it look like a murder',
#  "we don't know that yet  it's much too early  there's a lot to be done",
#  'how many victims are up there',
#  'there are two bodies found at this point',
#  'can we go up to the crime scene',
#  "you know you cannot do that  c'mon",
#  'is it drug related',
#  'detective  can you tell us what happened here',
#  'i understand but i noticed that the fire marshall is here with you  is this somehow related to the fire department',
#  'i really cannot give out any information right now at this point',
#  "okay  but i do understand that your partner leon jackson's been injured is that correct",
#  'he was hurt but not seriously  he will be fine',
#  'do you have the suspect in custody',
#  "umnow is not a good time okay detective jackson's hurt  he is fine i have got a fire marshall shot detective jackson is hurt but not seriously",
#  'eddie are you okay',
#  "yeah  now's not a good time",
#  'alright',
#  'alright',
#  'alright',
#  'alright',
#  'hey honey',
#  'what is your problem  why would you snap at me  i just wanted a statement',
#  'i cannoti cannot answer you just because you want me to answer you!',
#  "you didn't have to embarrass me in front of my colleagues  you could give me something",
#  'oh i am sorry  did i embarrass you sweetheart  oh',
#  'stop it',
#  'maybe i should just ya knowturn to the cameras and say do you mind if we just work something out',
#  "alright alright eddie  don't patronize me",
#  'i am not',
#  "yes you are  i am not just some reporter  i don't just stick a microphone in your face  you could give me something",
#  'yeah well you took the camera and put it right down on the evidence  that was',
#  'that was good  you were holding the evidence',
#  "you were merciless  you didn't give a shit if you got me or not",
#  'well who was it that taught me how to do that  huh',
#  'you are ruthless',
#  'look at this  you have blood on your shirt  whose is it',
#  "could be leon's",
#  "don't worry about the damn phone  i will not answer it",
#  'answer the phone',
#  'no  tell me what you want to say',
#  'answer it',
#  'oh my gd they want me to anchor  they want me to anchor tonight!',
#  'that is good',
#  'yeah',
#  'well that is great',
#  'okay  that is great  but i cannot go now we are in the middle of something here',
#  'no  go ahead  you are gonna be great',
#  'no  no listen to me here  i want to know what you are talking about  you know the shoe thing and the marriages and',
#  "i will tell you tonight  let's do it tonight  as soon as you get back we will talk  we will talk",
#  'promise',
#  'i promise  we will talk  you will be great  you will be fine  go ahead just imagine that uh just look into the lens and imagine you are talking to me',
#  'yeah  i will do that  as long as you are not patronizing me',
#  'patronizing you nay i love you',
#  'okay til tonight',
#  'tonight',
#  'you promise',
#  'yeah  i promise',
#  "okay  and you know what i will swing by my place grab a couple pairs of shoes and maybe just test them out next to yourshow's that would that be a good thing",
#  'yeah yeah  good thing',
#  'okay',
#  'see you later  good luck',
#  'thank you',
#  "so we are waitin' to hit this warrant  we got emergency service with the heavy weapons standin' by  ready to go  i say lemme get a cigar outta the car  i go to get the cigar and boom!  all the sudden i turn around and a kid with a shotgun let one go  right where i was standin'  that coulda been it  i coulda had my head blown off and for what  some stupid kid got panicky takes the safety off and it's over  if i hadn't gone back for that cigar  for a bad habit  i would have had my head blown off",
#  'sooner or later that is everybody',
#  'not chopped up  not chopped up like that  i mean what do i got left coupla articles  a medal or two plaque here and there and in a coupla years no one remembers me anymore',
#  'i think you are getting a little moody there eddie',
#  'how old are your kids',
#  'so what is unique',
#  'he is from antigua  his girlfriend was taking too long to put her makeup on they were late for a party  stabbed her with a beer bottle',
#  'that is unique',
#  "i hope this prick doesn't run  my knees are killing me  stay behind me",
#  'ready',
#  'keep them out of my way',
#  'okay  you ready',
#  'any chance we can do that again',
#  'okay  you work in a vodka factory  i understand that  and what kind of work do you do',
#  'i am butcher',
#  'you are a butcher  what do you use pig intestines for',
#  'you stuff sausage in it',
#  'and what do you do with the bones',
#  'are you married',
#  "come to 45 broadway  don't bring the police  come alone or you will be in my next film",
#  'look asshole  i have been threatened by better than you',
#  'no  i am the best that is ever threatened you',
#  'i will meet you on one condition  i get exclusivity and you surrender to me',
#  "we will talk about that  four o'clock gives you time to go to bank  three hundred thousand dollars",
#  "what  it doesn't work that way",
#  "if you don't want my film  i will call another show  and they will show it",
#  'wait a minute  wait a minute',
#  'were you a fireman  that how you knew how to rig the apartment',
#  "my father was  he gave me many lessons about fire  now it's my friend",
#  'you cannot kill me  you are not a cop just fireman with a gun  i bet you never shot anybody in your life',
#  "c'mon  pull the trigger  do it  oh look you are sweating  you don't have the balls",
#  'where is your partner',
#  'tell him to put his gun down!',
#  'let her go!  let her go!!',
#  'hi i am honey',
#  'where is czech girl',
#  "now i like to get business out of the way before we get down to pleasure  why don'tchya put my money on the dresser",
#  "it's an outcall service run out of an apartment  i don't meet the other girls  aren't you gonna get undressed",
#  'where is escort service',
#  'that is confidential  could you put the money on the dresser',
#  'i like to talk to the person who runs the service  can you give me address',
#  "listen to me  i don't want sex  just give me the address and then you go",
#  'give me the address!!',
#  'next  could i see your documents please',
#  'what is your intended purpose of your visit to the united states',
#  'two weeks holiday',
#  'how much money are you carrying with you',
#  'i have fivehundred dollars',
#  'is he with you  are you travelling together',
#  'yes',
#  'please join us  come on forward',
#  'is there a problem',
#  'we are both from prague',
#  'how long are you planning to stay',
#  'two weeks',
#  'i would like to speak for himself okay',
#  'who is he',
#  'this all you want',
#  'do you know how much killer gets for movie rights',
#  'in here says he wants a million',
#  'million!  the killer gets one million dollars for a television interview',
#  'hey tabloids paid ted bundy  famous serial killer  half a million for his interview  and how much you think monica got for writing book about the president coming on to her  it pays to be a killer or a whore in this country look you want magazine or not',
#  "just do what i do  say the same thing i say  don't open your mouth",
#  "don't fool around",
#  'did you hear what i said',
#  'look  times square  just like in the movies!',
#  "don't speak russian!",
#  'why  why do i always have to speak to you in czech',
#  'look  new videocameras  color viewfinder  image stabilization solarization  night vision',
#  ...]

# %% [markdown]
# Let's have a look at the clean_answers list we created above

# %%
clean_answers
# Out:
# ['well i thought we would start with pronunciation if that is okay with you',
#  'not the hacking and gagging and spitting part  please',
#  "okay then how 'bout we try out some french cuisine  saturday  night",
#  'forget it',
#  'cameron',
#  'the thing is cameron  i am at the mercy of a particularly hideous breed of loser  my sister  i cannot date until she does',
#  'seems like she could get a date easy enough',
#  'unsolved mystery  she used to be really popular when she started high school then it was just like she got sick of it or something',
#  'that is a shame',
#  'let me see what i can do',
#  'right  see  you are ready for the quiz',
#  "i don't want to know how to say that though  i want to know useful things like where the good stores are  how much does champagne cost  stuff like chat  i have never in my life had to point out my head to someone",
#  "that is because it's such a nice one",
#  'forget french',
#  "well there's someone i think might be ",
#  'where',
#  "i counted on you to help my cause you and that thug are obviously failing aren't we ever going on our date",
#  'you are sweet',
#  "eber's deep conditioner every two days and i never ever use a blowdryer without the diffuser attachment",
#  'i really really really wanna go but i cannot  not unless my sister goes',
#  "i am workin' on it but she doesn't seem to be goin' for him",
#  'lesbian  no i found a picture of jared leto in one of her drawers so i am pretty sure she is not harboring samesex tendencies',
#  'so that is the kind of guy she likes pretty ones',
#  'who knows  all i have ever heard her say is that she would dip before dating a guy that smokes',
#  'looks like things worked out tonight huh',
#  'i believe we share an art instructor',
#  'tons',
#  'i was',
#  "you never wanted to go out with 'me did you",
#  'then that is all you had to say',
#  'but',
#  'you always been this selfish',
#  'no',
#  'what crap',
#  'me  this endless blonde babble i am like boring myself',
#  'thank god!  if i had to hear one more story about your coiffure',
#  'what good stuff',
#  'the real you',
#  'like my fear of wearing pastels',
#  'no',
#  'okay  you are gonna need to learn how to lie',
#  "let's go",
#  'i hope so',
#  'they do not!',
#  'no',
#  'you might wanna think about it',
#  'who',
#  'joey',
#  'would you mind getting me a drink cameron',
#  'is he oily or dry',
#  "combination  i don't know  i thought he would be different  more of a gentleman",
#  'sometimes i wonder if the guys we are supposed to want to go out with are the ones we actually want to go out with you know',
#  'all i know is  i would give up my private line to go out with a guy like joey',
#  "i don't have to be home 'til two",
#  'i did',
#  'expensive',
#  'hopefully',
#  'queen harry',
#  "it's a gay cruise line but i will be like wearing a uniform and stuff",
#  'my agent says i have got a good shot at being the prada guy next year',
#  'hi joey',
#  "you are concentrating awfully hard considering it's gym class",
#  "you know the deal  i can ' t go if kat doesn't go ",
#  'nowhere hi daddy',
#  'can you at least start wearing a bra',
#  'it means that gigglepuss is playing at club skunk and we are going',
#  "oh i thought you might have a date  i don't know why i am bothering to ask but are you going to bogey lowenstein's party saturday night",
#  'what do you think',
#  'i think you are a freak  i think you do this to torture me  and i think you suck',
#  'what is normal',
#  "bogey lowenstein's party is normal but you are too busy listening to bitches who need prozac to know that",
#  'at least i am not a clouted fen sucked hedgepig',
#  "it's shakespeare  maybe you have heard of him",
#  "yeah he is your freak friend mandella's boyfriend  i guess since i am not allowed to go out i should obsess over a dead guy too",
#  'can we go now',
#  "i really don't think i need any social advice from you right now",
#  'you are welcome',
#  'like you care',
#  "i do care but i am a firm believer in doing something for your own reasons not someone else ' s ",
#  "i wish i had that luxury i am the only sophomore that got asked to the prom and i cannot go because you won ' t",
#  'what',
#  'in 9th  for a month',
#  'why',
#  'he was like a total babe',
#  'but you hate joey',
#  'now i do  back then was a different story',
#  'as in',
#  'you did what',
#  "just once  afterwards i told him i didn't want to anymore  i wasn't ready he got pissed  then he broke up with me",
#  "after that i swore i would never do anything just because everyone else was doing it  and i haven't since except for bogey's party and my stunning gastrointestinal display ",
#  "why didn't you tell me",
#  'i wanted to let you make up your own mind about him',
#  "no you didn't!  if you really thought i could make my own decisions you would have let me go out with him instead of helping daddy hold me hostage",
#  'i am not stupid enough to repeat your mistakes',
#  'i guess i thought i was protecting you',
#  'god you are just like him! just keep me locked away in the dark so i cannot experience anything for myself',
#  'not all experiences are good bianca you cannot always trust the people you want to',
#  'i guess i will never know will i',
#  'so did you',
#  'you set me up',
#  'i just wanted ',
#  'what to completely damage me  to send me to therapy forever what',
#  'no! i just wanted',
#  "it's just you",
#  'perm',
#  'no! you are not dating until your sister starts dating  end of discussion',
#  'what if she never starts dating',
#  'then neither will you  and i will get to sleep at night',
#  "but it's not fair  she is a mutant daddy!",
#  'exactly my point',
#  'and where are you going',
#  'if you must know we were attempting to go to a small study group of friends',
#  'otherwise known as an orgy',
#  "it's just a party daddy but i knew you would forbid me to go since gloria steinem over there isn't going ",
#  "if kat's not going you are not going",
#  "it's just a party daddy",
#  'daddy no!',
#  'just for a minute',
#  'why',
#  'because she will scare them away',
#  'the prom  kat has a date',
#  'no but',
#  "it's that hot rod joey right that ' s who you want me to bend my rules for",
#  'he is not a hot rod  whatever that is',
#  'you are not going unless your sister goes  end of story',
#  'fine  i see that i am a prisoner in my own house  i am not a daughter i am a possession!',
#  "i have a date daddy  and he ' s not a captain of oppression like some men we know",
#  "didn't have you pegged for a gigglepuss fan  aren't they a little too preteen bellybutton ring for you",
#  'fan of a fan  you see a couple of minors come in',
#  'never',
#  'padua girls  one tall decent body the other one kinda short and undersexed',
#  "just sent 'em through",
#  'so they tell me',
#  "c'mon  i am supposed to give you the tour",
#  'north actually  how would you   ',
#  'i was kidding people actually live there',
#  'yeah  a couple  we are outnumbered by the cows though',
#  'how many people were in your old school',
#  'thirtytwo',
#  'get out!',
#  'how many people go here',
#  'couple thousand most of them evil',
#  'yeah but these guys have never seen a horse  they just jack off to clint eastwood',
#  'you burn you pine you perish',
#  'who is she',
#  "bianca stratford  sophomore don't even think about it",
#  'why not',
#  "i could start with your haircut but it doesn't matter  she is not allowed to date until her older sister does  and that is an impossibility",
#  'because they are bred to  their mothers liked guys like that and their grandmothers before them their gene pool is rarely diluted',
#  'he always have that shiteating grin',
#  'joey dorsey  permashitgrin  i wish i could say he is a moron but he is number twelve in the class  and a model  mostly regional stuff but he is rumored to have a big tube sock ad coming out',
#  "sure do  my mom's from canada",
#  'guess who just signed up for a tutor',
#  'you mean i would get a chance to talk to her',
#  'you could consecrate with her my friend',
#  "that is her  bianca's sister",
#  'the mewling rampalian wretch herself',
#  'unlikely but even so she still cannot go out with you  so what is the point',
#  'you wanna go out with him',
#  'he seems like he thrives on danger',
#  'no kidding  he is a criminal  i heard he lit a state trooper on fire  he just got out of alcatraz',
#  'they always let felons sit in on honors biology',
#  'i am serious man he is whacked  he sold his own liver on the black market so he could buy new speakers',
#  'forget his reputation  do you think we have got a plan or not',
#  'did she actually say she would go out with you',
#  'that is what i just said',
#  'i thought you hated those people',
#  'hey  i have gotta have a few clients when i get to wall street',
#  'like we had a choice  besides  when you let the enemy think he is orchestrating the battle you are in a position of power we let him pretend he is calling the shots and while he is busy setting up the plan you have time to woo bianca',
#  'in that case we will need to make it a schoolwide blow out',
#  'will bogey get bent',
#  'are you kidding  he will piss himself with joy  he is the ultimate kiss ass',
#  "it's a lung cancer issue",
#  'her favorite uncle',
#  'dead at fortyone',
#  "okay!  i wasn't sure",
#  "it's her favorite band",
#  'hell i have just been going over the whole thing in my head and ',
#  "the hell is that  what kind of 'guy just picks up a girl and carries her away while you are talking to her",
#  'buttholus extremus  but hey you are making progress',
#  "no i ' m not",
#  'best case scenario you are back on the payroll for awhile',
#  'yeah  we will see',
#  'i have retrieved certain pieces of information on miss katarina stratford i think you will find helpful',
#  'so what does that give me  i am supposed to buy her some noodles and a book and sit around listening to chicks who cannot play their instruments',
#  "don't make me do it man",
#  "it's off the whole thing",
#  'she is partial to joey not me',
#  'sure',
#  'then go get her',
#  "i don ' t know  i decided not to nail her when she was too drunk to remember it",
#  'she just needs time to cool off i will give it a day',
#  'she kissed me',
#  'where',
#  'you get the girl',
#  'yeah and i noticed the only part of you featured in your big kmart spread was your elbow  tough break',
#  'they are running the rest of me next month',
#  'not at all',
#  'away',
#  'your sister here',
#  'and why would i do that',
#  'what do you think',
#  'yeah whatever  i want you to go out with her',
#  'sure sparky  i will get right on it',
#  'you just said',
#  'you need money to take a girl out',
#  'but you would go out with her if you had the cake',
#  'you are gonna pay me to take out some girl',
#  "i cannot date her sister until that one gets a boyfriend  and that is the catch she doesn't want a boyfriend",
#  'how much',
#  'fine thirty',
#  'fifty and you have got your man',
#  'i am on it',
#  "watching the bitch trash my car doesn't count as a date",
#  'i got her under control she just acts crazed in public to keep up the image',
#  'what',
#  'a hundred bucks a date',
#  'forget it',
#  'forget her sister then',
#  "a deal's a deal",
#  'do what',
#  'get her to act like a human',
#  "enough with the barbie n' ken shit i know",
#  'are you lost',
#  'nope  just came by to chat',
#  "we don't chat",
#  'well actually i thought i would run an idea by you  you know just to see if you are interested',
#  'we are not',
#  'does this conversation have a purpose',
#  "so what you need to do is recruit a guy who will go out with her  someone who's up for the job",
#  'uh  yeah  we are old friend*',
#  'you and verona',
#  'what  we took bathes together when we were kids',
#  "hey  it's all for the higher good right",
#  'patrick verona   random skid',
#  'that is pat verona the one who was gone for a year i heard he was doing porn movies',
#  'i am sure he is completely incapable of doing anything that interesting',
#  'he always look so',
#  'block e',
#  'just a little',
#  'an attempted slit',
#  'but imagine the things he would say during sex',
#  'you could always go with me  i am sure william has some friends',
#  'william would never have gone to a state school',
#  "william didn't even go to high school",
#  'that is never been proven',
#  'neither has his heterosexuality',
#  'does it matter',
#  "if i was bianca it would be any school you want precious  don't forget your tiara",
#  'no fear',
#  'who cares',
#  "i didn't have a choice",
#  "you didn't have a choice  where is kat and what have you done with her",
#  'i did bianca a favor and it backfired',
#  "you didn't",
#  'i got drunk  i puked  i got rejected it was big fun',
#  "well i guess we are not since we don't have dates ",
#  'listen to you!  you sound like betty all pissed off because archie is taking veronica',
#  "okay okay we will not go  it's not like i have a dress anyway",
#  "you ' re looking at this from the wrong perspective  we are making a statement",
#  'oh good  something new and different for us',
#  'who',
#  'william  he asked me to meet him here',
#  "oh honey  tell me we haven't' progressed to fullon hallucinations",
#  'sweating like a pig actually  and yourself',
#  "there's a way to get a guy's attention",
#  'my mission in life',
#  'oh right  friday',
#  'like where  the 7eleven on burnside do you even know my name screwboy',
#  'i know a lot more than that',
#  "i don't really think you warrant that strong an emotion",
#  'then say you will spend dollar night at the track with me',
#  'and why would i do that',
#  'come on  the ponies the flat beer you with money in your eyes me with my hand on your ass',
#  'you  covered in my vomit',
#  'seventhirty',
#  'i was in the laundromat i saw your car thought i would say hi',
#  'hi',
#  "depends on the topic my fenders don't really whip me into a verbal frenzy",
#  '',
#  "that is what you want isn't it",
#  'do you mind  you are sort of ruining it for me',
#  'you know who the raincoats are',
#  "why don't you",
#  "i am getting trashed man isn't that what you are supposed to do at a party",
#  'i say do what you wanna do',
#  'funny you are the only one',
#  'i am fine i am',
#  'i just need to lie down for awhile',
#  'uh uh you lie down and you will go to sleep',
#  'i know just let me sleep',
#  'what if you have a concussion my dog went to sleep with a concussion and woke up a vegetable not that i could tell the difference',
#  'leave it to you to use big words when you are shitfaced',
#  'why  are you doing this',
#  'i told you',
#  "you don't care if i die",
#  'sure i do',
#  'why',
#  'because then i would have to start taking out girls who like me',
#  'like you could find one',
#  'see that  who needs affection when i have got blind hatred',
#  'just let me sit down',
#  'who',
#  'dorsey',
#  'i hate him',
#  "i know  it would have to be a pretty big deal to get you to mainline tequila you don't seem like the type",
#  "hey man    you don ' t think i can be cool  you don't think i can be laid back like everyone else",
#  'i thought you were above all that',
#  'you know what they say',
#  'what',
#  "but it's gigglepuss  i know you like them  i saw you there",
#  'busy',
#  'were you in jail',
#  'maybe',
#  "no you weren't",
#  'then why would you ask',
#  'why would you lie',
#  'do what',
#  'this',
#  "my father wouldn't approve of that that",
#  "you don't strike me as the type that would ask permission",
#  "i am gettin' there",
#  'he just wants me to be someone i am not',
#  'who',
#  'bianca',
#  'no offense but you are sister is without  i know everyone likes her and all but ',
#  'what are you doing here',
#  'i heard there was a poetry reading',
#  'you  are so ',
#  'pleasant',
#  'unwelcome',
#  'unwelcome  i guess someone still has her panties in a twist',
#  "don't for one minute think that you had any effect whatsoever on my panties",
#  'so what did i have an effect on ',
#  'other than my upchuck reflex nothing',
#  'look up sunshine',
#  "c'mon  it's not that bad",
#  "try lookin' at it from this angle",
#  "forget it  i am stayin'",
#  'you want me to climb up and show you how to get down',
#  'maybe',
#  'i figured it had to be something ridiculous to win your respect  and piss you off',
#  'good call',
#  'so how would you get chapin to look the other way',
#  'i dazzled him with my wit',
#  "yeah well don't let it get out",
#  'so what is your excuse',
#  'acting the way we do',
#  'yes',
#  "i don't like to do what people expect then they expect it all the time and they get disappointed when you change",
#  'so if you disappoint them from the start you are covered',
#  'something like that',
#  'then you screwed up',
#  'how',
#  'you never disappointed me',
#  'for   ',
#  'fallacy',
#  'the duck',
#  'hearsay',
#  "i know the porn career's a lie",
#  'i hate peas',
#  'no  something real  something no one else knows',
#  'you are sweet  and sexy  and completely hot for me',
#  'what',
#  'no one else knows',
#  'you are amazingly selfassured has anyone ever told you that',
#  'go to the prom with me',
#  'you know what i mean',
#  'no',
#  'no what',
#  'no i will not go with you',
#  'why not',
#  "because i don't want to it's a stupid tradition",
#  'so i have to have a motive to be with you',
#  'you tell me',
#  'you need therapy  has anyone ever told you that',
#  'answer the question patrick',
#  "nothing!  there's nothing in it for me just the pleasure of your company",
#  "it's scurvy's  his date got convicted where would you get the dress",
#  "it's just something i had  you know",
#  'oh huh',
#  'look i am   sorry  that i questioned your motives  i was wrong',
#  'what',
#  "that is where i was last year  she would never lived alone  my grandfather died  i stayed with her  i wasn't in jail i don't know marilyn manson and i have never slept with a spice girl  i spent a year sitting next to my grandma on the couch watching wheel of fortune  end of story",
#  'it gets worse  you still have your freshman yearbook',
#  'you were paid to take me out!  by  the one person i truly hate  i knew it was a setup!',
#  "it wasn't like that",
#  'really  what was it like  a down payment now then a bonus for sleeping with me',
#  "i didn't care about the money",
#  'i thought you could use it when you start your band',
#  'is that right',
#  'yeah but then i fucked up i fell for her',
#  'because i like to torture you',
#  'oh bianca  can you get me my freshman yearbook',
#  "don ' t you even dare  ",
#  'i thought we decided you were going to school here  at u of 0',
#  'you decided',
#  'enough!',
#  'then tell them i had a seizure',
#  'is this about sarah lawrence you punishing me',
#  'i thought you were punishing me',
#  'why cannot we agree on this',
#  'because you are making decisions for me',
#  'as a parent that is my right',
#  "so what i want doesn't matter",
#  "you are eighteen  you don't know what you want  you will not know until you are fortyfive and you don't have it",
#  'i want to go to an east coast school! i want you to trust me to make my own choices  i want ',
#  'yeah  she left with some bikers big ones  full of sperm',
#  'funny',
#  'no daddy',
#  'so tell me about this dance was it fun',
#  'parts of it',
#  'which parts',
#  'the part where bianca beat the hell out of some guy',
#  'bianca did what',
#  'what is the matter  upset that i rubbed off on her',
#  'no  impressed',
#  'when i go',
#  "oh christ  don't tell me you have changed your mind  i already sent 'em a check",
#  'expressing my opinion is not a terrorist action',
#  "well yes compared to your other choices of expression this year today's events are quite mild  by the way bobby rictor's gonad retrieval operation went quite well in case you are interested",
#  'i still maintain that he kicked himself in the balls  i was merely a spectator',
#  'the point is kat  people perceive you as somewhat ',
#  'no  i believe heinous bitch is the term used most often',
#  'just smack her now',
#  'hi',
#  'cool pictures  you a fan',
#  'yeah  i guess',
#  'oh yeah',
#  'right',
#  'kat a fan too',
#  'yeah',
#  'what',
#  "whatever the hell it is you are standin' there waitin' to say",
#  'the situation is my man cameron here has a major jones for bianca stratford',
#  'what is it with this chick  she have three tits',
#  'dorsey can plow whoever he wants i am just in this for the cash',
#  'so dorsey can get the girl',
#  "patrick pat you are not looking at the big picture  joey's just a pawn we set this whole thing up so cameron can get the girl",
#  'we are your guys',
#  'good enough',
#  'just for now',
#  'yeah',
#  "i am likin' you guys better",
#  "no  i have got a sweetpayin' job that i am about to lose",
#  'sweet love renew thy force!',
#  "man  don't say shit like that to  me people can hear you",
#  'it says here you exposed yourself to a group of freshmen girls',
#  'it was a bratwurst  i was eating lunch',
#  'with the teeth of your zipper',
#  'touch of the flu',
#  'i am at a loss then  what should we talk about your year of absence',
#  'what is to discuss',
#  "you weren't abused you aren't stupid and as far as i can tell you are only slightly psychotic  so why is it that you are such a fuckup",
#  "well you know  there's the prestige of the job title and the benefits package is pretty good",
#  'see you next week!',
#  'make anyone cry today',
#  'sarah lawrence is on the other side of the country',
#  'tumescent!',
#  'you are not helping',
#  'pirate  no question',
#  "kissing  is that what you think happens  kissing isn't what keeps me up to my elbows in placenta all day",
#  'dr ruth',
#  'but  who  what ',
#  'your daughters went to the prom',
#  'did i have anything to say about it',
#  'absolutely not',
#  "that ' s what i thought",
#  "the water's going putrid in the barrels",
#  'you will be drinking your own piss for the glory of spain and admiral colon!  bastard!',
#  'ah leave him alone  he is doing no harm',
#  "with a face like that  i don't want you looking at me  you hear",
#  'we will all go crazy',
#  'we left three weeks ago alonso cannot be that near',
#  "cannot be that far i say  also i don't like the smell of the sea around here  smells like a cunt bad sign",
#  'yes your eminence  the voyage should not take more than six or seven weeks',
#  'unfortunately don colon that is precisely where our opinions differ  are you familiar with the work of aristotle  erathostene  ptolemeus',
#  'i am your eminence',
#  'then you cannot ignore that according to their calculations the circumference of the earth is approximately  22000 leagues or more  which makes the ocean uncrossable',
#  'excellency you are right',
#  'your life and that of others!',
#  'if they agree to follow me yes',
#  'is that all that interests you gold',
#  'no  the portuguese have already discovered blackskinned people  i too will find other populations  and bring them to the word of god',
#  "did he not choose a carpenter's son to reveal himself to the world",
#  'blind faith is what i consider heresy!',
#  'ifgodwillsit!',
#  'the judgment is ours!',
#  'naturally  but i would really deplore the loss of such a potential opportunity for spain for a dispute over a point of geography',
#  'indeed  the world is full of mercenaries  and states often make use of them when it benefits them  my only concern is the welfare and prosperity of spain',
#  'on the contrary your eminence  it seems to me the man is preparing his own cross',
#  'what a tragedy what a waste of a life',
#  'a waste  let me tell you something arojaz  if your name or mine is ever remembered  it will only be because of his',
#  'i know',
#  "i haven't given you much of a life",
#  "well that is true  i have a child by a man who will not marry me!  who's always leaving",
#  'are we going to argue',
#  'i would love to argue with you sometimes  but you are never here!',
#  'i find that hard to believe',
#  'thank god',
#  "i don't want you to wait for me",
#  'that is something you cannot decide',
#  "you don't usually ask",
#  'i can arrange for the queen to take fernando and diego into her service',
#  "they tried but i didn't let them",
#  "not everything do you think i care  i am a free man again  riches don't make a man rich they only make him busier",
#  'i am busy inside',
#  "i cannot keep my eyes off you  i would like to catch up with all the moments i didn't spend with you",
#  'forgive me don bobadilla  those positions have already been taken',
#  'may i ask by whom',
#  'bartolome and giacomo colon',
#  'yes i remember',
#  'appointment to what',
#  'viceroy of the west indies',
#  'congratulations  then i am free to search for the mainland',
#  'i am not a seaman  but i heard it is no more than a week at sea  i hope you are not too disappointed',
#  'how could i be  the mainland has been found  exactly as i said it would',
#  'i am afraid this is not the worst news',
#  'there will be a time',
#  'you promise  do you swear on st christopher',
#  'yes yes i do on all of them!',
#  'this time with me!',
#  'not bad',
#  'there must be a passage to that other ocean',
#  'i am not listening father  but i cannot help hearing',
#  'he asks when he can come to visit you  he left his address',
#  'he never had one except aboard my ships!',
#  "really  god i wouldn't know where to start and yet",
#  'tell me the first thing that comes to your mind',
#  'no',
#  'no!  i have waited too long fought too hard  now you expect me to take all the risks while you take the profit!  no i will not be your servant!',
#  'i am not bargaining!',
#  'then you are too ambitious',
#  'if you will not accept our proposal we will simply find someone who will',
#  'forgive me don colon  but what about gold',
#  ' for a commoner',
#  'don bobadilla is already a judge my dear don cristobal',
#  'good!  we are also in need of judges  except there are no thieves!',
#  'what  do i have so many already',
#  'to rise so high in so short a time is a dangerous occupation  a little hypocrisy goes a long way',
#  'call them',
#  'look out of that window',
#  'roofs towers palaces spires',
#  'all of them created by people like me',
#  'what is it  a tribe  an island',
#  'island  far',
#  'tell the chief we thank him',
#  'chief knows',
#  'tell him his country is very beautiful  tell him we are leaving men here  to build a fort',
#  'thousands',
#  'why',
#  'chief says  he has a god',
#  ' and also to bring medicine',
#  'chief says',
#  'he has medicine  tell him we admire his people',
#  'he understands',
#  'ask him if he will help',
#  'you did the same to your god!',
#  'you never learned how to speak my language',
#  'father i am doing what i think is the best for him  and he has the teacher i would have chosen for myself',
#  'that is what it says',
#  'how did you manage it',
#  'with some difficulty  i had to promise them you were not a total fool',
#  'to open a new route to asia  at the moment there are only two ways of reaching it',
#  'ignorance!  i believe the indies are no more than 750 leagues west of the canary islands',
#  'how can you be so certain',
#  'the calculations of toscanelli marin de tyr esdras',
#  'esdras is a jew',
#  'so was christ!',
#  'i will try to remember that marchena',
#  'father marchena!',
#  'passion is something one cannot control!',
#  'you get so carried away when you are being contradicted!',
#  'i have been contradicted all my life eternity!',
#  'only god knows the meaning of such words my son',
#  'wait!  i have waited seven years already!  how much longer do you want me to wait',
#  'if god intends you to go then you will go',
#  'damn god!',
#  'damn all of you!  you all set up theories based on what  you never leave the safety of your studies! go out!  find out what the world is about and then tell me something i can listen to!',
#  "colon!  don't!",
#  'forgive me father  for i have sinned',
#  'father i have betrayed my family i betrayed my men  and i betrayed you',
#  'what are you saying',
#  'i lied  the journey will be longer than i said',
#  'how long',
#  'i am not sure it could be twice the distance',
#  'if i tell them they will not follow me  you know that i am right father  you trust me',
#  "my son my son  your certitudes are sometimes frightening  christopher you must speak to them and if you don't i will",
#  'you are bound by an oath father',
#  'give me absolution',
#  'you will always be older than me father',
#  'i knew you would',
#  'new worlds create new people',
#  'oh  so you are a new man',
#  "i don't know i have the impression that i didn't change that much  i still cannot accept the world as it is!",
#  'no more than the woman who said she would take granada from the moors',
#  'what did they say about granada before today',
#  'that she was impregnable',
#  'surely you can do anything you want',
#  'you show no inclination to speak otherwise!',
#  "i know what i see  i see someone who doesn't accept the world as it is  who's not afraid  i see a women who thinks what if",
#  'a woman',
#  'thirty seven your majesty and you',
#  'they come and go as naked as the day god created them',
#  'thank you',
#  'there is one thing i would like to understand why do you want to go back after all this',
#  'your majesty  some men are content to read about things  i must see them with my own eyes  i cannot be other than i am',
#  'the indians have no such word don moxica',
#  'if you want to keep your head on your shoulders you will do as i say',
#  "we don't need to know",
#  'we came here to stay!  to build! not to start a crusade  in this forest there is enough danger to sweep us away in days!  so we will be brave and swallow our grief  and in the name of those who died we will accomplish what we came for',
#  "my horse doesn't work",
#  'you did not hear me don colon  not my horse',
#  'savagery is what monkeys understand',
#  'you will be held in detention deprived of your privileges and possessions  until you are returned to spain where you will be judged have you anything to say',
#  'you will regret this',
#  'god be with us admiral',
#  'and what do you think mendez',
#  'well i surely know what a quadrant is!  but i have never seen it used at night before',
#  'come over here',
#  'twenty eight',
#  'he is drawing an isthmus he is saying we are on an isthmus',
#  'we cannot be',
#  'immediately',
#  'six days ago yes',
#  'you must be mad!',
#  'we have to keep the hopes of these men alive!',
#  'we are on the verge of a mutiny colon!',
#  "you think i don't know that",
#  'we are lost!',
#  'the land is there  i know it!',
#  "you don't know anything!  listen colon these are my ships right so i am telling you we are turning back!",
#  'and then what  half of the water has gone the rest is nearly putrid! you know that!',
#  'jesus maria!  i should have never listened to you!',
#  'you never did  you did all the talking for both of us remember',
#  'you bloody',
#  'pinzon pinzon all we can do now is go forward!  think about that!',
#  'you tell that to them!',
#  'you are right  let the men decide',
#  'yes your majesty',
#  'never your majesty  although',
#  "yes  it would be a pity wouldn't it  call him back!",
#  "we weren't expecting immediate profits were we  we must have faith  we must give time for time",
#  'is this true brother buyl',
#  'he must be replaced',
#  'and who would you think of for such a task',
#  'then why',
#  'because he is not afraid of me',
#  'i am not your lawyer until i see the money',
#  'here  i have your money',
#  'emil  take it easy  stay with me  sit down  what do you need  what are you looking for',
#  'he has the camera!  he took the movie!',
#  'where are we going',
#  'i am coming with you',
#  'yes  yes come with me!',
#  'i am invoking rights  this man is represented by counsel  i am coming with him',
#  'you bring the cigarettes',
#  'oh sure',
#  'i was all of these',
#  "well you didn't appreciate the severity of it until recently  no question about that",
#  'what about oleg',
#  'disappeared  they are looking everywhere  maybe he went back to czechoslovakia',
#  'no he is here  shit',
#  "don't worry about him  think about yourself",
#  'what about my movie rights  book rights',
#  "look i haven't really focused on that kind of thing",
#  'what is your cut  how much',
#  'i would sayhalf  half is fair',
#  'no  no way',
#  "but it's",
#  "thirtypercent  no more  or i call another lawyer  this is the biggest case of your life  don't try to negotiate  thirty percent  say yes or no",
#  'this is not about money emil  i need your trust in me',
#  'what else do you need',
#  'i need to know about your background  i need to know about your upbringing  why you are here',
#  'give me another one please',
#  'my father always degraded me  killed my selfesteem  and my mother was blind',
#  'your mother was blind',
#  'yeah she went blind giving birth to me she went to fucking black market doctor to induce me',
#  'back in the czech republic',
#  'yeah yeahbad doctor gave her bad drugs which made her go blind  and my father blamed me for her blindness',
#  "your father blamed you for your mother's blindness",
#  'yeah he hated me from day when i was born  put it out  can you put the cigarette out',
#  'your father put cigarettes out on you',
#  'out on my back when i was a small boy',
#  'can i see your back',
#  "i don't think it's abuse i think it's torture",
#  "officers there's your killer do your duty arrest him!",
#  'alright  that is a justifiable homicide',
#  'yes but he was a cop',
#  'if you cooperate with the da  maybe they will help you with your situation',
#  "i will if they don't send me back",
#  'they will not until this is over',
#  'divorced',
#  'do you live alone  i have been in these clothes sincethe killings  could we stop at your place i could take a showerbefore i go into custody',
#  'somewhere else',
#  'sothe station is empty',
#  'yeah  this way',
#  'yes i considered it',
#  'did you ever turn tricks before',
#  'no',
#  'what about back home',
#  'no',
#  'so you were never a prostitute',
#  'what are you asking me',
#  'i am just trying to find out who you are',
#  'i know',
#  "you don't know  i am sorry  i was desperate  that is not me  i shot a cop  can you imagine what they will do to me when i got to prison",
#  'they are not gonna send you right back',
#  "i am sorry  i didn't mean toi am glad actually i am glad it's over  all this time  hiding  never being able to look anyone in the eyes always afraid that someone would find out who i was  never trusting anyone",
#  "i still cannot believe eddie's gone",
#  'i am sorry',
#  'ludwig  he is gay  are you jealous',
#  'if i was your boyfriend i might be',
#  "if you were my boyfriend i would suggest you find another girlfriend that isn't going to jail tenthousand miles away",
#  'no matter what happensi am glad i met you',
#  'i am glad i met you',
#  'right',
#  'in the kitchen',
#  'i will make some for us',
#  'i will get my clothes',
#  'pouring it out!',
#  'do you really want me to forget about you',
#  "i don't want to drag you down with me",
#  'daphne i',
#  "c'mon start at the beginning  you know these people",
#  'tamina was a friend of mine  my shower was broken she let me use theirs',
#  'go on',
#  'if i tell you will you arrest me',
#  'arrest you for what  why would we arrest you',
#  "no no don't talk to immigration!",
#  'i am from a small town in slovakia  like the south here  the police is right a civilian is wrong  so i fled',
#  'look we can help you but right now we have to deal with what is happening here tell us the truthis that the truth',
#  'you are a cop  you will never believe me',
#  'it was my decision not his',
#  'well i am the deputy chief fire marshall and every now and then i would like to be included in decisions',
#  'look after jordy briefs me you can do the press conference  how about that the case is all yours',
#  'oh yeah  alright',
#  'i am ready to be briefed  excuse us',
#  'yeah sure  beep me when you are ready for the press conference',
#  'who do you think chief!',
#  "then why didn't you talk to the reporter",
#  "'cause we got more important things to do like finding out who did it",
#  "i came to see how the investigation was going  i called and you are not here  i wait up at the station and you don't even show up!!!  i beep you  you don't return my call  where the hell have you been!",
#  "what do you mean 'cleaned up'",
#  'i let her take a shower',
#  'a shower!  did you take one too',
#  'no!  nothing happened',
#  "oh really  that is nice  you took a homicide witness to take a shower after your partner was shot  are you out of your fucking mind  are you having that much trouble gettin' dates!",
#  'okay  but not water sports',
#  'what was i supposed to do  the guy tried to mug me  i was gonna send a cop back  i just forgot',
#  'forgot  you handcuffed a civilian to a tree!',
#  'chief  i know i screwed up  but this guy was no innocent civilian',
#  'well this is gonna end your career and probably mine',
#  'end my career',
#  "how are you going to fight this  maybe if oleg hadn't gotten away and you would been on the front page as a hero this thing would be easier to fight  you would have the good to weight against the bad! it's unfortunate that i have to make decisions based upon your press coverage but there's nothing i can do!  gimme your shield",
#  'but chief  over this',
#  "there's nothing to talk about  get a good lawyer  you are suspended until your trial",
#  'yeah right',
#  'what was that korfin',
#  "i said yeah you are right chief  as soon as we get somethin' we will let you alert the media",
#  "you do that wiseguy  now let's solve this thing before eddie flemming does",
#  'yeah  he finished awhile ago',
#  'alright  swing by her apartment  let her pick up her clothes and take her straight to hoover street  you got that',
#  'yeah',
#  'vodka tonic',
#  'maybe you could just put in a shot of martell',
#  "what is the kid gonna say  sorry meanwhile i am not here anymore like last week  we were at the morgue and this guy was all chopped up  spleen here  liver there  his heart in a pan six hours ago this guy was walkin' his dog or buyin' a quart of milk  who knows  but some kid's robbed him for $3 or some shit and shot him and now you cannot tell if he is a piece of beef or a human being and i am thinkin' that is me sooner or later  that is me",
#  'when',
#  'tomorrow  at lunch',
#  'you ready',
#  'a timer',
#  "takin' a bath",
#  'any id',
#  'still unknown but we are running prints kid over there caught the case',
#  "it's okay",
#  'yeah',
#  "c'mere  you wanna go to homicide school  here  make yourself useful",
#  'stay with her',
#  'no  i am okay',
#  "i know  relax  take it easy  don't worry we will get those fuckers",
#  'police  we would like to ask you a few questions',
#  "i have nothin' to say  if you wanna contact my attorney",
#  "homicide miss hearn  it's detective eddie flemming  open up",
#  "we don't have her id yet but one of your girls was killed last night at the king edward hotel",
#  "oh my gd  honey!  honey's dead",
#  'do you have any czech girls working for you',
#  'no',
#  'did you tell him you did',
#  'what are you saying',
#  'daphne  another guy came in asking me about her too',
#  'describe him',
#  "tall shorthaired scary eyes  second guy with him wasshorter with a wrestler's build  and he wouldn't turn his videocamera off me",
#  'he had a videocamera  where is she quickly!',
#  "she washes hair up at ludwig's  a salon on 63rd and madison",
#  "no we don't mind  you mind leon",
#  'no what is it',
#  "why don't you explain it bobby  hey camello!  you mind punching a hole in the floor",
#  'watch the news',
#  'nah i musta missed it',
#  'well just so you know  i gave you guys the credit',
#  "well just so you know i don't care about that stuff",
#  'nah why should you',
#  "i don't even watch tv",
#  'good  good  commendable',
#  'sure  but i would like to ask you something  you got a problem with me',
#  "if you found me steppin' on your crime scene  it might piss you off too  what about the report",
#  'you were right they were both dead before the fire  the male was stabbed so hard the killer broke off the tip of the knife in his spine  that is usually an indicator of something personal',
#  'pretty',
#  'hmmmm',
#  "maybe you don't care about that either  prettiest suspect i have had in awhile",
#  'who says she is a suspect',
#  'look i am not even sure she has anything to do with this  i saw her outside after the fire  thought it was a lead maybe she saw something  maybe she was visiting somebody here  who knows',
#  'eastern europe  like what  romania hungary',
#  'or czechoslovakia  the slavs have been fighting the germans and the russians for a thousand years  these are very intense people and they take things personally',
#  "there wasn't a fire  there will be nothing for you to do",
#  'i can watch you eddie  maybe i will learn something',
#  "this isn't homicide school",
#  'my parents are from poland  i can help with the eastern european angle',
#  'you are polish',
#  'my folks are',
#  'stay here',
#  'you got any better ideas',
#  'mind if i ride along with you',
#  'this has nothing to do with your fire',
#  'but what if it does  you might need my help',
#  'this is ridiculous  i am not gonna be in your way  we can talk the case over',
#  "tell you what  i will flip you a coin if you win you can come with me  if you don't win you don't come",
#  'i will call it tails',
#  'better than one',
#  "i am on my way with eddie  ludwig's 63rd and madison  the suspects might be there already",
#  'i am on duty',
#  'so am i  alright i will go inside and you cover the back',
#  'of course',
#  "hey!  i always wanted to be a cop when i was a kid  i dreamed of running up to a door kicking it in pulling my gun and yelling 'freeze!' at the bad guy! what would you dream about",
#  'i wanted to run up to a building on fire kick in the door rush into the smoke and save a kid',
#  "then i guess we are doin' this the right way aren't we  if we pull up to a burning building i will gladly let you go first",
#  'she just saw two of her friends killed! they probably threatened her',
#  'is that all there is',
#  'something back home',
#  'raw deal',
#  'you wanna talk to her alone',
#  'yeah',
#  'what would your girlfriend think of that',
#  "i don't have a girlfriend",
#  'my point exactly',
#  'i am serious here',
#  'so am i',
#  "c'mon  you intimidate her 'cause you are a celebrity  she sees me differently",
#  'you are her savior  is she the kid you are gonna save from the burning building',
#  'you know what i am saying here',
#  'hey  i am a professional',
#  'women like that have a way of turning professionals into amateurs',
#  "well you shoulda because nobody's gonna believe you didn'tincluding me",
#  'i took her there for a shower and that is it',
#  'just a shower',
#  "no i don't think you were a fool i just think you were stupid about it  i mean to say the least you outta know better  you don't know her well enough she is got the potential to fucking hang you even if she suggests that you made a pass at her it's fuckin' over  you can deny it all you want but it will not make one fucking bit of difference you are dead",
#  'i told you you know i thought i was doing the right thing you know i think she is innocent',
#  "well it's not up to you to decide whether she is innocent or not  don't you understand that is why you are a professional",
#  "but i mean didn't you ever go out on a limb for somebody  i mean you shoulda heard her there  tellin' her whole storyi believed her",
#  "how you go out on a limb for somebody is by giving her a number of an immigration lawyer  here here's a number of an immigration lawyer  that is how you help her but you cannot get involved in her like that  you are gonna jeopardize your career your life and you are gonna jeopardize my case  and lemme give you another piece of advice  maybe you don't watch tv but i will let you in on a little secret  the whole fuckin' world watches television  and when you get out there they know your face  and the little fame the little fuckin' itty bitty fame that i get in this city makes it a lot easier for my job  and i get more done because of it",
#  "you know i don't know  i like you you remind me of a puppy i used to have he pissed on the rug all the time but i still kept him",
#  'what do you want',
#  'your opinion  you see they going to make a movie about me too eddie  and write books',
#  'what is your accomplishment',
#  'i kill someone famous',
#  'then do it asshole',
#  'good  be tough to the end  actor who plays you will want to die like hero',
#  'if you kill me and film it you are putting a noose around your neck',
#  'smarter than americans  you are fed cry baby talk shows all day long  not only will americans believe me they will cry for me  sodetective eddie flemming would you like to say goodbye to your nicolette maybe you can propose to her now',
#  "we don't know that yet  it's much too early  there's a lot to be done",
#  'how many victims are up there',
#  'there are two bodies found at this point',
#  'can we go up to the crime scene',
#  "you know you cannot do that  c'mon",
#  'is it drug related',
#  "we don't know  when i have more i will let you know",
#  'i cannot talk right now  we have some things to take care of',
#  'i really cannot give out any information right now at this point',
#  "okay  but i do understand that your partner leon jackson's been injured is that correct",
#  'he was hurt but not seriously  he will be fine',
#  'do you have the suspect in custody',
#  "umnow is not a good time okay detective jackson's hurt  he is fine i have got a fire marshall shot detective jackson is hurt but not seriously",
#  'alright cut cut cut',
#  "yeah  now's not a good time",
#  'alright',
#  'alright',
#  'alright',
#  'alright',
#  'okay',
#  'hey',
#  'i cannoti cannot answer you just because you want me to answer you!',
#  "you didn't have to embarrass me in front of my colleagues  you could give me something",
#  'oh i am sorry  did i embarrass you sweetheart  oh',
#  'stop it',
#  'maybe i should just ya knowturn to the cameras and say do you mind if we just work something out',
#  "alright alright eddie  don't patronize me",
#  'i am not',
#  "yes you are  i am not just some reporter  i don't just stick a microphone in your face  you could give me something",
#  'yeah well you took the camera and put it right down on the evidence  that was',
#  'that was good  you were holding the evidence',
#  "you were merciless  you didn't give a shit if you got me or not",
#  'well who was it that taught me how to do that  huh',
#  'you are ruthless',
#  'you are not so bad yourself',
#  "could be leon's",
#  'jesus  and last week you came over with blood on your shoes  what am i going to do with you',
#  'answer the phone',
#  'no  tell me what you want to say',
#  'answer it',
#  "okay  okay  hold that thought just for a second  they only call me when it's an emergency  just hold that thought  can you call back",
#  'that is good',
#  'yeah',
#  'well that is great',
#  'okay  that is great  but i cannot go now we are in the middle of something here',
#  'no  go ahead  you are gonna be great',
#  'no  no listen to me here  i want to know what you are talking about  you know the shoe thing and the marriages and',
#  "i will tell you tonight  let's do it tonight  as soon as you get back we will talk  we will talk",
#  'promise',
#  'i promise  we will talk  you will be great  you will be fine  go ahead just imagine that uh just look into the lens and imagine you are talking to me',
#  'yeah  i will do that  as long as you are not patronizing me',
#  'patronizing you nay i love you',
#  'i love you',
#  'tonight',
#  'you promise',
#  'yeah  i promise',
#  "okay  and you know what i will swing by my place grab a couple pairs of shoes and maybe just test them out next to yourshow's that would that be a good thing",
#  'yeah yeah  good thing',
#  'okay',
#  'see you later  good luck',
#  'thank you',
#  "don't be late",
#  'jesus christ',
#  'not chopped up  not chopped up like that  i mean what do i got left coupla articles  a medal or two plaque here and there and in a coupla years no one remembers me anymore',
#  'i think you are getting a little moody there eddie',
#  'i am not moody',
#  "my kids  let's seesusan's 15 aundrea's 9  don't tell me you are thinking about having a kid!  how old are you  never mind let me just tell you this every stupid cliche you hear about kids  they change your life they make you a better person they make you whole  it's all true!  before i had kids when friends talked about their kids i wanted to vomit  now  i get it  am i right leon",
#  'not what  who',
#  'that is unique',
#  'yeah  and he still went to the party',
#  'you are worried for my safety  i am touched',
#  'keep them out of my way',
#  'okay  you ready',
#  'yeah yeah  jesus',
#  "again  i didn't wanna do it the first time",
#  'i am butcher',
#  'you are a butcher  what do you use pig intestines for',
#  'you stuff sausage in it',
#  'and what do you do with the bones',
#  'dog food',
#  'no  are you proposing',
#  'look asshole  i have been threatened by better than you',
#  'no  i am the best that is ever threatened you',
#  'i will meet you on one condition  i get exclusivity and you surrender to me',
#  "we will talk about that  four o'clock gives you time to go to bank  three hundred thousand dollars",
#  "what  it doesn't work that way",
#  "if you don't want my film  i will call another show  and they will show it",
#  'wait a minute  wait a minute',
#  'come alone  bring cash  and we will talk about surrendering',
#  "my father was  he gave me many lessons about fire  now it's my friend",
#  'tommy take a walk',
#  'you will be my first',
#  'get down on your knees',
#  'the sheraton!  on broadway!  room 210 go get oleg  he will kill you',
#  'let her go!  let her go!!',
#  "if he doesn't lower his gun i will fucking kill her",
#  'where is czech girl',
#  'baby i am anybody you want me to be i am a little schoolgirl i am mommy i am a czech girl',
#  'i ordered a czech girl  daphne you know her',
#  'where is escort service',
#  'that is confidential  could you put the money on the dresser',
#  'i like to talk to the person who runs the service  can you give me address',
#  "look  do we have a problem here there's no reason to have a problem i am gonna make you feel real good  you wanna czech girl after i am done with you you will not miss her  now why don't you pay me",
#  "look man i don't give a shit if you want sex or not but you are payin' for my time",
#  "alright alright  don't hurt me! please it's in my book in my purse!",
#  'yes sir',
#  'two weeks holiday',
#  'how much money are you carrying with you',
#  'i have fivehundred dollars',
#  'can you show me  sir no cameras in the fis area!',
#  'yes',
#  'please join us  come on forward',
#  'is there a problem',
#  'no you are travelling together  i want to talk to you together  hi how are you  can i take a look at your documents  are you related',
#  'how long are you planning to stay',
#  'two weeks',
#  'i would like to speak for himself okay',
#  "he doesn't speak english",
#  "new york's finest  this is his case",
#  'do you know how much killer gets for movie rights',
#  'in here says he wants a million',
#  'million!  the killer gets one million dollars for a television interview',
#  'hey tabloids paid ted bundy  famous serial killer  half a million for his interview  and how much you think monica got for writing book about the president coming on to her  it pays to be a killer or a whore in this country look you want magazine or not',
#  'yes  both',
#  'okay',
#  'okay',
#  'i want to document my trip to america',
#  "don't speak russian!",
#  'why  why do i always have to speak to you in czech',
#  "because i don't like your ugly language i heard enough of it in school!  now speak czech or english  and don't fool around anymore  you almost got us thrown out!",
#  'we have no money  come on',
#  ...]

# %% [markdown]
# # Removing the not so frequent words from our corpus
# We are doing this because we want to optimize the training and for that we need only the essential words from the vocabulary
#
# For this we will create a dictionary, mapping each word to it's number of occurences in the corpus of movie dialogues
#
# 1. declare an empty dictionary in python
#
# 2. itertae through both clean_questions and for each question get the count of every word present
#
# 3. Similarly, iterate through clean_answers and for each answer get the count of every word present

# %%
word2count = {}
#going through the clean_questions
for question in clean_questions:
    for word in question.split():
        if word not in word2count:
            word2count[word] = 1
        else:
            word2count[word] += 1
#going through the clean_answers
for answer in clean_answers:
    for word in answer.split():
        if word not in word2count:
            word2count[word] = 1
        else:
            word2count[word] += 1

# %% [markdown]
# # Tokenization and filtering of the non-frequent words
#
# 1. We will assign a unique integer to each of the words present in the clean_questions and clean_answers list
#
# 2. for each of the words, we will compare the number of occurences (with the help of the word2count{} dictionary we created above) of that particular word and filter out those words which do not cross the threshold,i.e, removal of infrequent words
#
# 3. and for those words which cross the threshold, we will assign a unique integer value

# %%
threshold_questions = 20
threshold_answers = 20

# %% [markdown]
# The threshold is a hyperparameter in NLP, and please feel free to experiment with this value while training your model. But make sure not to keep the threshold value too low, else it might be too overwhelming for the model to learn

# %%
# carrying out the above mentioned steps for questions
questionswords2int = {}
word_number = 0
for word, count in word2count.items():
    if count >= threshold_questions:
        questionswords2int[word] = word_number
        word_number += 1
        
# carrying out the above mentioned steps for answers
answerswords2int = {}
word_number = 0
for word, count in word2count.items():
    if count >= threshold_answers:
        answerswords2int[word] = word_number
        word_number += 1

# %% [markdown]
# You might be wondering as to why did we create two dictionaries with exactly the same definition, well here's why:
#
# It is recommended to make two separate dictionaries in case we want to use different thresholds to filter out the non frequent words in the dictionaries of the questions and the answers. If we do that, these two dictionaries will be different.

# %% [markdown]
# Let's have a look at the questionswords2int dictionary we created above

# %%
questionswords2int
# Out:
# {'dowd': 2252,
#  'december': 7082,
#  'zuzu': 3282,
#  'impressed': 4407,
#  'ditch': 7778,
#  'bark': 2253,
#  'slut': 0,
#  'scattered': 8479,
#  'pa': 4033,
#  'italian': 1,
#  'box': 2056,
#  'thirteen': 8423,
#  'gone!': 7780,
#  'legit': 4409,
#  'health': 3334,
#  'lions': 8204,
#  'push': 1171,
#  'stepped': 2254,
#  'tear': 1172,
#  'league': 1173,
#  "worryin'": 3335,
#  'canada': 2272,
#  'insist': 6438,
#  'mason': 6732,
#  'bend': 2,
#  'voice': 2255,
#  'luca': 7620,
#  'joy': 2256,
#  '20': 3336,
#  'taping': 1174,
#  'envelope': 8053,
#  'everett': 4412,
#  'shirley': 1175,
#  'relaxed': 3337,
#  'rounds': 32,
#  'linked': 2257,
#  "family's": 8261,
#  'power': 3,
#  'skin': 4,
#  'labor': 5,
#  'staff': 6764,
#  'spaghetti': 7,
#  '2': 5627,
#  "gettin'": 7784,
#  'canyon': 1176,
#  'trying': 6185,
#  'amusing': 1177,
#  'anything!': 2258,
#  'gillis': 2259,
#  'duncan': 2291,
#  'primitive': 6772,
#  'office': 3340,
#  'king!': 8,
#  'whole': 2260,
#  'spencer': 5630,
#  'school': 2261,
#  'sneaking': 9,
#  'matthew': 5632,
#  'witnessed': 2262,
#  'rented': 5821,
#  'guide': 7785,
#  'lestat': 4418,
#  'americans': 10,
#  'pulling': 1178,
#  'pump': 8544,
#  'arrived': 11,
#  'albert': 12,
#  'pimp': 6735,
#  'claire': 5634,
#  'owner': 4420,
#  'accident!': 8429,
#  'june': 8177,
#  'shut': 8743,
#  'virus': 13,
#  'household': 3332,
#  'unou': 14,
#  'die': 6736,
#  'satisfied': 1179,
#  'indicted': 4422,
#  'able': 2263,
#  'discovered': 6737,
#  'old': 5635,
#  'terrible!': 8157,
#  'sickness': 8126,
#  'stone': 4408,
#  'started': 756,
#  'republican': 5636,
#  'nuclear': 5637,
#  'pig': 7956,
#  'certainly': 4219,
#  'promoted': 3341,
#  'valiant': 2623,
#  'hardest': 2322,
#  'vigo': 18,
#  'discuss': 4423,
#  'war!': 6740,
#  'catches': 3342,
#  "kid's": 6741,
#  "bringin'": 1170,
#  'exhusband': 5217,
#  'prenup': 16,
#  'thanks': 4425,
#  'missing': 4035,
#  'leap': 7083,
#  'painful': 4426,
#  'unemployment': 1180,
#  'remembering': 3578,
#  'men': 2267,
#  'joanne': 3343,
#  'craig': 4646,
#  'zero': 3344,
#  'murderers': 5642,
#  'dose': 8009,
#  'athos': 3408,
#  'stream': 5997,
#  'assignment': 1181,
#  'struck': 2268,
#  'hopes': 7787,
#  'dan': 17,
#  '25': 3345,
#  'german': 7789,
#  'picture': 6018,
#  'normally': 4513,
#  'spooky': 6950,
#  'johnson': 7792,
#  'sign': 2343,
#  'pneumonia': 2269,
#  'incredibly': 3347,
#  'multiple': 2270,
#  'leak': 2271,
#  'chairs': 105,
#  'glades': 7084,
#  'finds': 6743,
#  'sucks': 5643,
#  'terrified': 1182,
#  'politician': 1183,
#  'punch': 7625,
#  'elevator': 2109,
#  'rocket': 1184,
#  'snoopy': 113,
#  'patch': 7793,
#  'test': 4410,
#  'panes': 20,
#  'venice': 3349,
#  'null': 3350,
#  'barber': 5896,
#  'disco': 4429,
#  'youre': 1185,
#  "deal's": 21,
#  'smash': 118,
#  'cowboy': 7795,
#  'mad': 1186,
#  'areu': 4552,
#  'organism': 7499,
#  'nasal': 6912,
#  'norman': 7252,
#  'nobody': 4430,
#  'ron': 6069,
#  'wonder': 4431,
#  'appeared': 8713,
#  'returns': 8345,
#  'vitamin': 4557,
#  'collar': 5644,
#  'regulations': 1112,
#  'precinct': 22,
#  'shuts': 4560,
#  'coup': 8633,
#  'carter': 23,
#  'given': 8437,
#  'property': 6747,
#  'football': 542,
#  'crummy': 1127,
#  'kilos': 5716,
#  'swinging': 1088,
#  'personality': 4569,
#  'rosebud': 6852,
#  'sheriff': 2174,
#  'factor': 1187,
#  'butt': 6749,
#  'relation': 24,
#  'snake': 1188,
#  'flynn': 2273,
#  'gardner': 5648,
#  'bath': 3060,
#  'coach': 2274,
#  'week': 2275,
#  'glimpse': 7797,
#  'greedy': 7798,
#  'vulnerable': 1190,
#  'donald': 6752,
#  'couple': 1191,
#  'shot': 3504,
#  'fill': 25,
#  'launch': 8643,
#  'scrambled': 2276,
#  'cecile': 26,
#  'organization': 4587,
#  'decides': 1192,
#  'cheated': 27,
#  'lovely': 7799,
#  'nicky': 896,
#  'wouldnt': 2927,
#  'account': 8269,
#  'wendy': 5651,
#  'visual': 1193,
#  'disappointment': 3353,
#  'commission': 6754,
#  'behavior': 5652,
#  'gag': 7802,
#  'inappropriate': 2277,
#  'pentagon': 2278,
#  'experts': 5999,
#  'beans': 2279,
#  'mood': 7804,
#  'react': 30,
#  'sarge': 2280,
#  'nearly': 8736,
#  'dangerous': 7805,
#  'loomis': 6756,
#  'mall': 4435,
#  'warrant': 2281,
#  'nature': 1194,
#  'something': 1195,
#  'identify': 4436,
#  'prom': 31,
#  'yep': 5220,
#  'nails': 5654,
#  'mac': 5420,
#  'fella': 4414,
#  'christ': 6915,
#  'vivian': 5655,
#  'preacher': 1196,
#  'war': 8729,
#  'enough!': 2283,
#  'some': 2284,
#  'causes': 4437,
#  'severe': 5421,
#  'gamble': 33,
#  "water's": 34,
#  'carson': 35,
#  'sting': 6001,
#  'covered': 5656,
#  'management': 7807,
#  'tattoo': 192,
#  'lend': 6761,
#  'biological': 7467,
#  'come': 1199,
#  'reconsider': 7808,
#  'wont': 7809,
#  'dig': 1200,
#  'phoney': 36,
#  'sword': 1201,
#  'drinking': 37,
#  'imagination': 6762,
#  'four': 38,
#  'wretched': 2285,
#  'lord!': 7810,
#  'aw': 39,
#  'eating': 5004,
#  'george!': 6918,
#  'fox': 2286,
#  'denied': 3354,
#  'mulwray': 40,
#  'nude': 2287,
#  'dull': 3688,
#  'blond': 4633,
#  'lynette': 6766,
#  'busy': 41,
#  'excited': 2288,
#  'adopted': 1712,
#  'gorgeous': 6767,
#  'influence': 42,
#  'uyouru': 1203,
#  '11': 43,
#  'hans': 4644,
#  'myself!': 6768,
#  'liar': 4439,
#  'spends': 6769,
#  'popped': 4440,
#  'suspended': 6447,
#  'pepper': 1537,
#  'wife!': 4441,
#  'wall': 5659,
#  'bill!': 8637,
#  'nah': 44,
#  'captured': 2466,
#  'heights': 3356,
#  'radical': 6770,
#  'lotta': 3357,
#  'congratulate': 5660,
#  'fault': 3358,
#  'suitcase': 8490,
#  "bob's": 8548,
#  'lasted': 3359,
#  'pry': 5824,
#  'grant': 2289,
#  'twist': 8309,
#  'trusts': 6035,
#  'impossible': 4443,
#  'kent': 45,
#  'freud': 1026,
#  'como': 3361,
#  'mckenna': 1204,
#  'offended': 6959,
#  'stew': 47,
#  'apologize': 6771,
#  'blanks': 1205,
#  'embarrassed': 7816,
#  'austrian': 7817,
#  'edgar': 2292,
#  'supernatural': 7818,
#  'knights': 4415,
#  'gone': 48,
#  'this': 6773,
#  'cellar': 7609,
#  'sullivan': 5662,
#  'campaign': 5777,
#  'shave': 4040,
#  'extent': 6968,
#  "doesn't": 1207,
#  'path': 5664,
#  'biscuits': 6774,
#  'ethics': 7819,
#  'are': 2293,
#  'recall': 4445,
#  'gentle': 5423,
#  'fazeli': 6970,
#  'do!': 4416,
#  "better'n": 49,
#  "town's": 7430,
#  'wound': 50,
#  'countries': 4684,
#  'car!': 51,
#  'say!': 257,
#  'fulla': 5665,
#  'act': 7251,
#  'creating': 2294,
#  'transport': 6541,
#  'lowest': 2295,
#  'andrews': 5844,
#  'sake!': 1208,
#  "one's": 2296,
#  'she': 4449,
#  'pine': 5666,
#  'quickly': 1209,
#  'conflict': 52,
#  'connected': 4417,
#  'interrupting': 53,
#  'lama': 5668,
#  'lobby': 5631,
#  'confusing': 3368,
#  'charity': 272,
#  'tracy': 371,
#  'recognition': 6000,
#  'forcing': 3047,
#  'product': 7824,
#  'enforcement': 6995,
#  'carries': 54,
#  'volume': 5669,
#  'belong': 5670,
#  'kiddo': 1210,
#  'think!': 2517,
#  'joking': 5671,
#  'wladek': 6778,
#  'thief': 1211,
#  'despite': 1212,
#  'shack': 56,
#  'joan': 3369,
#  'cemetery': 6556,
#  'pm': 57,
#  'patient': 8449,
#  'cabin': 3371,
#  'chances': 3372,
#  'strung': 5007,
#  'nurse!': 531,
#  'jackson': 5672,
#  'jonah': 5673,
#  "else's": 7826,
#  'responsibilities': 3373,
#  'hated': 7827,
#  'wednesday': 4575,
#  'chest': 4450,
#  'motherfucker': 2298,
#  'likely': 1213,
#  'olive': 7828,
#  'armor': 7829,
#  'substitute': 2527,
#  '6': 3375,
#  'whatcha': 2299,
#  'onto': 1707,
#  'computers': 1214,
#  'instrument': 2301,
#  'around!': 2073,
#  'scientific': 4452,
#  "whoever's": 1215,
#  'worms': 2535,
#  'engine': 58,
#  'brenda': 7830,
#  'wheelchair': 1216,
#  'chili': 7482,
#  'snap': 4453,
#  'cecil': 1217,
#  'zip': 6780,
#  'beautifully': 2302,
#  'th': 4456,
#  'conditions': 7832,
#  'absolute': 7833,
#  'yankee': 2303,
#  'capable': 1218,
#  'play': 8640,
#  'convicted': 2304,
#  "child's": 3377,
#  'deed': 6251,
#  'picking': 1219,
#  'arrow': 59,
#  'operating': 3378,
#  "an'": 3852,
#  'erica': 7749,
#  'failure': 60,
#  'talks': 6781,
#  'regan': 61,
#  'paula': 7838,
#  'starving': 2305,
#  'edition': 62,
#  'twentyeight': 3379,
#  'saloon': 4744,
#  'caitlin': 1221,
#  'suspects': 7839,
#  'report': 2307,
#  'aid': 5684,
#  'chick': 5685,
#  'wiring': 4457,
#  'torpedo': 4458,
#  'marrow': 6783,
#  'either': 1222,
#  'afford': 7253,
#  'caliber': 1223,
#  'lucy': 8641,
#  'mobile': 64,
#  'preysing': 5686,
#  'resident': 65,
#  'desk': 8294,
#  'compound': 3807,
#  'gossip': 5229,
#  'joseph': 4460,
#  'allies': 7842,
#  'stephen': 66,
#  'wondered': 1225,
#  'unable': 4461,
#  'sacred': 5687,
#  'rachel': 7844,
#  'seconds': 2309,
#  'everywhere!': 2310,
#  'tank': 1227,
#  'scrap': 1228,
#  'until': 6784,
#  'claws': 8702,
#  'unfortunately': 1365,
#  'purple': 2580,
#  '300': 4463,
#  'wires': 3380,
#  'pursue': 7254,
#  'adds': 3381,
#  'isolation': 7071,
#  'performance': 67,
#  'scan': 8278,
#  'seemed': 1229,
#  'stay': 2311,
#  'perfect!': 8285,
#  'faster': 68,
#  "stayin'": 3382,
#  'develop': 69,
#  'sidney': 6930,
#  'poker': 4465,
#  'necklace': 6785,
#  'argon': 2312,
#  'severed': 70,
#  'papa': 7256,
#  'literature': 4322,
#  'trusting': 71,
#  'objection!': 370,
#  'kennedy': 3620,
#  'having': 72,
#  'tap': 4467,
#  'goddamned': 6559,
#  'exists': 2604,
#  'mark': 5691,
#  'tire': 1230,
#  'doesnt': 2313,
#  'square': 2314,
#  'business': 4723,
#  'sea': 74,
#  'quarrel': 1232,
#  'occupied': 6953,
#  'provided': 2315,
#  'undoubtedly': 5692,
#  'loaf': 502,
#  'stops': 1458,
#  'naive': 4468,
#  'hah': 7849,
#  'agency': 5693,
#  'grasp': 7850,
#  'wichita': 5694,
#  'love!': 2076,
#  'boat': 5695,
#  'uses': 7374,
#  'tray': 4661,
#  'camera': 2619,
#  'it!!': 75,
#  'jokes': 2316,
#  'safer': 6368,
#  'john!': 1233,
#  'missile': 6795,
#  'led': 1234,
#  'buff': 2317,
#  'greek': 4471,
#  'amateur': 4472,
#  "mom's": 2107,
#  'gotcha': 6338,
#  'requested': 4473,
#  'hid': 6786,
#  'shoulda': 6787,
#  'claudia': 2318,
#  'associated': 77,
#  'kastle': 2232,
#  'served': 2634,
#  'pretend': 3386,
#  'journey': 8342,
#  'teddy': 2319,
#  'broads': 2638,
#  'meltdown': 1235,
#  'dough': 78,
#  'remo': 5699,
#  'respect': 6738,
#  'vampires': 1236,
#  'rises': 7853,
#  'trusted': 7258,
#  'andand': 4478,
#  'cabinet': 4479,
#  'confident': 5700,
#  'heavy': 5701,
#  'coat': 4480,
#  'worthy': 7171,
#  'charming': 2078,
#  'teresa': 2321,
#  "'cept": 7856,
#  'mommy': 1237,
#  '35': 3389,
#  'straight': 4481,
#  'cigarette': 80,
#  'programming': 3390,
#  'pipeline': 7459,
#  'dreams': 1238,
#  'nest': 4863,
#  'hacker': 2657,
#  'noone': 8000,
#  'alpha': 5010,
#  'gasoline': 6792,
#  'napoleon': 1240,
#  'helpless': 2747,
#  'sammy': 5703,
#  'administration': 5830,
#  'gasket': 7090,
#  'solo': 8208,
#  'evidence': 2323,
#  'kim': 4873,
#  'bacon': 3392,
#  'fetch': 8032,
#  'skunk': 1242,
#  'scoop': 5638,
#  "it'sit's": 6793,
#  'ratings': 7857,
#  'dropped': 1079,
#  'lines': 4482,
#  'leonard': 4483,
#  'closing': 82,
#  'meaningless': 5707,
#  'orbit': 1243,
#  'balls': 4484,
#  'wanting': 3394,
#  'symphony': 2325,
#  'demands': 1244,
#  'exact': 7121,
#  'rest': 4485,
#  'breakdown': 8701,
#  'forgiveness': 4486,
#  'bloodshed': 1245,
#  'mean': 7860,
#  'inside': 3184,
#  'sings': 7150,
#  'trace': 2326,
#  'shinzon': 7861,
#  'koessler': 5639,
#  'hands': 4904,
#  'paid': 6920,
#  'iii': 8170,
#  'norm': 5708,
#  'farther': 6921,
#  'conference': 4911,
#  'guilty': 7862,
#  'came': 8379,
#  'circumstances': 2265,
#  'doug': 2704,
#  'strings': 83,
#  'exhibit': 1246,
#  'makes': 4489,
#  'masters': 3860,
#  'thomas': 84,
#  'whoa': 2327,
#  'using': 5710,
#  "o'clock": 2328,
#  'depth': 1248,
#  'methods': 5711,
#  'adrian': 2710,
#  "'kay": 5640,
#  'eyes!': 6797,
#  'mere': 472,
#  'seven': 7168,
#  'talk': 1250,
#  'garbage': 6009,
#  'us': 4491,
#  'pit': 6922,
#  'starfleet': 3398,
#  'such': 4360,
#  'pen': 7863,
#  'ton': 4492,
#  'instructions': 2266,
#  'keeps': 6798,
#  'mix': 6799,
#  'standard': 1723,
#  'drawer': 3399,
#  'necessary': 4929,
#  'stunt': 2723,
#  'cured': 7865,
#  'co': 2329,
#  'canary': 5912,
#  'ignorant': 3400,
#  'o': 1251,
#  'maxine': 2728,
#  'inject': 1252,
#  'ought': 3401,
#  'sometimes': 7024,
#  'slaughtered': 7513,
#  'outside': 1885,
#  'buildings': 1253,
#  'direction': 5013,
#  'internet': 3402,
#  'udou': 7867,
#  'dealers': 2331,
#  'bus': 3862,
#  'precise': 5641,
#  'fence': 775,
#  'sending': 4496,
#  'bombing': 7680,
#  "fightin'": 3403,
#  'zoo': 3404,
#  'tennis': 88,
#  'han': 7201,
#  'un': 7782,
#  'laying': 4958,
#  'twisted': 7030,
#  'apply': 6077,
#  'castle': 1880,
#  'halloween': 4498,
#  'absence': 4499,
#  'meetings': 1254,
#  'passion': 7869,
#  'ay': 8143,
#  'roll': 7208,
#  'settlement': 4500,
#  'realize': 5989,
#  'tow': 2332,
#  'permission': 2617,
#  'superman': 90,
#  'git': 1256,
#  'hollow': 5718,
#  'suggest': 4503,
#  'everybody!': 3405,
#  'sworn': 2333,
#  'curse': 3406,
#  'girl!': 2438,
#  'western': 1412,
#  'cheer': 4504,
#  'maid': 2334,
#  'talent': 7219,
#  'sat': 91,
#  'raving': 5720,
#  'pageant': 2765,
#  'instant': 3407,
#  'cared': 5721,
#  'hundreds': 1259,
#  'early': 6805,
#  'together': 8300,
#  'bible': 6806,
#  'first': 2336,
#  'checked': 4505,
#  'critical': 4427,
#  'receive': 2337,
#  'chew': 2338,
#  'chickens': 6807,
#  'copies': 6808,
#  'being': 1260,
#  'sophie': 93,
#  'exotic': 3409,
#  'cart': 2339,
#  'finer': 4506,
#  'flaw': 4507,
#  'bees': 94,
#  'wired': 7320,
#  'authorized': 4508,
#  'budget': 2779,
#  'vain': 7877,
#  'outa': 3410,
#  'thy': 1261,
#  'murder': 2456,
#  'relationship': 4510,
#  'pleases': 7241,
#  'hound': 4511,
#  'greg': 6804,
#  'sentence': 6253,
#  'shu': 95,
#  'millions': 5722,
#  'mainframe': 5723,
#  'knee': 96,
#  'religious': 7790,
#  'didnt': 6811,
#  'hill': 4512,
#  'blake': 2341,
#  'shape': 3111,
#  'donny': 5557,
#  'slim': 1262,
#  'crimes': 311,
#  'surfer': 1263,
#  'day': 8387,
#  'instead': 4514,
#  'well': 3164,
#  'weird': 546,
#  'fantastic': 6200,
#  'late': 3734,
#  'dragged': 4515,
#  'jockey': 98,
#  'pup': 8301,
#  "lady's": 5835,
#  'ladies': 4428,
#  'definite': 99,
#  'wheres': 4517,
#  'ginger': 5725,
#  'if': 6166,
#  'wrapped': 6373,
#  'dumbest': 6201,
#  'universe': 4518,
#  "stuff's": 5726,
#  'matrix': 1265,
#  'floors': 7883,
#  'seventytwo': 2345,
#  'leia': 2346,
#  'inch': 4519,
#  'skiing': 4520,
#  'aboard': 100,
#  'twelve': 7872,
#  'tall': 5027,
#  'sticking': 6374,
#  'farmers': 4521,
#  'rising': 3412,
#  "tellin'": 101,
#  'developing': 7443,
#  'few': 102,
#  'yelling': 4522,
#  'rise': 1266,
#  'hmmmm': 1267,
#  'sends': 4523,
#  'fortune': 4524,
#  'preparation': 7884,
#  'marines': 1368,
#  'rig': 6814,
#  'restore': 216,
#  'contempt': 6815,
#  'separated': 7129,
#  'anniversary': 2348,
#  'currency': 2349,
#  'emotions': 6817,
#  'civilians': 4525,
#  'cross': 4526,
#  'marx': 104,
#  'logic': 3414,
#  'people!': 6818,
#  'pure': 7885,
#  'prince': 2442,
#  'mothers': 3415,
#  "children's": 4527,
#  'outstanding': 4528,
#  'serial': 6819,
#  'submit': 3416,
#  'britain': 6926,
#  'ballroom': 4529,
#  'sod': 6820,
#  'sustain': 2350,
#  'hunger': 4530,
#  'films': 2351,
#  'baby': 5730,
#  "'no'": 7444,
#  'forever': 4532,
#  'pole': 5731,
#  'glenn': 5064,
#  'hunt': 7388,
#  'lame': 7901,
#  'weaker': 4533,
#  'chase': 6744,
#  'lose': 2352,
#  'round': 106,
#  'darned': 3418,
#  'lester': 3419,
#  'bay': 2353,
#  'corny': 3420,
#  'japanese': 6823,
#  'twentysix': 619,
#  'agnes': 107,
#  'physically': 2354,
#  'bowling': 6682,
#  'week!': 1268,
#  'africa': 108,
#  'swallow': 109,
#  'mallory': 6542,
#  'yea': 5733,
#  'medication': 4537,
#  'buttle': 3422,
#  'demon': 2851,
#  'christmas': 7313,
#  "'round": 6824,
#  'brave': 7888,
#  'honey': 5734,
#  'support': 6825,
#  'favorite': 5735,
#  'raise': 110,
#  'chopped': 3423,
#  'win': 111,
#  'prisoner': 1269,
#  'useless': 112,
#  'hobbes': 1270,
#  'nuisance': 2356,
#  'warned': 2357,
#  'fast!': 2358,
#  'according': 2359,
#  'confidence': 389,
#  'thrust': 4538,
#  'candy': 5736,
#  'banged': 7371,
#  'nasty': 1273,
#  'butler': 1274,
#  'revolutionary': 3425,
#  'excuses': 8653,
#  'rogers': 4539,
#  'nathan': 6794,
#  'parker': 2361,
#  'disaster': 1370,
#  'logan': 3426,
#  'unemployed': 5738,
#  'vicki': 7445,
#  'archie': 5440,
#  'rangers': 4540,
#  'retrieval': 7889,
#  'iraqis': 7890,
#  'meanwhile': 2362,
#  'unusual': 4541,
#  'those': 1276,
#  'accept': 2622,
#  'security': 1003,
#  'tomorrow!': 1277,
#  'science': 3427,
#  'ha': 6830,
#  'none': 2445,
#  'garage': 3428,
#  'burns': 2884,
#  'uareu': 5742,
#  'thumbs': 4542,
#  'anderson': 4543,
#  "m'sieu": 115,
#  'judgement': 3429,
#  'arnie': 5743,
#  'interrupt': 5744,
#  "heaven's": 5019,
#  'motto': 5128,
#  'trash': 5839,
#  'pms': 6363,
#  'prayed': 7265,
#  'corporation': 209,
#  'hojon': 7359,
#  'blessed': 1278,
#  'ashamed': 6831,
#  'smoked': 1279,
#  'fossils': 6832,
#  'ego': 3528,
#  'freezing': 390,
#  'ganz': 6833,
#  'award': 116,
#  'slaves': 1280,
#  'chiefs': 6910,
#  'door!': 2907,
#  'eat': 117,
#  'nuke': 7813,
#  'luthor': 6834,
#  'surprising': 6534,
#  'profit': 4637,
#  'jealous': 1281,
#  "friend's": 4547,
#  'pink': 6835,
#  'lando': 5745,
#  'rooms': 2912,
#  'wanna': 3430,
#  'senior': 1282,
#  'stores': 97,
#  'rufus': 2914,
#  'recognized': 7978,
#  'spies': 2363,
#  'cunning': 1283,
#  'magic': 5154,
#  'catherine': 3786,
#  'electricity': 119,
#  'ninth': 2364,
#  'divorce': 3432,
#  'form': 7606,
#  'dwight': 120,
#  'cockroaches': 2803,
#  'maiden': 1284,
#  'typewriter': 121,
#  'tea': 391,
#  'coming': 2921,
#  'disgusting': 1285,
#  'bronx': 707,
#  'tricked': 976,
#  'dana': 6837,
#  'him': 2804,
#  'spook': 1286,
#  'command': 5748,
#  'era': 122,
#  'mistaken': 393,
#  'organic': 7330,
#  'va': 5174,
#  'hell': 1287,
#  'federal': 123,
#  'perfume': 2367,
#  'agree': 7879,
#  'books': 124,
#  'royal': 1288,
#  'reasonable': 1289,
#  'mayfield': 8478,
#  'shocked': 6352,
#  "day's": 7896,
#  'screamed': 7099,
#  'drowned': 126,
#  'silence': 1290,
#  'cows': 3435,
#  'strangest': 6839,
#  'dreamed': 7560,
#  'lousy': 5189,
#  'spring': 6745,
#  'atomic': 3436,
#  'functions': 2368,
#  'are!': 6782,
#  'section': 4556,
#  'page': 3437,
#  'maximum': 1291,
#  'mail': 2447,
#  'cheese': 5200,
#  'appointment': 5751,
#  'lion': 4558,
#  'philip': 2369,
#  'sleeps': 4559,
#  'natalie': 2370,
#  'expedition': 1293,
#  'bills': 7195,
#  'uallu': 3440,
#  'team': 1294,
#  'tequila': 127,
#  'shots': 2371,
#  'baxter': 4595,
#  'robbed': 7270,
#  'barrel': 2587,
#  'oak': 1295,
#  'finished': 6844,
#  'confirm': 2372,
#  'grady': 2373,
#  'retreat': 6845,
#  'nickname': 7899,
#  'donna': 3442,
#  'dates': 6379,
#  'reservation': 5225,
#  'pension': 128,
#  'surely': 5754,
#  'credit': 129,
#  'promised': 7900,
#  'grounds': 1297,
#  'rita': 130,
#  'wheeler': 6929,
#  'amber': 1298,
#  'horse': 3443,
#  'network': 2374,
#  'result': 2375,
#  'guest': 5114,
#  'kisses': 8473,
#  ...}

# %% [markdown]
# Let's have a look at the answerswords2int dictionary we created above

# %%
answerswords2int
# Out:
# {'dowd': 2252,
#  'december': 7082,
#  'zuzu': 3282,
#  'impressed': 4407,
#  'ditch': 7778,
#  'bark': 2253,
#  'slut': 0,
#  'scattered': 8479,
#  'pa': 4033,
#  'italian': 1,
#  'box': 2056,
#  'thirteen': 8423,
#  'gone!': 7780,
#  'legit': 4409,
#  'health': 3334,
#  'lions': 8204,
#  'push': 1171,
#  'stepped': 2254,
#  'tear': 1172,
#  'league': 1173,
#  "worryin'": 3335,
#  'canada': 2272,
#  'insist': 6438,
#  'mason': 6732,
#  'bend': 2,
#  'voice': 2255,
#  'luca': 7620,
#  'joy': 2256,
#  '20': 3336,
#  'taping': 1174,
#  'envelope': 8053,
#  'everett': 4412,
#  'shirley': 1175,
#  'relaxed': 3337,
#  'rounds': 32,
#  'linked': 2257,
#  "family's": 8261,
#  'power': 3,
#  'skin': 4,
#  'labor': 5,
#  'staff': 6764,
#  'spaghetti': 7,
#  '2': 5627,
#  "gettin'": 7784,
#  'canyon': 1176,
#  'trying': 6185,
#  'amusing': 1177,
#  'anything!': 2258,
#  'gillis': 2259,
#  'duncan': 2291,
#  'primitive': 6772,
#  'office': 3340,
#  'king!': 8,
#  'whole': 2260,
#  'spencer': 5630,
#  'school': 2261,
#  'sneaking': 9,
#  'matthew': 5632,
#  'witnessed': 2262,
#  'rented': 5821,
#  'guide': 7785,
#  'lestat': 4418,
#  'americans': 10,
#  'pulling': 1178,
#  'pump': 8544,
#  'arrived': 11,
#  'albert': 12,
#  'pimp': 6735,
#  'claire': 5634,
#  'owner': 4420,
#  'accident!': 8429,
#  'june': 8177,
#  'shut': 8743,
#  'virus': 13,
#  'household': 3332,
#  'unou': 14,
#  'die': 6736,
#  'satisfied': 1179,
#  'indicted': 4422,
#  'able': 2263,
#  'discovered': 6737,
#  'old': 5635,
#  'terrible!': 8157,
#  'sickness': 8126,
#  'stone': 4408,
#  'started': 756,
#  'republican': 5636,
#  'nuclear': 5637,
#  'pig': 7956,
#  'certainly': 4219,
#  'promoted': 3341,
#  'valiant': 2623,
#  'hardest': 2322,
#  'vigo': 18,
#  'discuss': 4423,
#  'war!': 6740,
#  'catches': 3342,
#  "kid's": 6741,
#  "bringin'": 1170,
#  'exhusband': 5217,
#  'prenup': 16,
#  'thanks': 4425,
#  'missing': 4035,
#  'leap': 7083,
#  'painful': 4426,
#  'unemployment': 1180,
#  'remembering': 3578,
#  'men': 2267,
#  'joanne': 3343,
#  'craig': 4646,
#  'zero': 3344,
#  'murderers': 5642,
#  'dose': 8009,
#  'athos': 3408,
#  'stream': 5997,
#  'assignment': 1181,
#  'struck': 2268,
#  'hopes': 7787,
#  'dan': 17,
#  '25': 3345,
#  'german': 7789,
#  'picture': 6018,
#  'normally': 4513,
#  'spooky': 6950,
#  'johnson': 7792,
#  'sign': 2343,
#  'pneumonia': 2269,
#  'incredibly': 3347,
#  'multiple': 2270,
#  'leak': 2271,
#  'chairs': 105,
#  'glades': 7084,
#  'finds': 6743,
#  'sucks': 5643,
#  'terrified': 1182,
#  'politician': 1183,
#  'punch': 7625,
#  'elevator': 2109,
#  'rocket': 1184,
#  'snoopy': 113,
#  'patch': 7793,
#  'test': 4410,
#  'panes': 20,
#  'venice': 3349,
#  'null': 3350,
#  'barber': 5896,
#  'disco': 4429,
#  'youre': 1185,
#  "deal's": 21,
#  'smash': 118,
#  'cowboy': 7795,
#  'mad': 1186,
#  'areu': 4552,
#  'organism': 7499,
#  'nasal': 6912,
#  'norman': 7252,
#  'nobody': 4430,
#  'ron': 6069,
#  'wonder': 4431,
#  'appeared': 8713,
#  'returns': 8345,
#  'vitamin': 4557,
#  'collar': 5644,
#  'regulations': 1112,
#  'precinct': 22,
#  'shuts': 4560,
#  'coup': 8633,
#  'carter': 23,
#  'given': 8437,
#  'property': 6747,
#  'football': 542,
#  'crummy': 1127,
#  'kilos': 5716,
#  'swinging': 1088,
#  'personality': 4569,
#  'rosebud': 6852,
#  'sheriff': 2174,
#  'factor': 1187,
#  'butt': 6749,
#  'relation': 24,
#  'snake': 1188,
#  'flynn': 2273,
#  'gardner': 5648,
#  'bath': 3060,
#  'coach': 2274,
#  'week': 2275,
#  'glimpse': 7797,
#  'greedy': 7798,
#  'vulnerable': 1190,
#  'donald': 6752,
#  'couple': 1191,
#  'shot': 3504,
#  'fill': 25,
#  'launch': 8643,
#  'scrambled': 2276,
#  'cecile': 26,
#  'organization': 4587,
#  'decides': 1192,
#  'cheated': 27,
#  'lovely': 7799,
#  'nicky': 896,
#  'wouldnt': 2927,
#  'account': 8269,
#  'wendy': 5651,
#  'visual': 1193,
#  'disappointment': 3353,
#  'commission': 6754,
#  'behavior': 5652,
#  'gag': 7802,
#  'inappropriate': 2277,
#  'pentagon': 2278,
#  'experts': 5999,
#  'beans': 2279,
#  'mood': 7804,
#  'react': 30,
#  'sarge': 2280,
#  'nearly': 8736,
#  'dangerous': 7805,
#  'loomis': 6756,
#  'mall': 4435,
#  'warrant': 2281,
#  'nature': 1194,
#  'something': 1195,
#  'identify': 4436,
#  'prom': 31,
#  'yep': 5220,
#  'nails': 5654,
#  'mac': 5420,
#  'fella': 4414,
#  'christ': 6915,
#  'vivian': 5655,
#  'preacher': 1196,
#  'war': 8729,
#  'enough!': 2283,
#  'some': 2284,
#  'causes': 4437,
#  'severe': 5421,
#  'gamble': 33,
#  "water's": 34,
#  'carson': 35,
#  'sting': 6001,
#  'covered': 5656,
#  'management': 7807,
#  'tattoo': 192,
#  'lend': 6761,
#  'biological': 7467,
#  'come': 1199,
#  'reconsider': 7808,
#  'wont': 7809,
#  'dig': 1200,
#  'phoney': 36,
#  'sword': 1201,
#  'drinking': 37,
#  'imagination': 6762,
#  'four': 38,
#  'wretched': 2285,
#  'lord!': 7810,
#  'aw': 39,
#  'eating': 5004,
#  'george!': 6918,
#  'fox': 2286,
#  'denied': 3354,
#  'mulwray': 40,
#  'nude': 2287,
#  'dull': 3688,
#  'blond': 4633,
#  'lynette': 6766,
#  'busy': 41,
#  'excited': 2288,
#  'adopted': 1712,
#  'gorgeous': 6767,
#  'influence': 42,
#  'uyouru': 1203,
#  '11': 43,
#  'hans': 4644,
#  'myself!': 6768,
#  'liar': 4439,
#  'spends': 6769,
#  'popped': 4440,
#  'suspended': 6447,
#  'pepper': 1537,
#  'wife!': 4441,
#  'wall': 5659,
#  'bill!': 8637,
#  'nah': 44,
#  'captured': 2466,
#  'heights': 3356,
#  'radical': 6770,
#  'lotta': 3357,
#  'congratulate': 5660,
#  'fault': 3358,
#  'suitcase': 8490,
#  "bob's": 8548,
#  'lasted': 3359,
#  'pry': 5824,
#  'grant': 2289,
#  'twist': 8309,
#  'trusts': 6035,
#  'impossible': 4443,
#  'kent': 45,
#  'freud': 1026,
#  'como': 3361,
#  'mckenna': 1204,
#  'offended': 6959,
#  'stew': 47,
#  'apologize': 6771,
#  'blanks': 1205,
#  'embarrassed': 7816,
#  'austrian': 7817,
#  'edgar': 2292,
#  'supernatural': 7818,
#  'knights': 4415,
#  'gone': 48,
#  'this': 6773,
#  'cellar': 7609,
#  'sullivan': 5662,
#  'campaign': 5777,
#  'shave': 4040,
#  'extent': 6968,
#  "doesn't": 1207,
#  'path': 5664,
#  'biscuits': 6774,
#  'ethics': 7819,
#  'are': 2293,
#  'recall': 4445,
#  'gentle': 5423,
#  'fazeli': 6970,
#  'do!': 4416,
#  "better'n": 49,
#  "town's": 7430,
#  'wound': 50,
#  'countries': 4684,
#  'car!': 51,
#  'say!': 257,
#  'fulla': 5665,
#  'act': 7251,
#  'creating': 2294,
#  'transport': 6541,
#  'lowest': 2295,
#  'andrews': 5844,
#  'sake!': 1208,
#  "one's": 2296,
#  'she': 4449,
#  'pine': 5666,
#  'quickly': 1209,
#  'conflict': 52,
#  'connected': 4417,
#  'interrupting': 53,
#  'lama': 5668,
#  'lobby': 5631,
#  'confusing': 3368,
#  'charity': 272,
#  'tracy': 371,
#  'recognition': 6000,
#  'forcing': 3047,
#  'product': 7824,
#  'enforcement': 6995,
#  'carries': 54,
#  'volume': 5669,
#  'belong': 5670,
#  'kiddo': 1210,
#  'think!': 2517,
#  'joking': 5671,
#  'wladek': 6778,
#  'thief': 1211,
#  'despite': 1212,
#  'shack': 56,
#  'joan': 3369,
#  'cemetery': 6556,
#  'pm': 57,
#  'patient': 8449,
#  'cabin': 3371,
#  'chances': 3372,
#  'strung': 5007,
#  'nurse!': 531,
#  'jackson': 5672,
#  'jonah': 5673,
#  "else's": 7826,
#  'responsibilities': 3373,
#  'hated': 7827,
#  'wednesday': 4575,
#  'chest': 4450,
#  'motherfucker': 2298,
#  'likely': 1213,
#  'olive': 7828,
#  'armor': 7829,
#  'substitute': 2527,
#  '6': 3375,
#  'whatcha': 2299,
#  'onto': 1707,
#  'computers': 1214,
#  'instrument': 2301,
#  'around!': 2073,
#  'scientific': 4452,
#  "whoever's": 1215,
#  'worms': 2535,
#  'engine': 58,
#  'brenda': 7830,
#  'wheelchair': 1216,
#  'chili': 7482,
#  'snap': 4453,
#  'cecil': 1217,
#  'zip': 6780,
#  'beautifully': 2302,
#  'th': 4456,
#  'conditions': 7832,
#  'absolute': 7833,
#  'yankee': 2303,
#  'capable': 1218,
#  'play': 8640,
#  'convicted': 2304,
#  "child's": 3377,
#  'deed': 6251,
#  'picking': 1219,
#  'arrow': 59,
#  'operating': 3378,
#  "an'": 3852,
#  'erica': 7749,
#  'failure': 60,
#  'talks': 6781,
#  'regan': 61,
#  'paula': 7838,
#  'starving': 2305,
#  'edition': 62,
#  'twentyeight': 3379,
#  'saloon': 4744,
#  'caitlin': 1221,
#  'suspects': 7839,
#  'report': 2307,
#  'aid': 5684,
#  'chick': 5685,
#  'wiring': 4457,
#  'torpedo': 4458,
#  'marrow': 6783,
#  'either': 1222,
#  'afford': 7253,
#  'caliber': 1223,
#  'lucy': 8641,
#  'mobile': 64,
#  'preysing': 5686,
#  'resident': 65,
#  'desk': 8294,
#  'compound': 3807,
#  'gossip': 5229,
#  'joseph': 4460,
#  'allies': 7842,
#  'stephen': 66,
#  'wondered': 1225,
#  'unable': 4461,
#  'sacred': 5687,
#  'rachel': 7844,
#  'seconds': 2309,
#  'everywhere!': 2310,
#  'tank': 1227,
#  'scrap': 1228,
#  'until': 6784,
#  'claws': 8702,
#  'unfortunately': 1365,
#  'purple': 2580,
#  '300': 4463,
#  'wires': 3380,
#  'pursue': 7254,
#  'adds': 3381,
#  'isolation': 7071,
#  'performance': 67,
#  'scan': 8278,
#  'seemed': 1229,
#  'stay': 2311,
#  'perfect!': 8285,
#  'faster': 68,
#  "stayin'": 3382,
#  'develop': 69,
#  'sidney': 6930,
#  'poker': 4465,
#  'necklace': 6785,
#  'argon': 2312,
#  'severed': 70,
#  'papa': 7256,
#  'literature': 4322,
#  'trusting': 71,
#  'objection!': 370,
#  'kennedy': 3620,
#  'having': 72,
#  'tap': 4467,
#  'goddamned': 6559,
#  'exists': 2604,
#  'mark': 5691,
#  'tire': 1230,
#  'doesnt': 2313,
#  'square': 2314,
#  'business': 4723,
#  'sea': 74,
#  'quarrel': 1232,
#  'occupied': 6953,
#  'provided': 2315,
#  'undoubtedly': 5692,
#  'loaf': 502,
#  'stops': 1458,
#  'naive': 4468,
#  'hah': 7849,
#  'agency': 5693,
#  'grasp': 7850,
#  'wichita': 5694,
#  'love!': 2076,
#  'boat': 5695,
#  'uses': 7374,
#  'tray': 4661,
#  'camera': 2619,
#  'it!!': 75,
#  'jokes': 2316,
#  'safer': 6368,
#  'john!': 1233,
#  'missile': 6795,
#  'led': 1234,
#  'buff': 2317,
#  'greek': 4471,
#  'amateur': 4472,
#  "mom's": 2107,
#  'gotcha': 6338,
#  'requested': 4473,
#  'hid': 6786,
#  'shoulda': 6787,
#  'claudia': 2318,
#  'associated': 77,
#  'kastle': 2232,
#  'served': 2634,
#  'pretend': 3386,
#  'journey': 8342,
#  'teddy': 2319,
#  'broads': 2638,
#  'meltdown': 1235,
#  'dough': 78,
#  'remo': 5699,
#  'respect': 6738,
#  'vampires': 1236,
#  'rises': 7853,
#  'trusted': 7258,
#  'andand': 4478,
#  'cabinet': 4479,
#  'confident': 5700,
#  'heavy': 5701,
#  'coat': 4480,
#  'worthy': 7171,
#  'charming': 2078,
#  'teresa': 2321,
#  "'cept": 7856,
#  'mommy': 1237,
#  '35': 3389,
#  'straight': 4481,
#  'cigarette': 80,
#  'programming': 3390,
#  'pipeline': 7459,
#  'dreams': 1238,
#  'nest': 4863,
#  'hacker': 2657,
#  'noone': 8000,
#  'alpha': 5010,
#  'gasoline': 6792,
#  'napoleon': 1240,
#  'helpless': 2747,
#  'sammy': 5703,
#  'administration': 5830,
#  'gasket': 7090,
#  'solo': 8208,
#  'evidence': 2323,
#  'kim': 4873,
#  'bacon': 3392,
#  'fetch': 8032,
#  'skunk': 1242,
#  'scoop': 5638,
#  "it'sit's": 6793,
#  'ratings': 7857,
#  'dropped': 1079,
#  'lines': 4482,
#  'leonard': 4483,
#  'closing': 82,
#  'meaningless': 5707,
#  'orbit': 1243,
#  'balls': 4484,
#  'wanting': 3394,
#  'symphony': 2325,
#  'demands': 1244,
#  'exact': 7121,
#  'rest': 4485,
#  'breakdown': 8701,
#  'forgiveness': 4486,
#  'bloodshed': 1245,
#  'mean': 7860,
#  'inside': 3184,
#  'sings': 7150,
#  'trace': 2326,
#  'shinzon': 7861,
#  'koessler': 5639,
#  'hands': 4904,
#  'paid': 6920,
#  'iii': 8170,
#  'norm': 5708,
#  'farther': 6921,
#  'conference': 4911,
#  'guilty': 7862,
#  'came': 8379,
#  'circumstances': 2265,
#  'doug': 2704,
#  'strings': 83,
#  'exhibit': 1246,
#  'makes': 4489,
#  'masters': 3860,
#  'thomas': 84,
#  'whoa': 2327,
#  'using': 5710,
#  "o'clock": 2328,
#  'depth': 1248,
#  'methods': 5711,
#  'adrian': 2710,
#  "'kay": 5640,
#  'eyes!': 6797,
#  'mere': 472,
#  'seven': 7168,
#  'talk': 1250,
#  'garbage': 6009,
#  'us': 4491,
#  'pit': 6922,
#  'starfleet': 3398,
#  'such': 4360,
#  'pen': 7863,
#  'ton': 4492,
#  'instructions': 2266,
#  'keeps': 6798,
#  'mix': 6799,
#  'standard': 1723,
#  'drawer': 3399,
#  'necessary': 4929,
#  'stunt': 2723,
#  'cured': 7865,
#  'co': 2329,
#  'canary': 5912,
#  'ignorant': 3400,
#  'o': 1251,
#  'maxine': 2728,
#  'inject': 1252,
#  'ought': 3401,
#  'sometimes': 7024,
#  'slaughtered': 7513,
#  'outside': 1885,
#  'buildings': 1253,
#  'direction': 5013,
#  'internet': 3402,
#  'udou': 7867,
#  'dealers': 2331,
#  'bus': 3862,
#  'precise': 5641,
#  'fence': 775,
#  'sending': 4496,
#  'bombing': 7680,
#  "fightin'": 3403,
#  'zoo': 3404,
#  'tennis': 88,
#  'han': 7201,
#  'un': 7782,
#  'laying': 4958,
#  'twisted': 7030,
#  'apply': 6077,
#  'castle': 1880,
#  'halloween': 4498,
#  'absence': 4499,
#  'meetings': 1254,
#  'passion': 7869,
#  'ay': 8143,
#  'roll': 7208,
#  'settlement': 4500,
#  'realize': 5989,
#  'tow': 2332,
#  'permission': 2617,
#  'superman': 90,
#  'git': 1256,
#  'hollow': 5718,
#  'suggest': 4503,
#  'everybody!': 3405,
#  'sworn': 2333,
#  'curse': 3406,
#  'girl!': 2438,
#  'western': 1412,
#  'cheer': 4504,
#  'maid': 2334,
#  'talent': 7219,
#  'sat': 91,
#  'raving': 5720,
#  'pageant': 2765,
#  'instant': 3407,
#  'cared': 5721,
#  'hundreds': 1259,
#  'early': 6805,
#  'together': 8300,
#  'bible': 6806,
#  'first': 2336,
#  'checked': 4505,
#  'critical': 4427,
#  'receive': 2337,
#  'chew': 2338,
#  'chickens': 6807,
#  'copies': 6808,
#  'being': 1260,
#  'sophie': 93,
#  'exotic': 3409,
#  'cart': 2339,
#  'finer': 4506,
#  'flaw': 4507,
#  'bees': 94,
#  'wired': 7320,
#  'authorized': 4508,
#  'budget': 2779,
#  'vain': 7877,
#  'outa': 3410,
#  'thy': 1261,
#  'murder': 2456,
#  'relationship': 4510,
#  'pleases': 7241,
#  'hound': 4511,
#  'greg': 6804,
#  'sentence': 6253,
#  'shu': 95,
#  'millions': 5722,
#  'mainframe': 5723,
#  'knee': 96,
#  'religious': 7790,
#  'didnt': 6811,
#  'hill': 4512,
#  'blake': 2341,
#  'shape': 3111,
#  'donny': 5557,
#  'slim': 1262,
#  'crimes': 311,
#  'surfer': 1263,
#  'day': 8387,
#  'instead': 4514,
#  'well': 3164,
#  'weird': 546,
#  'fantastic': 6200,
#  'late': 3734,
#  'dragged': 4515,
#  'jockey': 98,
#  'pup': 8301,
#  "lady's": 5835,
#  'ladies': 4428,
#  'definite': 99,
#  'wheres': 4517,
#  'ginger': 5725,
#  'if': 6166,
#  'wrapped': 6373,
#  'dumbest': 6201,
#  'universe': 4518,
#  "stuff's": 5726,
#  'matrix': 1265,
#  'floors': 7883,
#  'seventytwo': 2345,
#  'leia': 2346,
#  'inch': 4519,
#  'skiing': 4520,
#  'aboard': 100,
#  'twelve': 7872,
#  'tall': 5027,
#  'sticking': 6374,
#  'farmers': 4521,
#  'rising': 3412,
#  "tellin'": 101,
#  'developing': 7443,
#  'few': 102,
#  'yelling': 4522,
#  'rise': 1266,
#  'hmmmm': 1267,
#  'sends': 4523,
#  'fortune': 4524,
#  'preparation': 7884,
#  'marines': 1368,
#  'rig': 6814,
#  'restore': 216,
#  'contempt': 6815,
#  'separated': 7129,
#  'anniversary': 2348,
#  'currency': 2349,
#  'emotions': 6817,
#  'civilians': 4525,
#  'cross': 4526,
#  'marx': 104,
#  'logic': 3414,
#  'people!': 6818,
#  'pure': 7885,
#  'prince': 2442,
#  'mothers': 3415,
#  "children's": 4527,
#  'outstanding': 4528,
#  'serial': 6819,
#  'submit': 3416,
#  'britain': 6926,
#  'ballroom': 4529,
#  'sod': 6820,
#  'sustain': 2350,
#  'hunger': 4530,
#  'films': 2351,
#  'baby': 5730,
#  "'no'": 7444,
#  'forever': 4532,
#  'pole': 5731,
#  'glenn': 5064,
#  'hunt': 7388,
#  'lame': 7901,
#  'weaker': 4533,
#  'chase': 6744,
#  'lose': 2352,
#  'round': 106,
#  'darned': 3418,
#  'lester': 3419,
#  'bay': 2353,
#  'corny': 3420,
#  'japanese': 6823,
#  'twentysix': 619,
#  'agnes': 107,
#  'physically': 2354,
#  'bowling': 6682,
#  'week!': 1268,
#  'africa': 108,
#  'swallow': 109,
#  'mallory': 6542,
#  'yea': 5733,
#  'medication': 4537,
#  'buttle': 3422,
#  'demon': 2851,
#  'christmas': 7313,
#  "'round": 6824,
#  'brave': 7888,
#  'honey': 5734,
#  'support': 6825,
#  'favorite': 5735,
#  'raise': 110,
#  'chopped': 3423,
#  'win': 111,
#  'prisoner': 1269,
#  'useless': 112,
#  'hobbes': 1270,
#  'nuisance': 2356,
#  'warned': 2357,
#  'fast!': 2358,
#  'according': 2359,
#  'confidence': 389,
#  'thrust': 4538,
#  'candy': 5736,
#  'banged': 7371,
#  'nasty': 1273,
#  'butler': 1274,
#  'revolutionary': 3425,
#  'excuses': 8653,
#  'rogers': 4539,
#  'nathan': 6794,
#  'parker': 2361,
#  'disaster': 1370,
#  'logan': 3426,
#  'unemployed': 5738,
#  'vicki': 7445,
#  'archie': 5440,
#  'rangers': 4540,
#  'retrieval': 7889,
#  'iraqis': 7890,
#  'meanwhile': 2362,
#  'unusual': 4541,
#  'those': 1276,
#  'accept': 2622,
#  'security': 1003,
#  'tomorrow!': 1277,
#  'science': 3427,
#  'ha': 6830,
#  'none': 2445,
#  'garage': 3428,
#  'burns': 2884,
#  'uareu': 5742,
#  'thumbs': 4542,
#  'anderson': 4543,
#  "m'sieu": 115,
#  'judgement': 3429,
#  'arnie': 5743,
#  'interrupt': 5744,
#  "heaven's": 5019,
#  'motto': 5128,
#  'trash': 5839,
#  'pms': 6363,
#  'prayed': 7265,
#  'corporation': 209,
#  'hojon': 7359,
#  'blessed': 1278,
#  'ashamed': 6831,
#  'smoked': 1279,
#  'fossils': 6832,
#  'ego': 3528,
#  'freezing': 390,
#  'ganz': 6833,
#  'award': 116,
#  'slaves': 1280,
#  'chiefs': 6910,
#  'door!': 2907,
#  'eat': 117,
#  'nuke': 7813,
#  'luthor': 6834,
#  'surprising': 6534,
#  'profit': 4637,
#  'jealous': 1281,
#  "friend's": 4547,
#  'pink': 6835,
#  'lando': 5745,
#  'rooms': 2912,
#  'wanna': 3430,
#  'senior': 1282,
#  'stores': 97,
#  'rufus': 2914,
#  'recognized': 7978,
#  'spies': 2363,
#  'cunning': 1283,
#  'magic': 5154,
#  'catherine': 3786,
#  'electricity': 119,
#  'ninth': 2364,
#  'divorce': 3432,
#  'form': 7606,
#  'dwight': 120,
#  'cockroaches': 2803,
#  'maiden': 1284,
#  'typewriter': 121,
#  'tea': 391,
#  'coming': 2921,
#  'disgusting': 1285,
#  'bronx': 707,
#  'tricked': 976,
#  'dana': 6837,
#  'him': 2804,
#  'spook': 1286,
#  'command': 5748,
#  'era': 122,
#  'mistaken': 393,
#  'organic': 7330,
#  'va': 5174,
#  'hell': 1287,
#  'federal': 123,
#  'perfume': 2367,
#  'agree': 7879,
#  'books': 124,
#  'royal': 1288,
#  'reasonable': 1289,
#  'mayfield': 8478,
#  'shocked': 6352,
#  "day's": 7896,
#  'screamed': 7099,
#  'drowned': 126,
#  'silence': 1290,
#  'cows': 3435,
#  'strangest': 6839,
#  'dreamed': 7560,
#  'lousy': 5189,
#  'spring': 6745,
#  'atomic': 3436,
#  'functions': 2368,
#  'are!': 6782,
#  'section': 4556,
#  'page': 3437,
#  'maximum': 1291,
#  'mail': 2447,
#  'cheese': 5200,
#  'appointment': 5751,
#  'lion': 4558,
#  'philip': 2369,
#  'sleeps': 4559,
#  'natalie': 2370,
#  'expedition': 1293,
#  'bills': 7195,
#  'uallu': 3440,
#  'team': 1294,
#  'tequila': 127,
#  'shots': 2371,
#  'baxter': 4595,
#  'robbed': 7270,
#  'barrel': 2587,
#  'oak': 1295,
#  'finished': 6844,
#  'confirm': 2372,
#  'grady': 2373,
#  'retreat': 6845,
#  'nickname': 7899,
#  'donna': 3442,
#  'dates': 6379,
#  'reservation': 5225,
#  'pension': 128,
#  'surely': 5754,
#  'credit': 129,
#  'promised': 7900,
#  'grounds': 1297,
#  'rita': 130,
#  'wheeler': 6929,
#  'amber': 1298,
#  'horse': 3443,
#  'network': 2374,
#  'result': 2375,
#  'guest': 5114,
#  'kisses': 8473,
#  ...}

# %% [markdown]
# # Adding the last tokens to the above two dictionaries
#
# EOS = End of sentence
#
# SOS = Start of sentence

# %%
tokens = ['<PAD>', '<EOS>', '<OUT>', '<SOS>']

# %% [markdown]
# Here we need to assign a unique integer to token in the questionswords2int dictionary. Since words are added, by incrementing one at a time, hence here we just calculate the length of the dictionary and 1 to it

# %%
for token in tokens:
    questionswords2int[token] = len(questionswords2int) + 1

# %% [markdown]
# Doing the same as above to answerswords2int dictionary
#
# Here we need to assign a unique integer to token in the answerswords2int dictionary. Since words are added, by incrementing one at a time, hence here we just calculate the length of the dictionary and 1 to it

# %%
for token in tokens:
    answerswords2int[token] = len(answerswords2int) + 1

# %% [markdown]
# # Creating an inverse dictionary of the answerswords2int dictionary

# %% [markdown]
# We are doing so because we need the inverse mapping from integers to answers words in the implementation of the Seq2Seq architectural model.
# Also, we need this only for the answerswords dictionary and not for questionswords.
#
# 1. declare a new dictionary in python
#
# 2. there is a single line trick in python to reverse the mapping of a dictionary,i.e, to interchange the key-value pairs and store them in a new dictionary

# %%
answersints2word = {w_i: w for w, w_i in answerswords2int.items()}

# %% [markdown]
# Let's have a look at the newly created answersints2word dictionary (inverse mapped dictionary)

# %%
answersints2word
# Out:
# {0: 'slut',
#  1: 'italian',
#  2: 'bend',
#  3: 'power',
#  4: 'skin',
#  5: 'labor',
#  6: 'bore',
#  7: 'spaghetti',
#  8: 'king!',
#  9: 'sneaking',
#  10: 'americans',
#  11: 'arrived',
#  12: 'albert',
#  13: 'virus',
#  14: 'unou',
#  15: 'older',
#  16: 'prenup',
#  17: 'dan',
#  18: 'vigo',
#  19: 'hour',
#  20: 'panes',
#  21: "deal's",
#  22: 'precinct',
#  23: 'carter',
#  24: 'relation',
#  25: 'fill',
#  26: 'cecile',
#  27: 'cheated',
#  28: 'eastern',
#  29: 'grow',
#  30: 'react',
#  31: 'prom',
#  32: 'rounds',
#  33: 'gamble',
#  34: "water's",
#  35: 'carson',
#  36: 'phoney',
#  37: 'drinking',
#  38: 'four',
#  39: 'aw',
#  40: 'mulwray',
#  41: 'busy',
#  42: 'influence',
#  43: '11',
#  44: 'nah',
#  45: 'kent',
#  46: 'too!',
#  47: 'stew',
#  48: 'gone',
#  49: "better'n",
#  50: 'wound',
#  51: 'car!',
#  52: 'conflict',
#  53: 'interrupting',
#  54: 'carries',
#  55: 'therapy',
#  56: 'shack',
#  57: 'pm',
#  58: 'engine',
#  59: 'arrow',
#  60: 'failure',
#  61: 'regan',
#  62: 'edition',
#  63: 'him!',
#  64: 'mobile',
#  65: 'resident',
#  66: 'stephen',
#  67: 'performance',
#  68: 'faster',
#  69: 'develop',
#  70: 'severed',
#  71: 'trusting',
#  72: 'having',
#  73: 'grace',
#  74: 'sea',
#  75: 'it!!',
#  76: 'combined',
#  77: 'associated',
#  78: 'dough',
#  79: 'levels',
#  80: 'cigarette',
#  81: 'hardcore',
#  82: 'closing',
#  83: 'strings',
#  84: 'thomas',
#  85: 'malkovich',
#  86: 'promotion',
#  87: 'autograph',
#  88: 'tennis',
#  89: 'mine',
#  90: 'superman',
#  91: 'sat',
#  92: 'matters',
#  93: 'sophie',
#  94: 'bees',
#  95: 'shu',
#  96: 'knee',
#  97: 'stores',
#  98: 'jockey',
#  99: 'definite',
#  100: 'aboard',
#  101: "tellin'",
#  102: 'few',
#  103: 'come!',
#  104: 'marx',
#  105: 'chairs',
#  106: 'round',
#  107: 'agnes',
#  108: 'africa',
#  109: 'swallow',
#  110: 'raise',
#  111: 'win',
#  112: 'useless',
#  113: 'snoopy',
#  114: 'posters',
#  115: "m'sieu",
#  116: 'award',
#  117: 'eat',
#  118: 'smash',
#  119: 'electricity',
#  120: 'dwight',
#  121: 'typewriter',
#  122: 'era',
#  123: 'federal',
#  124: 'books',
#  125: 'jews',
#  126: 'drowned',
#  127: 'tequila',
#  128: 'pension',
#  129: 'credit',
#  130: 'rita',
#  131: 'sylvia',
#  132: 'treves',
#  133: 'sneak',
#  134: 'would',
#  135: 'travel',
#  136: 'filed',
#  137: 'grew',
#  138: 'terrifying',
#  139: 'completely',
#  140: 'shuttle',
#  141: 'hop',
#  142: 'failed',
#  143: 'harris',
#  144: 'pot',
#  145: 'towards',
#  146: 'voyage',
#  147: 'rape',
#  148: 'janitor',
#  149: 'fled',
#  150: 'billions',
#  151: 'angry',
#  152: 'diamond',
#  153: 'purchase',
#  154: 'tracks',
#  155: 'scandal',
#  156: 'scouts',
#  157: '30',
#  158: 'fee',
#  159: '150',
#  160: 'badly',
#  161: 'shep',
#  162: 'son',
#  163: 'tribe',
#  164: 'nothing',
#  165: 'retire',
#  166: 'seventyfive',
#  167: 'howard',
#  168: 'warmer',
#  169: 'spray',
#  170: 'reporting',
#  171: 'heading',
#  172: 'actor',
#  173: 'bugs',
#  174: 'paradise',
#  175: 'pirate',
#  176: "holdin'",
#  177: 'lonesome',
#  178: 'fine',
#  179: 'beats',
#  180: 'hood',
#  181: 'chained',
#  182: 'glorious',
#  183: 'fortress',
#  184: 'row',
#  185: 'prey',
#  186: 'heart',
#  187: 'gruner',
#  188: 'pete',
#  189: 'allows',
#  190: 'outpost',
#  191: "walkin'",
#  192: 'tattoo',
#  193: 'anytime',
#  194: 'desperate',
#  195: 'josh',
#  196: 'pushed',
#  197: 'call',
#  198: 'transmit',
#  199: 'depends',
#  200: 'tricky',
#  201: "head's",
#  202: 'nolan',
#  203: 'enid',
#  204: 'angel',
#  205: 'tuesday',
#  206: 'slept',
#  207: 'bookstore',
#  208: 'dick',
#  209: 'corporation',
#  210: 'salvation',
#  211: 'merit',
#  212: 'haven',
#  213: 'manhattan',
#  214: 'tragic',
#  215: "mary's",
#  216: 'restore',
#  217: 'approved',
#  218: 'need',
#  219: 'systems',
#  220: 'admitting',
#  221: 'remembered',
#  222: 'story!',
#  223: 'lt',
#  224: 'serious',
#  225: 'observation',
#  226: 'dot',
#  227: 'treats',
#  228: 'dancer',
#  229: 'rust',
#  230: 'aunt',
#  231: 'hip',
#  232: 'proposing',
#  233: 'jesus!',
#  234: 'huey',
#  235: 'enemy',
#  236: 'bomb',
#  237: 'swing',
#  238: 'owed',
#  239: 'wise',
#  240: 'fits',
#  241: 'yelled',
#  242: 'fighting',
#  243: 'resume',
#  244: 'bang',
#  245: 'dixie',
#  246: 'crawled',
#  247: 'since',
#  248: 'work',
#  249: 'keep',
#  250: 'overseas',
#  251: 'whaddya',
#  252: 'signal',
#  253: 'bloom',
#  254: 'christian',
#  255: 'jobs',
#  256: 'palace',
#  257: 'say!',
#  258: 'salad',
#  259: 'bleed',
#  260: 'quoting',
#  261: 'everyone',
#  262: 'stir',
#  263: 'option',
#  264: 'mcmurphy',
#  265: 'resist',
#  266: 'marriages',
#  267: 'release',
#  268: 'quaint',
#  269: 'feared',
#  270: 'freelance',
#  271: 'medicine',
#  272: 'charity',
#  273: 'disturb',
#  274: 'cool!',
#  275: 'tried',
#  276: 'questions',
#  277: 'powder',
#  278: 'nightmares',
#  279: 'right',
#  280: "president's",
#  281: 'reputation',
#  282: 'soze',
#  283: 'life!',
#  284: 'enjoy',
#  285: 'isu',
#  286: 'theres',
#  287: 'austria',
#  288: 'chinatown',
#  289: 'gun',
#  290: 'stewardess',
#  291: 'connect',
#  292: 'thursday',
#  293: "christ's",
#  294: 'facing',
#  295: 'sympathetic',
#  296: 'darkness',
#  297: 'model',
#  298: 'scobie',
#  299: 'existed',
#  300: 'five',
#  301: 'eats',
#  302: 'cancel',
#  303: 'ahm',
#  304: 'dollar',
#  305: 'conscience',
#  306: 'llewelyn',
#  307: 'bless',
#  308: 'fifty',
#  309: 'whadda',
#  310: 'berserk',
#  311: 'crimes',
#  312: 'basis',
#  313: 'queen',
#  314: 'camp',
#  315: 'sacrificed',
#  316: 'bravo',
#  317: 'remotely',
#  318: 'region',
#  319: 'cold',
#  320: 'bride',
#  321: 'pupils',
#  322: 'african',
#  323: 'scientists',
#  324: 'attention',
#  325: 'mccoy',
#  326: 'father!',
#  327: 'fuss',
#  328: 'grenade',
#  329: 'vietnamese',
#  330: 'kincaid',
#  331: 'vomit',
#  332: 'restless',
#  333: 'hot',
#  334: 'race',
#  335: 'houses',
#  336: 'identical',
#  337: 'hallway',
#  338: 'cases',
#  339: "today's",
#  340: 'imperial',
#  341: 'uandu',
#  342: 'memory',
#  343: 'remark',
#  344: 'sebastian',
#  345: 'new',
#  346: 'respected',
#  347: 'non',
#  348: 'doe',
#  349: 'kurtz',
#  350: 'hire',
#  351: 'condemned',
#  352: 'donut',
#  353: 'surgery',
#  354: 'october',
#  355: 'madness',
#  356: 'decided',
#  357: 'surge',
#  358: 'cruiser',
#  359: 'packs',
#  360: 'surface',
#  361: "dyin'",
#  362: 'holes',
#  363: 'contract',
#  364: 'murders',
#  365: 'readers',
#  366: 'northern',
#  367: 'bum',
#  368: 'their',
#  369: 'breakin',
#  370: 'objection!',
#  371: 'tracy',
#  372: 'brandon',
#  373: 'cake',
#  374: 'detectives',
#  375: 'hicks',
#  376: 'maya',
#  377: 'sail',
#  378: 'female',
#  379: 'sakes',
#  380: 'generation',
#  381: 'junk',
#  382: 'swim',
#  383: 'her!',
#  384: 'insect',
#  385: 'malfunction',
#  386: 'archer',
#  387: 'sole',
#  388: "'you",
#  389: 'confidence',
#  390: 'freezing',
#  391: 'tea',
#  392: 'oswald',
#  393: 'mistaken',
#  394: 'jeffrey',
#  395: 'puts',
#  396: 'entry',
#  397: 'dickie',
#  398: 'stories',
#  399: 'boom',
#  400: 'blew',
#  401: "needn't",
#  402: 'booze',
#  403: 'signing',
#  404: 'dark',
#  405: 'stares',
#  406: 'terrorist',
#  407: 'indians',
#  408: 'bialystock',
#  409: 'dirt',
#  410: 'log',
#  411: 'lemon',
#  412: 'del',
#  413: 'passport',
#  414: 'mush',
#  415: 'brilliant',
#  416: 'morals',
#  417: 'funding',
#  418: 'restaurant',
#  419: 'walk',
#  420: 'no',
#  421: 'otherwise',
#  422: 'courtesy',
#  423: 'information',
#  424: 'tracked',
#  425: 'flames',
#  426: 'benefits',
#  427: 'steed',
#  428: 'load',
#  429: 'adolf',
#  430: 'beaches',
#  431: 'certain',
#  432: 'flyer',
#  433: 'paranoia',
#  434: '50',
#  435: 'is',
#  436: 'betray',
#  437: 'newspapers',
#  438: 'channing',
#  439: 'leash',
#  440: 'size',
#  441: 'ridiculous!',
#  442: 'telegram',
#  443: 'samples',
#  444: "killer's",
#  445: 'happen!',
#  446: 'basically',
#  447: 'lethal',
#  448: 'luck!',
#  449: 'majesty',
#  450: '4',
#  451: 'nam',
#  452: 'explosion',
#  453: 'wes',
#  454: 'hmm',
#  455: 'vengeance',
#  456: 'twombley',
#  457: 'because',
#  458: 'fairly',
#  459: "jus'",
#  460: 'reduced',
#  461: 'merry',
#  462: 'bullshit!',
#  463: 'wishes',
#  464: 'educated',
#  465: 'leather',
#  466: 'armed',
#  467: 'intention',
#  468: 'town',
#  469: 'violent',
#  470: 'bitch',
#  471: 'meet',
#  472: 'mere',
#  473: 'amount',
#  474: 'rendezvous',
#  475: 'lauren',
#  476: 'college',
#  477: 'tearing',
#  478: 'stored',
#  479: 'frances',
#  480: 'proceed',
#  481: 'determine',
#  482: 'wh',
#  483: 'lust',
#  484: 'cream',
#  485: 'asks',
#  486: 'aside',
#  487: 'promise',
#  488: 'toys',
#  489: 'fergus',
#  490: 'mantan',
#  491: 'accuse',
#  492: 'physician',
#  493: 'gently',
#  494: 'change',
#  495: 'disrespect',
#  496: 'contracts',
#  497: 'rafe',
#  498: 'pd',
#  499: 'bitter',
#  500: 'told',
#  501: 'umeu',
#  502: 'loaf',
#  503: 'jurisdiction',
#  504: 'luxury',
#  505: 'food',
#  506: 'sensitive',
#  507: 'coin',
#  508: 'portrait',
#  509: 'tricks',
#  510: 'equal',
#  511: 'boats',
#  512: 'soup',
#  513: 'justi',
#  514: 'faggot',
#  515: 'vancouver',
#  516: 'appointed',
#  517: 'sum',
#  518: 'burden',
#  519: 'hi',
#  520: 'announce',
#  521: 'satellites',
#  522: 'within',
#  523: 'easier',
#  524: 'buffy',
#  525: 'critic',
#  526: 'freeway',
#  527: 'shipment',
#  528: 'confession',
#  529: 'stress',
#  530: 'rorschach',
#  531: 'nurse!',
#  532: 'faces',
#  533: 'nasa',
#  534: 'eliminate',
#  535: 'bump',
#  536: 'fighters',
#  537: 'dante',
#  538: 'shelly',
#  539: 'cubans',
#  540: 'destiny',
#  541: 'penis',
#  542: 'football',
#  543: "fuck's",
#  544: 'cooperate',
#  545: 'sin',
#  546: 'weird',
#  547: 'firm',
#  548: 'competitive',
#  549: 'ships',
#  550: 'cloud',
#  551: 'sir',
#  552: 'harder',
#  553: 'blair',
#  554: 'gee',
#  555: 'movie',
#  556: 'payment',
#  557: 'blast',
#  558: '200',
#  559: 'banks',
#  560: 'leaning',
#  561: 'very',
#  562: 'played',
#  563: 'safe',
#  564: 'bernie',
#  565: 'players',
#  566: 'dutch',
#  567: 'brace',
#  568: 'properly',
#  569: 'skills',
#  570: 'postcard',
#  571: 'dead!',
#  572: 'bait',
#  573: 'crawl',
#  574: 'poem',
#  575: 'turner',
#  576: 'unexpected',
#  577: 'acting',
#  578: 'staring',
#  579: 'reynolds',
#  580: 'hate',
#  581: 'lifetime',
#  582: 'recommend',
#  583: 'tramp',
#  584: 'toddy',
#  585: 'thirtytwo',
#  586: 'insulting',
#  587: 'mechanical',
#  588: 'julian',
#  589: 'lebowski',
#  590: 'gods',
#  591: 'kitty',
#  592: 'units',
#  593: 'ethel',
#  594: 'crusher',
#  595: 'doubts',
#  596: 'county',
#  597: 'ryan',
#  598: 'lo',
#  599: 'episode',
#  600: 'lombard',
#  601: 'dozen',
#  602: 'burnt',
#  603: 'challenge',
#  604: 'fight',
#  605: 'altogether',
#  606: 'know!',
#  607: 'atlanta',
#  608: 'connecticut',
#  609: 'exposed',
#  610: 'gibson',
#  611: 'hockey',
#  612: 'sees',
#  613: 'rubber',
#  614: 'snuff',
#  615: 'transmission',
#  616: 'broker',
#  617: 'luis',
#  618: '10',
#  619: 'twentysix',
#  620: 'hearts',
#  621: 'cleaning',
#  622: 'trajectory',
#  623: 'ing',
#  624: 'wire',
#  625: 'eggs',
#  626: 'wandering',
#  627: 'toes',
#  628: 'awhile',
#  629: 'jabez',
#  630: 'whenever',
#  631: 'awful',
#  632: 'jane',
#  633: 'stones',
#  634: 'j',
#  635: 'doctor',
#  636: 'cliff',
#  637: 'really!',
#  638: 'discussing',
#  639: 'career',
#  640: 'mel',
#  641: 'siddown',
#  642: 'gregory',
#  643: 'before!',
#  644: 'lydia',
#  645: 'scum',
#  646: 'snitch',
#  647: 'experiencing',
#  648: "whatever's",
#  649: 'okay',
#  650: 'purity',
#  651: 'minute!',
#  652: 'awright',
#  653: "'im",
#  654: 'scream',
#  655: 'esther',
#  656: 'stranger',
#  657: 'crew',
#  658: "everything's",
#  659: 'gracious',
#  660: 'tampering',
#  661: "world's",
#  662: 'hunters',
#  663: 'record',
#  664: 'shipping',
#  665: 'militia',
#  666: 'ministry',
#  667: 'harmony',
#  668: "michael's",
#  669: 'emergency',
#  670: 'b',
#  671: 'benedict',
#  672: 'promote',
#  673: 'discretion',
#  674: 'smear',
#  675: 'passing',
#  676: 'cafe',
#  677: 'egypt',
#  678: 'vickie',
#  679: 'maria',
#  680: 'launched',
#  681: 'addressed',
#  682: 'occasional',
#  683: 'uhoh',
#  684: 'waited',
#  685: 'col',
#  686: 'identification',
#  687: 'soft',
#  688: 'harper',
#  689: 'stadium',
#  690: 'pearls',
#  691: 'hatred',
#  692: 'shield',
#  693: 'fuel',
#  694: 'ruining',
#  695: 'ralph',
#  696: 'raymond',
#  697: 'million',
#  698: 'turn',
#  699: 'kirsty',
#  700: 'musta',
#  701: 'link',
#  702: 'insomnia',
#  703: 'track',
#  704: 'headache',
#  705: 'grocery',
#  706: 'among',
#  707: 'bronx',
#  708: 'wally',
#  709: 'norma',
#  710: 'tempted',
#  711: 'approach',
#  712: 'succeed',
#  713: 'button',
#  714: 'daniel',
#  715: 'devoted',
#  716: 'reliant',
#  717: 'work!',
#  718: 'pork',
#  719: 'integrity',
#  720: 'singer',
#  721: 'country',
#  722: 'morning!',
#  723: 'stella',
#  724: 'conspiracy',
#  725: 'witches',
#  726: "ain't",
#  727: 'strategy',
#  728: 'mindless',
#  729: 'zira',
#  730: 'restraining',
#  731: 'stretch',
#  732: 'crawford',
#  733: 'design',
#  734: 'lay',
#  735: 'lottery',
#  736: 'stewart',
#  737: 'seats',
#  738: 'presume',
#  739: 'chump',
#  740: 'employees',
#  741: 'passed',
#  742: 'carlos',
#  743: "car's",
#  744: 'digging',
#  745: 'ahhh',
#  746: 'witty',
#  747: 'apart',
#  748: 'academy',
#  749: 'friend!',
#  750: 'explorer',
#  751: 'heard',
#  752: 'image',
#  753: 'bon',
#  754: 'crucial',
#  755: 'discreet',
#  756: 'started',
#  757: 'been',
#  758: 'unless',
#  759: "who's",
#  760: 'grip',
#  761: 'folk',
#  762: 'throughout',
#  763: 'flowers',
#  764: 'peel',
#  765: 'estimate',
#  766: 'kitchen',
#  767: 'mmhmm',
#  768: 'loosen',
#  769: 'freaking',
#  770: 'zulu',
#  771: 'funeral',
#  772: 'exposure',
#  773: 'mole',
#  774: 'nels',
#  775: 'fence',
#  776: 'allowed',
#  777: 'hospitals',
#  778: 'lap',
#  779: 'bonus',
#  780: "dog's",
#  781: 'owned',
#  782: 'roots',
#  783: 'uniforms',
#  784: 'blow',
#  785: 'bennett',
#  786: 'excellent',
#  787: 'loser',
#  788: 'maneuver',
#  789: 'victory',
#  790: 'vital',
#  791: 'frighten',
#  792: 'rabbits',
#  793: 'eve',
#  794: 'king',
#  795: "shootin'",
#  796: 'damn',
#  797: 'will!',
#  798: 'sybok',
#  799: 'accounts',
#  800: 'swore',
#  801: 'cell',
#  802: 'discharge',
#  803: 'caswell',
#  804: 'drive',
#  805: 'leland',
#  806: 'accepting',
#  807: 'reading',
#  808: 'proposed',
#  809: 'y',
#  810: 'cheating',
#  811: 'asia',
#  812: 'persuade',
#  813: 'ten',
#  814: 'rally',
#  815: 'heller',
#  816: 'payments',
#  817: 'deemed',
#  818: 'settled',
#  819: 'laurie',
#  820: 'check',
#  821: 'damage',
#  822: 'sharp',
#  823: 'photograph',
#  824: "doin'",
#  825: 'currently',
#  826: 'humiliate',
#  827: 'bullets',
#  828: 'sitting',
#  829: 'forgetting',
#  830: 'purse',
#  831: 'hand',
#  832: 'kept',
#  833: 'rumors',
#  834: 'shhh!',
#  835: 'ones',
#  836: 'sling',
#  837: 'barbara',
#  838: 'focused',
#  839: 'comic',
#  840: 'seen',
#  841: 'self',
#  842: 'alphabet',
#  843: 'flag',
#  844: 'cannot',
#  845: 'media',
#  846: 'whats',
#  847: 'concentration',
#  848: 'fired!',
#  849: 'lucas',
#  850: 'cult',
#  851: 'pooch',
#  852: 'teaching',
#  853: 'believed',
#  854: 'mourning',
#  855: "v'ger",
#  856: 'duties',
#  857: 'secret',
#  858: 'rear',
#  859: 'ball',
#  860: 'date',
#  861: 'considerate',
#  862: 'ask',
#  863: 'there',
#  864: 'boone',
#  865: "driver's",
#  866: 'fruit',
#  867: 'modest',
#  868: 'anti',
#  869: 'programs',
#  870: 'sutphin',
#  871: "s'posed",
#  872: 'guess',
#  873: 'assholes',
#  874: 'bowler',
#  875: 'ceiling',
#  876: 'personnel',
#  877: 'butts',
#  878: 'camel',
#  879: 'becky',
#  880: 'israel',
#  881: 'tommy',
#  882: 'undressed',
#  883: 'over',
#  884: 'heap',
#  885: 'phoned',
#  886: 'bundy',
#  887: 'shock',
#  888: 'walter',
#  889: 'convict',
#  890: 'winter',
#  891: 'fired',
#  892: 'specimen',
#  893: 'sad',
#  894: 'inconvenience',
#  895: 'neighbor',
#  896: 'nicky',
#  897: 'spoiled',
#  898: 'term',
#  899: 'farms',
#  900: 'many',
#  901: "mike's",
#  902: 'appeal',
#  903: 'his',
#  904: 'phones',
#  905: 'treat',
#  906: 'se',
#  907: 'entrance',
#  908: 'seymour',
#  909: 'oughta',
#  910: 'increase',
#  911: 'downstairs',
#  912: 'granted',
#  913: 'crashed',
#  914: 'bothers',
#  915: 'bateman',
#  916: 'flame',
#  917: 'clayton',
#  918: 'extra',
#  919: 'right!',
#  920: 'thea',
#  921: 'scholarship',
#  922: 'ohh',
#  923: 'unotu',
#  924: 'slave',
#  925: 'venture',
#  926: 'nevertheless',
#  927: 'sweetie',
#  928: 'starck',
#  929: 'guessing',
#  930: 'crashes',
#  931: 'thesis',
#  932: 'suite',
#  933: 'sane',
#  934: 'reality',
#  935: 'scott',
#  936: 'thieves',
#  937: 'boost',
#  938: 'emerald',
#  939: 'shadows',
#  940: 'kidnap',
#  941: 'pumping',
#  942: 'grey',
#  943: 'holding',
#  944: 'loss',
#  945: 'pleased',
#  946: 'temperature',
#  947: 'tests',
#  948: 'shells',
#  949: 'gideon',
#  950: 't',
#  951: 'x',
#  952: 'impatient',
#  953: 'total',
#  954: 'nice',
#  955: 'schedule',
#  956: 'investment',
#  957: 'procedure',
#  958: 'irs',
#  959: 'coordinates',
#  960: 'virgin',
#  961: 'chains',
#  962: 'artillery',
#  963: 'gentlemen',
#  964: 'born',
#  965: 'mr',
#  966: 'motive',
#  967: 'breaking',
#  968: 'union',
#  969: 'sheriffs',
#  970: 'shaw',
#  971: 'benjamin',
#  972: 'outta',
#  973: 'lined',
#  974: 'exwife',
#  975: 'everything',
#  976: 'tricked',
#  977: 'bitches',
#  978: 'tee',
#  979: 'daisy',
#  980: 'suck',
#  981: 'envy',
#  982: 'sucking',
#  983: 'bid',
#  984: 'case',
#  985: 'airplane',
#  986: 'mimi',
#  987: 'carol',
#  988: 'begins',
#  989: 'sheila',
#  990: '5000',
#  991: 'several',
#  992: 'andy',
#  993: 'trade',
#  994: 'flattered',
#  995: 'nowadays',
#  996: 'fire!',
#  997: 'sunday',
#  998: 'talked',
#  999: 'babies',
#  ...}

# %% [markdown]
# # Adding the End Of String token to the end of every answer
#
# We now need to add the EOS token to end of every answer. It is very important for the decoding part of the Seq2Seq architectural implementation.
# The end of the answer is specified by the EOS token.
#
# 1. loop through all the answers in the clean_answers list, and to each of these cleaned answers append the EOS token one by one.
#
# Note: Make sure to separate the last word of each answer and the EOS token with a space

# %%
for i in range(len(clean_answers)):
    clean_answers[i] += ' <EOS>'

# %% [markdown]
# Let's have a look at the modified clean_answers list after appending the EOS token

# %%
clean_answers
# Out:
# ['well i thought we would start with pronunciation if that is okay with you <EOS>',
#  'not the hacking and gagging and spitting part  please <EOS>',
#  "okay then how 'bout we try out some french cuisine  saturday  night <EOS>",
#  'forget it <EOS>',
#  'cameron <EOS>',
#  'the thing is cameron  i am at the mercy of a particularly hideous breed of loser  my sister  i cannot date until she does <EOS>',
#  'seems like she could get a date easy enough <EOS>',
#  'unsolved mystery  she used to be really popular when she started high school then it was just like she got sick of it or something <EOS>',
#  'that is a shame <EOS>',
#  'let me see what i can do <EOS>',
#  'right  see  you are ready for the quiz <EOS>',
#  "i don't want to know how to say that though  i want to know useful things like where the good stores are  how much does champagne cost  stuff like chat  i have never in my life had to point out my head to someone <EOS>",
#  "that is because it's such a nice one <EOS>",
#  'forget french <EOS>',
#  "well there's someone i think might be  <EOS>",
#  'where <EOS>',
#  "i counted on you to help my cause you and that thug are obviously failing aren't we ever going on our date <EOS>",
#  'you are sweet <EOS>',
#  "eber's deep conditioner every two days and i never ever use a blowdryer without the diffuser attachment <EOS>",
#  'i really really really wanna go but i cannot  not unless my sister goes <EOS>',
#  "i am workin' on it but she doesn't seem to be goin' for him <EOS>",
#  'lesbian  no i found a picture of jared leto in one of her drawers so i am pretty sure she is not harboring samesex tendencies <EOS>',
#  'so that is the kind of guy she likes pretty ones <EOS>',
#  'who knows  all i have ever heard her say is that she would dip before dating a guy that smokes <EOS>',
#  'looks like things worked out tonight huh <EOS>',
#  'i believe we share an art instructor <EOS>',
#  'tons <EOS>',
#  'i was <EOS>',
#  "you never wanted to go out with 'me did you <EOS>",
#  'then that is all you had to say <EOS>',
#  'but <EOS>',
#  'you always been this selfish <EOS>',
#  'no <EOS>',
#  'what crap <EOS>',
#  'me  this endless blonde babble i am like boring myself <EOS>',
#  'thank god!  if i had to hear one more story about your coiffure <EOS>',
#  'what good stuff <EOS>',
#  'the real you <EOS>',
#  'like my fear of wearing pastels <EOS>',
#  'no <EOS>',
#  'okay  you are gonna need to learn how to lie <EOS>',
#  "let's go <EOS>",
#  'i hope so <EOS>',
#  'they do not! <EOS>',
#  'no <EOS>',
#  'you might wanna think about it <EOS>',
#  'who <EOS>',
#  'joey <EOS>',
#  'would you mind getting me a drink cameron <EOS>',
#  'is he oily or dry <EOS>',
#  "combination  i don't know  i thought he would be different  more of a gentleman <EOS>",
#  'sometimes i wonder if the guys we are supposed to want to go out with are the ones we actually want to go out with you know <EOS>',
#  'all i know is  i would give up my private line to go out with a guy like joey <EOS>',
#  "i don't have to be home 'til two <EOS>",
#  'i did <EOS>',
#  'expensive <EOS>',
#  'hopefully <EOS>',
#  'queen harry <EOS>',
#  "it's a gay cruise line but i will be like wearing a uniform and stuff <EOS>",
#  'my agent says i have got a good shot at being the prada guy next year <EOS>',
#  'hi joey <EOS>',
#  "you are concentrating awfully hard considering it's gym class <EOS>",
#  "you know the deal  i can ' t go if kat doesn't go  <EOS>",
#  'nowhere hi daddy <EOS>',
#  'can you at least start wearing a bra <EOS>',
#  'it means that gigglepuss is playing at club skunk and we are going <EOS>',
#  "oh i thought you might have a date  i don't know why i am bothering to ask but are you going to bogey lowenstein's party saturday night <EOS>",
#  'what do you think <EOS>',
#  'i think you are a freak  i think you do this to torture me  and i think you suck <EOS>',
#  'what is normal <EOS>',
#  "bogey lowenstein's party is normal but you are too busy listening to bitches who need prozac to know that <EOS>",
#  'at least i am not a clouted fen sucked hedgepig <EOS>',
#  "it's shakespeare  maybe you have heard of him <EOS>",
#  "yeah he is your freak friend mandella's boyfriend  i guess since i am not allowed to go out i should obsess over a dead guy too <EOS>",
#  'can we go now <EOS>',
#  "i really don't think i need any social advice from you right now <EOS>",
#  'you are welcome <EOS>',
#  'like you care <EOS>',
#  "i do care but i am a firm believer in doing something for your own reasons not someone else ' s  <EOS>",
#  "i wish i had that luxury i am the only sophomore that got asked to the prom and i cannot go because you won ' t <EOS>",
#  'what <EOS>',
#  'in 9th  for a month <EOS>',
#  'why <EOS>',
#  'he was like a total babe <EOS>',
#  'but you hate joey <EOS>',
#  'now i do  back then was a different story <EOS>',
#  'as in <EOS>',
#  'you did what <EOS>',
#  "just once  afterwards i told him i didn't want to anymore  i wasn't ready he got pissed  then he broke up with me <EOS>",
#  "after that i swore i would never do anything just because everyone else was doing it  and i haven't since except for bogey's party and my stunning gastrointestinal display  <EOS>",
#  "why didn't you tell me <EOS>",
#  'i wanted to let you make up your own mind about him <EOS>',
#  "no you didn't!  if you really thought i could make my own decisions you would have let me go out with him instead of helping daddy hold me hostage <EOS>",
#  'i am not stupid enough to repeat your mistakes <EOS>',
#  'i guess i thought i was protecting you <EOS>',
#  'god you are just like him! just keep me locked away in the dark so i cannot experience anything for myself <EOS>',
#  'not all experiences are good bianca you cannot always trust the people you want to <EOS>',
#  'i guess i will never know will i <EOS>',
#  'so did you <EOS>',
#  'you set me up <EOS>',
#  'i just wanted  <EOS>',
#  'what to completely damage me  to send me to therapy forever what <EOS>',
#  'no! i just wanted <EOS>',
#  "it's just you <EOS>",
#  'perm <EOS>',
#  'no! you are not dating until your sister starts dating  end of discussion <EOS>',
#  'what if she never starts dating <EOS>',
#  'then neither will you  and i will get to sleep at night <EOS>',
#  "but it's not fair  she is a mutant daddy! <EOS>",
#  'exactly my point <EOS>',
#  'and where are you going <EOS>',
#  'if you must know we were attempting to go to a small study group of friends <EOS>',
#  'otherwise known as an orgy <EOS>',
#  "it's just a party daddy but i knew you would forbid me to go since gloria steinem over there isn't going  <EOS>",
#  "if kat's not going you are not going <EOS>",
#  "it's just a party daddy <EOS>",
#  'daddy no! <EOS>',
#  'just for a minute <EOS>',
#  'why <EOS>',
#  'because she will scare them away <EOS>',
#  'the prom  kat has a date <EOS>',
#  'no but <EOS>',
#  "it's that hot rod joey right that ' s who you want me to bend my rules for <EOS>",
#  'he is not a hot rod  whatever that is <EOS>',
#  'you are not going unless your sister goes  end of story <EOS>',
#  'fine  i see that i am a prisoner in my own house  i am not a daughter i am a possession! <EOS>',
#  "i have a date daddy  and he ' s not a captain of oppression like some men we know <EOS>",
#  "didn't have you pegged for a gigglepuss fan  aren't they a little too preteen bellybutton ring for you <EOS>",
#  'fan of a fan  you see a couple of minors come in <EOS>',
#  'never <EOS>',
#  'padua girls  one tall decent body the other one kinda short and undersexed <EOS>',
#  "just sent 'em through <EOS>",
#  'so they tell me <EOS>',
#  "c'mon  i am supposed to give you the tour <EOS>",
#  'north actually  how would you    <EOS>',
#  'i was kidding people actually live there <EOS>',
#  'yeah  a couple  we are outnumbered by the cows though <EOS>',
#  'how many people were in your old school <EOS>',
#  'thirtytwo <EOS>',
#  'get out! <EOS>',
#  'how many people go here <EOS>',
#  'couple thousand most of them evil <EOS>',
#  'yeah but these guys have never seen a horse  they just jack off to clint eastwood <EOS>',
#  'you burn you pine you perish <EOS>',
#  'who is she <EOS>',
#  "bianca stratford  sophomore don't even think about it <EOS>",
#  'why not <EOS>',
#  "i could start with your haircut but it doesn't matter  she is not allowed to date until her older sister does  and that is an impossibility <EOS>",
#  'because they are bred to  their mothers liked guys like that and their grandmothers before them their gene pool is rarely diluted <EOS>',
#  'he always have that shiteating grin <EOS>',
#  'joey dorsey  permashitgrin  i wish i could say he is a moron but he is number twelve in the class  and a model  mostly regional stuff but he is rumored to have a big tube sock ad coming out <EOS>',
#  "sure do  my mom's from canada <EOS>",
#  'guess who just signed up for a tutor <EOS>',
#  'you mean i would get a chance to talk to her <EOS>',
#  'you could consecrate with her my friend <EOS>',
#  "that is her  bianca's sister <EOS>",
#  'the mewling rampalian wretch herself <EOS>',
#  'unlikely but even so she still cannot go out with you  so what is the point <EOS>',
#  'you wanna go out with him <EOS>',
#  'he seems like he thrives on danger <EOS>',
#  'no kidding  he is a criminal  i heard he lit a state trooper on fire  he just got out of alcatraz <EOS>',
#  'they always let felons sit in on honors biology <EOS>',
#  'i am serious man he is whacked  he sold his own liver on the black market so he could buy new speakers <EOS>',
#  'forget his reputation  do you think we have got a plan or not <EOS>',
#  'did she actually say she would go out with you <EOS>',
#  'that is what i just said <EOS>',
#  'i thought you hated those people <EOS>',
#  'hey  i have gotta have a few clients when i get to wall street <EOS>',
#  'like we had a choice  besides  when you let the enemy think he is orchestrating the battle you are in a position of power we let him pretend he is calling the shots and while he is busy setting up the plan you have time to woo bianca <EOS>',
#  'in that case we will need to make it a schoolwide blow out <EOS>',
#  'will bogey get bent <EOS>',
#  'are you kidding  he will piss himself with joy  he is the ultimate kiss ass <EOS>',
#  "it's a lung cancer issue <EOS>",
#  'her favorite uncle <EOS>',
#  'dead at fortyone <EOS>',
#  "okay!  i wasn't sure <EOS>",
#  "it's her favorite band <EOS>",
#  'hell i have just been going over the whole thing in my head and  <EOS>',
#  "the hell is that  what kind of 'guy just picks up a girl and carries her away while you are talking to her <EOS>",
#  'buttholus extremus  but hey you are making progress <EOS>',
#  "no i ' m not <EOS>",
#  'best case scenario you are back on the payroll for awhile <EOS>',
#  'yeah  we will see <EOS>',
#  'i have retrieved certain pieces of information on miss katarina stratford i think you will find helpful <EOS>',
#  'so what does that give me  i am supposed to buy her some noodles and a book and sit around listening to chicks who cannot play their instruments <EOS>',
#  "don't make me do it man <EOS>",
#  "it's off the whole thing <EOS>",
#  'she is partial to joey not me <EOS>',
#  'sure <EOS>',
#  'then go get her <EOS>',
#  "i don ' t know  i decided not to nail her when she was too drunk to remember it <EOS>",
#  'she just needs time to cool off i will give it a day <EOS>',
#  'she kissed me <EOS>',
#  'where <EOS>',
#  'you get the girl <EOS>',
#  'yeah and i noticed the only part of you featured in your big kmart spread was your elbow  tough break <EOS>',
#  'they are running the rest of me next month <EOS>',
#  'not at all <EOS>',
#  'away <EOS>',
#  'your sister here <EOS>',
#  'and why would i do that <EOS>',
#  'what do you think <EOS>',
#  'yeah whatever  i want you to go out with her <EOS>',
#  'sure sparky  i will get right on it <EOS>',
#  'you just said <EOS>',
#  'you need money to take a girl out <EOS>',
#  'but you would go out with her if you had the cake <EOS>',
#  'you are gonna pay me to take out some girl <EOS>',
#  "i cannot date her sister until that one gets a boyfriend  and that is the catch she doesn't want a boyfriend <EOS>",
#  'how much <EOS>',
#  'fine thirty <EOS>',
#  'fifty and you have got your man <EOS>',
#  'i am on it <EOS>',
#  "watching the bitch trash my car doesn't count as a date <EOS>",
#  'i got her under control she just acts crazed in public to keep up the image <EOS>',
#  'what <EOS>',
#  'a hundred bucks a date <EOS>',
#  'forget it <EOS>',
#  'forget her sister then <EOS>',
#  "a deal's a deal <EOS>",
#  'do what <EOS>',
#  'get her to act like a human <EOS>',
#  "enough with the barbie n' ken shit i know <EOS>",
#  'are you lost <EOS>',
#  'nope  just came by to chat <EOS>',
#  "we don't chat <EOS>",
#  'well actually i thought i would run an idea by you  you know just to see if you are interested <EOS>',
#  'we are not <EOS>',
#  'does this conversation have a purpose <EOS>',
#  "so what you need to do is recruit a guy who will go out with her  someone who's up for the job <EOS>",
#  'uh  yeah  we are old friend* <EOS>',
#  'you and verona <EOS>',
#  'what  we took bathes together when we were kids <EOS>',
#  "hey  it's all for the higher good right <EOS>",
#  'patrick verona   random skid <EOS>',
#  'that is pat verona the one who was gone for a year i heard he was doing porn movies <EOS>',
#  'i am sure he is completely incapable of doing anything that interesting <EOS>',
#  'he always look so <EOS>',
#  'block e <EOS>',
#  'just a little <EOS>',
#  'an attempted slit <EOS>',
#  'but imagine the things he would say during sex <EOS>',
#  'you could always go with me  i am sure william has some friends <EOS>',
#  'william would never have gone to a state school <EOS>',
#  "william didn't even go to high school <EOS>",
#  'that is never been proven <EOS>',
#  'neither has his heterosexuality <EOS>',
#  'does it matter <EOS>',
#  "if i was bianca it would be any school you want precious  don't forget your tiara <EOS>",
#  'no fear <EOS>',
#  'who cares <EOS>',
#  "i didn't have a choice <EOS>",
#  "you didn't have a choice  where is kat and what have you done with her <EOS>",
#  'i did bianca a favor and it backfired <EOS>',
#  "you didn't <EOS>",
#  'i got drunk  i puked  i got rejected it was big fun <EOS>',
#  "well i guess we are not since we don't have dates  <EOS>",
#  'listen to you!  you sound like betty all pissed off because archie is taking veronica <EOS>',
#  "okay okay we will not go  it's not like i have a dress anyway <EOS>",
#  "you ' re looking at this from the wrong perspective  we are making a statement <EOS>",
#  'oh good  something new and different for us <EOS>',
#  'who <EOS>',
#  'william  he asked me to meet him here <EOS>',
#  "oh honey  tell me we haven't' progressed to fullon hallucinations <EOS>",
#  'sweating like a pig actually  and yourself <EOS>',
#  "there's a way to get a guy's attention <EOS>",
#  'my mission in life <EOS>',
#  'oh right  friday <EOS>',
#  'like where  the 7eleven on burnside do you even know my name screwboy <EOS>',
#  'i know a lot more than that <EOS>',
#  "i don't really think you warrant that strong an emotion <EOS>",
#  'then say you will spend dollar night at the track with me <EOS>',
#  'and why would i do that <EOS>',
#  'come on  the ponies the flat beer you with money in your eyes me with my hand on your ass <EOS>',
#  'you  covered in my vomit <EOS>',
#  'seventhirty <EOS>',
#  'i was in the laundromat i saw your car thought i would say hi <EOS>',
#  'hi <EOS>',
#  "depends on the topic my fenders don't really whip me into a verbal frenzy <EOS>",
#  ' <EOS>',
#  "that is what you want isn't it <EOS>",
#  'do you mind  you are sort of ruining it for me <EOS>',
#  'you know who the raincoats are <EOS>',
#  "why don't you <EOS>",
#  "i am getting trashed man isn't that what you are supposed to do at a party <EOS>",
#  'i say do what you wanna do <EOS>',
#  'funny you are the only one <EOS>',
#  'i am fine i am <EOS>',
#  'i just need to lie down for awhile <EOS>',
#  'uh uh you lie down and you will go to sleep <EOS>',
#  'i know just let me sleep <EOS>',
#  'what if you have a concussion my dog went to sleep with a concussion and woke up a vegetable not that i could tell the difference <EOS>',
#  'leave it to you to use big words when you are shitfaced <EOS>',
#  'why  are you doing this <EOS>',
#  'i told you <EOS>',
#  "you don't care if i die <EOS>",
#  'sure i do <EOS>',
#  'why <EOS>',
#  'because then i would have to start taking out girls who like me <EOS>',
#  'like you could find one <EOS>',
#  'see that  who needs affection when i have got blind hatred <EOS>',
#  'just let me sit down <EOS>',
#  'who <EOS>',
#  'dorsey <EOS>',
#  'i hate him <EOS>',
#  "i know  it would have to be a pretty big deal to get you to mainline tequila you don't seem like the type <EOS>",
#  "hey man    you don ' t think i can be cool  you don't think i can be laid back like everyone else <EOS>",
#  'i thought you were above all that <EOS>',
#  'you know what they say <EOS>',
#  'what <EOS>',
#  "but it's gigglepuss  i know you like them  i saw you there <EOS>",
#  'busy <EOS>',
#  'were you in jail <EOS>',
#  'maybe <EOS>',
#  "no you weren't <EOS>",
#  'then why would you ask <EOS>',
#  'why would you lie <EOS>',
#  'do what <EOS>',
#  'this <EOS>',
#  "my father wouldn't approve of that that <EOS>",
#  "you don't strike me as the type that would ask permission <EOS>",
#  "i am gettin' there <EOS>",
#  'he just wants me to be someone i am not <EOS>',
#  'who <EOS>',
#  'bianca <EOS>',
#  'no offense but you are sister is without  i know everyone likes her and all but  <EOS>',
#  'what are you doing here <EOS>',
#  'i heard there was a poetry reading <EOS>',
#  'you  are so  <EOS>',
#  'pleasant <EOS>',
#  'unwelcome <EOS>',
#  'unwelcome  i guess someone still has her panties in a twist <EOS>',
#  "don't for one minute think that you had any effect whatsoever on my panties <EOS>",
#  'so what did i have an effect on  <EOS>',
#  'other than my upchuck reflex nothing <EOS>',
#  'look up sunshine <EOS>',
#  "c'mon  it's not that bad <EOS>",
#  "try lookin' at it from this angle <EOS>",
#  "forget it  i am stayin' <EOS>",
#  'you want me to climb up and show you how to get down <EOS>',
#  'maybe <EOS>',
#  'i figured it had to be something ridiculous to win your respect  and piss you off <EOS>',
#  'good call <EOS>',
#  'so how would you get chapin to look the other way <EOS>',
#  'i dazzled him with my wit <EOS>',
#  "yeah well don't let it get out <EOS>",
#  'so what is your excuse <EOS>',
#  'acting the way we do <EOS>',
#  'yes <EOS>',
#  "i don't like to do what people expect then they expect it all the time and they get disappointed when you change <EOS>",
#  'so if you disappoint them from the start you are covered <EOS>',
#  'something like that <EOS>',
#  'then you screwed up <EOS>',
#  'how <EOS>',
#  'you never disappointed me <EOS>',
#  'for    <EOS>',
#  'fallacy <EOS>',
#  'the duck <EOS>',
#  'hearsay <EOS>',
#  "i know the porn career's a lie <EOS>",
#  'i hate peas <EOS>',
#  'no  something real  something no one else knows <EOS>',
#  'you are sweet  and sexy  and completely hot for me <EOS>',
#  'what <EOS>',
#  'no one else knows <EOS>',
#  'you are amazingly selfassured has anyone ever told you that <EOS>',
#  'go to the prom with me <EOS>',
#  'you know what i mean <EOS>',
#  'no <EOS>',
#  'no what <EOS>',
#  'no i will not go with you <EOS>',
#  'why not <EOS>',
#  "because i don't want to it's a stupid tradition <EOS>",
#  'so i have to have a motive to be with you <EOS>',
#  'you tell me <EOS>',
#  'you need therapy  has anyone ever told you that <EOS>',
#  'answer the question patrick <EOS>',
#  "nothing!  there's nothing in it for me just the pleasure of your company <EOS>",
#  "it's scurvy's  his date got convicted where would you get the dress <EOS>",
#  "it's just something i had  you know <EOS>",
#  'oh huh <EOS>',
#  'look i am   sorry  that i questioned your motives  i was wrong <EOS>',
#  'what <EOS>',
#  "that is where i was last year  she would never lived alone  my grandfather died  i stayed with her  i wasn't in jail i don't know marilyn manson and i have never slept with a spice girl  i spent a year sitting next to my grandma on the couch watching wheel of fortune  end of story <EOS>",
#  'it gets worse  you still have your freshman yearbook <EOS>',
#  'you were paid to take me out!  by  the one person i truly hate  i knew it was a setup! <EOS>',
#  "it wasn't like that <EOS>",
#  'really  what was it like  a down payment now then a bonus for sleeping with me <EOS>',
#  "i didn't care about the money <EOS>",
#  'i thought you could use it when you start your band <EOS>',
#  'is that right <EOS>',
#  'yeah but then i fucked up i fell for her <EOS>',
#  'because i like to torture you <EOS>',
#  'oh bianca  can you get me my freshman yearbook <EOS>',
#  "don ' t you even dare   <EOS>",
#  'i thought we decided you were going to school here  at u of 0 <EOS>',
#  'you decided <EOS>',
#  'enough! <EOS>',
#  'then tell them i had a seizure <EOS>',
#  'is this about sarah lawrence you punishing me <EOS>',
#  'i thought you were punishing me <EOS>',
#  'why cannot we agree on this <EOS>',
#  'because you are making decisions for me <EOS>',
#  'as a parent that is my right <EOS>',
#  "so what i want doesn't matter <EOS>",
#  "you are eighteen  you don't know what you want  you will not know until you are fortyfive and you don't have it <EOS>",
#  'i want to go to an east coast school! i want you to trust me to make my own choices  i want  <EOS>',
#  'yeah  she left with some bikers big ones  full of sperm <EOS>',
#  'funny <EOS>',
#  'no daddy <EOS>',
#  'so tell me about this dance was it fun <EOS>',
#  'parts of it <EOS>',
#  'which parts <EOS>',
#  'the part where bianca beat the hell out of some guy <EOS>',
#  'bianca did what <EOS>',
#  'what is the matter  upset that i rubbed off on her <EOS>',
#  'no  impressed <EOS>',
#  'when i go <EOS>',
#  "oh christ  don't tell me you have changed your mind  i already sent 'em a check <EOS>",
#  'expressing my opinion is not a terrorist action <EOS>',
#  "well yes compared to your other choices of expression this year today's events are quite mild  by the way bobby rictor's gonad retrieval operation went quite well in case you are interested <EOS>",
#  'i still maintain that he kicked himself in the balls  i was merely a spectator <EOS>',
#  'the point is kat  people perceive you as somewhat  <EOS>',
#  'no  i believe heinous bitch is the term used most often <EOS>',
#  'just smack her now <EOS>',
#  'hi <EOS>',
#  'cool pictures  you a fan <EOS>',
#  'yeah  i guess <EOS>',
#  'oh yeah <EOS>',
#  'right <EOS>',
#  'kat a fan too <EOS>',
#  'yeah <EOS>',
#  'what <EOS>',
#  "whatever the hell it is you are standin' there waitin' to say <EOS>",
#  'the situation is my man cameron here has a major jones for bianca stratford <EOS>',
#  'what is it with this chick  she have three tits <EOS>',
#  'dorsey can plow whoever he wants i am just in this for the cash <EOS>',
#  'so dorsey can get the girl <EOS>',
#  "patrick pat you are not looking at the big picture  joey's just a pawn we set this whole thing up so cameron can get the girl <EOS>",
#  'we are your guys <EOS>',
#  'good enough <EOS>',
#  'just for now <EOS>',
#  'yeah <EOS>',
#  "i am likin' you guys better <EOS>",
#  "no  i have got a sweetpayin' job that i am about to lose <EOS>",
#  'sweet love renew thy force! <EOS>',
#  "man  don't say shit like that to  me people can hear you <EOS>",
#  'it says here you exposed yourself to a group of freshmen girls <EOS>',
#  'it was a bratwurst  i was eating lunch <EOS>',
#  'with the teeth of your zipper <EOS>',
#  'touch of the flu <EOS>',
#  'i am at a loss then  what should we talk about your year of absence <EOS>',
#  'what is to discuss <EOS>',
#  "you weren't abused you aren't stupid and as far as i can tell you are only slightly psychotic  so why is it that you are such a fuckup <EOS>",
#  "well you know  there's the prestige of the job title and the benefits package is pretty good <EOS>",
#  'see you next week! <EOS>',
#  'make anyone cry today <EOS>',
#  'sarah lawrence is on the other side of the country <EOS>',
#  'tumescent! <EOS>',
#  'you are not helping <EOS>',
#  'pirate  no question <EOS>',
#  "kissing  is that what you think happens  kissing isn't what keeps me up to my elbows in placenta all day <EOS>",
#  'dr ruth <EOS>',
#  'but  who  what  <EOS>',
#  'your daughters went to the prom <EOS>',
#  'did i have anything to say about it <EOS>',
#  'absolutely not <EOS>',
#  "that ' s what i thought <EOS>",
#  "the water's going putrid in the barrels <EOS>",
#  'you will be drinking your own piss for the glory of spain and admiral colon!  bastard! <EOS>',
#  'ah leave him alone  he is doing no harm <EOS>',
#  "with a face like that  i don't want you looking at me  you hear <EOS>",
#  'we will all go crazy <EOS>',
#  'we left three weeks ago alonso cannot be that near <EOS>',
#  "cannot be that far i say  also i don't like the smell of the sea around here  smells like a cunt bad sign <EOS>",
#  'yes your eminence  the voyage should not take more than six or seven weeks <EOS>',
#  'unfortunately don colon that is precisely where our opinions differ  are you familiar with the work of aristotle  erathostene  ptolemeus <EOS>',
#  'i am your eminence <EOS>',
#  'then you cannot ignore that according to their calculations the circumference of the earth is approximately  22000 leagues or more  which makes the ocean uncrossable <EOS>',
#  'excellency you are right <EOS>',
#  'your life and that of others! <EOS>',
#  'if they agree to follow me yes <EOS>',
#  'is that all that interests you gold <EOS>',
#  'no  the portuguese have already discovered blackskinned people  i too will find other populations  and bring them to the word of god <EOS>',
#  "did he not choose a carpenter's son to reveal himself to the world <EOS>",
#  'blind faith is what i consider heresy! <EOS>',
#  'ifgodwillsit! <EOS>',
#  'the judgment is ours! <EOS>',
#  'naturally  but i would really deplore the loss of such a potential opportunity for spain for a dispute over a point of geography <EOS>',
#  'indeed  the world is full of mercenaries  and states often make use of them when it benefits them  my only concern is the welfare and prosperity of spain <EOS>',
#  'on the contrary your eminence  it seems to me the man is preparing his own cross <EOS>',
#  'what a tragedy what a waste of a life <EOS>',
#  'a waste  let me tell you something arojaz  if your name or mine is ever remembered  it will only be because of his <EOS>',
#  'i know <EOS>',
#  "i haven't given you much of a life <EOS>",
#  "well that is true  i have a child by a man who will not marry me!  who's always leaving <EOS>",
#  'are we going to argue <EOS>',
#  'i would love to argue with you sometimes  but you are never here! <EOS>',
#  'i find that hard to believe <EOS>',
#  'thank god <EOS>',
#  "i don't want you to wait for me <EOS>",
#  'that is something you cannot decide <EOS>',
#  "you don't usually ask <EOS>",
#  'i can arrange for the queen to take fernando and diego into her service <EOS>',
#  "they tried but i didn't let them <EOS>",
#  "not everything do you think i care  i am a free man again  riches don't make a man rich they only make him busier <EOS>",
#  'i am busy inside <EOS>',
#  "i cannot keep my eyes off you  i would like to catch up with all the moments i didn't spend with you <EOS>",
#  'forgive me don bobadilla  those positions have already been taken <EOS>',
#  'may i ask by whom <EOS>',
#  'bartolome and giacomo colon <EOS>',
#  'yes i remember <EOS>',
#  'appointment to what <EOS>',
#  'viceroy of the west indies <EOS>',
#  'congratulations  then i am free to search for the mainland <EOS>',
#  'i am not a seaman  but i heard it is no more than a week at sea  i hope you are not too disappointed <EOS>',
#  'how could i be  the mainland has been found  exactly as i said it would <EOS>',
#  'i am afraid this is not the worst news <EOS>',
#  'there will be a time <EOS>',
#  'you promise  do you swear on st christopher <EOS>',
#  'yes yes i do on all of them! <EOS>',
#  'this time with me! <EOS>',
#  'not bad <EOS>',
#  'there must be a passage to that other ocean <EOS>',
#  'i am not listening father  but i cannot help hearing <EOS>',
#  'he asks when he can come to visit you  he left his address <EOS>',
#  'he never had one except aboard my ships! <EOS>',
#  "really  god i wouldn't know where to start and yet <EOS>",
#  'tell me the first thing that comes to your mind <EOS>',
#  'no <EOS>',
#  'no!  i have waited too long fought too hard  now you expect me to take all the risks while you take the profit!  no i will not be your servant! <EOS>',
#  'i am not bargaining! <EOS>',
#  'then you are too ambitious <EOS>',
#  'if you will not accept our proposal we will simply find someone who will <EOS>',
#  'forgive me don colon  but what about gold <EOS>',
#  ' for a commoner <EOS>',
#  'don bobadilla is already a judge my dear don cristobal <EOS>',
#  'good!  we are also in need of judges  except there are no thieves! <EOS>',
#  'what  do i have so many already <EOS>',
#  'to rise so high in so short a time is a dangerous occupation  a little hypocrisy goes a long way <EOS>',
#  'call them <EOS>',
#  'look out of that window <EOS>',
#  'roofs towers palaces spires <EOS>',
#  'all of them created by people like me <EOS>',
#  'what is it  a tribe  an island <EOS>',
#  'island  far <EOS>',
#  'tell the chief we thank him <EOS>',
#  'chief knows <EOS>',
#  'tell him his country is very beautiful  tell him we are leaving men here  to build a fort <EOS>',
#  'thousands <EOS>',
#  'why <EOS>',
#  'chief says  he has a god <EOS>',
#  ' and also to bring medicine <EOS>',
#  'chief says <EOS>',
#  'he has medicine  tell him we admire his people <EOS>',
#  'he understands <EOS>',
#  'ask him if he will help <EOS>',
#  'you did the same to your god! <EOS>',
#  'you never learned how to speak my language <EOS>',
#  'father i am doing what i think is the best for him  and he has the teacher i would have chosen for myself <EOS>',
#  'that is what it says <EOS>',
#  'how did you manage it <EOS>',
#  'with some difficulty  i had to promise them you were not a total fool <EOS>',
#  'to open a new route to asia  at the moment there are only two ways of reaching it <EOS>',
#  'ignorance!  i believe the indies are no more than 750 leagues west of the canary islands <EOS>',
#  'how can you be so certain <EOS>',
#  'the calculations of toscanelli marin de tyr esdras <EOS>',
#  'esdras is a jew <EOS>',
#  'so was christ! <EOS>',
#  'i will try to remember that marchena <EOS>',
#  'father marchena! <EOS>',
#  'passion is something one cannot control! <EOS>',
#  'you get so carried away when you are being contradicted! <EOS>',
#  'i have been contradicted all my life eternity! <EOS>',
#  'only god knows the meaning of such words my son <EOS>',
#  'wait!  i have waited seven years already!  how much longer do you want me to wait <EOS>',
#  'if god intends you to go then you will go <EOS>',
#  'damn god! <EOS>',
#  'damn all of you!  you all set up theories based on what  you never leave the safety of your studies! go out!  find out what the world is about and then tell me something i can listen to! <EOS>',
#  "colon!  don't! <EOS>",
#  'forgive me father  for i have sinned <EOS>',
#  'father i have betrayed my family i betrayed my men  and i betrayed you <EOS>',
#  'what are you saying <EOS>',
#  'i lied  the journey will be longer than i said <EOS>',
#  'how long <EOS>',
#  'i am not sure it could be twice the distance <EOS>',
#  'if i tell them they will not follow me  you know that i am right father  you trust me <EOS>',
#  "my son my son  your certitudes are sometimes frightening  christopher you must speak to them and if you don't i will <EOS>",
#  'you are bound by an oath father <EOS>',
#  'give me absolution <EOS>',
#  'you will always be older than me father <EOS>',
#  'i knew you would <EOS>',
#  'new worlds create new people <EOS>',
#  'oh  so you are a new man <EOS>',
#  "i don't know i have the impression that i didn't change that much  i still cannot accept the world as it is! <EOS>",
#  'no more than the woman who said she would take granada from the moors <EOS>',
#  'what did they say about granada before today <EOS>',
#  'that she was impregnable <EOS>',
#  'surely you can do anything you want <EOS>',
#  'you show no inclination to speak otherwise! <EOS>',
#  "i know what i see  i see someone who doesn't accept the world as it is  who's not afraid  i see a women who thinks what if <EOS>",
#  'a woman <EOS>',
#  'thirty seven your majesty and you <EOS>',
#  'they come and go as naked as the day god created them <EOS>',
#  'thank you <EOS>',
#  'there is one thing i would like to understand why do you want to go back after all this <EOS>',
#  'your majesty  some men are content to read about things  i must see them with my own eyes  i cannot be other than i am <EOS>',
#  'the indians have no such word don moxica <EOS>',
#  'if you want to keep your head on your shoulders you will do as i say <EOS>',
#  "we don't need to know <EOS>",
#  'we came here to stay!  to build! not to start a crusade  in this forest there is enough danger to sweep us away in days!  so we will be brave and swallow our grief  and in the name of those who died we will accomplish what we came for <EOS>',
#  "my horse doesn't work <EOS>",
#  'you did not hear me don colon  not my horse <EOS>',
#  'savagery is what monkeys understand <EOS>',
#  'you will be held in detention deprived of your privileges and possessions  until you are returned to spain where you will be judged have you anything to say <EOS>',
#  'you will regret this <EOS>',
#  'god be with us admiral <EOS>',
#  'and what do you think mendez <EOS>',
#  'well i surely know what a quadrant is!  but i have never seen it used at night before <EOS>',
#  'come over here <EOS>',
#  'twenty eight <EOS>',
#  'he is drawing an isthmus he is saying we are on an isthmus <EOS>',
#  'we cannot be <EOS>',
#  'immediately <EOS>',
#  'six days ago yes <EOS>',
#  'you must be mad! <EOS>',
#  'we have to keep the hopes of these men alive! <EOS>',
#  'we are on the verge of a mutiny colon! <EOS>',
#  "you think i don't know that <EOS>",
#  'we are lost! <EOS>',
#  'the land is there  i know it! <EOS>',
#  "you don't know anything!  listen colon these are my ships right so i am telling you we are turning back! <EOS>",
#  'and then what  half of the water has gone the rest is nearly putrid! you know that! <EOS>',
#  'jesus maria!  i should have never listened to you! <EOS>',
#  'you never did  you did all the talking for both of us remember <EOS>',
#  'you bloody <EOS>',
#  'pinzon pinzon all we can do now is go forward!  think about that! <EOS>',
#  'you tell that to them! <EOS>',
#  'you are right  let the men decide <EOS>',
#  'yes your majesty <EOS>',
#  'never your majesty  although <EOS>',
#  "yes  it would be a pity wouldn't it  call him back! <EOS>",
#  "we weren't expecting immediate profits were we  we must have faith  we must give time for time <EOS>",
#  'is this true brother buyl <EOS>',
#  'he must be replaced <EOS>',
#  'and who would you think of for such a task <EOS>',
#  'then why <EOS>',
#  'because he is not afraid of me <EOS>',
#  'i am not your lawyer until i see the money <EOS>',
#  'here  i have your money <EOS>',
#  'emil  take it easy  stay with me  sit down  what do you need  what are you looking for <EOS>',
#  'he has the camera!  he took the movie! <EOS>',
#  'where are we going <EOS>',
#  'i am coming with you <EOS>',
#  'yes  yes come with me! <EOS>',
#  'i am invoking rights  this man is represented by counsel  i am coming with him <EOS>',
#  'you bring the cigarettes <EOS>',
#  'oh sure <EOS>',
#  'i was all of these <EOS>',
#  "well you didn't appreciate the severity of it until recently  no question about that <EOS>",
#  'what about oleg <EOS>',
#  'disappeared  they are looking everywhere  maybe he went back to czechoslovakia <EOS>',
#  'no he is here  shit <EOS>',
#  "don't worry about him  think about yourself <EOS>",
#  'what about my movie rights  book rights <EOS>',
#  "look i haven't really focused on that kind of thing <EOS>",
#  'what is your cut  how much <EOS>',
#  'i would sayhalf  half is fair <EOS>',
#  'no  no way <EOS>',
#  "but it's <EOS>",
#  "thirtypercent  no more  or i call another lawyer  this is the biggest case of your life  don't try to negotiate  thirty percent  say yes or no <EOS>",
#  'this is not about money emil  i need your trust in me <EOS>',
#  'what else do you need <EOS>',
#  'i need to know about your background  i need to know about your upbringing  why you are here <EOS>',
#  'give me another one please <EOS>',
#  'my father always degraded me  killed my selfesteem  and my mother was blind <EOS>',
#  'your mother was blind <EOS>',
#  'yeah she went blind giving birth to me she went to fucking black market doctor to induce me <EOS>',
#  'back in the czech republic <EOS>',
#  'yeah yeahbad doctor gave her bad drugs which made her go blind  and my father blamed me for her blindness <EOS>',
#  "your father blamed you for your mother's blindness <EOS>",
#  'yeah he hated me from day when i was born  put it out  can you put the cigarette out <EOS>',
#  'your father put cigarettes out on you <EOS>',
#  'out on my back when i was a small boy <EOS>',
#  'can i see your back <EOS>',
#  "i don't think it's abuse i think it's torture <EOS>",
#  "officers there's your killer do your duty arrest him! <EOS>",
#  'alright  that is a justifiable homicide <EOS>',
#  'yes but he was a cop <EOS>',
#  'if you cooperate with the da  maybe they will help you with your situation <EOS>',
#  "i will if they don't send me back <EOS>",
#  'they will not until this is over <EOS>',
#  'divorced <EOS>',
#  'do you live alone  i have been in these clothes sincethe killings  could we stop at your place i could take a showerbefore i go into custody <EOS>',
#  'somewhere else <EOS>',
#  'sothe station is empty <EOS>',
#  'yeah  this way <EOS>',
#  'yes i considered it <EOS>',
#  'did you ever turn tricks before <EOS>',
#  'no <EOS>',
#  'what about back home <EOS>',
#  'no <EOS>',
#  'so you were never a prostitute <EOS>',
#  'what are you asking me <EOS>',
#  'i am just trying to find out who you are <EOS>',
#  'i know <EOS>',
#  "you don't know  i am sorry  i was desperate  that is not me  i shot a cop  can you imagine what they will do to me when i got to prison <EOS>",
#  'they are not gonna send you right back <EOS>',
#  "i am sorry  i didn't mean toi am glad actually i am glad it's over  all this time  hiding  never being able to look anyone in the eyes always afraid that someone would find out who i was  never trusting anyone <EOS>",
#  "i still cannot believe eddie's gone <EOS>",
#  'i am sorry <EOS>',
#  'ludwig  he is gay  are you jealous <EOS>',
#  'if i was your boyfriend i might be <EOS>',
#  "if you were my boyfriend i would suggest you find another girlfriend that isn't going to jail tenthousand miles away <EOS>",
#  'no matter what happensi am glad i met you <EOS>',
#  'i am glad i met you <EOS>',
#  'right <EOS>',
#  'in the kitchen <EOS>',
#  'i will make some for us <EOS>',
#  'i will get my clothes <EOS>',
#  'pouring it out! <EOS>',
#  'do you really want me to forget about you <EOS>',
#  "i don't want to drag you down with me <EOS>",
#  'daphne i <EOS>',
#  "c'mon start at the beginning  you know these people <EOS>",
#  'tamina was a friend of mine  my shower was broken she let me use theirs <EOS>',
#  'go on <EOS>',
#  'if i tell you will you arrest me <EOS>',
#  'arrest you for what  why would we arrest you <EOS>',
#  "no no don't talk to immigration! <EOS>",
#  'i am from a small town in slovakia  like the south here  the police is right a civilian is wrong  so i fled <EOS>',
#  'look we can help you but right now we have to deal with what is happening here tell us the truthis that the truth <EOS>',
#  'you are a cop  you will never believe me <EOS>',
#  'it was my decision not his <EOS>',
#  'well i am the deputy chief fire marshall and every now and then i would like to be included in decisions <EOS>',
#  'look after jordy briefs me you can do the press conference  how about that the case is all yours <EOS>',
#  'oh yeah  alright <EOS>',
#  'i am ready to be briefed  excuse us <EOS>',
#  'yeah sure  beep me when you are ready for the press conference <EOS>',
#  'who do you think chief! <EOS>',
#  "then why didn't you talk to the reporter <EOS>",
#  "'cause we got more important things to do like finding out who did it <EOS>",
#  "i came to see how the investigation was going  i called and you are not here  i wait up at the station and you don't even show up!!!  i beep you  you don't return my call  where the hell have you been! <EOS>",
#  "what do you mean 'cleaned up' <EOS>",
#  'i let her take a shower <EOS>',
#  'a shower!  did you take one too <EOS>',
#  'no!  nothing happened <EOS>',
#  "oh really  that is nice  you took a homicide witness to take a shower after your partner was shot  are you out of your fucking mind  are you having that much trouble gettin' dates! <EOS>",
#  'okay  but not water sports <EOS>',
#  'what was i supposed to do  the guy tried to mug me  i was gonna send a cop back  i just forgot <EOS>',
#  'forgot  you handcuffed a civilian to a tree! <EOS>',
#  'chief  i know i screwed up  but this guy was no innocent civilian <EOS>',
#  'well this is gonna end your career and probably mine <EOS>',
#  'end my career <EOS>',
#  "how are you going to fight this  maybe if oleg hadn't gotten away and you would been on the front page as a hero this thing would be easier to fight  you would have the good to weight against the bad! it's unfortunate that i have to make decisions based upon your press coverage but there's nothing i can do!  gimme your shield <EOS>",
#  'but chief  over this <EOS>',
#  "there's nothing to talk about  get a good lawyer  you are suspended until your trial <EOS>",
#  'yeah right <EOS>',
#  'what was that korfin <EOS>',
#  "i said yeah you are right chief  as soon as we get somethin' we will let you alert the media <EOS>",
#  "you do that wiseguy  now let's solve this thing before eddie flemming does <EOS>",
#  'yeah  he finished awhile ago <EOS>',
#  'alright  swing by her apartment  let her pick up her clothes and take her straight to hoover street  you got that <EOS>',
#  'yeah <EOS>',
#  'vodka tonic <EOS>',
#  'maybe you could just put in a shot of martell <EOS>',
#  "what is the kid gonna say  sorry meanwhile i am not here anymore like last week  we were at the morgue and this guy was all chopped up  spleen here  liver there  his heart in a pan six hours ago this guy was walkin' his dog or buyin' a quart of milk  who knows  but some kid's robbed him for $3 or some shit and shot him and now you cannot tell if he is a piece of beef or a human being and i am thinkin' that is me sooner or later  that is me <EOS>",
#  'when <EOS>',
#  'tomorrow  at lunch <EOS>',
#  'you ready <EOS>',
#  'a timer <EOS>',
#  "takin' a bath <EOS>",
#  'any id <EOS>',
#  'still unknown but we are running prints kid over there caught the case <EOS>',
#  "it's okay <EOS>",
#  'yeah <EOS>',
#  "c'mere  you wanna go to homicide school  here  make yourself useful <EOS>",
#  'stay with her <EOS>',
#  'no  i am okay <EOS>',
#  "i know  relax  take it easy  don't worry we will get those fuckers <EOS>",
#  'police  we would like to ask you a few questions <EOS>',
#  "i have nothin' to say  if you wanna contact my attorney <EOS>",
#  "homicide miss hearn  it's detective eddie flemming  open up <EOS>",
#  "we don't have her id yet but one of your girls was killed last night at the king edward hotel <EOS>",
#  "oh my gd  honey!  honey's dead <EOS>",
#  'do you have any czech girls working for you <EOS>',
#  'no <EOS>',
#  'did you tell him you did <EOS>',
#  'what are you saying <EOS>',
#  'daphne  another guy came in asking me about her too <EOS>',
#  'describe him <EOS>',
#  "tall shorthaired scary eyes  second guy with him wasshorter with a wrestler's build  and he wouldn't turn his videocamera off me <EOS>",
#  'he had a videocamera  where is she quickly! <EOS>',
#  "she washes hair up at ludwig's  a salon on 63rd and madison <EOS>",
#  "no we don't mind  you mind leon <EOS>",
#  'no what is it <EOS>',
#  "why don't you explain it bobby  hey camello!  you mind punching a hole in the floor <EOS>",
#  'watch the news <EOS>',
#  'nah i musta missed it <EOS>',
#  'well just so you know  i gave you guys the credit <EOS>',
#  "well just so you know i don't care about that stuff <EOS>",
#  'nah why should you <EOS>',
#  "i don't even watch tv <EOS>",
#  'good  good  commendable <EOS>',
#  'sure  but i would like to ask you something  you got a problem with me <EOS>',
#  "if you found me steppin' on your crime scene  it might piss you off too  what about the report <EOS>",
#  'you were right they were both dead before the fire  the male was stabbed so hard the killer broke off the tip of the knife in his spine  that is usually an indicator of something personal <EOS>',
#  'pretty <EOS>',
#  'hmmmm <EOS>',
#  "maybe you don't care about that either  prettiest suspect i have had in awhile <EOS>",
#  'who says she is a suspect <EOS>',
#  'look i am not even sure she has anything to do with this  i saw her outside after the fire  thought it was a lead maybe she saw something  maybe she was visiting somebody here  who knows <EOS>',
#  'eastern europe  like what  romania hungary <EOS>',
#  'or czechoslovakia  the slavs have been fighting the germans and the russians for a thousand years  these are very intense people and they take things personally <EOS>',
#  "there wasn't a fire  there will be nothing for you to do <EOS>",
#  'i can watch you eddie  maybe i will learn something <EOS>',
#  "this isn't homicide school <EOS>",
#  'my parents are from poland  i can help with the eastern european angle <EOS>',
#  'you are polish <EOS>',
#  'my folks are <EOS>',
#  'stay here <EOS>',
#  'you got any better ideas <EOS>',
#  'mind if i ride along with you <EOS>',
#  'this has nothing to do with your fire <EOS>',
#  'but what if it does  you might need my help <EOS>',
#  'this is ridiculous  i am not gonna be in your way  we can talk the case over <EOS>',
#  "tell you what  i will flip you a coin if you win you can come with me  if you don't win you don't come <EOS>",
#  'i will call it tails <EOS>',
#  'better than one <EOS>',
#  "i am on my way with eddie  ludwig's 63rd and madison  the suspects might be there already <EOS>",
#  'i am on duty <EOS>',
#  'so am i  alright i will go inside and you cover the back <EOS>',
#  'of course <EOS>',
#  "hey!  i always wanted to be a cop when i was a kid  i dreamed of running up to a door kicking it in pulling my gun and yelling 'freeze!' at the bad guy! what would you dream about <EOS>",
#  'i wanted to run up to a building on fire kick in the door rush into the smoke and save a kid <EOS>',
#  "then i guess we are doin' this the right way aren't we  if we pull up to a burning building i will gladly let you go first <EOS>",
#  'she just saw two of her friends killed! they probably threatened her <EOS>',
#  'is that all there is <EOS>',
#  'something back home <EOS>',
#  'raw deal <EOS>',
#  'you wanna talk to her alone <EOS>',
#  'yeah <EOS>',
#  'what would your girlfriend think of that <EOS>',
#  "i don't have a girlfriend <EOS>",
#  'my point exactly <EOS>',
#  'i am serious here <EOS>',
#  'so am i <EOS>',
#  "c'mon  you intimidate her 'cause you are a celebrity  she sees me differently <EOS>",
#  'you are her savior  is she the kid you are gonna save from the burning building <EOS>',
#  'you know what i am saying here <EOS>',
#  'hey  i am a professional <EOS>',
#  'women like that have a way of turning professionals into amateurs <EOS>',
#  "well you shoulda because nobody's gonna believe you didn'tincluding me <EOS>",
#  'i took her there for a shower and that is it <EOS>',
#  'just a shower <EOS>',
#  "no i don't think you were a fool i just think you were stupid about it  i mean to say the least you outta know better  you don't know her well enough she is got the potential to fucking hang you even if she suggests that you made a pass at her it's fuckin' over  you can deny it all you want but it will not make one fucking bit of difference you are dead <EOS>",
#  'i told you you know i thought i was doing the right thing you know i think she is innocent <EOS>',
#  "well it's not up to you to decide whether she is innocent or not  don't you understand that is why you are a professional <EOS>",
#  "but i mean didn't you ever go out on a limb for somebody  i mean you shoulda heard her there  tellin' her whole storyi believed her <EOS>",
#  "how you go out on a limb for somebody is by giving her a number of an immigration lawyer  here here's a number of an immigration lawyer  that is how you help her but you cannot get involved in her like that  you are gonna jeopardize your career your life and you are gonna jeopardize my case  and lemme give you another piece of advice  maybe you don't watch tv but i will let you in on a little secret  the whole fuckin' world watches television  and when you get out there they know your face  and the little fame the little fuckin' itty bitty fame that i get in this city makes it a lot easier for my job  and i get more done because of it <EOS>",
#  "you know i don't know  i like you you remind me of a puppy i used to have he pissed on the rug all the time but i still kept him <EOS>",
#  'what do you want <EOS>',
#  'your opinion  you see they going to make a movie about me too eddie  and write books <EOS>',
#  'what is your accomplishment <EOS>',
#  'i kill someone famous <EOS>',
#  'then do it asshole <EOS>',
#  'good  be tough to the end  actor who plays you will want to die like hero <EOS>',
#  'if you kill me and film it you are putting a noose around your neck <EOS>',
#  'smarter than americans  you are fed cry baby talk shows all day long  not only will americans believe me they will cry for me  sodetective eddie flemming would you like to say goodbye to your nicolette maybe you can propose to her now <EOS>',
#  "we don't know that yet  it's much too early  there's a lot to be done <EOS>",
#  'how many victims are up there <EOS>',
#  'there are two bodies found at this point <EOS>',
#  'can we go up to the crime scene <EOS>',
#  "you know you cannot do that  c'mon <EOS>",
#  'is it drug related <EOS>',
#  "we don't know  when i have more i will let you know <EOS>",
#  'i cannot talk right now  we have some things to take care of <EOS>',
#  'i really cannot give out any information right now at this point <EOS>',
#  "okay  but i do understand that your partner leon jackson's been injured is that correct <EOS>",
#  'he was hurt but not seriously  he will be fine <EOS>',
#  'do you have the suspect in custody <EOS>',
#  "umnow is not a good time okay detective jackson's hurt  he is fine i have got a fire marshall shot detective jackson is hurt but not seriously <EOS>",
#  'alright cut cut cut <EOS>',
#  "yeah  now's not a good time <EOS>",
#  'alright <EOS>',
#  'alright <EOS>',
#  'alright <EOS>',
#  'alright <EOS>',
#  'okay <EOS>',
#  'hey <EOS>',
#  'i cannoti cannot answer you just because you want me to answer you! <EOS>',
#  "you didn't have to embarrass me in front of my colleagues  you could give me something <EOS>",
#  'oh i am sorry  did i embarrass you sweetheart  oh <EOS>',
#  'stop it <EOS>',
#  'maybe i should just ya knowturn to the cameras and say do you mind if we just work something out <EOS>',
#  "alright alright eddie  don't patronize me <EOS>",
#  'i am not <EOS>',
#  "yes you are  i am not just some reporter  i don't just stick a microphone in your face  you could give me something <EOS>",
#  'yeah well you took the camera and put it right down on the evidence  that was <EOS>',
#  'that was good  you were holding the evidence <EOS>',
#  "you were merciless  you didn't give a shit if you got me or not <EOS>",
#  'well who was it that taught me how to do that  huh <EOS>',
#  'you are ruthless <EOS>',
#  'you are not so bad yourself <EOS>',
#  "could be leon's <EOS>",
#  'jesus  and last week you came over with blood on your shoes  what am i going to do with you <EOS>',
#  'answer the phone <EOS>',
#  'no  tell me what you want to say <EOS>',
#  'answer it <EOS>',
#  "okay  okay  hold that thought just for a second  they only call me when it's an emergency  just hold that thought  can you call back <EOS>",
#  'that is good <EOS>',
#  'yeah <EOS>',
#  'well that is great <EOS>',
#  'okay  that is great  but i cannot go now we are in the middle of something here <EOS>',
#  'no  go ahead  you are gonna be great <EOS>',
#  'no  no listen to me here  i want to know what you are talking about  you know the shoe thing and the marriages and <EOS>',
#  "i will tell you tonight  let's do it tonight  as soon as you get back we will talk  we will talk <EOS>",
#  'promise <EOS>',
#  'i promise  we will talk  you will be great  you will be fine  go ahead just imagine that uh just look into the lens and imagine you are talking to me <EOS>',
#  'yeah  i will do that  as long as you are not patronizing me <EOS>',
#  'patronizing you nay i love you <EOS>',
#  'i love you <EOS>',
#  'tonight <EOS>',
#  'you promise <EOS>',
#  'yeah  i promise <EOS>',
#  "okay  and you know what i will swing by my place grab a couple pairs of shoes and maybe just test them out next to yourshow's that would that be a good thing <EOS>",
#  'yeah yeah  good thing <EOS>',
#  'okay <EOS>',
#  'see you later  good luck <EOS>',
#  'thank you <EOS>',
#  "don't be late <EOS>",
#  'jesus christ <EOS>',
#  'not chopped up  not chopped up like that  i mean what do i got left coupla articles  a medal or two plaque here and there and in a coupla years no one remembers me anymore <EOS>',
#  'i think you are getting a little moody there eddie <EOS>',
#  'i am not moody <EOS>',
#  "my kids  let's seesusan's 15 aundrea's 9  don't tell me you are thinking about having a kid!  how old are you  never mind let me just tell you this every stupid cliche you hear about kids  they change your life they make you a better person they make you whole  it's all true!  before i had kids when friends talked about their kids i wanted to vomit  now  i get it  am i right leon <EOS>",
#  'not what  who <EOS>',
#  'that is unique <EOS>',
#  'yeah  and he still went to the party <EOS>',
#  'you are worried for my safety  i am touched <EOS>',
#  'keep them out of my way <EOS>',
#  'okay  you ready <EOS>',
#  'yeah yeah  jesus <EOS>',
#  "again  i didn't wanna do it the first time <EOS>",
#  'i am butcher <EOS>',
#  'you are a butcher  what do you use pig intestines for <EOS>',
#  'you stuff sausage in it <EOS>',
#  'and what do you do with the bones <EOS>',
#  'dog food <EOS>',
#  'no  are you proposing <EOS>',
#  'look asshole  i have been threatened by better than you <EOS>',
#  'no  i am the best that is ever threatened you <EOS>',
#  'i will meet you on one condition  i get exclusivity and you surrender to me <EOS>',
#  "we will talk about that  four o'clock gives you time to go to bank  three hundred thousand dollars <EOS>",
#  "what  it doesn't work that way <EOS>",
#  "if you don't want my film  i will call another show  and they will show it <EOS>",
#  'wait a minute  wait a minute <EOS>',
#  'come alone  bring cash  and we will talk about surrendering <EOS>',
#  "my father was  he gave me many lessons about fire  now it's my friend <EOS>",
#  'tommy take a walk <EOS>',
#  'you will be my first <EOS>',
#  'get down on your knees <EOS>',
#  'the sheraton!  on broadway!  room 210 go get oleg  he will kill you <EOS>',
#  'let her go!  let her go!! <EOS>',
#  "if he doesn't lower his gun i will fucking kill her <EOS>",
#  'where is czech girl <EOS>',
#  'baby i am anybody you want me to be i am a little schoolgirl i am mommy i am a czech girl <EOS>',
#  'i ordered a czech girl  daphne you know her <EOS>',
#  'where is escort service <EOS>',
#  'that is confidential  could you put the money on the dresser <EOS>',
#  'i like to talk to the person who runs the service  can you give me address <EOS>',
#  "look  do we have a problem here there's no reason to have a problem i am gonna make you feel real good  you wanna czech girl after i am done with you you will not miss her  now why don't you pay me <EOS>",
#  "look man i don't give a shit if you want sex or not but you are payin' for my time <EOS>",
#  "alright alright  don't hurt me! please it's in my book in my purse! <EOS>",
#  'yes sir <EOS>',
#  'two weeks holiday <EOS>',
#  'how much money are you carrying with you <EOS>',
#  'i have fivehundred dollars <EOS>',
#  'can you show me  sir no cameras in the fis area! <EOS>',
#  'yes <EOS>',
#  'please join us  come on forward <EOS>',
#  'is there a problem <EOS>',
#  'no you are travelling together  i want to talk to you together  hi how are you  can i take a look at your documents  are you related <EOS>',
#  'how long are you planning to stay <EOS>',
#  'two weeks <EOS>',
#  'i would like to speak for himself okay <EOS>',
#  "he doesn't speak english <EOS>",
#  "new york's finest  this is his case <EOS>",
#  'do you know how much killer gets for movie rights <EOS>',
#  'in here says he wants a million <EOS>',
#  'million!  the killer gets one million dollars for a television interview <EOS>',
#  'hey tabloids paid ted bundy  famous serial killer  half a million for his interview  and how much you think monica got for writing book about the president coming on to her  it pays to be a killer or a whore in this country look you want magazine or not <EOS>',
#  'yes  both <EOS>',
#  'okay <EOS>',
#  'okay <EOS>',
#  'i want to document my trip to america <EOS>',
#  "don't speak russian! <EOS>",
#  'why  why do i always have to speak to you in czech <EOS>',
#  "because i don't like your ugly language i heard enough of it in school!  now speak czech or english  and don't fool around anymore  you almost got us thrown out! <EOS>",
#  'we have no money  come on <EOS>',
#  ...]

# %% [markdown]
# # Tranalating all the questions and the answers into integers and replacing all the words that were filtered out by "< OUT>"
#
# 1. We are doing this because we want to sort all the questions and all the answers by their length.
#
# 2. The reason we are sorting them based on length is because it optimizes the training perfomance.
#
#
# So the step by step approach will be as follows:
#
# declare an empty list in python (questions_into_int[])
#
# 1. loop over all the questions in clean_questions list
#
# 2. create an empty list to store the integer values(ints[])
#
# 3. loop over all the words in a question
#
#     if word is not present in questionswords2int, we want to replace that word by the integer that represents token <OUT> ,
#
#     hence append the integer representing token <OUT> to the list names ints[]
#
#     else, if word is present in the questionswords2int, we will append the unique integer associated with the word from questionswords2int list.
#
# 4. now outside the inner for loop, append the ints[] list to the questions_into_int[] list

# %%
questions_into_int = []
for question in clean_questions:
    ints = [] # list of integers, which will be the associated integer to each of the word present in that question
    for word in question.split():
        if word not in questionswords2int:
            ints.append(questionswords2int['<OUT>'])
        else:
            ints.append(questionswords2int[word])
    questions_into_int.append(ints)

# %% [markdown]
# Doing the same set of above steps for answers

# %%
answers_into_int = []
for answer in clean_answers:
    ints = [] # list of integers, which will be the associated integer to each of the word present in that question
    for word in answer.split():
        if word not in answerswords2int:
            ints.append(answerswords2int['<OUT>'])
        else:
            ints.append(answerswords2int[word])
    answers_into_int.append(ints)

# %% [markdown]
# Let's have a look at the questions_to_int list

# %%
questions_into_int
# Out:
# [[8065,
#   3783,
#   3552,
#   6773,
#   1310,
#   8824,
#   8824,
#   6112,
#   3217,
#   8824,
#   2293,
#   72,
#   4780,
#   3347,
#   8824,
#   4244,
#   5451,
#   4866,
#   2513,
#   6233,
#   8824,
#   5107],
#  [3164,
#   2079,
#   4359,
#   3783,
#   134,
#   3579,
#   1036,
#   8824,
#   6166,
#   8419,
#   435,
#   649,
#   1036,
#   4069],
#  [3727, 6233, 8824, 6112, 8824, 6112, 8824, 2854, 4378],
#  [4069,
#   2293,
#   4899,
#   7412,
#   2659,
#   8419,
#   435,
#   3544,
#   2734,
#   8476,
#   435,
#   6947,
#   5747,
#   5107],
#  [420, 420, 6511, 5910, 3358, 3783, 6290, 8129, 7717, 6355, 8824],
#  [3525],
#  [6233,
#   1567,
#   435,
#   3525,
#   2079,
#   3325,
#   6874,
#   6233,
#   3701,
#   4874,
#   7717,
#   5463,
#   8824,
#   6471,
#   4874,
#   787,
#   5910,
#   4712,
#   2079,
#   844,
#   860,
#   6784,
#   4449,
#   6495],
#  [2792],
#  [8824,
#   5044,
#   4449,
#   6423,
#   1130,
#   7148,
#   2583,
#   5618,
#   1540,
#   4449,
#   756,
#   3138,
#   2261,
#   1162,
#   8410,
#   3459,
#   1435,
#   6902,
#   4449,
#   6988,
#   5487,
#   4874,
#   8410,
#   5268,
#   1195],
#  [8509, 6166, 4166, 3783, 2403, 6418, 8390, 7717, 8289],
#  [8824, 8500, 8824, 6773, 435, 5910, 3577],
#  [279, 5750, 4069, 2293, 6994, 6039, 6233, 8824],
#  [2079,
#   5991,
#   8210,
#   1130,
#   6985,
#   1061,
#   1130,
#   6132,
#   8419,
#   2887,
#   2079,
#   8210,
#   1130,
#   6985,
#   8304,
#   6228,
#   6902,
#   7333,
#   6233,
#   1647,
#   97,
#   2293,
#   1061,
#   2145,
#   6495,
#   4102,
#   2120,
#   8385,
#   6902,
#   8275,
#   2079,
#   8129,
#   5918,
#   4341,
#   5910,
#   5973,
#   6975,
#   1130,
#   4275,
#   2659,
#   5910,
#   3577,
#   1130,
#   6205],
#  [8419, 435, 457, 6511, 4360, 7717, 954, 8353],
#  [1061, 435, 1826, 2733, 6418, 6233, 8824, 7717, 860, 3895, 8824],
#  [863],
#  [4069, 6988, 1195, 2513, 6947, 5308],
#  [4069, 8129, 5910, 2180, 8752, 7717, 1331],
#  [1061, 8238, 4069, 7986, 6947, 4861, 1130, 7384, 6902, 8419],
#  [3945, 8129],
#  [2079,
#   2583,
#   2583,
#   2583,
#   3430,
#   6093,
#   1751,
#   2079,
#   844,
#   3727,
#   758,
#   5910,
#   4712,
#   8045],
#  [4449, 435, 3727, 7717],
#  [6203,
#   420,
#   2079,
#   3025,
#   7717,
#   6018,
#   4874,
#   8824,
#   8824,
#   4341,
#   8353,
#   4874,
#   7892,
#   8824,
#   3544,
#   2079,
#   3325,
#   4792,
#   3945,
#   4449,
#   435,
#   3727,
#   8824,
#   8824,
#   8824],
#  [3544, 8419, 435, 6233, 1613, 4874, 7038, 4449, 4064, 4792, 835],
#  [519],
#  [4069, 6985, 8824],
#  [8129, 2036, 5231],
#  [2079,
#   3657,
#   6039,
#   4069,
#   3839,
#   6874,
#   6233,
#   2608,
#   1751,
#   4069,
#   1505,
#   1229,
#   1130,
#   7148,
#   6953],
#  [2079, 3459],
#  [3164, 420],
#  [1162, 8419, 435, 1489, 4069, 6975, 1130, 6132],
#  [1751],
#  [1162,
#   8824,
#   3760,
#   6166,
#   4069,
#   6093,
#   2991,
#   6257,
#   4069,
#   2293,
#   7557,
#   7384,
#   6902,
#   4780,
#   918,
#   2513,
#   8824],
#  [8238, 4069, 1869, 1130, 6773, 1825],
#  [8476, 1825],
#  [7412, 6773, 1753, 5966, 8824, 2079, 3325, 6902, 8735, 7048],
#  [2079, 6801, 4069, 134, 7986, 1130, 6233, 1647, 8385, 2020],
#  [8476, 1647, 8385],
#  [6233, 8279, 4069],
#  [2079,
#   3325,
#   6496,
#   4069,
#   6985,
#   1061,
#   7024,
#   4069,
#   1435,
#   6636,
#   6773,
#   8824,
#   6112,
#   4069,
#   5991,
#   6985,
#   1061,
#   1130,
#   6223],
#  [420],
#  [8198],
#  [4449, 649],
#  [7614, 8238, 2751],
#  [8393, 4069, 494, 6947, 4861],
#  [420],
#  [7333, 8393, 4585, 6093, 4585, 3459, 1435, 1910],
#  [1892],
#  [7023],
#  [4585,
#   1998,
#   808,
#   1540,
#   4585,
#   3025,
#   2659,
#   3783,
#   6975,
#   6233,
#   2047,
#   8824,
#   2079,
#   7860,
#   3293,
#   8824,
#   435,
#   1647,
#   6039,
#   2991,
#   4874,
#   6773,
#   6112,
#   1162,
#   4069,
#   6093,
#   7255,
#   8824,
#   1540,
#   4069,
#   7986,
#   1910],
#  [1869,
#   2079,
#   6985,
#   4069,
#   580,
#   72,
#   1130,
#   2250,
#   1416,
#   457,
#   2079,
#   3325,
#   3727,
#   7509,
#   3138,
#   2261],
#  [6902, 4069, 4282],
#  [2079,
#   8238,
#   4282,
#   1751,
#   2079,
#   3325,
#   7717,
#   547,
#   3131,
#   4341,
#   2387,
#   1195,
#   6039,
#   6947,
#   3664,
#   7068,
#   3727,
#   6205,
#   2839,
#   5657,
#   8180],
#  [7184, 5918, 500, 4069, 3783, 4234, 2659, 8393, 4585],
#  [8476],
#  [4341, 8824, 6039, 7717, 5226],
#  [2792],
#  [4585, 3459, 6902, 7717, 953, 2355],
#  [1751, 4069, 580, 7184],
#  [2682, 2079, 8238, 3839, 1162, 3459, 7717, 4754, 6199],
#  [4585, 4707, 261, 3459, 2387, 8410, 3544, 2079, 8393, 8410],
#  [4069, 8393, 8476],
#  [1751],
#  [7307,
#   8419,
#   2079,
#   800,
#   2079,
#   134,
#   5918,
#   8238,
#   5942,
#   1435,
#   457,
#   261,
#   2839,
#   3459,
#   2387,
#   8410,
#   6112,
#   2079,
#   7220,
#   247,
#   4697,
#   6039,
#   8824,
#   2608,
#   6112,
#   5910,
#   8824,
#   8824,
#   3959],
#  [2792, 6290, 4069, 5809, 7412],
#  [2079, 5996, 1130, 2929, 4069, 3552, 4866, 6947, 3664, 5308, 5506, 2804],
#  [8419, 435, 3727],
#  [2079, 3325, 3727, 1742, 3212, 1130, 7363, 6947, 2691],
#  [2079, 872, 2079, 4359, 2079, 3459, 1424, 4069],
#  [1460,
#   4069,
#   2293,
#   1435,
#   6902,
#   63,
#   1435,
#   249,
#   7412,
#   4662,
#   5216,
#   4341,
#   6233,
#   404,
#   3544,
#   2079,
#   844,
#   5143,
#   5942,
#   6039,
#   7048],
#  [3727,
#   1489,
#   3919,
#   2293,
#   1647,
#   6871,
#   4069,
#   844,
#   1505,
#   3439,
#   6233,
#   7589,
#   4069,
#   8210,
#   1130],
#  [4069, 3657, 5221, 6215, 2553, 4069, 6985],
#  [2929, 4029],
#  [4069, 6712, 7412, 4866],
#  [2079, 1435, 5996],
#  [8476, 1130, 139, 821, 7412, 1130, 4184, 7412, 1130, 55, 4532, 8476],
#  [435, 8419, 3607, 7717, 6286, 8824, 5268, 435, 8410, 1435, 7412],
#  [7302, 435, 8419, 7717],
#  [2682,
#   5991,
#   7986,
#   5364,
#   3963,
#   1751,
#   6180,
#   6773,
#   8118,
#   6112,
#   2079,
#   6546,
#   4585,
#   1013,
#   862],
#  [8421,
#   4069,
#   2293,
#   3727,
#   5228,
#   6784,
#   6947,
#   4712,
#   5880,
#   5228,
#   7981,
#   4874,
#   3917],
#  [8476, 6166, 4449, 5918, 5880, 5228],
#  [1162, 8580, 8806, 4069, 6112, 2079, 8806, 7986, 1130, 3393, 6874, 2553],
#   6233,
#   8824,
#   8824],
#  [8824, 435, 4382, 863, 8480, 2553],
#  [3525, 2079, 3325, 7717, 2733, 41],
#  [8476, 2293, 4069, 8213, 5506],
#  [3525, 8238, 4069, 6902, 6233, 2486],
#  [3945],
#  [8476, 134, 4069, 8238, 1130, 7892],
#  [4449,
#   5164,
#   4069,
#   1036,
#   6233,
#   5782,
#   4874,
#   7717,
#   4172,
#   8824,
#   8419,
#   435,
#   7717,
#   1887,
#   2110],
#  [4069, 2488, 2991, 8824],
#  [4449, 3501, 7412],
#  [8476, 435, 6233, 5266],
#  [6233, 8824, 7384, 435, 883, 8390, 7220, 4069, 757, 807, 6947, 8824],
#  [5318,
#   6112,
#   2079,
#   2672,
#   6233,
#   4166,
#   2854,
#   4874,
#   4069,
#   8824,
#   4341,
#   6947,
#   8471,
#   8824,
#   7644,
#   3459,
#   6947,
#   2014,
#   8007,
#   5451],
#  [3315, 8238, 4069, 5308],
#  [7333, 8461, 5755],
#  [5216],
#  [4119, 5910, 4712, 8682],
#  [5318],
#  [7288, 2707, 954, 3246],
#  [5318, 4348, 2079, 8210, 4069, 1130, 6093, 2659, 1036, 7892],
#  [3945, 8824, 2079, 8806, 7986, 279, 2513, 8410],
#  [4069, 1435, 4707],
#  [4069, 218, 5262, 1130, 2596, 7717, 2486, 2659],
#  [4069,
#   6988,
#   8410,
#   2532,
#   2079,
#   3774,
#   4866,
#   6233,
#   7767,
#   4069,
#   8238,
#   6233,
#   8824],
#  [4069, 2293, 7557, 1748, 7412, 1130, 2596, 2659, 2284, 2486],
#  [2079,
#   844,
#   860,
#   7892,
#   4712,
#   6784,
#   8419,
#   8353,
#   5919,
#   7717,
#   8289,
#   6112,
#   8419,
#   435,
#   6233,
#   6256,
#   4449,
#   1207,
#   8210,
#   7717,
#   8289],
#  [2079, 844, 2596, 7717, 2486, 6902, 8419, 2659, 2513, 7938, 7991],
#  [2596, 8410, 5268, 4119, 8410, 6773, 1016, 7717, 5906],
#  [1540, 2079, 1710, 2659, 308, 2079, 3660, 2059],
#  [2079, 3325, 2513, 8410],
#  [4877, 6233, 470, 5839, 5910, 3196, 1207, 7821, 8752, 7717, 860],
#  [2079, 1435, 8824, 5910, 8373],
#  [8476],
#  [7717, 6254, 7991, 7717, 860],
#  [2084, 8410],
#  [6511, 5506, 5287],
#  [1061, 134, 4069, 8238, 8410],
#  [8238, 8476],
#  [2079, 5991, 6985, 8824, 6233, 8824, 763, 2222, 6254, 6039, 6233, 8824],
#  [3315],
#  [2293, 4069, 1947],
#  [4943, 1435, 8379, 8526, 1130, 8275],
#  [3783, 5991, 8275],
#  [3164,
#   4716,
#   2079,
#   4359,
#   2079,
#   134,
#   6610,
#   4780,
#   2739,
#   8526,
#   4069,
#   4069,
#   6985,
#   1435,
#   1130,
#   5750,
#   6166,
#   4069,
#   2293,
#   6109],
#  [1751,
#   4449,
#   844,
#   6093,
#   2659,
#   1036,
#   4069,
#   457,
#   7892,
#   4712,
#   435,
#   6773,
#   5408,
#   3577,
#   984,
#   6112,
#  [134, 4069, 8790, 7148, 8824, 8526, 7717, 175, 5268, 7717, 1902, 858, 4687],
#  [7614,
#   8806,
#   3450,
#   7614,
#   8806,
#   7120,
#   7614,
#   8806,
#   1199,
#   1416,
#   2929,
#   7892,
#   6093],
#  [8476,
#   8238,
#   4069,
#   3430,
#   5206,
#   3783,
#   8129,
#   6988,
#   1825,
#   1825,
#   1825,
#   5268,
#   1825],
#  [8129, 7717, 7023, 5287, 6618],
#  [8476, 1435, 2041],
#  [6947, 2523, 4234, 1130, 6233, 31],
#  [8393, 2079, 8129, 5942, 1130, 6132, 5506, 8410],
#  [4055, 3727],
#  [2079, 5918, 840, 7935, 6902, 1969, 3727, 6055, 4341, 1851, 8824],
#  [6233, 34, 4340, 8824, 4341, 6233, 8824],
#  [8476, 2293, 4069, 5303, 1130, 1570, 4205],
#  [4263, 4119, 2804, 8682, 4585, 435, 2387, 420, 8777],
#  [4585, 435, 6233, 6023, 8799],
#  [3783, 8389, 8129, 840, 8556],
#  [3783, 4312, 6887, 5032, 6330, 8824, 844, 7148, 8419, 6065],
#  [4069, 6132, 811, 8065, 7148, 3025, 8526, 1943, 7450],
#  [6840,
#   6947,
#   8824,
#   6233,
#   146,
#   8389,
#   3727,
#   2596,
#   4140,
#   8246,
#   5299,
#   5268,
#   7168,
#   5032],
#  [1365,
#   6232,
#   8824,
#   8419,
#   435,
#   3625,
#   7333,
#   1826,
#   1899,
#   8824,
#   2293,
#   4069,
#   1823,
#   1036,
#   6233,
#   248,
#   4874,
#   8824,
#   8824,
#   8824],
#  [2079, 3325, 6947, 8824],
#  [8824,
#   8824,
#   4780,
#   1714,
#   2495,
#   4360,
#   8752,
#   2858,
#   8806,
#   2446,
#   1826,
#   6459,
#   1036,
#   6233,
#   657,
#   2079,
#   3325,
#   3727,
#   3056,
#   1130,
#   8129,
#   2513,
#   5910,
#   305,
#   6233,
#   944,
#   4874,
#   2267,
#   1892,
#   134,
#   8129,
#   8824,
#   3916,
#   1826,
#   6629],
#  [6947,
#   8824,
#   863,
#   435,
#   4166,
#   8353,
#   3703,
#   1130,
#   3708,
#   6233,
#   3135,
#   6112,
#   8419,
#   435,
#   1130,
#   3552,
#   6233,
#   8342,
#   2079,
#   3325,
#   6994,
#   1130,
#   5617,
#   5910,
#   5973,
#   1130,
#   7224,
#   8410,
#   8158],
#  [6947, 5973, 6112, 8419, 4874, 8824],
#  [993,
#   6947,
#   1754,
#   2359,
#   1130,
#   8824,
#   5568,
#   6233,
#   2516,
#   4874,
#   7825,
#   435,
#   8353,
#   4874,
#   6233,
#   4041,
#   4874,
#   6233,
#   5714,
#   6055,
#   6233,
#   8824,
#   1253,
#   2293,
#   8824,
#   1036,
#   1300],
#  [435, 8419, 1489, 8419, 5460, 4069, 1300],
#  [6166,
#   1460,
#   6102,
#   1826,
#   8824,
#   1130,
#   811,
#   8238,
#   4069,
#   3851,
#   4585,
#   134,
#   8129,
#   684,
#   6039,
#   4069,
#   1130,
#   7340,
#   8410,
#   1130,
#   6233,
#   5714],
#  [345, 6073, 5843, 345, 7589],
#  [1776, 3544, 4069, 2293, 7717, 345, 5254],
#  [2079,
#   8389,
#   3727,
#   6055,
#   7148,
#   5303,
#   1130,
#   4069,
#   247,
#   5910,
#   8691,
#   4707,
#   420,
#   1751,
#   8824,
#   8586,
#   7412,
#   4069,
#   2293,
#   7717,
#   5254,
#   4874,
#   8016,
#   6112,
#   8824,
#   6112,
#   8700,
#   8419,
#   4069,
#   2293,
#   3727,
#   7717,
#   7611],
#  [6233, 2573, 435, 8824],
#  [8476, 8393, 7614, 6132, 5506, 8824, 2612, 6439],
#  [2079, 844, 8493, 6233, 8824, 4874, 5910, 8691],
#  [1761, 2079, 1603, 6284],
#  [4069, 7340, 420, 8824, 1130, 1603, 8824],
#  [2079,
#   6985,
#   8476,
#   2079,
#   5750,
#   2079,
#   5750,
#   6205,
#   1892,
#   1207,
#   2622,
#   6233,
#   5714,
#   8752,
#   8410,
#   435,
#   759,
#   3727,
#   7508,
#   2079,
#   5750,
#   7717,
#   2883,
#   1892,
#   7866,
#   8476,
#   6166],
#  [1061, 5635, 2293, 4069, 8824, 8824],
#  [8238, 7614, 8129, 4360, 5051],
#  [1751,
#   4058,
#   6947,
#   3050,
#   3239,
#   2293,
#   4069,
#   1130,
#   3328,
#   1130,
#   8824,
#   8824,
#   5268,
#   2991,
#   4874,
#   6233,
#   2027,
#   8824,
#   4069,
#   1761,
#   8002,
#   6233,
#   1914],
#  [3892, 4069],
#  [863,
#   435,
#   8353,
#   1567,
#   2079,
#   134,
#   6902,
#   1130,
#   2446,
#   2792,
#   8238,
#   4069,
#   8210,
#   1130,
#   6093,
#   3839,
#   7307,
#   1489,
#   6773],
#  [6112,
#   4069,
#   6132,
#   6773,
#   435,
#   4780,
#   4048,
#   5444,
#   8526,
#   1697,
#   2079,
#   5991,
#   5750,
#   2991,
#   1613,
#   4874,
#   2784,
#   8419,
#   134,
#   3552,
#   6773,
#   7717,
#   545],
#  [3783, 1947, 4047, 7181, 3783, 8806, 8755, 6773, 4341, 5317],
#  [4069,
#   8210,
#   7717,
#   8729,
#   178,
#   3783,
#   2293,
#   7717,
#   4172,
#   7614,
#   8824,
#   4491,
#   8526,
#   8824,
#   1892,
#   8806,
#   4069,
#   5253,
#   2614,
#   163],
#  [3783, 5991, 218, 1130, 6985],
#  [3783, 844, 110, 6233, 6262, 4058, 8410],
#  [6232, 8824, 3783, 1489, 8129, 1130, 248],
#  [4341,
#   8353,
#   7251,
#   4874,
#   8824,
#   4069,
#   8129,
#   4610,
#   4590,
#   8824,
#   1892,
#   2146,
#   242,
#   5911,
#   2027,
#   2293,
#   2682,
#   4470,
#   3074,
#   3270,
#   4314,
#   1489,
#   8419,
#   457,
#   4874,
#   6947,
#   5948,
#   8824],
#  [8824, 435, 8476, 7387, 2446],
#  [4069,
#   8806,
#   7148,
#   4352,
#   4341,
#   8824,
#   2026,
#   4874,
#   6947,
#   8824,
#   6112,
#   8824,
#   6784,
#   4069,
#   2293,
#   6879,
#   1130,
#   2380,
#   7333,
#  [2293, 4069, 5910, 3719, 2079, 3325, 8824, 2079, 3325, 5408],
#  [2079, 3325, 3727, 6947, 7225, 6784, 2079, 5750, 6233, 5262],
#  [1776, 8421, 8421, 6412],
#  [8824,
#   2596,
#   8410,
#   2189,
#   2311,
#   1036,
#   7412,
#   2250,
#   4316,
#   8476,
#   8238,
#   4069,
#   218,
#   8476,
#   2293,
#   4069,
#   4968,
#   6039],
#  [5991, 6132, 5942],
#  [7333, 2293, 3783, 4340],
#  [2079, 3325, 2921, 1036, 4069],
#  [6840, 6840, 1199, 1036, 6896],
#  [2079,
#   5111,
#   4069,
#   2284,
#   4026,
#   6511,
#   2583,
#   2112,
#   2447,
#   2883,
#   7310,
#   8353,
#   4756,
#   1130,
#   1858,
#   4069,
#   5131,
#   2222,
#   4568,
#   7717,
#   820,
#   2222,
#   4756,
#   7717,
#   820],
#  [4069, 1800, 6233, 3652],
#  [2297, 6112, 433],
#  [2079, 3459, 1489, 4874, 2140],
#  [3164,
#   4069,
#   6290,
#   7534,
#   6233,
#   8824,
#   4874,
#   8410,
#   6784,
#   5995,
#   420,
#   5958,
#   5506,
#   8419],
#  [8476, 5506, 8824],
#  [5203, 7614, 2293, 4968, 1977, 2537, 4585, 4234, 3839, 1130, 8824],
#  [420, 4585, 435, 1910, 7028],
#  [5991, 1371, 5506, 2804, 6546, 5506, 2858],
#  [8476, 5506, 5910, 555, 7571, 8603, 7571],
#  [7384, 2079, 7220, 2583, 838, 2513, 8419, 1613, 4874, 1567],
#  [8476, 435, 6947, 2458, 1061, 2145],
#  [2079, 134, 8824, 2942, 435, 2511],
#  [420, 420, 3703],
#  [1751, 6511],
#  [8824,
#   420,
#   4140,
#   5268,
#   2079,
#   197,
#   2222,
#   7225,
#   6773,
#   435,
#   6233,
#   8094,
#   984,
#   4874,
#   6947,
#   5973,
#   5991,
#   4659,
#   1130,
#   4049,
#   1672,
#   1550,
#   6132,
#   6840,
#   5268,
#   420],
#  [6773, 435, 3727, 5506, 5262, 8824, 2079, 218, 6947, 3439, 4341, 7412],
#  [8476, 2839, 8238, 4069, 218],
#  [2079,
#   218,
#   1130,
#   6985,
#   5506,
#   6947,
#   5801,
#   2079,
#   218,
#   1130,
#   6985,
#   5506,
#   6947,
#   8824,
#   2792,
#   4069,
#   2293,
#   1910],
#  [5809,
#   7412,
#   5506,
#   2858,
#   8476,
#   4069,
#   8393,
#   8752,
#   7717,
#   3666,
#   8118,
#   8476,
#   6947,
#   3541,
#   2146,
#   6902],
#  [5910,
#   6842,
#   1505,
#   8824,
#   7412,
#   7548,
#   5910,
#   8824,
#   6112,
#   5910,
#   5242,
#   3459,
#   3982],
#  [6947, 5242, 3459, 3982],
#  [5318,
#   4449,
#   4234,
#   3982,
#   2306,
#   7398,
#   1130,
#   7412,
#   4449,
#   4234,
#   1130,
#   8404,
#   3280,
#   7904,
#   635,
#   1130,
#   8824,
#   7412],
#  [3839, 4341, 6233, 3283, 8824],
#  [5318,
#   8824,
#   635,
#   6734,
#   7892,
#   4476,
#   7944,
#   2614,
#   1886,
#  [1162, 2792, 6290, 4069, 1250, 1130, 6233, 7686],
#  [3315, 4271, 8476, 2293, 4069, 2387, 1910],
#  [5251,
#   3336,
#   3459,
#   2513,
#   6233,
#   5935,
#   6039,
#   7774,
#   3783,
#   8283,
#   863,
#   3544,
#   4449,
#   2403,
#   7986,
#   1508,
#   4866],
#  [8476, 8238, 4069, 7860, 8824, 8824],
#  [2079, 2929, 7892, 2596, 7717, 1864],
#  [7717, 8824, 8393, 4069, 2596, 8353, 8021],
#  [8421, 164, 2041],
#  [4271, 5308, 6166, 2079, 2596, 7892],
#  [6233,
#   4244,
#   1207,
#   8129,
#   2991,
#   2739,
#   8476,
#   3783,
#   8238,
#   6112,
#   2682,
#   4069,
#   2293,
#   4340,
#   1130,
#   5769,
#   1826,
#   8824,
#   6773,
#   435,
#   4340,
#   1130,
#   7148,
#   1826,
#   8824,
#   8],
#  [8476,
#   3459,
#   2079,
#   2953,
#   1130,
#   8238,
#   6233,
#   7038,
#   275,
#   1130,
#   3502,
#   7412,
#   2079,
#   3459,
#   7557,
#   4184,
#   7717,
#   5302,
#   3839,
#   2079,
#   1435,
#   6014],
#  [6014, 4069, 8824, 7717, 4424, 1130, 7717, 8824],
#  [4271, 2079, 6985, 2079, 7600, 4866, 1751, 6773, 7038, 3459, 420, 6790, 4424],
#  [3164, 6773, 435, 7557, 7981, 6947, 639, 6112, 5089, 89],
#  [7981, 5910, 639],
#  [1061,
#   2293,
#   4069,
#   4340,
#   1130,
#   604,
#   6773,
#   2537,
#   6166,
#   8824,
#   8235,
#   6632,
#   5216,
#   6112,
#   4069,
#   134,
#   757,
#   2513,
#   6233,
#   7911,
#   3437,
#   8752,
#   7717,
#   3981,
#   6773,
#   1567,
#   134,
#   7148,
#   523,
#   1130,
#   604,
#   4069,
#   134,
#   8129,
#   6233,
#   1647,
#   1130,
#   2033,
#   3270,
#   6233,
#   8824,
#   6511,
#   5161,
#   8419,
#   2079,
#   8129,
#   1130,
#   3552,
#   8759,
#   2459,
#   3916,
#   6947,
#   2203,
#   7244,
#   1751,
#   6180,
#   164,
#   2079,
#   8065,
#   4416,
#   1340,
#   6947,
#   692],
#  [1751, 4271, 883, 6773],
#  [5991,
#   4069,
#   1696,
#   2446,
#   6511,
#   1489,
#   5506,
#   752,
#   6233,
#   3470,
#   3783,
#   7384,
#   6233,
#   4140,
#   5262,
#   2079,
#   7986,
#   1130,
#   1748,
#   4069,
#   1696,
#   2913],
#  [5318, 279],
#  [8476, 3459, 8419, 8824],
#  [2079,
#   4707,
#   5318,
#   4069,
#   2293,
#   279,
#   4271,
#   8752,
#   3980,
#   8752,
#   3783,
#   7986,
#   4965,
#   3783,
#   8806,
#   2929,
#   4069,
#   3850,
#   6233,
#   845],
#  [8393, 6233, 7521, 8824, 7892, 1198],
#  [5318, 4585, 6844, 628, 6330],
#  [3555,
#   237,
#   8526,
#   7892,
#   7064,
#   2929,
#   7892,
#   3774,
#   4866,
#   7892,
#   5131,
#   6112,
# ...
#   2079,
#   5991,
#   6546,
#   4069,
#   2146,
#   7717,
#   7611,
#   2079,
#   1435,
#   6546,
#   4069,
#   2146,
#   1742,
#   5506,
#   8410,
#   2079,
#   7860,
#   1130,
#   6132,
#   6233,
#   7109,
#   4069,
#   972,
#   6985,
#   3470,
#   4069,
#   5991,
#   6985,
#   7892,
#   3164,
#   3212,
#   4449,
#   435,
#   6988,
#   6233,
#   5594,
#   1130,
#   8404,
#   7300,
#   4069,
#   6055,
#   6166,
#   4449,
#   4774,
#   8419,
#   4069,
#   1886,
#   7717,
#   5581,
#   6874,
#   7892,
#   6511,
#   6507,
#   883,
#   4069,
#   8065,
#   6452,
#   8410,
#   1489,
#   4069,
#   8210,
#   1751,
#   8410,
#   8806,
#   3727,
#   3552,
#   8353,
#   8404,
#   2746,
#   4874,
#   6329,
#   4069,
#   2293,
#   2436],
#  [2079,
#   500,
#   4069,
#   4069,
#   6985,
#   2079,
#   4359,
#   2079,
#   3459,
#   2387,
#   6233,
#   279,
#   1567,
#   4069,
#   6985,
#   2079,
#   6546,
#   4449,
#   435,
#   6790],
#  [3164,
#   6511,
#   3727,
#   4866,
#   1130,
#   4069,
#   1130,
#   3434,
#   5149,
#   4449,
#   435,
#   6790,
#   5268,
#   3727,
#   5991,
#   4069,
#   2446,
#   8419,
#   435,
#   2792,
#   4069,
#   2293,
#   7717,
#   2404],
#  [1751,
#   2079,
#   7860,
#   6290,
#   4069,
#   1387,
#   6093,
#   2659,
#   2513,
#   7717,
#   6880,
#   6039,
#   6155,
#   2079,
#   7860,
#   4069,
#   6787,
#   751,
#   7892,
#   863,
#   101,
#   7892,
#   2260,
#   8824,
#   853,
#   7892],
#  [2792,
#   134,
#   4069,
#   6502,
#   7412,
#   3839,
#   863,
#   1036,
#   6233,
#   4271,
#   2792,
#   134,
#   4069,
#   1504,
#   4866,
#   6039,
#   7412,
#   6902,
#   8419],
#  [8824, 896],
#  [8476, 8238, 4069, 8210],
#  [6947,
#   7765,
#   4069,
#   5750,
#   7614,
#   4340,
#   1130,
#   3552,
#   7717,
#   555,
#   5506,
#   7412,
#   8021,
#   2908,
#   6112,
#   4243,
#   124],
#  [8476, 435, 6947, 8824],
#  [2079, 5253, 6205, 8551],
#  [1162, 8238, 8410, 2631],
#  [3544,
#   8824,
#   5991,
#   8129,
#   1130,
#   8238,
#   5289,
#   8824,
#   7614,
#   4340,
#   1130,
#   8129,
#   8279,
#   555,
#   6773,
#   5287],
#  [4069,
#   2583,
#   6546,
#   4069,
#   8806,
#   7148,
#   2263,
#   1130,
#   7611,
#   7717,
#   1701,
#   1036,
#   6773,
#   3208,
#   1061,
#   6507,
#   1742,
#   2293,
#   4069],
#  [4154, 6495, 8410, 7384, 6902, 7717, 2456],
#  [3783,
#   5991,
#   6985,
#   8419,
#   5076,
#   6511,
#   2145,
#   8021,
#   6805,
#   6180,
#   7717,
#   3806,
#   1130,
#   7148,
#   8307],
#  [1061, 900, 3941, 2293, 4866, 863],
#  [863, 2293, 7288, 1875, 3025, 6874, 6773, 4275],
#  [8065, 3783, 6093, 4866, 1130, 6233, 6107, 7437],
#  [4069, 6985, 4069, 844, 8238, 8419, 5377],
#  [435, 8410, 2342, 7354],
#  [4154, 8065, 4069, 5809, 4491, 8476, 2041, 1910],
#  [2079,
#   2446,
#   1751,
#   2079,
#   2672,
#   8419,
#   6233,
#   5782,
#   1169,
#   435,
#   1910,
#   1036,
#   4069,
#   435,
#   6773,
#   7040,
#   7354,
#   1130,
#   6233,
#   5782,
#   2514],
#  [2079, 2583, 844, 5556, 2659, 2991, 423, 279, 2682, 6874, 6773, 4275],
#  [649,
#   1751,
#   2079,
#   8238,
#   2446,
#   8419,
#   6947,
#   2948,
#   4622,
#   8824,
#   757,
#   7664,
#   435,
#   8419,
#   2943],
#  [4585, 3459, 7669, 1751, 3727, 5602, 4585, 8806, 7148, 178],
#  [8238, 4069, 8129, 6233, 7601, 4341, 6462],
#  [8824,
#   435,
#   3727,
#   7717,
#   1647,
#   5287,
#   649,
#   4154,
#   8824,
#   7669,
#   4585,
#   435,
#   178,
#   2079,
#   8129,
#   6988,
#   7717,
#   5782,
#   1169,
#   3504,
#   4154,
#   5672,
#   435,
#   7669,
#   1751,
#   3727,
#   5602],
#  [2908, 2293, 4069, 649],
#  [5318, 1090, 3727, 7717, 1647, 5287],
#  [3555],
#  [3555],
#  [3555],
#  [3555],
#  [3315, 5734],
#  [8476,
#   435,
#   6947,
#   3244,
#   2792,
#   134,
#   4069,
#   4453,
#   6874,
#   7412,
#   2079,
#   1435,
#   5996,
#   7717,
#   7212],
#  [2079, 8824, 844, 3861, 4069, 1435, 457, 4069, 8210, 7412, 1130, 3861, 8750],
#  [4069,
#   6290,
#   8129,
#   1130,
#   6457,
#   7412,
#   4341,
#   7911,
#   4874,
#   5910,
#   4973,
#   4069,
#   2403,
#   5556,
#   7412,
#   1195],
#  [1776, 2079, 3325, 7425, 8393, 2079, 6457, 4069, 6583, 1776],
#  [1740, 8410],
#  [2537,
#   2079,
#   8389,
#   1435,
#   8461,
#   8824,
#   1130,
#   6233,
#   3292,
#   6112,
#   6132,
#   8238,
#   4069,
#   5308,
#   6166,
#   3783,
#   1435,
#   248,
#   1195,
#   2659],
#  [3555, 3555, 2908, 5991, 8824, 7412],
#  [2079, 3325, 3727],
#  [6840,
#   4069,
#   2293,
#   2079,
#   3325,
#   3727,
#   1435,
#   2284,
#   7686,
#   2079,
#   5991,
#   1435,
#   6105,
#   7717,
#   8824,
#   4341,
#   6947,
#   1617,
#   4069,
#   2403,
#   5556,
#   7412,
#   1195],
#  [5318,
#   3164,
#   4069,
#   1533,
#   6233,
#   2619,
#   6112,
#   2678,
#   8410,
#   279,
#   4316,
#   2513,
#   6233,
#   2323,
#   8419,
#   3459],
#  [8419, 3459, 1647, 4069, 2146, 943, 6233, 2323],
#  [4069,
#   2146,
#   8824,
#   4069,
#   6290,
#   5556,
#   7717,
#   7028,
#   6166,
#   4069,
#   6988,
#   7412,
#   5268,
#   3727],
#  [3164, 1892, 3459, 8410, 8419, 6033, 7412, 1061, 1130, 8238, 8419, 3259],
#   2079,
#   7986,
#   8824,
#   6112,
#   4069,
#   1901,
#   1130,
#   7412],
#  [3783,
#   8806,
#   1250,
#   5506,
#   8419,
#   38,
#   2328,
#   6482,
#   4069,
#   5287,
#   1130,
#   6093,
#   1130,
#   2603,
#   6887,
#   6254,
#   4172,
#   4268],
#  [8476, 8410, 1207, 248, 8419, 3703],
#  [6166,
#   4069,
#   5991,
#   8210,
#   5910,
#   4571,
#   2079,
#   8806,
#   197,
#   2222,
#   7340,
#   6112,
#   7614,
#   8806,
#   7340,
#   8410],
#  [4886, 7717, 4323, 4886, 7717, 4323],
#  [2146,
#   4069,
#   7717,
#   4670,
#   8419,
#   1061,
#   4069,
#   6034,
#   1061,
#   1130,
#   6814,
#   6233,
#   7064],
#  [5910,
#   6842,
#   3459,
#   4585,
#   6734,
#   7412,
#   900,
#   2740,
#   5506,
#   5782,
#   2682,
#   6511,
#   5910,
#   4658],
#  [4069,
#   844,
#   5253,
#   7412,
#   4069,
#   2293,
#   3727,
#   7717,
#   5302,
#   1435,
#   4670,
#   1036,
#   7717,
#   289,
#   2079,
#   3046,
#   4069,
#   5918,
#   3504,
#   7987,
#   4341,
#   6947,
#   5973],
#  [5377,
#   3187,
#   6233,
#   8113,
#   8238,
#   8410,
#   1776,
#   7384,
#   4069,
#   2293,
#   5395,
#   4069,
#   5991,
#   8129,
#   6233,
#   4484],
#  [7333, 435, 6947, 2948],
#  [5809, 2804, 1130, 2678, 903, 289, 4871],
#  [2929, 7892, 4029, 2929, 7892, 8824],
#  [519, 2079, 3325, 5734],
#  [7333, 435, 3283, 2486],
#  [2682,
#   2079,
#   6902,
#   1130,
#   7986,
#   4723,
#   2659,
#   4874,
#   6233,
#   3703,
#   2612,
#   3783,
#   7986,
#   4316,
#   1130,
#   2784,
#   2792,
#   8824,
#   2678,
#   5910,
#   5262,
#   2513,
#   6233,
#   8824],
#  [6511,
#   4780,
#   8824,
#   2215,
#   6610,
#   2659,
#   4874,
#   4780,
#   7064,
#   2079,
#   5991,
#   471,
#   6233,
#   2027,
#   1197,
#   6951,
#   4069,
#   7557,
#   7986,
#   882],
#  [7333, 435, 4266, 2215],
#  [8419, 435, 8244, 2403, 4069, 2678, 6233, 5262, 2513, 6233, 8824],
#  [2079,
#   6902,
#   1130,
#   1250,
#   1130,
#   6233,
#   7542,
#   1892,
#   7010,
#   6233,
#   2215,
#   8065,
#   4069,
#   5556,
#   7412,
#   8651],
#  [1869,
#   1130,
#   7412,
#   2079,
#   5991,
#   8210,
#   8600,
#   1435,
#   5556,
#   7412,
#   6233,
#   8651,
#   6112,
#   1162,
#   4069,
#   6093],
#  [5556, 7412, 6233, 8824],
#  [8808, 2403, 2079, 5750, 6947, 5258, 4378],
#  [8476, 435, 6947, 6102, 4377, 4874, 6947, 8488, 1130, 6233, 6608, 4014],
#  [7288, 5032, 7573],
#  [1061, 2145, 5262, 2293, 4069, 6435, 1036, 4069],
#  [2079, 8129, 8824, 4268],
#  [435, 4585, 1036, 4069, 2293, 4069, 4131, 8300],
#  [6840],
#  [4378, 6274, 4491, 1199, 2513, 1025],
#  [435, 863, 7717, 3244],
#  [3783, 2293, 7588, 4236, 3648],
#  [1061, 8131, 2293, 4069, 2952, 1130, 2311],
#  [7288, 5032],
#  [2079, 134, 6902, 1130, 1603, 6039, 5486, 649],
#  [1892, 435, 4585],
#  [6773, 1489, 4069, 8210],
#  [8238, 4069, 6985, 1061, 2145, 3570, 5919, 6039, 555, 7571],
#  [4341, 1910, 3760, 4585, 4756, 7717, 697],
#  [8824, 6233, 3570, 5919, 8353, 697, 4268, 6039, 7717, 6619, 7933],
#  [3315,
#   8824,
#   6920,
#   4907,
#   886,
#   8551,
#   6819,
#   3570,
#   2942,
#   7717,
#   697,
#   6039,
#   903,
#   7933,
#   6112,
#   1061,
#   2145,
#   4069,
#   6546,
#   2924,
#   6988,
#   6039,
#   8071,
#   8603,
#   5506,
#   6233,
#   7036,
#   2921,
#   2513,
#   1130,
#   7892,
#   8410,
#   6455,
#   1130,
#   7148,
#   7717,
#   3570,
#   5268,
#   7717,
#   4869,
#   4341,
#   6773,
#   721,
#   7384,
#   4069,
#   8210,
#   5126,
#   5268,
#   3727],
#  [1435,
#   8238,
#   8476,
#   2079,
#   8238,
#   6132,
#   6233,
#   2047,
#   1567,
#   2079,
#   6132,
#   5991,
#   7918,
#   6947,
#   1849],
#  [5991, 7611, 6864],
#  [8393, 4069, 4374, 8476, 2079, 4707],
#  [7384, 5956, 2314, 1435, 6902, 4341, 6233, 8824],
#  [5991, 1603, 8824],
#  [2792, 2792, 8238, 2079, 1505, 8129, 1130, 1603, 1130, 4069, 4341, 3283],
#  [7384, 345, 8824, 6032, 8824, 752, 8824, 8824, 2553, 7411],
#  ...]

# %% [markdown]
# Let's have a look at the answers_into_int list

# %%
answers_into_int
# Out:
# [[3164,
#   2079,
#   4359,
#   3783,
#   134,
#   3579,
#   1036,
#   8824,
#   6166,
#   8419,
#   435,
#   649,
#   1036,
#   4069,
#   8823],
#  [3727, 6233, 8824, 6112, 8824, 6112, 8824, 2854, 4378, 8823],
#  [649, 1162, 1061, 4950, 3783, 4659, 2659, 2284, 4153, 8824, 6791, 2553, 8823],
#  [2084, 8410, 8823],
#  [3525, 8823],
#  [6233,
#   1567,
#   435,
#   3525,
#   2079,
#   3325,
#   6874,
#   6233,
#   3701,
#   4874,
#   7717,
#   5463,
#   8824,
#   6471,
#   4874,
#   787,
#   5910,
#   4712,
#   2079,
#   844,
#   860,
#   6784,
#   4449,
#   6495,
#   8823],
#  [5858, 6902, 4449, 2403, 7986, 7717, 860, 2189, 3212, 8823],
#  [8824,
#   5044,
#   4449,
#   6423,
#   1130,
#   7148,
#   2583,
#   5618,
#   1540,
#   4449,
#   756,
#   3138,
#   2261,
#   1162,
#   8410,
#   3459,
#   1435,
#   6902,
#   4449,
#   6988,
#   5487,
#   4874,
#   8410,
#   5268,
#   1195,
#   8823],
#  [8419, 435, 7717, 3489, 8823],
#  [2929, 7412, 5750, 8476, 2079, 8065, 8238, 8823],
#  [6219, 6180, 6947, 3570, 8238, 6947, 4708, 3253, 63, 8823],
#  [3555, 8419, 435, 7717, 8824, 1559, 8823],
#  [6840, 1751, 4585, 3459, 7717, 5302, 8823],
#  [6166,
#   4069,
#   544,
#   1036,
#   6233,
#   7521,
#   2537,
#   7614,
#   8806,
#   6502,
#   4069,
#   1036,
#   6947,
#   5272,
# ...
#   7717,
#   507,
#   6166,
#   4069,
#   111,
#   4069,
#   8065,
#   1199,
#   1036,
#   7412,
#   6166,
#   4069,
#   5991,
#   111,
#   4069,
#   5991,
#   1199,
#   8823],
#  [2079, 8806, 197, 8410, 8824, 8823],
#  [3470, 8246, 8353, 8823],
#  [2079,
#   3325,
#   2513,
#   5910,
#   3703,
#   1036,
#   2908,
#   8824,
#   8824,
#   6112,
#   7062,
#   6233,
#   7839,
#   1013,
#   7148,
#   863,
#   8350,
#   8823],
#  [2079, 3325, 2513, 4708, 8823],
#  [3544,
#   3325,
#   2079,
#   3555,
#   2079,
#   8806,
#   6093,
#   3184,
#   6112,
#   4069,
#   7975,
#   6233,
#   3839,
#   8823],
#  [4874, 5789, 8823],
#  [2231,
#   2079,
#   1505,
#   5996,
#   1130,
#   7148,
#   7717,
#   5302,
#   1540,
#   2079,
#   3459,
#   7717,
#   4126,
#   2079,
#   7560,
#   4874,
#   7434,
#   4866,
#   1130,
#   7717,
#   8107,
#   2132,
#   8410,
#   4341,
#   1178,
#   5910,
#   289,
#   6112,
#   4522,
#   8824,
#   6874,
#   6233,
#   4476,
#   4353,
#   8476,
#   134,
#   4069,
#   2609,
#   5506,
#   8823],
#  [2079,
#   5996,
#   1130,
#   6610,
#   4866,
#   1130,
#   7717,
#   2650,
#   2513,
#   5782,
#   3908,
#   4341,
#   6233,
#   8107,
#   2958,
#   4731,
#   6233,
#   5454,
#   6112,
#   8276,
#   7717,
#   4126,
#   8823],
#  [1162,
#   2079,
#   872,
#   3783,
#   2293,
#   824,
#   6773,
#   6233,
#   279,
#   3703,
#   6951,
#   3783,
#   6166,
#   3783,
#   3187,
#   4866,
#   1130,
#   7717,
#   4065,
#   2650,
#   2079,
#   8806,
#   5520,
#   2929,
#   4069,
#   6093,
#   2336,
#   8823],
#  [4449,
#   1435,
#   3661,
#   7288,
#   4874,
#   7892,
#   7181,
#   5904,
#   7614,
#   5089,
#   4583,
#   7892,
#   8823],
#  [435, 8419, 1489, 863, 435, 8823],
#  [1195, 3839, 1416, 8823],
#  [6218, 3763, 8823],
#  [4069, 3430, 1250, 1130, 7892, 8682, 8823],
#  [5318, 8823],
#  [8476, 134, 6947, 2141, 6546, 4874, 8419, 8823],
#  [2079, 5991, 8129, 7717, 2141, 8823],
#  [5910, 4275, 7742, 8823],
#  [2079, 3325, 224, 1910, 8823],
#  [3544, 3325, 2079, 8823],
#  [5377,
#   4069,
#   7128,
#   7892,
#   8015,
#   4069,
#   2293,
#   7717,
#   7017,
#   4449,
#   612,
#   7412,
#   7006,
#   8823],
#  [4069,
#   2293,
#   7892,
#   8824,
#   435,
#   4449,
#   6233,
#   4126,
#   2293,
#   4131,
#   8300,
#   2079,
#   8210,
#   1130,
#   1250,
#   1130,
#   4069,
#   8300,
#   519,
#   1061,
#   2293,
#   4069,
#   8065,
#   2079,
#   2596,
#   7717,
#   7384,
#   6874,
#   6947,
#   5258,
#   2293,
#   4069,
#   7354,
#   8823],
#  [1061, 8131, 2293, 4069, 2952, 1130, 2311, 8823],
#  [7288, 5032, 8823],
#  [2079, 134, 6902, 1130, 1603, 6039, 5486, 649, 8823],
#  [4585, 1207, 1603, 6184, 8823],
#  [345, 8824, 8555, 6773, 435, 903, 984, 8823],
#  [8238, 4069, 6985, 1061, 2145, 3570, 5919, 6039, 555, 7571, 8823],
#  [4341, 1910, 3760, 4585, 4756, 7717, 697, 8823],
#  [8824, 6233, 3570, 5919, 8353, 697, 4268, 6039, 7717, 6619, 7933, 8823],
#  [3315,
#   8824,
#   6920,
#   4907,
#   886,
#   8551,
#   6819,
#   3570,
#   2942,
#   7717,
#   697,
#   6039,
#   903,
#   7933,
#   6112,
#   1061,
#   2145,
#   4069,
#   6546,
#   2924,
#   6988,
#   6039,
#   8071,
#   8603,
#   5506,
#   6233,
#   7036,
#   2921,
#   2513,
#   1130,
#   7892,
#   8410,
#   6455,
#   1130,
#   7148,
#   7717,
#   3570,
#   5268,
#   7717,
#   4869,
#   4341,
#   6773,
#   721,
#   7384,
#   4069,
#   8210,
#   5126,
#   5268,
#   3727,
#   8823],
#  [6840, 7588, 8823],
#  [649, 8823],
#  [649, 8823],
#  [2079, 8210, 1130, 6621, 5910, 5828, 1130, 2235, 8823],
#  [5991, 1603, 8824, 8823],
#  [2792,
#   2792,
#   8238,
#   2079,
#   1505,
#   8129,
#   1130,
#   1603,
#   1130,
#   4069,
#   4341,
#   3283,
#   8823],
#  [457,
#   2079,
#   5991,
#   6902,
#   6947,
#   3457,
#   4883,
#   2079,
#   751,
#   3212,
#   4874,
#   8410,
#   4341,
#   8824,
#   2682,
#   1603,
#   3283,
#   5268,
#   6184,
#   6112,
#   5991,
#   7611,
#   6864,
#   7953,
#   4069,
#   4247,
#   6988,
#   4491,
#   8566,
#   4956,
#   8823],
#  [3783, 8129, 420, 5262, 1199, 2513, 8823],
#  ...]

# %% [markdown]
# # Sorting questions and answers by the length of the questions
#
# We are doing so because it will speed up the training and help to reduce the loss. The reason for this is because it will reduce the amount of padding during training.
#
# 1.create two empty lists in python
#  one called sorted_clean_answers[] and the other sorted_clean_questions[]
#
#  We will place a limit on the length of the questions, because very lengthy questions will be too overwhelming for the chatbot to learn from.
# Also this limit on the length can be considered as a hyperparamater which can be tuned to get better perfomance.(here let's take the limit to be 25)
#
# 2. looping over different possible lengths of the questions(upto the limit)
#     for each of the questions, we need to get two important elements - index of     the question and the question itself
#
#     the trick to get these two elements at the same time is to use the enumerate function

# %%
sorted_clean_questions = []
sorted_clean_answers = []
for length in range(1, 25 + 1):
    for i in enumerate(questions_into_int):
        if len(i[1]) == length:
            sorted_clean_questions.append(questions_into_int[i[0]])
            sorted_clean_answers.append(answers_into_int[i[0]])

# %% [markdown]
# Let's have a look at the sorted_clean_questions

# %%
sorted_clean_questions
# Out:
# [[3525],
#  [2792],
#  [863],
#  [519],
#  [1751],
#  [420],
#  [8198],
#  [420],
#  [1892],
#  [7023],
#  [3882],
#  [8476],
#  [2792],
#  [1751],
#  [2792],
#  [5918],
#  [585],
#  [3945],
#  [5216],
#  [5318],
#  [8476],
#  [3315],
#  [1892],
#  [649],
#  [2792],
#  [1892],
#  [8824],
#  [41],
#  [2537],
#  [1892],
#  [6871],
#  [8824],
#  [8824],
#  [6840],
#  [1061],
#  [8824],
#  [8824],
#  [8476],
#  [420],
#  [8476],
#  [8824],
#  [519],
#  [279],
#  [8476],
#  [8433],
#  [8824],
#  [6842],
#  [420],
#  [420],
#  [6563],
#  [8824],
#  [6981],
#  [420],
#  [1776],
#  [1540],
#  [5318],
#  [420],
#  [4792],
#  [1267],
#  [5318],
#  [3555],
#  [3555],
#  [3555],
#  [3555],
#  [5318],
#  [487],
#  [5231],
#  [649],
#  [6994],
#  [6840],
#  [8476],
#  [4869],
#  [129],
#  [8824],
#  [8824],
#  [7202],
#  [5318],
#  [1933],
#  [8476],
#  [8476],
#  [5318],
#  [2675],
#  [2675],
#  [2675],
#  [2675],
#  [2675],
#  [2675],
#  [649],
#  [6840],
#  [2583],
#  [6840],
#  [1776],
#  [1061],
#  [7422],
#  [2675],
#  [2675],
#  [2675],
#  [8824],
#  [2675],
#  [2675],
#  [2583],
#  [4219],
#  [7204],
#  [8127],
#  [5318],
#  [5747],
#  [5318],
#  [5277],
#  [5318],
#  [3208],
#  [5318],
#  [3164],
#  [863],
#  [8476],
#  [2792],
#  [2688],
#  [4425],
#  [5318],
#  [3937],
#  [5318],
#  [5318],
#  [1818],
#  [3315],
#  [3846],
#  [1540],
#  [8824],
#  [1892],
#  [5318],
#  [1818],
#  [6367],
#  [1818],
#  [5318],
#  [1818],
#  [8500],
#  [519],
#  [6412],
#  [8824],
#  [7317],
#  [8824],
#  [4217],
#  [8824],
#  [8824],
#  [3048],
#  [7742],
#  [3048],
#  [4425],
#  [5565],
#  [8824],
#  [8824],
#  [1818],
#  [4955],
#  [5991],
#  [8476],
#  [614],
#  [3208],
#  [8824],
#  [4917],
#  [786],
#  [7425],
#  [2908],
#  [8476],
#  [5318],
#  [2792],
#  [5384],
#  [1818],
#  [4839],
#  [4562],
#  [3914],
#  [420],
#  [649],
#  [1818],
#  [649],
#  [1818],
#  [6840],
#  [420],
#  [420],
#  [6840],
#  [420],
#  [8476],
#  [1818],
#  [420],
#  [8476],
#  [420],
#  [3544],
#  [8824],
#  [8476],
#  [1237],
#  [5773],
#  [8824],
#  [1033],
#  [8824],
#  [8476],
#  [1892],
#  [5318],
#  [331],
#  [5691],
#  [6840],
#  [8824],
#  [3259],
#  [3544],
#  [8824],
#  [8824],
#  [5318],
#  [3164],
#  [5345],
#  [5942],
#  [3259],
#  [8476],
#  [8824],
#  [2792],
#  [2666],
#  [1892],
#  [1892],
#  [420],
#  [6840],
#  [1776],
#  [5318],
#  [6255],
#  [5318],
#  [1776],
#  [2583],
#  [454],
#  [5318],
#  [5318],
#  [8476],
#  [5318],
#  [8824],
#  [5318],
#  [420],
#  [6840],
#  [6840],
#  [6840],
#  [6840],
#  [6656],
#  [5388],
#  [420],
#  [164],
#  [649],
#  [3259],
#  [3259],
#  [3544],
#  [2537],
#  [8824],
#  [5318],
#  [5318],
#  [5262],
#  [1344],
#  [1061],
#  [8065],
#  [8476],
#  [8824],
#  [3937],
#  [8824],
#  [164],
#  [2897],
#  [5318],
#  [5318],
#  [8824],
#  [8824],
#  [8824],
#  [5148],
#  [1892],
#  [456],
#  [3259],
#  [1892],
#  [5262],
#  [5318],
#  [1033],
#  [1811],
#  [8824],
#  [3963],
#  [2792],
#  [2436],
#  [2585],
#  [1061],
#  [6840],
#  [420],
#  [38],
#  [8237],
#  [1740],
#  [8476],
#  [8353],
#  [1751],
#  [8824],
#  [7028],
#  [8476],
#  [8824],
#  [8824],
#  [551],
#  [5181],
#  [8824],
#  [5181],
#  [4907],
#  [5181],
#  [8824],
#  [8824],
#  [8824],
#  [3016],
#  [3613],
#  [2537],
#  [8127],
#  [1168],
#  [1168],
#  [8824],
#  [3945],
#  [5318],
#  [8476],
#  [6840],
#  [8824],
#  [420],
#  [8824],
#  [8824],
#  [7490],
#  [4907],
#  [6840],
#  [8824],
#  [4604],
#  [6840],
#  [8127],
#  [8127],
#  [6840],
#  [6840],
#  [1910],
#  [6840],
#  [164],
#  [164],
#  [2792],
#  [6412],
#  [8824],
#  [5318],
#  [8476],
#  [8824],
#  [8506],
#  [8476],
#  [4990],
#  [3110],
#  [3544],
#  [551],
#  [1745],
#  [4662],
#  [5549],
#  [4425],
#  [7708],
#  [48],
#  [8824],
#  [8533],
#  [8824],
#  [6840],
#  [420],
#  [7333],
#  [8104],
#  [2792],
#  [8476],
#  [8476],
#  [8476],
#  [3087],
#  [551],
#  [8253],
#  [7333],
#  [2682],
#  [2709],
#  [2792],
#  [7333],
#  [8421],
#  [8824],
#  [8476],
#  [117],
#  [6840],
#  [2709],
#  [8421],
#  [2709],
#  [8824],
#  [8824],
#  [8824],
#  [8476],
#  [8824],
#  [2583],
#  [8824],
#  [5231],
#  [8682],
#  [8476],
#  [8824],
#  [2231],
#  [8824],
#  [1396],
#  [8824],
#  [8824],
#  [2583],
#  [6840],
#  [3843],
#  [2583],
#  [6840],
#  [8824],
#  [619],
#  [321],
#  [6840],
#  [6840],
#  [8824],
#  [6842],
#  [7333],
#  [6840],
#  [8476],
#  [8824],
#  [8824],
#  [3164],
#  [1769],
#  [8824],
#  [8824],
#  [8476],
#  [6840],
#  [420],
#  [4299],
#  [2583],
#  [1619],
#  [6840],
#  [8476],
#  [1892],
#  [8476],
#  [8824],
#  [6840],
#  [6840],
#  [6840],
#  [6840],
#  [7742],
#  [2945],
#  [2945],
#  [2945],
#  [3544],
#  [7333],
#  [3164],
#  [8476],
#  [6840],
#  [6840],
#  [7742],
#  [6840],
#  [7333],
#  [2168],
#  [8824],
#  [6840],
#  [6840],
#  [7025],
#  [4425],
#  [8824],
#  [8824],
#  [6840],
#  [3315],
#  [519],
#  [3315],
#  [5318],
#  [3945],
#  [3470],
#  [8476],
#  [8824],
#  [7001],
#  [7425],
#  [3259],
#  [1801],
#  [8824],
#  [8824],
#  [8824],
#  [8414],
#  [3315],
#  [3315],
#  [5318],
#  [8476],
#  [2915],
#  [2792],
#  [7955],
#  [4034],
#  [4925],
#  [2473],
#  [5318],
#  [6060],
#  [8824],
#  [8824],
#  [8824],
#  [6060],
#  [2473],
#  [420],
#  [420],
#  [5712],
#  [6840],
#  [8824],
#  [1383],
#  [5318],
#  [2792],
#  [1647],
#  [7333],
#  [2552],
#  [2792],
#  [420],
#  [1540],
#  [5318],
#  [5318],
#  [5318],
#  [6840],
#  [8808],
#  [8824],
#  [8824],
#  [8824],
#  [7425],
#  [5262],
#  [4442],
#  [5318],
#  [4943],
#  [6840],
#  [1892],
#  [5318],
#  [8824],
#  [7425],
#  [7412],
#  [3544],
#  [5318],
#  [2436],
#  [5318],
#  [8476],
#  [6902],
#  [2994],
#  [1801],
#  [8476],
#  [4476],
#  [4425],
#  [3280],
#  [6840],
#  [420],
#  [3164],
#  [8824],
#  [8476],
#  [8824],
#  [5221],
#  [7938],
#  [4604],
#  [6840],
#  [8824],
#  [8433],
#  [8824],
#  [279],
#  [5107],
#  [4943],
#  [6840],
#  [6840],
#  [5158],
#  [420],
#  [8824],
#  [8476],
#  [649],
#  [649],
#  [6840],
#  [6424],
#  [3945],
#  [2709],
#  [8824],
#  ...]

# %% [markdown]
# Let's have a look at the sorted_clean_answers

# %%
sorted_clean_answers
# Out:
# [[6233,
#   1567,
#   435,
#   3525,
#   2079,
#   3325,
#   6874,
#   6233,
#   3701,
#   4874,
#   7717,
#   5463,
#   8824,
#   6471,
#   4874,
#   787,
#   5910,
#   4712,
#   2079,
#   844,
#   860,
#   6784,
#   4449,
#   6495,
#   8823],
#  [8824,
#   5044,
#   4449,
#   6423,
#   1130,
#   7148,
#   2583,
#   5618,
#   1540,
#   4449,
#   756,
#   3138,
#   2261,
#   1162,
#   8410,
#   3459,
#   1435,
#   6902,
#   4449,
#   6988,
#   5487,
#   4874,
#   8410,
#   5268,
#   1195,
#   8823],
#  [7333, 8823],
#  [4451, 6902, 6228, 1463, 2659, 5231, 3259, 8823],
#  [4069, 1505, 757, 6773, 1390, 8823],
#  [649, 4069, 2293, 7557, 218, 1130, 4791, 1061, 1130, 8518, 8823],
#  [1925, 6093, 8823],
#  [4069, 1013, 3430, 6546, 5506, 8410, 8823],
#  [7184, 8823],
#  [134, 4069, 5308, 4910, 7412, 7717, 6581, 3525, 8823],
#  [5910,
#   2022,
#   3760,
#   2079,
#   8129,
#   6988,
#   7717,
#   1647,
#   3504,
#   6874,
#   1260,
#   6233,
#   8824,
#   7038,
#   8808,
#   5604,
#   8823],
#  [4341, 8824, 6039, 7717, 5226, 8823],
#  [4585, 3459, 6902, 7717, 953, 2355, 8823],
#  [7307,
#   8419,
#   2079,
#   800,
#   2079,
#   134,
#   5918,
#   8238,
#   2260,
#   3806,
#   4140,
#   8246,
#   1372,
#   2079,
#   757,
#   8419,
#   8064,
#   6112,
#   2079,
#   6985,
#   6233,
#   6329,
#   6773,
#   435,
#   4754,
#   8823],
#  [6233, 2027, 7038, 8823],
#  [7717,
#   4701,
#   4341,
#   248,
#   6112,
#   8578,
#   8824,
#   4069,
#   8806,
#   3892,
#   7412,
#   6039,
#   6773,
#   8353,
#   8387,
#   1305,
#   698,
#   2730,
#   8419,
#   8824,
#   8823],
#  [4069, 8824, 8824, 8823],
#  [4069, 1743, 5167, 8824, 8823],
#  [2079,
#   4505,
#   2513,
#   7892,
#   4449,
#   6975,
#   6233,
#   5945,
#   8824,
#   319,
#   5991,
#   2602,
#   7892,
#   8752,
#   2145,
#   8752,
#   7412,
#   2614,
#   435,
#   2792,
#   2079,
#   5556,
#   7892,
#   6233,
#   8824,
#   8823],
#  [8824, 8823],
#  [4069, 6112, 7412, 8823],
#  [164,
#   4341,
#   6233,
#   8404,
#   1406,
#   1130,
#   6581,
#   3727,
#   7717,
#   8404,
#   1567,
#   5910,
#   1406,
#   5910,
#   5262,
#   5910,
#   1086,
#   8824,
#   8823],
#  [5148, 8823],
#  [5318,
#   4101,
#   7384,
#   2079,
#   3459,
#   5838,
#   4028,
#   1478,
#   863,
#   757,
#   5942,
#   2513,
#   7424,
#   4341,
#   4816,
#   5506,
#   7717,
#   7781,
#   4095,
#   1036,
#   7717,
#   7038,
#   3120,
#   456,
#   3153,
#   456,
#   8823],
#  [456, 8823],
#  [420, 7028, 8823],
#  [6233, 2553, 2612, 6233, 5928, 8823],
#  [4185,
#   2079,
#   3459,
#   3920,
#   4874,
#   4910,
#   7717,
#   7225,
#   2537,
#   4069,
#   8065,
#   6502,
#   7412,
#   8823],
#  [1892,
#   134,
#   1748,
#   2804,
#   8419,
#   1613,
#   4874,
#   5262,
#   3727,
#   6233,
#   4337,
#   7614,
#   6988,
#   368,
#   3664,
#   1696,
#   8824,
#   8823],
#  [2079, 580, 1130, 5803, 4069, 1751, 2079, 5991, 6546, 8410, 2041, 8823],
#  [1811, 1435, 6773, 6376, 5556, 8410, 7717, 4485, 8823],
#  [6840, 1113, 8823],
#  [3963, 8823],
#  [1033, 2079, 8823],
#  [457, 8410, 435, 5910, 4708, 8823],
#  [1061, 900, 4474, 7548, 8823],
#  [2991, 4874, 4491, 8823],
#  [8824,
#   8824,
#   6511,
#   6233,
#   4166,
#   5509,
#   4069,
#   3470,
#   7986,
#   8824,
#   4316,
#   863,
#   5374,
#   758,
#   4874,
#   5789,
#   4069,
#   134,
#   8790,
#   7148,
#   7717,
#   8824,
#   8246,
#   7717,
#   8824,
#   8823],
#  [2792, 8238, 4069, 284, 8410, 8823],
#  [6132, 1195, 1113, 8823],
#  [8237, 8823],
#  [6887, 8823],
#  [4069, 8806, 8238, 8410, 8823],
#  [2079, 5370, 4069, 6112, 2079, 5370, 7892, 8823],
#  [1751, 8823],
#  [7288, 6887, 4029, 8823],
#  [551, 8823],
#  [1061, 8694, 8410, 757, 247, 4069, 4620, 551, 8823],
#   8824,
#   8824,
#   8824,
#   1547,
#   6233,
#   5752,
#   3847,
#   8823],
#  [1504, 3839, 8823],
#  [5991, 7148, 8131, 5549, 8823],
#  [3048, 8476, 435, 8808, 8823],
#  [1435, 7708, 8419, 435, 3470, 8246, 4493, 6874, 7109, 8823],
#  [4069, 7860, 2436, 8823],
#  [279, 1910, 5730, 279, 1910, 8823],
#  [2140, 8824, 4219, 6985, 1647, 5140, 1540, 7614, 4374, 8410, 8823],
#  [1647, 7980, 8823],
#  [435, 863, 7717, 2854, 6039, 7412, 8823],
#  [1061, 8238, 4069, 6985, 8823],
#  [4341, 7717, 8824, 8823],
#  [7717, 7926, 8824, 8823],
#  [4451, 6112, 7219, 5991, 1505, 6093, 8300, 8824, 8823],
#  [6233, 8824, 8823],
#  [5991, 2602, 8823],
#  [2079,
#   8209,
#   4449,
#   435,
#   6233,
#   8824,
#   4341,
#   8419,
#   2514,
#   863,
#   844,
#   7148,
#   2991,
#   2027,
#   6293,
#   4069,
#   134,
#   7959,
#   6205,
#   6902,
#   8419,
#   8823],
#  [1776,
#   551,
#   2709,
#   4585,
#   435,
#   5506,
#   1130,
#   3552,
#   6233,
#   5266,
#   6699,
#   4874,
#   903,
#   5973,
#   2284,
#   2733,
#   8824,
#   0,
#   435,
#   6185,
#   1130,
#   2673,
#   2804,
#   4731,
#   4215,
#   2079,
#   6985,
#   5910,
#   162,
#   4585,
#   435,
#   8021,
#   5321,
#   1130,
#   5750,
#   6233,
#   1358,
#   6112,
#   863,
#   435,
#   420,
#   8353,
#   863,
#   1892,
#   2583,
#   6104,
#   6039,
#   2804,
#   8823],
#  [6947, 162, 435, 4780, 8824, 897, 8824, 8708, 8823],
#  [1061,
#   2145,
#   8824,
#   3325,
#   2079,
#   1130,
#   8824,
#   4236,
#   4069,
#   6233,
#   4140,
#   7323,
#   2079,
#   6872,
#   4069,
#   6233,
#   4140,
#   4069,
#   2596,
#   8823],
#  [2079, 8210, 1130, 6093, 3839, 1130, 3542, 8823],
#  [2709, 8823],
#  [2792, 8823],
#  [2079, 2984, 2977, 2079, 2984, 2977, 1260, 1910, 8823],
#  [3783, 2293, 4341, 6233, 1666, 4874, 6233, 8824, 4874, 8824, 8823],
#  [1435,
#   6132,
#   8410,
#   4069,
#   8806,
#   5750,
#   6511,
#   561,
#   224,
#   8102,
#   8824,
#   8102,
#   8824,
#   8823],
#  [8783,
#   1751,
#   8824,
#   1751,
#   2079,
#   8824,
#   4217,
#   1751,
#   2079,
#   4217,
#   1975,
#   4069,
#   2079,
#   4217,
#   8750,
#   8823],
#  [8824, 8824, 8823],
#  [6840, 8823],
#  [117, 5910, 1619, 8823],
#  [3164, 5991, 8238, 8419, 4719, 8823],
#  [2709, 8823],
#  [2079, 4217, 8750, 2079, 4217, 8750, 8823],
#  [8476, 1061, 8065, 4069, 7148, 3544, 8735, 8824, 8823],
#  [420,
#   6511,
#   279,
#   4585,
#   8389,
#   4374,
#   2079,
#   3325,
#   5487,
#   1130,
#   2552,
#   4874,
#   8410,
#   8526,
#   7717,
#   7023,
#   7912,
#   5268,
#   3604,
#   1892,
#   463,
#   1130,
#   8430,
#   8824,
#   7272,
#   8823],
#  [8824, 8823],
#  [8824, 2311, 1910, 8823],
#  [8824, 7772, 8824, 8823],
#  [2079,
#   5809,
#   4069,
#   2079,
#   3742,
#   4866,
#   7717,
#   1188,
#   4341,
#   8824,
#   6215,
#   2275,
#   7872,
#   1313,
#   8131,
#   8824,
#   4866,
#   1130,
#   5299,
#   2201,
#   1435,
#   6902,
#   7717,
#   6490,
#   2112,
#   6511,
#   7717,
#   4411,
#   8823],
#  [4874, 4137, 8476, 2839, 8238, 4069, 6546, 7614, 1603, 1910, 8823],
#  [2678, 8410, 4871, 8823],
#  [8476, 6233, 8824, 8476, 134, 4069, 6546, 8823],
#  [8065, 2079, 5750, 8410, 8823],
#  [2792, 3727, 8823],
#  [6773,
#   435,
#   2879,
#   2945,
#   5910,
#   1113,
#   6233,
#   3666,
#   5254,
#   2879,
#   8824,
#   8622,
#   1130,
#   7394,
#   1826,
#   8824,
#   7333,
#   435,
#   4449,
#   8823],
#  [8824, 8824, 8824, 8823],
#  [7717, 7553, 2733, 1048, 1751, 8410, 8824, 2284, 1647, 6228, 8823],
#  [2079, 5918, 6034, 8419, 5140, 6902, 8419, 3459, 8158, 8823],
#  [2079, 3325, 8021, 3666, 1130, 7148, 3544, 5487, 8823],
#  [6233, 5254, 4585, 435, 1910, 8823],
#  [7717, 5782, 2614, 5918, 8587, 4065, 8353, 4532, 8823],
#  [1199, 1925, 1357, 8823],
#  [3544, 2682, 7717, 6230, 2934, 8823],
#  [2440,
#   4037,
#   4997,
#   1990,
#   5393,
#   2513,
#   8392,
#   8824,
#   8824,
#   8824,
#   6112,
#   6135,
#   4037,
#   6135,
#   1990,
#   1576,
#   8824,
#   8824,
#   8824,
#   8771,
#   8824,
#   8238,
#   4069,
#   8129,
#   8419,
#   8823],
#  [6135,
#   4037,
#   4997,
#   1990,
#   8099,
#   8824,
#   8824,
#   8824,
#   8824,
#   8824,
#   8824,
#   8824,
#   8823],
#  [1162,
#   2929,
#   7412,
#   4374,
#   8410,
#   1489,
#   4874,
#   8410,
#   6233,
#   2260,
#   1567,
#   4236,
#   6233,
#   2237,
#   3016,
#   8823],
#  [1162, 2792, 6623, 6495, 8410, 8129, 1130, 7148, 4341, 7789, 8823],
#  [7614,
#   580,
#   5910,
#   5140,
#   8410,
#   8824,
#   2433,
#   6233,
#   4166,
#   8037,
#   8824,
#   2446,
#   435,
#   8824,
#   8824,
#   6112,
#   8824,
#   8824,
#   6112,
#   8824,
#   4236,
#   1910,
#   1130,
#   8824,
#   8824,
#   8824,
#   8824,
#   8824,
#   5942,
#   2839,
#   435,
#   8824,
#   8823],
#  [7340,
#   2433,
#   8353,
#   3662,
#   8824,
#   6112,
#   7614,
#   5291,
#   8824,
#   8824,
#   8824,
#   8824,
#   2293,
#   7582,
#   3438,
#   6112,
#   4069,
#   8210,
#   2433,
#   1130,
#   2637,
#   5910,
#   2636,
#   8823],
#   4767,
#   4491,
#   1130,
#   1910,
#   2943,
#   5107,
#   8823],
#  [7333, 2293, 4069, 1536, 6233, 7573, 6161, 8823],
#  [3164,
#   8419,
#   3034,
#   975,
#   7986,
#   6233,
#   3446,
#   5216,
#   4236,
#   8183,
#   2079,
#   7860,
#   75,
#   8823],
#  [6112, 8419, 435, 8410, 8823],
#  [2079, 5991, 8129, 1130, 2596, 7717, 2605, 4341, 6947, 3676, 2426, 8823],
#  [5158, 8824, 4069, 6975, 63, 6093, 1468, 6093, 1468, 8823],
#  [8824, 8823],
#  [1776,
#   1740,
#   8152,
#   1697,
#   1869,
#   2079,
#   6985,
#   4069,
#   6902,
#   7412,
#   2079,
#   8065,
#   5809,
#   1751,
#   4069,
#   6985,
#   8476,
#   7717,
#   3806,
#   4874,
#   1696,
#   6902,
#   7412,
#   3727,
#   7412,
#   7742,
#   6511,
#   4140,
#   6902,
#   6233,
#   2707,
#   5268,
#   6233,
#   6749,
#   5268,
#   6233,
#   4861,
#   5268,
#   2284,
#   7465,
#   4874,
#   6233,
#   3037,
#   8823],
#  [2792, 6495, 8410, 5918, 248, 2659, 4069, 8824, 8823],
#  [8410,
#   5918,
#   3118,
#   2659,
#   457,
#   2079,
#   3325,
#   4731,
#   2707,
#   6112,
#   877,
#   6112,
#   4861,
#   6768,
#   8419,
#   435,
#   6424,
#   3544,
#   2079,
#   4204,
#   4866,
#   1036,
#   1696,
#   1892,
#   2293,
#   561,
#   1647,
#   4968,
#   1751,
#   6055,
#   4140,
#   8824,
#   8246,
#   2079,
#   3325,
#   6166,
#   4069,
#   8065,
#   6018,
#   8419,
#   2682,
#   6166,
#   4069,
#   8806,
#   2606,
#   7412,
#   2079,
#   8129,
#   1130,
#   6093,
#   6418,
#   2222,
#   8824,
#   8824,
#   7069,
#   7333,
#   2284,
#   7038,
#   3120,
#   2992,
#   6798,
#   8618,
#   7412,
#   1061,
#   5189,
#   903,
#   4215,
#   435,
#   8823],
#  [2682, 1925, 2596, 6233, 1086, 3839, 6112, 7986, 1195, 1130, 117, 8823],
#  [8476, 6039, 8823],
#  [2079, 5991, 8210, 1130, 7148, 8682, 8823],
#  [2079, 6290, 6985, 8419, 8823],
#  [2079, 6902, 8410, 8823],
#  [2079, 4359, 4166, 7034, 7091, 1276, 6228, 8823],
#  ...]

# %% [markdown]
# -------------------------------------------------------------------------------
# # PART 2 - BUILDING THE SEQ2SEQ MODEL
# -------------------------------------------------------------------------------

# %% [markdown]
# # Creating placeholders for the inputs and the targets
#
# In TensorFlow, all avariables are used in tensors. Tensors are like an advanced numpy array that allows very fast computations in Deep Neural Networks.
#
# All variables used as tensors must be defined as what we call TensorFlow placeholders.
#
# This is more of an advanced data structure that can contain tensors and also additional features.
#
# -------------------------------------------------------------------------------

# %% [markdown]
# We will be defining a function that will call model inputs, and inside this function we will create a placeholder for the inputs and a placeholder for the targets.
# Then we will add a learning rate and even more hybrid parameters.
#
# In short, we will be creating placeholders to be able to use these variables in future training.
#
# -------------------------------------------------------------------------------

# %% [markdown]
# 1. we will start by creating a new variable called inputs which will be the TensorFlow place holder containing the input
#
# we will need to call the tensorflow placeholder function
#
# we will take 3 paramters for this function
#
# the first parameter is going to be type of the data(integers in this case)
#
# the second argument is going to be dimensions of the matrix from the input data. And since the inputs are the lists of questions encoded into unique integer (lists of integers) and therefore with padding we will get a 2 dimesnional matrix. (represented as [None,None]
#
# the last argument is just the name we are going to give to the input.
#
# ------------------------------------------------------------------------------
#
# We are going to do the same set of steps for targets as well
#
# -------------------------------------------------------------------------------
# Now we are going to create 2 more tensorflow placeholders, one which will hold the learning rate(hyper parameter) and the other(keep_prob parameter) which will hold the parameter to control the drop-out rate(regularization).

# %%
def model_inputs():
    inputs = tf.placeholder(tf.int32, [None,None], name = 'input')
    targets = tf.placeholder(tf.int32, [None,None], name = 'target')
    lr = tf.placeholder(tf.float32, name = 'learning_rate')
    keep_prob = tf.placeholder(tf.float32,name = 'keep_prob')
    return inputs,targets,lr,keep_prob

# %% [markdown]
# # Preprocessing the targets

# %% [markdown]
# Before we start creating the encoding layer and the decoding layers, we have to prepare a set of targets. This is because the decoder will only accept a certain format of the targets.
#
# Q) What exactly is this format ?
#
# ans:  The format is two-fold.
#
#    First, the target needs to be in two batches. The RNN of the decoder will not accept single targets i.e, single answers.
#
#    Second important element is that each of the answers in the batch must start with the SOS token.
#
# -------------------------------------------------------------------------------
# So the two things we will do in the below function is to create batches and add the SOS token.
#
# How to add this SOS token?
# Since we need to keep the same size for all the answers using padding, what we will do is take all the answers inside batches and remove the last column of these answers.
#
# We will remove the last column and take the rest of the columns a dthen make a concatenation to add a SOS tokens at the beginning of the target in batches.
#
# -------------------------------------------------------------------------------
#
# 1.create the left side of the concatenation which is a matrix of batch size lines and one column filled with the SOS tokens.
#
# 2.then make the right side of the concatentation which will be target answers in the batch except the last token identifier of these answers, for all the answers in the batch.

# %%
def preprocess_targets(targets, word2int, batch_size):
    left_side = tf.fill([batch_size, 1], word2int['<SOS>'])
    right_side = tf.strided_slice(targets, [0,0], [batch_size,-1], [1,1])
    preprocessed_targets = tf.concat([left_side, right_side], 1)
    return preprocessed_targets

# %% [markdown]
# -------------------------------------------------------------------------------
#
# # Creating the Encoder RNN Layer

# %% [markdown]
# The arguments of this function include:
#
# 1. rnn_inputs that corresponds to the model inputs
#
# 2. rnn_size is the number of input tensors of the encoder
#
# 3. num_layers, the number of layers in the RNN
#
# 4. keep_prob, for dropout regularization(to improve accuracy)
#
# 5. sequence_length, which is the list of th elength of each question in the batch.
# -------------------------------------------------------------------------------
#
# 1. In tensorflow we have an amazing class that will help us create an LSTM
#
# assign variable lstm  to tf.contrib(module).rnn(submodule).BasicLSTMCell(rnn_size)
#
# 2. assign variable lstm_dropout to  tf.contrib(module).rnn(submodule).DropoutWrapper(class)(lstm, keep_prob)
#
# 3. we are now ready to create the encoder cell
#
# assign variable encoder_cell to tf.contrib(module).rnn(submodule).MultiRNNCell(the number of lstm dropout mulitplied to number of layers we have as an argument to the function)
#
# 4. now to get the encoder_state, we will get ot from the bidirectional_dynamic_rnn function from the nn module by tensorflow
#
# the above step created a dynamic version of a bidirectional RNN(this will help us in making our chatbot more powerful)
#
# the dynamic version of bidirectional rnn will take the input and build independent forward and abckward RNN's.
#
# NOTE: We need to make sure in case of dynamic bidirectional RNNs that inpput size of forward cell and backward cell must match.

# %%
def encoder_rnn(rnn_inputs, rnn_size, num_layers, keep_prob, sequence_length):
    lstm = tf.contrib.rnn.BasicLSTMCell(rnn_size)
    lstm_dropout = tf.contrib.rnn.DropoutWrapper(lstm, input_keep_prob = keep_prob)
    encoder_cell = tf.contrib.rnn.MultiRNNCell([lstm_dropout] * num_layers)
    _, encoder_state = tf.nn.bidirectional_dynamic_rnn(cell_fw = encoder_cell, 
                                                       cell_bw = encoder_cell, 
                                                       sequence_length = sequence_length, 
                                                       inputs = rnn_inputs,
                                                       dtype = tf.float32)
    return encoder_state

# %% [markdown]
# -------------------------------------------------------------------------------
#
# # Creating the Decoder of the RNN layer

# %% [markdown]
# We will be doing this in three steps:
#
# 1. Decode the training set
#
# 2. Decode the validation set
#
# 3. And eventually, we will be ready to take care of the decoder of the RNN layer

# %% [markdown]
# # Step 1. Decoding the training set
#
# The arguments of this function include:
#
# 1. encoder_state
#
# 2. decoder_cell
#
# 3. decoder_embedded_input
#
# 4. sequence_length
#
# 5. decoding_scope
#
# 6. output_function
#
# 7. keep_prob
#
# 8. batch_size
# -------------------------------------------------------------------------------
#
# 1. The first thing we need to do is get the attention states
#
# initialize attention_states as a 3 dimesnional matrix initialized with zeros
#
# Since we are dealing with batches, the number of lines is going to be batch_size
#
# The number of elements on the third axis is going to be decoder_cell.output_size
#
# 2. We will get the attention_keys, the attention_values, the atention_score_function and attention_construct_function using the TensorFlow function belonging to the seq2seq submodule which is prepare_attention()
#
# the attention_keys is the keys that are to be compared with the target_states
#
# the attention_values, the values that we will use to construct the context vectors
#
# the attention_score_function is used to compute the similarity in between keys and the target
#
# the attention_construct_function is function used to build the attention state
#
# 3. The next step is to get the training_decoder_function that will do the decoding of the training set.
#
# training_decoder_function is obtained from another tensorflow function present in the seq2seq submodule called attention_decoder_fn_train()
#
#
# 4. the next step is to get the decoder_output, decoder_final_state and the decoder_final_context_state(but we need only the decoder_output)
#
# this is obtained from the function present in the dynamic_rnn_encoder submodule present in the TensorFlow library
#
# 5. the final step is to apply dropout to our decoder_output
# decoder_output_dropout = tf.nn(module).dropout()
#
# 6. return the output_function(decoder_output_dropout)

# %%
def decode_training_set(encoder_state, decoder_cell, decoder_embedded_input, sequence_length, decoding_scope, output_function, keep_prob, batch_size):
    attention_states = tf.zeros([batch_size, 1, decoder_cell.output_size])
    attention_keys, attention_values, attention_score_function, attention_construct_function = tf.contrib.seq2seq.prepare_attention(attention_states, attention_option = "bahdanau", num_units = decoder_cell.output_size)
    training_decoder_function = tf.contrib.seq2seq.attention_decoder_fn_train(encoder_state[0],
                                                                              attention_keys,
                                                                              attention_values,
                                                                              attention_score_function,
                                                                              attention_construct_function,
                                                                              name = "attn_dec_train")
    decoder_output, decoder_final_state, decoder_final_context_state = tf.contrib.seq2seq.dynamic_rnn_decoder(decoder_cell,
                                                                                                              training_decoder_function,
                                                                                                              decoder_embedded_input,
                                                                                                              sequence_length,
                                                                                                              scope = decoding_scope)
    decoder_output_dropout = tf.nn.dropout(decoder_output, keep_prob)
    return output_function(decoder_output_dropout)

# %% [markdown]
# # Step 2. Decoding the test/validation set
#
#
# Here are we are going to make a very similar function as above, but for the observatoins of the test set and the validation set.
#
# These are new observations that will not be used in the training.
#
# In this function, we will not be using the attention_decoder_fn_train function by tensorflow, instead we will be using attention_decoder_fn_inference()
#
# This function will take 4 new arguments in addition the function above, these include:
#
# 1.sos_id
#
# 2.eos_id
#
# 3.maximum_length
#
# 4.num_words

# %%
def decode_test_set(encoder_state, decoder_cell, decoder_embeddings_matrix, sos_id, eos_id, maximum_length, num_words, decoding_scope, output_function, keep_prob, batch_size):
    attention_states = tf.zeros([batch_size, 1, decoder_cell.output_size])
    attention_keys, attention_values, attention_score_function, attention_construct_function = tf.contrib.seq2seq.prepare_attention(attention_states, attention_option = "bahdanau", num_units = decoder_cell.output_size)
    test_decoder_function = tf.contrib.seq2seq.attention_decoder_fn_inference(output_function,
                                                                              encoder_state[0],
                                                                              attention_keys,
                                                                              attention_values,
                                                                              attention_score_function,
                                                                              attention_construct_function,
                                                                              decoder_embeddings_matrix,
                                                                              sos_id,
                                                                              eos_id,
                                                                              maximum_length,
                                                                              num_words,
                                                                              name = "attn_dec_inf")
    test_predictions, decoder_final_state, decoder_final_context_state = tf.contrib.seq2seq.dynamic_rnn_decoder(decoder_cell,
                                                                                                                test_decoder_function,
                                                                                                                scope = decoding_scope)
    return test_predictions

# %% [markdown]
# # Step 3. Creating the Decoder RNN
#
# This function will have the following arguments:
#
# 1.decoder_rnn
#
# 2.decoder_embeddings_matrix
#
# 3.encoder_state  // output of the encoder becomes input of the decoder
#
# 4.num_words //total number of words in our corpus of words
#
# 5.sequence_length
#
# 6.rnn_size // number of layers we want in our RNN decoder
#
# 7.num_layers
#
# 8.word2int //the dictionary which we have defined earlier
#
# 9.keep_prob // for the dropout(regularization) rate
#
# 10.batch_size
#
# -----------------------------------------------------------------------------
#
# 1.introduce the decoding scope from tensorflow
#     with tf.variable_scope("decoding") as decoding_scope
#
# 2.assign the variable lstm to the tensorflow function BasicLSTMCell in submodule nn and pass the rnn_size as parameter
#
# 3.apply dropout regularization to reduce overfitting and improve accuracy
#
# assign variable lstm_dropout to the tensorflow function called DropoutWrapper present in the rnn submodule. Pass the parameters lstm and input_keep_prob to the function
#
# 4.to the variable decoder_cell apply the tensorflow function MultiRNNCell present in the rnn submodule. To this function pass the product of lstm_dropout and num_layers as a parameter.
#
# 5.we need to initialize some weights that will be associated to the neurons of the fully connected layers of the neural network inside our decoder.
#
# assign the variable weight to the the tensorflow function call truncated_normal_initializer that will generate a truncated normal distribution of the weights.
#
# To this function call pass argument stddev(standard deviation as 0.1)
#
# 6.to a new variable called biases initialize zeros, for that use the tensorflow function called zeros_initializer()
#
# 7.the next step is to make the output function
#
# assign the variable output_function to the tensorflow function fully_connected present in the layers module
#
# the arguments to this function will be (x,
#                                         num_words,
#                                         None(for normalization),
#                                         scope = decoding_scope,
#                                         weights_initializers = weights,
#                                         biases_initializers = biases)
#
#
# 8.the next step is to get our training predictions(with the help of function we defined above) decode_training_set()
#
# training_predictions = decode_training_set()
# #refer the function definition for the arguments and figure it yourself ;)
#
# 9.we have to take our decoding scope and specify that we want to reuse the variables introduced in this decoding scope
#
# 10.we now need to get the test_predictions. We will get this with a function we defined called decode_test_set.
# #refer the function definition for the arguments and figure it yourself ;)
#
# 11.finally return the training_predictions and the test_predictions

# %%
def decoder_rnn(decoder_embedded_input, decoder_embeddings_matrix, encoder_state, num_words, sequence_length, rnn_size, num_layers, word2int, keep_prob, batch_size):
    with tf.variable_scope("decoding") as decoding_scope:
        lstm = tf.contrib.rnn.BasicLSTMCell(rnn_size)
        lstm_dropout = tf.contrib.rnn.DropoutWrapper(lstm, input_keep_prob = keep_prob)
        decoder_cell = tf.contrib.rnn.MultiRNNCell([lstm_dropout] * num_layers)
        weights = tf.truncated_normal_initializer(stddev = 0.1)
        biases = tf.zeros_initializer()
        output_function = lambda x: tf.contrib.layers.fully_connected(x,
                                                                      num_words,
                                                                      None,
                                                                      scope = decoding_scope,
                                                                      weights_initializer = weights,
                                                                      biases_initializer = biases)
        training_predictions = decode_training_set(encoder_state,
                                                   decoder_cell,
                                                   decoder_embedded_input,
                                                   sequence_length,
                                                   decoding_scope,
                                                   output_function,
                                                   keep_prob,
                                                   batch_size)
        decoding_scope.reuse_variables()
        test_predictions = decode_test_set(encoder_state,
                                           decoder_cell,
                                           decoder_embeddings_matrix,
                                           word2int['<SOS>'],
                                           word2int['<EOS>'],
                                           sequence_length - 1,
                                           num_words,
                                           decoding_scope,
                                           output_function,
                                           keep_prob,
                                           batch_size)
    return training_predictions, test_predictions

# %% [markdown]
# -----------------------------------------------------------------------------
#
# # Building the Seq2Seq Model
#
# This function is the final ultimate function which we will build using the above defined functions. This will be the brain of our chatbot.
#
# This function will take the following arguments:
#
# 1.inputs which are the questions of the Cornell movie corpus dialogue dataset
#
# 2.targets. which will be the answers to our questions
#
# 3.keep_prob
#
# 4.batch_size
#
# 5.sequence_length
#
# 6.answers_num_words
#
# 7.questions_num_words
#
# 8.encoder_embedding_size, which is the number of dimensions of the embedding matrix for the encoder
#
# 9.decoder_embedding_size, which is the number of dimesnions of the embeddig matrix for the decoder
#
# 10.rnn_size
#
# 11.num_layers
#
# 12.questionswords2int, dictionary which we defined previously to preprocess the targets
#
# -----------------------------------------------------------------------------
#
# 1.Before we get the encoder_state we need the encoder_embedded_input, that's why the first thing we have to do is introduce encoder_embedded_input and assign it to the twnsorflow function of embed_sequence present in the layers submodule.
# encoder_embedded_input = tf.contrib(module).embed_sequence(submodule)(inputs,#inputs is the argument we want to embed
#                                                                       answers_num + 1, # total number of answer words
#                                                                       encoder_embedding_size, #number of dimesnions in the                                                                              #embedding matrix of the encoder
#                                                                       initializer = random uniform initializer(tf function))
#
# 2.encoder_state is the output of the encoder and will be the input of the decoder. We will get this from the RNN of our encoder. We will feed the RNN with the encoder_embedded input and will return the encoder_state.
#
# encoder_state = encoder_rnn(), function which we have defined previously
# #kindly refer the function definition to figure out the arguments
#
# 3.we now need to get the preprocessed_targets, because we will need them for training
#
# preprocessed_targets = preprocessed_targets(), function which we have defined previously
# #kindly refer the function definition to figure out the arguments
#
# 4.decoder_embeddings_matrix which we will get by creating a tensorflow variable using the Variable class.
# The variable class takes several arguments which are going ti=o be mostly the dimensions of the emddings_matrix.
# decoder_embeddings_matrix = tf.Variable(tf.random_uniform([questions_num_words + 1, decoder_embedding_size]#raindom numbers taken between 0 and 1 for uniform distributions
#                        0,
#                        1))
#
# 5.the next step naturally is to get the decoder_embedded_input
#
# we will use the tensorflow function called embedding_lookup present in the nn module which will take the decoder_embeddings_matrix as argument as well as preprocessed_targets
#
# 6.now we need to assign the training_predictions and test_predictions to the function decoder_rnn(), function which we defined earlier
# #kindly refer to the function definition to develop an intution of the argument
#
# 7.finally return the two variables training_predictions and the test_predictions

# %%
def seq2seq_model(inputs, targets, keep_prob, batch_size, sequence_length, answers_num_words, questions_num_words, encoder_embedding_size, decoder_embedding_size, rnn_size, num_layers, questionswords2int):
    encoder_embedded_input = tf.contrib.layers.embed_sequence(inputs,
                                                              answers_num_words + 1,
                                                              encoder_embedding_size,
                                                              initializer = tf.random_uniform_initializer(0, 1))
    encoder_state = encoder_rnn(encoder_embedded_input, rnn_size, num_layers, keep_prob, sequence_length)
    preprocessed_targets = preprocess_targets(targets, questionswords2int, batch_size)
    decoder_embeddings_matrix = tf.Variable(tf.random_uniform([questions_num_words + 1, decoder_embedding_size], 0, 1))
    decoder_embedded_input = tf.nn.embedding_lookup(decoder_embeddings_matrix, preprocessed_targets)
    training_predictions, test_predictions = decoder_rnn(decoder_embedded_input,
                                                         decoder_embeddings_matrix,
                                                         encoder_state,
                                                         questions_num_words,
                                                         sequence_length,
                                                         rnn_size,
                                                         num_layers,
                                                         questionswords2int,
                                                         keep_prob,
                                                         batch_size)
    return training_predictions, test_predictions

# %% [markdown]
# -------------------------------------------------------------------------------
#
# # PART 3 -  TRAINING THE SEQ2SEQ MODEL
#
# -------------------------------------------------------------------------------

# %% [markdown]
# # Setting the hyperparameters

# %% [markdown]
# The whole process of getting the batches of input into the neural network and then forward propagating them inside the encoders in the encoder states and then forward propagating the encoder states with targets inside the deep recurrent neural network to get the final answers/outputs.Then back-propagating the loss generated by the outputs and the targets back into the neural network and updating the weights towards the direction of a better ability for the chatbot to speak like a human.
#
# 1.An epoch is basically one whole iteration of the above mentioned steps(take 100, if training is taking too long, adjust it to 50, but not lower).
#
# 2.batch_size, we are setting it to be 64(usually a power of 2)
#
# 3.rnn_size, we are setting it to be 512
#
# 4.num_layers, we are setting it to be 3, can change later if necessary
#
# 5.encoding_embedding_size,(number of columns in the embedded matrix), taken as 512
#
# 6.similarly, decoding_embedding_size is taken to be as 512
#
# 7.learning_rate, we will start with 0.01
#
# 8.learning_rate_decay, which represents the percentage by wich learning_rate is reduced over the iterations of the training
#
# 9.min_learning_rate, as a lower bound to take care of early stopping if the learning_rate decreases drastically
#
# 10.keep_probability, dropout regularization hyperparameter to prevent overfitting
# According to Geoffery Hinton, the master of Deep Learning and Artificial Intelligence, in his paper states: dropping out 20% of the input units and 50% of the hidden units was often found to be optimal.

# %%
epochs = 100

batch_size = 64

rnn_size = 512

num_layers = 3

encoding_embedding_size = 512

decoding_embedding_size = 512

learning_rate = 0.01

learning_rate_decay = 0.9

min_learning_rate = 0.0001

keep_probability = 0.5

# %% [markdown]
# -------------------------------------------------------------------------------
#
# # Defining a session

# %% [markdown]
# We will define a TensorFlow session in which all the tensorflow training will be run.
#
# To open a session in TensorFlow, we are going to create an object of the interactive session class.
#
# Before startinig a session, it is necessary to reset the graph, and hence
#
# 1. reset graph using tensorflow library:
#     tf.compat.v1.reset_default_graph()
#
# 2. define a session:
#     session = tf.compat.v1.InteractiveSession()

# %%
tf.reset_default_graph()
session = tf.InteractiveSession()

# %% [markdown]
# -------------------------------------------------------------------------------
#
# # Loading the Model Inputs
#
# We will be using a function which we defined previously in Part 2

# %%
inputs, targets, lr, keep_prob = model_inputs()

# %% [markdown]
# -------------------------------------------------------------------------------
#
# # Setting the sequence length
#
# We are going to set the sequence length to maximum length which will be 25(which we have already done in end of part 1 - data preprocessing).
#
#
# We are going to use tensorflow palceholder with default function.
#
# 1.The arguments will be: maximum_length(25)
#
# 2.Sequence shape, since there is no tensor to deal with, input None
#
# 3.name of the sequence_length

# %%
sequence_length = tf.placeholder_with_default(25, None, name = 'sequence_length')

# %% [markdown]
# -------------------------------------------------------------------------------
#
# # Getting the shape of the input tensor
#
# We need to get the shape of the input because this will be one of the arguments of one specific function we will use for training.
#
# The specific function is actually the ones function by tensorflow(created a tensor of ones)
#
# For this we will use shape function of tenorflow

# %%
input_shape = tf.shape(inputs)

# %% [markdown]
# -------------------------------------------------------------------------------
#
# # Getting the training and test predictions
#
# We will use the function seq2seq_model we defined above

# %%
training_predictions, test_predictions = seq2seq_model(tf.reverse(inputs, [-1]),
                                                       targets,
                                                       keep_prob,
                                                       batch_size,
                                                       sequence_length,
                                                       len(answerswords2int),
                                                       len(questionswords2int),
                                                       encoding_embedding_size,
                                                       decoding_embedding_size,
                                                       rnn_size,
                                                       num_layers,
                                                       questionswords2int)

# %% [markdown]
# --------------------------------------------------------------------------------
# # Setting up the loss error, the Optimizer and Gradient Clipping

# %% [markdown]
# We are going to define a new scope here which will contain two final elements that we will use for the training:
#
# 1.The loss error - weighted cross entropy loss error
#
# 2.Optimizer with gradient clipping -Adam Optimizer and then apply gradient clipping to avoid exploding and vanishing gradient issues
#
# We will obtain our loss_error from the sequence loss function present in the seq2seq submodule present in the contrib module.
# It takes the arguments the training_predictions and the targets.
# This is necessary as we will be calculating our loss_error based on the difference between the two.
# The third argument is the tensor of weights initialized to ones to appropriate shape.
#
# We will get the optimizer which will be an object of the AdamOptimizer class which is a class in tensorflow and taken from the module train.
#
# We will compute the gradients by a function provided by the optimizer object called compute_gradients
#
# Clipped gradients mean the gradients are clipped to a particular value, below and above which our gradient values cannot go(to avoid vanishing and exploding gradient problems)

# %%
with tf.name_scope("optimization"):
    loss_error = tf.contrib.seq2seq.sequence_loss(training_predictions,
                                                  targets,
                                                  tf.ones([input_shape[0], sequence_length]))
    optimizer = tf.train.AdamOptimizer(learning_rate)
    gradients = optimizer.compute_gradients(loss_error)
    clipped_gradients = [(tf.clip_by_value(grad_tensor, -5., 5.), grad_variable) for grad_tensor, grad_variable in gradients if grad_tensor is not None]
    optimizer_gradient_clipping = optimizer.apply_gradients(clipped_gradients)

# %% [markdown]
# # Padding the sequences with the < PAD> token
#
# Why do we need to do padding ?
#
# All the sentences in a batch, whether they are questions or answers must have the same length. This a must do in Deep NLP.
#
# Creating a function called apply_padding.
#
# It will take 2 arguments:
#
# 1.batch_of_sequences and 2.word2int dictionary
#
# The task of the function is to complete the sentences using PAD tokens so that all the sentences in the batch have the same length.

# %%
def apply_padding(batch_of_sequences, word2int):
    max_sequence_length = max([len(sequence) for sequence in batch_of_sequences])
    return [sequence + [word2int['<PAD>']] * (max_sequence_length - len(sequence)) for sequence in batch_of_sequences]

# %% [markdown]
# --------------------------------------------------------------------------------
# # Splitting the data into batches of questions and answers

# %% [markdown]
# We can naturally guess the arguments of this function:
#
# 1.questions
#
# 2.answers
#
# 3.batch size

# %%
def split_into_batches(questions, answers, batch_size):
    for batch_index in range(0, len(questions) // batch_size):
        start_index = batch_index * batch_size
        questions_in_batch = questions[start_index : start_index + batch_size]
        answers_in_batch = answers[start_index : start_index + batch_size]
        padded_questions_in_batch = np.array(apply_padding(questions_in_batch, questionswords2int))
        padded_answers_in_batch = np.array(apply_padding(answers_in_batch, answerswords2int))
        yield padded_questions_in_batch, padded_answers_in_batch

# %% [markdown]
# --------------------------------------------------------------------------------
# # Splitting the questions and answers into training and validation sets
#
# The valiation set is keeping 10%-15% of the training data as validation set and will not be used for training the neural network. It will be used to check the predictive power of the model.

# %%
training_validation_split = int(len(sorted_clean_questions) * 0.15)
training_questions = sorted_clean_questions[training_validation_split:]
training_answers = sorted_clean_answers[training_validation_split:]
validation_questions = sorted_clean_questions[:training_validation_split]
validation_answers = sorted_clean_answers[:training_validation_split]

# %% [markdown]
# --------------------------------------------------------------------------------
# # Training

# %%
batch_index_check_training_loss = 100
batch_index_check_validation_loss = ((len(training_questions)) // batch_size // 2) - 1
total_training_loss_error = 0
list_validation_loss_error = []
early_stopping_check = 0
early_stopping_stop = 1000
checkpoint = "chatbot_weights.ckpt" # For Windows users, replace this line of code by: checkpoint = "./chatbot_weights.ckpt"
session.run(tf.global_variables_initializer())
for epoch in range(1, epochs + 1):
    for batch_index, (padded_questions_in_batch, padded_answers_in_batch) in enumerate(split_into_batches(training_questions, training_answers, batch_size)):
        starting_time = time.time()
        _, batch_training_loss_error = session.run([optimizer_gradient_clipping, loss_error], {inputs: padded_questions_in_batch,
                                                                                               targets: padded_answers_in_batch,
                                                                                               lr: learning_rate,
                                                                                               sequence_length: padded_answers_in_batch.shape[1],
                                                                                               keep_prob: keep_probability})
        total_training_loss_error += batch_training_loss_error
        ending_time = time.time()
        batch_time = ending_time - starting_time
        if batch_index % batch_index_check_training_loss == 0:
            print('Epoch: {:>3}/{}, Batch: {:>4}/{}, Training Loss Error: {:>6.3f}, Training Time on 100 Batches: {:d} seconds'.format(epoch,
                                                                                                                                       epochs,
                                                                                                                                       batch_index,
                                                                                                                                       len(training_questions) // batch_size,
                                                                                                                                       total_training_loss_error / batch_index_check_training_loss,
                                                                                                                                       int(batch_time * batch_index_check_training_loss)))
            total_training_loss_error = 0
        if batch_index % batch_index_check_validation_loss == 0 and batch_index > 0:
            total_validation_loss_error = 0
            starting_time = time.time()
            for batch_index_validation, (padded_questions_in_batch, padded_answers_in_batch) in enumerate(split_into_batches(validation_questions, validation_answers, batch_size)):
                batch_validation_loss_error = session.run(loss_error, {inputs: padded_questions_in_batch,
                                                                       targets: padded_answers_in_batch,
                                                                       lr: learning_rate,
                                                                       sequence_length: padded_answers_in_batch.shape[1],
                                                                       keep_prob: 1})
                total_validation_loss_error += batch_validation_loss_error
            ending_time = time.time()
            batch_time = ending_time - starting_time
            average_validation_loss_error = total_validation_loss_error / (len(validation_questions) / batch_size)
            print('Validation Loss Error: {:>6.3f}, Batch Validation Time: {:d} seconds'.format(average_validation_loss_error, int(batch_time)))
            learning_rate *= learning_rate_decay
            if learning_rate < min_learning_rate:
                learning_rate = min_learning_rate
            list_validation_loss_error.append(average_validation_loss_error)
            if average_validation_loss_error <= min(list_validation_loss_error):
                print('I speak better now!!')
                early_stopping_check = 0
                saver = tf.train.Saver()
                saver.save(session, checkpoint)
            else:
                print("Sorry I do not speak better, I need to practice more.")
                early_stopping_check += 1
                if early_stopping_check == early_stopping_stop:
                    break
    if early_stopping_check == early_stopping_stop:
        print("My apologies, I cannot speak better anymore. This is the best I can do.")
        break
print("Game Over")

# %% [markdown]
# --------------------------------------------------------------------------------
#
# # PART 4 - TESTING THE SEQ2SEQ MODEL
#
# --------------------------------------------------------------------------------

# %% [markdown]
# # Loading the weights and running the session

# %%
checkpoint = "./chatbot_weights.ckpt"
session = tf.InteractiveSession()
session.run(tf.global_variables_initializer())
saver = tf.train.Saver()
saver.restore(session, checkpoint)

# %% [markdown]
# --------------------------------------------------------------------------------
# # Converting the questions from strings to list of encoding integers

# %%
def convert_string2int(question, word2int):
    question = clean_text(question)
    return [word2int.get(word, word2int['<OUT>']) for word in question.split()]

# %% [markdown]
# --------------------------------------------------------------------------------
# # Setting up the chat

# %%
while(True):
    question = input("You: ")
    if question == 'Goodbye':
        break
    question = convert_string2int(question, questionswords2int)
    question = question + [questionswords2int['<PAD>']] * (25 - len(question))
    fake_batch = np.zeros((batch_size, 25))
    fake_batch[0] = question
    predicted_answer = session.run(test_predictions, {inputs: fake_batch, keep_prob: 0.5})[0]
    answer = ''
    for i in np.argmax(predicted_answer, 1):
        if answersints2word[i] == 'i':
            token = ' I'
        elif answersints2word[i] == '<EOS>':
            token = '.'
        elif answersints2word[i] == '<OUT>':
            token = 'out'
        else:
            token = ' ' + answersints2word[i]
        answer += token
        if token == '.':
            break
    print('ChatBot: ' + answer)
